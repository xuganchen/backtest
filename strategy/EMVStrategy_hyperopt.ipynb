# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from EMVStrategy import EMVStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import hyperopt.pyll.stochastic

# %%
def run_backtest(config, trading_data, ohlc_data, window, n, m):
    window = int(window)
    n = int(n)
    m = int(m)
    if window == 0 or n == 0 or m == 0:
        return 1
    config['title'] = "EMVStrategy" + "_" + str(window) + "_" + str(n) + "_" + str(m)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")
    
    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data = trading_data, ohlc_data = ohlc_data
    )
    strategy = EMVStrategy(config, events_queue, data_handler,
                           window=window, n=n, m=m)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler= data_handler)

    results = backtest.start_trading()
    
    # dict_ans = {
    #     "window": [window],
    #     "n": [n],
    #     "m": [m],
    #     "Sharpe Ratio": [results['sharpe']],
    #     "Total Returns": [(results['cum_returns'][-1] - 1)],
    #     "Max Drawdown": [(results["max_drawdown"] * 100.0)],
    #     "Max Drawdown Duration": [(results['max_drawdown_duration'])],
    #     "Trades": [results['trade_info']['trading_num']],
    #     "Trade Winning": [results['trade_info']['win_pct']],
    #     "Average Trade": [results['trade_info']['avg_trd_pct']],
    #     "Average Win": [results['trade_info']['avg_win_pct']],
    #     "Average Loss": [results['trade_info']['avg_loss_pct']],
    #     "Best Trade": [results['trade_info']['max_win_pct']],
    #     "Worst Trade": [results['trade_info']['max_loss_pct']],
    #     "Worst Trade Date": [results['trade_info']['max_loss_dt']],
    #     "Avg Days in Trade": [results['trade_info']['avg_dit']]
    # }
    # return pd.DataFrame(dict_ans)
    return -1 * (results['cum_returns'][-1] - 1)

# %%
def f(params):
    config = {
        "csv_dir": "C:/backtest/Binance",
        "out_dir": "C:/backtest/results/EMVStrategy",
        "title": "EMVStrategy",
        "is_plot": False,
        "save_plot": False,
        "save_tradelog": False,
        "start_date": pd.Timestamp("2017-07-01T00:0:00", freq = "60" + "T"),    # str(freq) + "T"
        "end_date": pd.Timestamp("2018-04-01T00:00:00", freq = "60" + "T"),
        "equity": 1.0,
        "freq": 60,      # min
        "commission_ratio": 0.001,
        "suggested_quantity": None,     # None or a value
        "max_quantity": None,           # None or a value, Maximum purchase quantity
        "min_quantity": None,           # None or a value, Minimum purchase quantity
        "min_handheld_cash": None,      # None or a value, Minimum handheld funds
        "exchange": "Binance",
        "tickers": ['BTCUSDT']
    }
    # trading_data = {}
    # for ticker in config['tickers']:
    #     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
    #     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

    ohlc_data = {}
    for ticker in config['tickers']:
        # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
        ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '_OHLC_60min.h5', key=ticker)

    trading_data = None
    
    window = params['window']
    n = params['n']
    m = params['m']
    val = run_backtest(config, trading_data, ohlc_data, window, n, m)
    return {'loss': val, 'status': STATUS_OK}

# %%
space = {
    'window': hp.randint('window', 120),
    'n': hp.randint('n', 120),
    'm': hp.randint('m', 120)
}

# %%
# print(hyperopt.pyll.stochastic.sample(space))

# %%
trials = Trials()

# %%
best = fmin(fn=f, space=space, algo=tpe.suggest, max_evals=150, trials=trials)
# Out:
# ---------------------------------
# EMVStrategy_117_31_36
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5536136322
# Max Drawdown: 48.6915353831
# Max Drawdown Duration: 2736
# Total Returns: 0.1237417244
# ---------------------------------
# Trades: 19
# Trade Winning: 47%
# Average Trade: 2.09%
# Average Win: 15.20%
# Average Loss: -9.71%
# Best Trade: 34.32%
# Worst Trade: -28.60%
# Worst Trade Date: 1 days 11:00:00
# Avg Days in Trade: 4 days 03:22:06
# ---------------------------------
# ---------------------------------
# EMVStrategy_118_20_59
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4814672677
# Max Drawdown: 48.4502739525
# Max Drawdown Duration: 2736
# Total Returns: 0.0839452492
# ---------------------------------
# Trades: 17
# Trade Winning: 53%
# Average Trade: 1.59%
# Average Win: 11.16%
# Average Loss: -9.18%
# Best Trade: 34.92%
# Worst Trade: -20.69%
# Worst Trade Date: 3 days 21:00:00
# Avg Days in Trade: 4 days 15:45:53
# ---------------------------------
# ---------------------------------
# EMVStrategy_31_98_16
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9514403915
# Max Drawdown: 51.5381063766
# Max Drawdown Duration: 2018
# Total Returns: 1.3606313505
# ---------------------------------
# Trades: 25
# Trade Winning: 52%
# Average Trade: 4.21%
# Average Win: 12.63%
# Average Loss: -4.92%
# Best Trade: 29.05%
# Worst Trade: -14.80%
# Worst Trade Date: 1 days 04:00:00
# Avg Days in Trade: 3 days 01:14:24
# ---------------------------------
# ---------------------------------
# EMVStrategy_78_61_53
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5255596007
# Max Drawdown: 65.7734906193
# Max Drawdown Duration: 2277
# Total Returns: 0.0994172356
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 1.81%
# Average Win: 11.92%
# Average Loss: -9.75%
# Best Trade: 31.33%
# Worst Trade: -25.23%
# Worst Trade Date: 3 days 06:00:00
# Avg Days in Trade: 5 days 01:28:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_111_41_26
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5714002171
# Max Drawdown: 44.1141176447
# Max Drawdown Duration: 2277
# Total Returns: 0.1309445759
# ---------------------------------
# Trades: 18
# Trade Winning: 44%
# Average Trade: 1.91%
# Average Win: 14.95%
# Average Loss: -8.52%
# Best Trade: 32.89%
# Worst Trade: -21.02%
# Worst Trade Date: 3 days 18:00:00
# Avg Days in Trade: 4 days 10:06:40
# ---------------------------------
# ---------------------------------
# EMVStrategy_8_44_18
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3991259366
# Max Drawdown: 68.4347374773
# Max Drawdown Duration: 2510
# Total Returns: 0.0093654588
# ---------------------------------
# Trades: 70
# Trade Winning: 53%
# Average Trade: 0.62%
# Average Win: 6.14%
# Average Loss: -5.57%
# Best Trade: 29.47%
# Worst Trade: -24.12%
# Worst Trade Date: 0 days 23:00:00
# Avg Days in Trade: 1 days 02:42:51
# ---------------------------------
# ---------------------------------
# EMVStrategy_80_104_75
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1727374848
# Max Drawdown: 57.0706736523
# Max Drawdown Duration: 2736
# Total Returns: -0.0762382918
# ---------------------------------
# Trades: 15
# Trade Winning: 47%
# Average Trade: 0.83%
# Average Win: 14.31%
# Average Loss: -10.97%
# Best Trade: 34.32%
# Worst Trade: -20.32%
# Worst Trade Date: 4 days 04:00:00
# Avg Days in Trade: 5 days 05:36:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_70_68_16
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3183687111
# Max Drawdown: 65.2288409514
# Max Drawdown Duration: 2277
# Total Returns: 0.7112764151
# ---------------------------------
# Trades: 16
# Trade Winning: 56%
# Average Trade: 4.59%
# Average Win: 15.01%
# Average Loss: -8.80%
# Best Trade: 29.45%
# Worst Trade: -24.55%
# Worst Trade Date: 3 days 05:00:00
# Avg Days in Trade: 4 days 18:33:45
# ---------------------------------
# ---------------------------------
# EMVStrategy_54_98_64
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3775253755
# Max Drawdown: 65.7591680494
# Max Drawdown Duration: 2736
# Total Returns: 0.0162451704
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 1.02%
# Average Win: 9.80%
# Average Loss: -9.01%
# Best Trade: 23.18%
# Worst Trade: -19.81%
# Worst Trade Date: 3 days 21:00:00
# Avg Days in Trade: 5 days 04:08:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_117_5_77
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4680240162
# Max Drawdown: 51.4664579991
# Max Drawdown Duration: 2510
# Total Returns: 0.0747626258
# ---------------------------------
# Trades: 20
# Trade Winning: 50%
# Average Trade: 1.62%
# Average Win: 12.33%
# Average Loss: -9.09%
# Best Trade: 40.07%
# Worst Trade: -21.16%
# Worst Trade Date: 3 days 15:00:00
# Avg Days in Trade: 3 days 22:18:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_102_71_96
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2519539178
# Max Drawdown: 59.7239291018
# Max Drawdown Duration: 2736
# Total Returns: -0.2362872105
# ---------------------------------
# Trades: 13
# Trade Winning: 38%
# Average Trade: -0.79%
# Average Win: 16.36%
# Average Loss: -11.51%
# Best Trade: 34.52%
# Worst Trade: -17.04%
# Worst Trade Date: 3 days 01:00:00
# Avg Days in Trade: 6 days 06:09:14
# ---------------------------------
# ---------------------------------
# EMVStrategy_64_19_116
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7358800417
# Max Drawdown: 67.1333648457
# Max Drawdown Duration: 2277
# Total Returns: 0.2306675629
# ---------------------------------
# Trades: 16
# Trade Winning: 69%
# Average Trade: 2.69%
# Average Win: 11.17%
# Average Loss: -15.99%
# Best Trade: 31.66%
# Worst Trade: -29.82%
# Worst Trade Date: 3 days 04:00:00
# Avg Days in Trade: 4 days 16:15:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_80_87_44
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6570854640
# Max Drawdown: 61.4300759975
# Max Drawdown Duration: 2736
# Total Returns: 0.1852841157
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 2.09%
# Average Win: 11.40%
# Average Loss: -8.55%
# Best Trade: 27.90%
# Worst Trade: -19.03%
# Worst Trade Date: 3 days 18:00:00
# Avg Days in Trade: 5 days 02:24:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_31_39_81
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1387234402
# Max Drawdown: 50.4225600578
# Max Drawdown Duration: 1687
# Total Returns: 0.5325981036
# ---------------------------------
# Trades: 30
# Trade Winning: 47%
# Average Trade: 2.26%
# Average Win: 11.27%
# Average Loss: -5.62%
# Best Trade: 25.36%
# Worst Trade: -30.59%
# Worst Trade Date: 3 days 14:00:00
# Avg Days in Trade: 2 days 13:34:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_92_56_50
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5852834857
# Max Drawdown: 61.0305822000
# Max Drawdown Duration: 2736
# Total Returns: 0.1397360019
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 1.94%
# Average Win: 12.03%
# Average Loss: -9.59%
# Best Trade: 31.16%
# Worst Trade: -18.67%
# Worst Trade Date: 3 days 02:00:00
# Avg Days in Trade: 5 days 02:12:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_46_117_8
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3583046174
# Max Drawdown: 55.5308545551
# Max Drawdown Duration: 2018
# Total Returns: 0.7172720576
# ---------------------------------
# Trades: 20
# Trade Winning: 60%
# Average Trade: 3.84%
# Average Win: 12.39%
# Average Loss: -8.98%
# Best Trade: 35.81%
# Worst Trade: -24.27%
# Worst Trade Date: 3 days 14:00:00
# Avg Days in Trade: 3 days 15:45:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_52_5_68
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0445702651
# Max Drawdown: 44.4787335700
# Max Drawdown Duration: 2277
# Total Returns: 0.4598797912
# ---------------------------------
# Trades: 30
# Trade Winning: 53%
# Average Trade: 1.84%
# Average Win: 8.78%
# Average Loss: -6.08%
# Best Trade: 23.31%
# Worst Trade: -13.77%
# Worst Trade Date: 4 days 05:00:00
# Avg Days in Trade: 2 days 13:14:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_96_17_117
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2634899703
# Max Drawdown: 63.2215090450
# Max Drawdown Duration: 2736
# Total Returns: -0.0452850323
# ---------------------------------
# Trades: 15
# Trade Winning: 47%
# Average Trade: 0.95%
# Average Win: 13.80%
# Average Loss: -10.30%
# Best Trade: 43.10%
# Worst Trade: -16.60%
# Worst Trade Date: 4 days 21:00:00
# Avg Days in Trade: 5 days 03:16:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_47_6_30
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9155586595
# Max Drawdown: 47.7170484092
# Max Drawdown Duration: 2736
# Total Returns: 0.3689905011
# ---------------------------------
# Trades: 40
# Trade Winning: 48%
# Average Trade: 1.61%
# Average Win: 10.07%
# Average Loss: -6.04%
# Best Trade: 32.47%
# Worst Trade: -29.86%
# Worst Trade Date: 4 days 10:00:00
# Avg Days in Trade: 1 days 23:54:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_113_2_8
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9441476166
# Max Drawdown: 52.7590148357
# Max Drawdown Duration: 2510
# Total Returns: 0.3804398470
# ---------------------------------
# Trades: 131
# Trade Winning: 57%
# Average Trade: 0.57%
# Average Win: 3.44%
# Average Loss: -3.26%
# Best Trade: 32.30%
# Worst Trade: -16.01%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 0 days 13:21:04
# ---------------------------------
# ---------------------------------
# EMVStrategy_61_83_52
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2698505350
# Max Drawdown: 71.3560312551
# Max Drawdown Duration: 2277
# Total Returns: -0.0511689443
# ---------------------------------
# Trades: 15
# Trade Winning: 67%
# Average Trade: 0.87%
# Average Win: 9.06%
# Average Loss: -15.50%
# Best Trade: 21.56%
# Worst Trade: -31.27%
# Worst Trade Date: 3 days 17:00:00
# Avg Days in Trade: 5 days 04:48:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_46_117_118
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3363797989
# Max Drawdown: 51.0250034577
# Max Drawdown Duration: 2089
# Total Returns: 0.7399950950
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 5.59%
# Average Win: 19.37%
# Average Loss: -10.15%
# Best Trade: 59.50%
# Worst Trade: -14.52%
# Worst Trade Date: 2 days 22:00:00
# Avg Days in Trade: 5 days 07:56:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_49_63_118
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4726383932
# Max Drawdown: 67.1387858738
# Max Drawdown Duration: 2736
# Total Returns: 0.0713373187
# ---------------------------------
# Trades: 16
# Trade Winning: 56%
# Average Trade: 1.49%
# Average Win: 11.23%
# Average Loss: -11.04%
# Best Trade: 21.55%
# Worst Trade: -23.59%
# Worst Trade Date: 3 days 12:00:00
# Avg Days in Trade: 4 days 20:26:15
# ---------------------------------
# ---------------------------------
# EMVStrategy_14_42_119
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1027820617
# Max Drawdown: 35.5225757993
# Max Drawdown Duration: 2736
# Total Returns: 0.4836865405
# ---------------------------------
# Trades: 29
# Trade Winning: 55%
# Average Trade: 1.98%
# Average Win: 7.79%
# Average Loss: -5.18%
# Best Trade: 19.15%
# Worst Trade: -18.22%
# Worst Trade Date: 2 days 13:00:00
# Avg Days in Trade: 2 days 13:47:35
# ---------------------------------
# ---------------------------------
# EMVStrategy_66_54_41
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8694511062
# Max Drawdown: 62.0683997304
# Max Drawdown Duration: 2277
# Total Returns: 0.3202150813
# ---------------------------------
# Trades: 18
# Trade Winning: 56%
# Average Trade: 2.50%
# Average Win: 11.69%
# Average Loss: -8.99%
# Best Trade: 23.98%
# Worst Trade: -23.54%
# Worst Trade Date: 3 days 16:00:00
# Avg Days in Trade: 4 days 05:50:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_5_55_62
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.0124395827
# Max Drawdown: 65.4920386976
# Max Drawdown Duration: 2736
# Total Returns: -0.1572124382
# ---------------------------------
# Trades: 50
# Trade Winning: 42%
# Average Trade: 0.27%
# Average Win: 7.12%
# Average Loss: -4.70%
# Best Trade: 25.16%
# Worst Trade: -21.00%
# Worst Trade Date: 2 days 01:00:00
# Avg Days in Trade: 1 days 13:10:48
# ---------------------------------
# ---------------------------------
# EMVStrategy_48_27_61
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2137284847
# Max Drawdown: 51.6226719841
# Max Drawdown Duration: 1687
# Total Returns: 0.5690097388
# ---------------------------------
# Trades: 25
# Trade Winning: 60%
# Average Trade: 2.52%
# Average Win: 9.00%
# Average Loss: -7.21%
# Best Trade: 21.43%
# Worst Trade: -15.70%
# Worst Trade Date: 3 days 21:00:00
# Avg Days in Trade: 3 days 02:55:12
# ---------------------------------
# ---------------------------------
# EMVStrategy_46_18_95
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6618540653
# Max Drawdown: 47.8256379921
# Max Drawdown Duration: 1687
# Total Returns: 0.9637037299
# ---------------------------------
# Trades: 21
# Trade Winning: 67%
# Average Trade: 3.94%
# Average Win: 9.09%
# Average Loss: -6.37%
# Best Trade: 22.34%
# Worst Trade: -15.69%
# Worst Trade Date: 3 days 13:00:00
# Avg Days in Trade: 3 days 11:40:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_55_18_100
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6315793110
# Max Drawdown: 61.4491685045
# Max Drawdown Duration: 2018
# Total Returns: 0.9785090328
# ---------------------------------
# Trades: 18
# Trade Winning: 61%
# Average Trade: 4.77%
# Average Win: 13.21%
# Average Loss: -8.49%
# Best Trade: 20.38%
# Worst Trade: -15.32%
# Worst Trade Date: 3 days 17:00:00
# Avg Days in Trade: 4 days 01:40:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_31_88_16
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4033912914
# Max Drawdown: 47.2659434859
# Max Drawdown Duration: 2736
# Total Returns: 0.7179047141
# ---------------------------------
# Trades: 26
# Trade Winning: 54%
# Average Trade: 3.00%
# Average Win: 10.72%
# Average Loss: -6.01%
# Best Trade: 33.89%
# Worst Trade: -27.68%
# Worst Trade Date: 3 days 05:00:00
# Avg Days in Trade: 3 days 00:41:32
# ---------------------------------
# ---------------------------------
# EMVStrategy_19_10_37
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5523878417
# Max Drawdown: 42.6652299359
# Max Drawdown Duration: 2510
# Total Returns: 0.9742239636
# ---------------------------------
# Trades: 53
# Trade Winning: 51%
# Average Trade: 1.87%
# Average Win: 8.58%
# Average Loss: -5.10%
# Best Trade: 34.53%
# Worst Trade: -13.61%
# Worst Trade Date: 0 days 21:00:00
# Avg Days in Trade: 1 days 11:32:50
# ---------------------------------
# ---------------------------------
# EMVStrategy_55_93_74
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7578451676
# Max Drawdown: 65.3653935332
# Max Drawdown Duration: 2277
# Total Returns: 0.2498661158
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 2.60%
# Average Win: 12.62%
# Average Loss: -8.84%
# Best Trade: 37.38%
# Worst Trade: -20.15%
# Worst Trade Date: 3 days 20:00:00
# Avg Days in Trade: 5 days 04:36:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_13_78_3
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3296960802
# Max Drawdown: 39.5320391094
# Max Drawdown Duration: 1687
# Total Returns: 0.6971285220
# ---------------------------------
# Trades: 106
# Trade Winning: 51%
# Average Trade: 0.87%
# Average Win: 4.75%
# Average Loss: -3.17%
# Best Trade: 17.35%
# Worst Trade: -13.04%
# Worst Trade Date: 0 days 13:00:00
# Avg Days in Trade: 0 days 16:59:26
# ---------------------------------
# ---------------------------------
# EMVStrategy_28_12_110
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2945819294
# Max Drawdown: 40.5097140595
# Max Drawdown Duration: 2277
# Total Returns: 0.6208156232
# ---------------------------------
# Trades: 34
# Trade Winning: 44%
# Average Trade: 2.17%
# Average Win: 10.11%
# Average Loss: -4.09%
# Best Trade: 29.53%
# Worst Trade: -22.88%
# Worst Trade Date: 3 days 01:00:00
# Avg Days in Trade: 2 days 03:54:42
# ---------------------------------
# ---------------------------------
# EMVStrategy_55_98_46
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3507448420
# Max Drawdown: 68.2328957409
# Max Drawdown Duration: 2736
# Total Returns: 0.0004754096
# ---------------------------------
# Trades: 15
# Trade Winning: 60%
# Average Trade: 1.05%
# Average Win: 9.68%
# Average Loss: -11.90%
# Best Trade: 19.24%
# Worst Trade: -26.98%
# Worst Trade Date: 3 days 21:00:00
# Avg Days in Trade: 5 days 04:08:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_91_102_78
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2688003566
# Max Drawdown: 62.0401638787
# Max Drawdown Duration: 2736
# Total Returns: -0.2565309741
# ---------------------------------
# Trades: 14
# Trade Winning: 36%
# Average Trade: -0.53%
# Average Win: 20.15%
# Average Loss: -12.02%
# Best Trade: 35.11%
# Worst Trade: -21.59%
# Worst Trade Date: 3 days 04:00:00
# Avg Days in Trade: 5 days 18:21:26
# ---------------------------------
# ---------------------------------
# EMVStrategy_33_48_109
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4905970109
# Max Drawdown: 52.4640487120
# Max Drawdown Duration: 2018
# Total Returns: 0.7987527335
# ---------------------------------
# Trades: 19
# Trade Winning: 68%
# Average Trade: 3.83%
# Average Win: 9.28%
# Average Loss: -7.98%
# Best Trade: 20.02%
# Worst Trade: -18.13%
# Worst Trade Date: 3 days 07:00:00
# Avg Days in Trade: 3 days 21:44:13
# ---------------------------------
# ---------------------------------
# EMVStrategy_32_72_73
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9694921576
# Max Drawdown: 59.6864669696
# Max Drawdown Duration: 2018
# Total Returns: 0.3890315491
# ---------------------------------
# Trades: 21
# Trade Winning: 57%
# Average Trade: 2.28%
# Average Win: 9.45%
# Average Loss: -7.28%
# Best Trade: 17.14%
# Worst Trade: -19.12%
# Worst Trade Date: 4 days 00:00:00
# Avg Days in Trade: 3 days 14:54:17
# ---------------------------------
# ---------------------------------
# EMVStrategy_34_35_100
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7581021453
# Max Drawdown: 46.2047742300
# Max Drawdown Duration: 1687
# Total Returns: 1.0561813879
# ---------------------------------
# Trades: 24
# Trade Winning: 58%
# Average Trade: 3.72%
# Average Win: 10.10%
# Average Loss: -5.22%
# Best Trade: 26.24%
# Worst Trade: -15.72%
# Worst Trade Date: 3 days 08:00:00
# Avg Days in Trade: 2 days 23:22:30
# ---------------------------------
# ---------------------------------
# EMVStrategy_2_109_35
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.0296749048
# Max Drawdown: 55.4256085273
# Max Drawdown Duration: 2736
# Total Returns: -0.1658597053
# ---------------------------------
# Trades: 111
# Trade Winning: 44%
# Average Trade: 0.16%
# Average Win: 4.13%
# Average Loss: -2.99%
# Best Trade: 27.11%
# Worst Trade: -12.07%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 16:29:11
# ---------------------------------
# ---------------------------------
# EMVStrategy_34_79_100
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7245925196
# Max Drawdown: 62.4245516791
# Max Drawdown Duration: 2018
# Total Returns: 0.2276395658
# ---------------------------------
# Trades: 17
# Trade Winning: 59%
# Average Trade: 2.20%
# Average Win: 11.11%
# Average Loss: -10.53%
# Best Trade: 20.83%
# Worst Trade: -24.67%
# Worst Trade Date: 3 days 21:00:00
# Avg Days in Trade: 4 days 13:24:42
# ---------------------------------
# ---------------------------------
# EMVStrategy_87_11_66
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8110143211
# Max Drawdown: 65.7540966235
# Max Drawdown Duration: 2277
# Total Returns: 0.2850536061
# ---------------------------------
# Trades: 17
# Trade Winning: 59%
# Average Trade: 2.49%
# Average Win: 11.26%
# Average Loss: -10.05%
# Best Trade: 34.98%
# Worst Trade: -17.83%
# Worst Trade Date: 2 days 05:00:00
# Avg Days in Trade: 4 days 07:56:28
# ---------------------------------
# ---------------------------------
# EMVStrategy_17_45_12
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4635115207
# Max Drawdown: 63.3358829620
# Max Drawdown Duration: 2437
# Total Returns: 0.0593052711
# ---------------------------------
# Trades: 48
# Trade Winning: 48%
# Average Trade: 0.77%
# Average Win: 7.75%
# Average Loss: -5.65%
# Best Trade: 35.55%
# Worst Trade: -26.25%
# Worst Trade Date: 1 days 09:00:00
# Avg Days in Trade: 1 days 15:51:15
# ---------------------------------
# ---------------------------------
# EMVStrategy_16_53_114
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5313932222
# Max Drawdown: 47.8212871305
# Max Drawdown Duration: 2736
# Total Returns: 0.1091044069
# ---------------------------------
# Trades: 26
# Trade Winning: 42%
# Average Trade: 1.28%
# Average Win: 11.35%
# Average Loss: -6.10%
# Best Trade: 25.78%
# Worst Trade: -26.40%
# Worst Trade Date: 3 days 05:00:00
# Avg Days in Trade: 2 days 20:43:51
# ---------------------------------
# ---------------------------------
# EMVStrategy_23_35_70
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4262740824
# Max Drawdown: 50.0683152917
# Max Drawdown Duration: 2736
# Total Returns: 0.0530493621
# ---------------------------------
# Trades: 32
# Trade Winning: 41%
# Average Trade: 0.86%
# Average Win: 10.37%
# Average Loss: -5.65%
# Best Trade: 25.56%
# Worst Trade: -22.45%
# Worst Trade Date: 3 days 23:00:00
# Avg Days in Trade: 2 days 10:52:30
# ---------------------------------
# ---------------------------------
# EMVStrategy_15_30_17
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7572939681
# Max Drawdown: 49.5338744339
# Max Drawdown Duration: 2510
# Total Returns: 0.2569678887
# ---------------------------------
# Trades: 54
# Trade Winning: 48%
# Average Trade: 1.01%
# Average Win: 8.48%
# Average Loss: -5.93%
# Best Trade: 32.30%
# Worst Trade: -17.15%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 1 days 11:21:07
# ---------------------------------
# ---------------------------------
# EMVStrategy_62_92_34
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3266061948
# Max Drawdown: 68.8661172780
# Max Drawdown Duration: 2277
# Total Returns: -0.0179237641
# ---------------------------------
# Trades: 15
# Trade Winning: 67%
# Average Trade: 0.95%
# Average Win: 8.85%
# Average Loss: -14.86%
# Best Trade: 19.01%
# Worst Trade: -27.40%
# Worst Trade Date: 3 days 19:00:00
# Avg Days in Trade: 5 days 04:40:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_103_13_94
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6429641432
# Max Drawdown: 51.2538750991
# Max Drawdown Duration: 2736
# Total Returns: 0.1772284411
# ---------------------------------
# Trades: 18
# Trade Winning: 61%
# Average Trade: 2.12%
# Average Win: 10.73%
# Average Loss: -11.41%
# Best Trade: 45.08%
# Worst Trade: -17.92%
# Worst Trade Date: 4 days 23:00:00
# Avg Days in Trade: 4 days 07:46:40
# ---------------------------------
# ---------------------------------
# EMVStrategy_27_69_79
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4930887699
# Max Drawdown: 46.0739853877
# Max Drawdown Duration: 2018
# Total Returns: 0.7594232791
# ---------------------------------
# Trades: 22
# Trade Winning: 64%
# Average Trade: 3.20%
# Average Win: 7.98%
# Average Loss: -5.17%
# Best Trade: 18.86%
# Worst Trade: -16.44%
# Worst Trade Date: 3 days 20:00:00
# Avg Days in Trade: 3 days 12:13:38
# ---------------------------------
# ---------------------------------
# EMVStrategy_84_60_10
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1265937754
# Max Drawdown: 59.3389513487
# Max Drawdown Duration: 2277
# Total Returns: 0.5237855246
# ---------------------------------
# Trades: 15
# Trade Winning: 73%
# Average Trade: 3.86%
# Average Win: 9.31%
# Average Loss: -11.13%
# Best Trade: 34.41%
# Worst Trade: -21.79%
# Worst Trade Date: 3 days 02:00:00
# Avg Days in Trade: 5 days 00:24:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_115_96_55
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4201569070
# Max Drawdown: 45.0259858368
# Max Drawdown Duration: 2736
# Total Returns: 0.0555048587
# ---------------------------------
# Trades: 12
# Trade Winning: 50%
# Average Trade: 1.77%
# Average Win: 14.88%
# Average Loss: -11.35%
# Best Trade: 29.59%
# Worst Trade: -18.87%
# Worst Trade Date: 4 days 17:00:00
# Avg Days in Trade: 6 days 19:10:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_36_47_83
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8920239137
# Max Drawdown: 49.3349169670
# Max Drawdown Duration: 1687
# Total Returns: 1.1989761902
# ---------------------------------
# Trades: 24
# Trade Winning: 71%
# Average Trade: 4.06%
# Average Win: 9.11%
# Average Loss: -8.21%
# Best Trade: 23.25%
# Worst Trade: -13.77%
# Worst Trade Date: 1 days 22:00:00
# Avg Days in Trade: 3 days 02:17:30
# ---------------------------------
# ---------------------------------
# EMVStrategy_36_119_6
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3941229147
# Max Drawdown: 59.4547162483
# Max Drawdown Duration: 2018
# Total Returns: 0.7701489047
# ---------------------------------
# Trades: 28
# Trade Winning: 57%
# Average Trade: 2.76%
# Average Win: 8.89%
# Average Loss: -5.42%
# Best Trade: 26.63%
# Worst Trade: -12.23%
# Worst Trade Date: 4 days 00:00:00
# Avg Days in Trade: 2 days 11:34:17
# ---------------------------------
# ---------------------------------
# EMVStrategy_12_47_83
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6217089615
# Max Drawdown: 50.8775300767
# Max Drawdown Duration: 2736
# Total Returns: 0.1669228092
# ---------------------------------
# Trades: 34
# Trade Winning: 44%
# Average Trade: 1.15%
# Average Win: 9.15%
# Average Loss: -5.16%
# Best Trade: 24.11%
# Worst Trade: -22.64%
# Worst Trade Date: 4 days 02:00:00
# Avg Days in Trade: 2 days 07:38:49
# ---------------------------------
# ---------------------------------
# EMVStrategy_40_91_51
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3555461445
# Max Drawdown: 58.4736929509
# Max Drawdown Duration: 2018
# Total Returns: 0.7616647675
# ---------------------------------
# Trades: 16
# Trade Winning: 69%
# Average Trade: 4.80%
# Average Win: 12.09%
# Average Loss: -11.22%
# Best Trade: 23.72%
# Worst Trade: -24.84%
# Worst Trade Date: 3 days 19:00:00
# Avg Days in Trade: 4 days 20:48:45
# ---------------------------------
# ---------------------------------
# EMVStrategy_95_62_5
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7034132600
# Max Drawdown: 61.5330601266
# Max Drawdown Duration: 2277
# Total Returns: 0.2146441737
# ---------------------------------
# Trades: 22
# Trade Winning: 50%
# Average Trade: 1.81%
# Average Win: 10.46%
# Average Loss: -6.84%
# Best Trade: 33.51%
# Worst Trade: -18.96%
# Worst Trade Date: 2 days 22:00:00
# Avg Days in Trade: 3 days 10:13:38
# ---------------------------------
# ---------------------------------
# EMVStrategy_65_14_9
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.2398651444
# Max Drawdown: 34.5105598545
# Max Drawdown Duration: 629
# Total Returns: 1.8429319714
# ---------------------------------
# Trades: 49
# Trade Winning: 59%
# Average Trade: 2.71%
# Average Win: 7.90%
# Average Loss: -4.82%
# Best Trade: 23.02%
# Worst Trade: -19.05%
# Worst Trade Date: 1 days 05:00:00
# Avg Days in Trade: 1 days 11:15:55
# ---------------------------------
# ---------------------------------
# EMVStrategy_1_14_9
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -3.9038457456
# Max Drawdown: 91.4196830221
# Max Drawdown Duration: 3532
# Total Returns: -0.9010923611
# ---------------------------------
# Trades: 358
# Trade Winning: 39%
# Average Trade: -0.39%
# Average Win: 2.28%
# Average Loss: -2.11%
# Best Trade: 20.50%
# Worst Trade: -12.88%
# Worst Trade Date: 0 days 10:00:00
# Avg Days in Trade: 0 days 05:11:04
# ---------------------------------
# ---------------------------------
# EMVStrategy_65_77_43
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2286176647
# Max Drawdown: 71.5314743154
# Max Drawdown Duration: 2277
# Total Returns: -0.0699748467
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 0.72%
# Average Win: 10.76%
# Average Loss: -10.74%
# Best Trade: 22.14%
# Worst Trade: -31.67%
# Worst Trade Date: 3 days 11:00:00
# Avg Days in Trade: 5 days 04:08:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_99_95_115
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0281018237
# Max Drawdown: 53.4658995864
# Max Drawdown Duration: 2736
# Total Returns: -0.1250609051
# ---------------------------------
# Trades: 13
# Trade Winning: 54%
# Average Trade: 0.38%
# Average Win: 13.42%
# Average Loss: -14.82%
# Best Trade: 29.68%
# Worst Trade: -24.55%
# Worst Trade Date: 3 days 01:00:00
# Avg Days in Trade: 6 days 09:09:14
# ---------------------------------
# ---------------------------------
# EMVStrategy_90_51_106
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1203353347
# Max Drawdown: 61.0189785621
# Max Drawdown Duration: 2736
# Total Returns: -0.1034914046
# ---------------------------------
# Trades: 15
# Trade Winning: 53%
# Average Trade: 0.57%
# Average Win: 12.54%
# Average Loss: -13.11%
# Best Trade: 37.12%
# Worst Trade: -19.96%
# Worst Trade Date: 4 days 03:00:00
# Avg Days in Trade: 5 days 04:24:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_69_49_23
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4739842150
# Max Drawdown: 53.3224214898
# Max Drawdown Duration: 2018
# Total Returns: 0.7976673987
# ---------------------------------
# Trades: 20
# Trade Winning: 65%
# Average Trade: 3.78%
# Average Win: 10.14%
# Average Loss: -8.02%
# Best Trade: 21.47%
# Worst Trade: -14.64%
# Worst Trade Date: 3 days 11:00:00
# Avg Days in Trade: 3 days 19:03:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_42_50_49
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0071896988
# Max Drawdown: 49.8812664540
# Max Drawdown Duration: 1687
# Total Returns: 0.3987299513
# ---------------------------------
# Trades: 25
# Trade Winning: 56%
# Average Trade: 2.04%
# Average Win: 9.00%
# Average Loss: -6.83%
# Best Trade: 22.07%
# Worst Trade: -17.17%
# Worst Trade Date: 3 days 22:00:00
# Avg Days in Trade: 3 days 02:55:12
# ---------------------------------
# ---------------------------------
# EMVStrategy_104_100_60
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.0477938895
# Max Drawdown: 55.2715789095
# Max Drawdown Duration: 2736
# Total Returns: -0.1582848868
# ---------------------------------
# Trades: 13
# Trade Winning: 46%
# Average Trade: 0.01%
# Average Win: 14.37%
# Average Loss: -12.30%
# Best Trade: 29.47%
# Worst Trade: -19.59%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 6 days 06:41:32
# ---------------------------------
# ---------------------------------
# EMVStrategy_30_107_88
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7320158717
# Max Drawdown: 65.3401551236
# Max Drawdown Duration: 2736
# Total Returns: 0.2329505714
# ...
# Sharpe Ratio: 1.6427252638
# Max Drawdown: 47.3092658844
# Max Drawdown Duration: 2043
# Total Returns: 0.9714506383
# ---------------------------------
# Trades: 36
# Trade Winning: 61%
# Average Trade: 2.59%
# Average Win: 8.94%
# Average Loss: -7.39%
# Best Trade: 25.37%
# Worst Trade: -29.62%
# Worst Trade Date: 3 days 11:00:00
# Avg Days in Trade: 2 days 01:15:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_22_118_16
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0152533198
# Max Drawdown: 66.7184670825
# Max Drawdown Duration: 2277
# Total Returns: -0.1910770969
# ---------------------------------
# Trades: 39
# Trade Winning: 38%
# Average Trade: 0.32%
# Average Win: 11.24%
# Average Loss: -6.50%
# Best Trade: 37.37%
# Worst Trade: -21.42%
# Worst Trade Date: 1 days 03:00:00
# Avg Days in Trade: 1 days 23:30:46
# ---------------------------------
# ---------------------------------
# EMVStrategy_110_84_107
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8569738473
# Max Drawdown: 33.0569397416
# Max Drawdown Duration: 1774
# Total Returns: 0.3090912528
# ---------------------------------
# Trades: 12
# Trade Winning: 67%
# Average Trade: 3.45%
# Average Win: 12.04%
# Average Loss: -13.73%
# Best Trade: 27.91%
# Worst Trade: -15.38%
# Worst Trade Date: 2 days 17:00:00
# Avg Days in Trade: 6 days 22:15:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_100_61_71
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2061066483
# Max Drawdown: 62.9217312697
# Max Drawdown Duration: 2736
# Total Returns: -0.2610028197
# ---------------------------------
# Trades: 14
# Trade Winning: 43%
# Average Trade: -0.62%
# Average Win: 15.10%
# Average Loss: -12.41%
# Best Trade: 42.43%
# Worst Trade: -22.85%
# Worst Trade Date: 10 days 14:00:00
# Avg Days in Trade: 5 days 16:47:09
# ---------------------------------
# ---------------------------------
# EMVStrategy_18_25_104
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5004513423
# Max Drawdown: 55.8864581641
# Max Drawdown Duration: 2277
# Total Returns: 0.0964009981
# ---------------------------------
# Trades: 40
# Trade Winning: 42%
# Average Trade: 0.88%
# Average Win: 8.49%
# Average Loss: -4.74%
# Best Trade: 30.78%
# Worst Trade: -13.37%
# Worst Trade Date: 2 days 18:00:00
# Avg Days in Trade: 1 days 21:43:30
# ---------------------------------
# ---------------------------------
# EMVStrategy_31_32_75
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0911736388
# Max Drawdown: 44.0019157602
# Max Drawdown Duration: 2018
# Total Returns: 0.4922666298
# ---------------------------------
# Trades: 30
# Trade Winning: 50%
# Average Trade: 2.09%
# Average Win: 9.94%
# Average Loss: -5.76%
# Best Trade: 23.07%
# Worst Trade: -24.70%
# Worst Trade Date: 3 days 16:00:00
# Avg Days in Trade: 2 days 14:30:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_45_43_91
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1090880970
# Max Drawdown: 63.2909363138
# Max Drawdown Duration: 2018
# Total Returns: 0.4864390674
# ---------------------------------
# Trades: 19
# Trade Winning: 58%
# Average Trade: 2.89%
# Average Win: 10.34%
# Average Loss: -7.37%
# Best Trade: 19.75%
# Worst Trade: -12.40%
# Worst Trade Date: 3 days 18:00:00
# Avg Days in Trade: 3 days 22:28:25
# ---------------------------------
# ---------------------------------
# EMVStrategy_8_2_27
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.1352715653
# Max Drawdown: 64.4741865335
# Max Drawdown Duration: 1922
# Total Returns: -0.2569679243
# ---------------------------------
# Trades: 147
# Trade Winning: 46%
# Average Trade: 0.13%
# Average Win: 4.32%
# Average Loss: -3.38%
# Best Trade: 22.09%
# Worst Trade: -13.76%
# Worst Trade Date: 0 days 15:00:00
# Avg Days in Trade: 0 days 12:53:04
# ---------------------------------
# ---------------------------------
# EMVStrategy_9_20_36
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3894625192
# Max Drawdown: 45.4146495798
# Max Drawdown Duration: 720
# Total Returns: 0.8304292644
# ---------------------------------
# Trades: 58
# Trade Winning: 50%
# Average Trade: 1.58%
# Average Win: 8.26%
# Average Loss: -5.11%
# Best Trade: 28.29%
# Worst Trade: -18.66%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 1 days 08:35:10
# ---------------------------------
# ---------------------------------
# EMVStrategy_71_113_116
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2475608943
# Max Drawdown: 62.2369028782
# Max Drawdown Duration: 2736
# Total Returns: -0.2625152617
# ---------------------------------
# Trades: 14
# Trade Winning: 36%
# Average Trade: -0.52%
# Average Win: 20.74%
# Average Loss: -12.33%
# Best Trade: 34.52%
# Worst Trade: -20.69%
# Worst Trade Date: 3 days 08:00:00
# Avg Days in Trade: 5 days 18:08:34
# ---------------------------------
# ---------------------------------
# EMVStrategy_112_15_26
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6075693653
# Max Drawdown: 48.3491676460
# Max Drawdown Duration: 2510
# Total Returns: 0.1481266472
# ---------------------------------
# Trades: 32
# Trade Winning: 47%
# Average Trade: 1.49%
# Average Win: 11.70%
# Average Loss: -7.52%
# Best Trade: 41.71%
# Worst Trade: -21.90%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 2 days 08:15:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_111_98_9
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.1460898510
# Max Drawdown: 58.8564227623
# Max Drawdown Duration: 2736
# Total Returns: -0.2321292525
# ---------------------------------
# Trades: 14
# Trade Winning: 29%
# Average Trade: -0.57%
# Average Win: 20.05%
# Average Loss: -8.82%
# Best Trade: 37.02%
# Worst Trade: -19.32%
# Worst Trade Date: 5 days 15:00:00
# Avg Days in Trade: 5 days 18:47:09
# ---------------------------------
# ---------------------------------
# EMVStrategy_54_41_41
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0540129098
# Max Drawdown: 48.7128646786
# Max Drawdown Duration: 1860
# Total Returns: 0.4447624544
# ---------------------------------
# Trades: 23
# Trade Winning: 57%
# Average Trade: 2.26%
# Average Win: 8.87%
# Average Loss: -6.35%
# Best Trade: 18.47%
# Worst Trade: -13.32%
# Worst Trade Date: 3 days 23:00:00
# Avg Days in Trade: 3 days 07:46:57
# ---------------------------------
# ---------------------------------
# EMVStrategy_61_44_57
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2253443274
# Max Drawdown: 59.3689191501
# Max Drawdown Duration: 2018
# Total Returns: 0.5832738461
# ---------------------------------
# Trades: 18
# Trade Winning: 56%
# Average Trade: 3.61%
# Average Win: 13.56%
# Average Loss: -8.83%
# Best Trade: 20.52%
# Worst Trade: -19.86%
# Worst Trade Date: 3 days 23:00:00
# Avg Days in Trade: 4 days 05:16:40
# ---------------------------------
# ---------------------------------
# EMVStrategy_47_104_96
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1184397162
# Max Drawdown: 60.8584221853
# Max Drawdown Duration: 2277
# Total Returns: 0.5141439094
# ---------------------------------
# Trades: 15
# Trade Winning: 60%
# Average Trade: 4.04%
# Average Win: 13.17%
# Average Loss: -9.67%
# Best Trade: 37.53%
# Worst Trade: -19.71%
# Worst Trade Date: 3 days 23:00:00
# Avg Days in Trade: 5 days 04:24:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_117_56_84
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0645079782
# Max Drawdown: 52.6605997055
# Max Drawdown Duration: 2736
# Total Returns: -0.1091640853
# ---------------------------------
# Trades: 13
# Trade Winning: 54%
# Average Trade: 0.21%
# Average Win: 11.22%
# Average Loss: -12.63%
# Best Trade: 25.70%
# Worst Trade: -21.09%
# Worst Trade Date: 2 days 20:00:00
# Avg Days in Trade: 6 days 08:09:14
# ---------------------------------
# ---------------------------------
# EMVStrategy_64_71_50
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3103262641
# Max Drawdown: 70.3239373331
# Max Drawdown Duration: 2277
# Total Returns: -0.0217946873
# ---------------------------------
# Trades: 15
# Trade Winning: 60%
# Average Trade: 0.89%
# Average Win: 9.45%
# Average Loss: -11.95%
# Best Trade: 22.09%
# Worst Trade: -25.32%
# Worst Trade Date: 3 days 13:00:00
# Avg Days in Trade: 5 days 04:48:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_60_6_61
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5316418758
# Max Drawdown: 49.9662985133
# Max Drawdown Duration: 1687
# Total Returns: 0.8074875934
# ---------------------------------
# Trades: 30
# Trade Winning: 60%
# Average Trade: 2.68%
# Average Win: 9.02%
# Average Loss: -6.83%
# Best Trade: 24.61%
# Worst Trade: -25.31%
# Worst Trade Date: 3 days 10:00:00
# Avg Days in Trade: 2 days 12:18:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_36_47_18
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7842156229
# Max Drawdown: 45.1533379469
# Max Drawdown Duration: 2277
# Total Returns: 0.2676242733
# ---------------------------------
# Trades: 31
# Trade Winning: 48%
# Average Trade: 1.50%
# Average Win: 9.47%
# Average Loss: -5.97%
# Best Trade: 25.12%
# Worst Trade: -23.51%
# Worst Trade Date: 4 days 06:00:00
# Avg Days in Trade: 2 days 11:52:15
# ---------------------------------
# ---------------------------------
# EMVStrategy_78_83_77
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1603511711
# Max Drawdown: 44.3845767589
# Max Drawdown Duration: 2736
# Total Returns: 0.5575698271
# ---------------------------------
# Trades: 15
# Trade Winning: 47%
# Average Trade: 4.42%
# Average Win: 17.95%
# Average Loss: -7.42%
# Best Trade: 46.78%
# Worst Trade: -14.49%
# Worst Trade Date: 3 days 19:00:00
# Avg Days in Trade: 5 days 03:28:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_52_68_119
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3013646270
# Max Drawdown: 71.1684523045
# Max Drawdown Duration: 2277
# Total Returns: -0.0305598849
# ---------------------------------
# Trades: 15
# Trade Winning: 67%
# Average Trade: 1.25%
# Average Win: 9.46%
# Average Loss: -15.17%
# Best Trade: 31.97%
# Worst Trade: -35.20%
# Worst Trade Date: 3 days 15:00:00
# Avg Days in Trade: 5 days 04:40:00
# ---------------------------------
# ---------------------------------
# EMVStrategy_113_17_59
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6035547928
# Max Drawdown: 49.1357983077
# Max Drawdown Duration: 2510
# Total Returns: 0.1511875188
# ---------------------------------
# Trades: 17
# Trade Winning: 53%
# Average Trade: 2.16%
# Average Win: 13.01%
# Average Loss: -10.04%
# Best Trade: 39.85%
# Worst Trade: -23.11%
# Worst Trade Date: 4 days 00:00:00
# Avg Days in Trade: 4 days 16:10:35
# ---------------------------------

# %%
best
# Out:
# {'m': 9, 'n': 14, 'window': 65}

# %%
for trial in trials.trials:
    print(trial['misc']['vals'], "\t",trial['result']['loss'])
# Out:
# {'m': [36], 'n': [31], 'window': [117]} 	 -0.12374172436752318
# {'m': [59], 'n': [20], 'window': [118]} 	 -0.08394524921096913
# {'m': [16], 'n': [98], 'window': [31]} 	 -1.3606313505224303
# {'m': [53], 'n': [61], 'window': [78]} 	 -0.09941723559450422
# {'m': [26], 'n': [41], 'window': [111]} 	 -0.13094457594854703
# {'m': [18], 'n': [44], 'window': [8]} 	 -0.009365458835277618
# {'m': [84], 'n': [15], 'window': [0]} 	 1.0
# {'m': [75], 'n': [104], 'window': [80]} 	 0.07623829178016672
# {'m': [16], 'n': [68], 'window': [70]} 	 -0.7112764150665396
# {'m': [64], 'n': [98], 'window': [54]} 	 -0.016245170395169817
# {'m': [77], 'n': [5], 'window': [117]} 	 -0.07476262577008241
# {'m': [96], 'n': [71], 'window': [102]} 	 0.23628721049806756
# {'m': [116], 'n': [19], 'window': [64]} 	 -0.23066756286370604
# {'m': [44], 'n': [87], 'window': [80]} 	 -0.1852841157132692
# {'m': [81], 'n': [39], 'window': [31]} 	 -0.5325981035575666
# {'m': [50], 'n': [56], 'window': [92]} 	 -0.13973600187377855
# {'m': [8], 'n': [117], 'window': [46]} 	 -0.7172720576282203
# {'m': [68], 'n': [5], 'window': [52]} 	 -0.45987979122199163
# {'m': [117], 'n': [17], 'window': [96]} 	 0.04528503232317094
# {'m': [30], 'n': [6], 'window': [47]} 	 -0.3689905010650818
# {'m': [8], 'n': [2], 'window': [113]} 	 -0.38043984698947586
# {'m': [52], 'n': [83], 'window': [61]} 	 0.05116894428847607
# {'m': [118], 'n': [117], 'window': [46]} 	 -0.7399950950454677
# {'m': [118], 'n': [63], 'window': [49]} 	 -0.07133731873401694
# {'m': [119], 'n': [42], 'window': [14]} 	 -0.48368654048603354
# {'m': [41], 'n': [54], 'window': [66]} 	 -0.3202150813165532
# {'m': [13], 'n': [0], 'window': [119]} 	 1.0
# {'m': [62], 'n': [55], 'window': [5]} 	 0.157212438154804
# {'m': [61], 'n': [27], 'window': [48]} 	 -0.5690097387906765
# {'m': [95], 'n': [18], 'window': [46]} 	 -0.9637037299308815
# {'m': [100], 'n': [18], 'window': [55]} 	 -0.978509032781979
# {'m': [16], 'n': [88], 'window': [31]} 	 -0.7179047140790971
# {'m': [37], 'n': [10], 'window': [19]} 	 -0.9742239635884677
# {'m': [74], 'n': [93], 'window': [55]} 	 -0.24986611581628515
# {'m': [3], 'n': [78], 'window': [13]} 	 -0.697128521993871
# {'m': [110], 'n': [12], 'window': [28]} 	 -0.6208156232111928
# {'m': [46], 'n': [98], 'window': [55]} 	 -0.0004754096276895492
# {'m': [78], 'n': [102], 'window': [91]} 	 0.2565309740531093
# {'m': [109], 'n': [48], 'window': [33]} 	 -0.7987527335373599
# {'m': [73], 'n': [72], 'window': [32]} 	 -0.38903154906744786
# {'m': [100], 'n': [35], 'window': [34]} 	 -1.0561813879423974
# {'m': [35], 'n': [109], 'window': [2]} 	 0.16585970530093008
# {'m': [100], 'n': [79], 'window': [34]} 	 -0.22763956584034362
# {'m': [66], 'n': [11], 'window': [87]} 	 -0.2850536060890174
# {'m': [12], 'n': [45], 'window': [17]} 	 -0.05930527114682671
# {'m': [114], 'n': [53], 'window': [16]} 	 -0.10910440692941603
# {'m': [70], 'n': [35], 'window': [23]} 	 -0.053049362050551885
# {'m': [17], 'n': [30], 'window': [15]} 	 -0.2569678887133253
# {'m': [34], 'n': [92], 'window': [62]} 	 0.017923764081962057
# {'m': [94], 'n': [13], 'window': [103]} 	 -0.17722844112790148
# {'m': [79], 'n': [69], 'window': [27]} 	 -0.7594232791359907
# {'m': [10], 'n': [60], 'window': [84]} 	 -0.5237855245711454
# {'m': [55], 'n': [96], 'window': [115]} 	 -0.05550485873334998
# {'m': [83], 'n': [47], 'window': [36]} 	 -1.1989761902318095
# {'m': [6], 'n': [119], 'window': [36]} 	 -0.7701489047047343
# {'m': [83], 'n': [47], 'window': [12]} 	 -0.16692280915193414
# {'m': [51], 'n': [91], 'window': [40]} 	 -0.7616647675180366
# {'m': [5], 'n': [62], 'window': [95]} 	 -0.21464417370109
# {'m': [9], 'n': [14], 'window': [65]} 	 -1.8429319714477885
# {'m': [9], 'n': [14], 'window': [1]} 	 0.9010923611161247
# {'m': [43], 'n': [77], 'window': [65]} 	 0.06997484669720466
# {'m': [115], 'n': [95], 'window': [99]} 	 0.1250609051139432
# {'m': [106], 'n': [51], 'window': [90]} 	 0.10349140462883955
# {'m': [23], 'n': [49], 'window': [69]} 	 -0.7976673986746083
# {'m': [49], 'n': [50], 'window': [42]} 	 -0.39872995128596767
# {'m': [60], 'n': [100], 'window': [104]} 	 0.15828488682610387
# {'m': [88], 'n': [107], 'window': [30]} 	 -0.23295057139057884
# {'m': [16], 'n': [36], 'window': [37]} 	 0.054225402470016726
# {'m': [76], 'n': [3], 'window': [36]} 	 -0.4403959291124018
# {'m': [9], 'n': [33], 'window': [65]} 	 -0.20487494866414035
# {'m': [47], 'n': [1], 'window': [108]} 	 -0.23645897635986235
# {'m': [97], 'n': [108], 'window': [93]} 	 0.1812441112397748
# {'m': [21], 'n': [97], 'window': [53]} 	 -0.4822137439700023
# {'m': [102], 'n': [98], 'window': [68]} 	 -0.30418837515747477
# {'m': [28], 'n': [73], 'window': [31]} 	 -0.34302152236902583
# {'m': [33], 'n': [21], 'window': [82]} 	 -0.8318165085369689
# {'m': [83], 'n': [58], 'window': [41]} 	 -0.3073307765098281
# {'m': [58], 'n': [75], 'window': [109]} 	 0.16080336419863506
# {'m': [67], 'n': [111], 'window': [73]} 	 -0.33493310032529644
# {'m': [82], 'n': [37], 'window': [38]} 	 -0.9096217252701511
# {'m': [7], 'n': [99], 'window': [74]} 	 -0.4328549370663677
# {'m': [93], 'n': [29], 'window': [24]} 	 0.24368759801563622
# {'m': [111], 'n': [82], 'window': [7]} 	 -0.38846531173088206
# {'m': [15], 'n': [47], 'window': [58]} 	 -0.440661950779462
# {'m': [29], 'n': [106], 'window': [116]} 	 -0.12820528511030904
# {'m': [65], 'n': [28], 'window': [11]} 	 -0.12126337014638766
# {'m': [87], 'n': [74], 'window': [20]} 	 -0.6870775799932449
# {'m': [45], 'n': [70], 'window': [4]} 	 -0.5592960089994437
# {'m': [72], 'n': [14], 'window': [43]} 	 -0.5036981084386656
# {'m': [103], 'n': [9], 'window': [101]} 	 -0.15857806291723953
# {'m': [69], 'n': [81], 'window': [72]} 	 -0.25662784348969714
# {'m': [1], 'n': [94], 'window': [76]} 	 -0.0
# {'m': [42], 'n': [24], 'window': [97]} 	 -0.22576337339951413
# {'m': [4], 'n': [112], 'window': [83]} 	 -0.19671057375419565
# {'m': [0], 'n': [114], 'window': [26]} 	 1.0
# {'m': [92], 'n': [66], 'window': [89]} 	 0.06391925477621807
# {'m': [56], 'n': [90], 'window': [10]} 	 -1.220745667913378
# {'m': [48], 'n': [90], 'window': [88]} 	 0.11178917006441813
# {'m': [85], 'n': [101], 'window': [10]} 	 -0.6084349770895467
# {'m': [56], 'n': [40], 'window': [10]} 	 0.06322980509712517
# {'m': [56], 'n': [103], 'window': [44]} 	 -0.05998635642881989
# {'m': [2], 'n': [34], 'window': [67]} 	 -0.37172604262643283
# {'m': [22], 'n': [116], 'window': [106]} 	 0.09134569652806568
# {'m': [98], 'n': [59], 'window': [81]} 	 -0.29889634827024425
# {'m': [101], 'n': [90], 'window': [85]} 	 0.31258130134721496
# {'m': [54], 'n': [115], 'window': [105]} 	 -0.012862676129590245
# {'m': [108], 'n': [57], 'window': [50]} 	 -0.15862643791525133
# {'m': [11], 'n': [7], 'window': [59]} 	 -0.001768885914810614
# {'m': [31], 'n': [65], 'window': [107]} 	 -0.059953689443193126
# {'m': [89], 'n': [52], 'window': [56]} 	 -0.2127747260217061
# {'m': [32], 'n': [86], 'window': [77]} 	 -0.1535396034403198
# {'m': [19], 'n': [23], 'window': [21]} 	 -0.70641703238316
# {'m': [40], 'n': [110], 'window': [39]} 	 -0.6672956849218001
# {'m': [80], 'n': [80], 'window': [94]} 	 0.3667557371324023
# {'m': [63], 'n': [26], 'window': [25]} 	 0.13109927292075907
# {'m': [14], 'n': [89], 'window': [29]} 	 -0.7399077036337396
# {'m': [113], 'n': [16], 'window': [98]} 	 0.11944478921074919
# {'m': [90], 'n': [8], 'window': [63]} 	 -1.1004074063032796
# {'m': [99], 'n': [22], 'window': [51]} 	 -1.076309411171907
# {'m': [112], 'n': [64], 'window': [114]} 	 -0.013095605012235945
# {'m': [105], 'n': [46], 'window': [3]} 	 -0.3567928460152241
# {'m': [38], 'n': [105], 'window': [57]} 	 -0.052748084268695594
# {'m': [20], 'n': [38], 'window': [86]} 	 -0.18826028432094777
# {'m': [86], 'n': [85], 'window': [6]} 	 -0.22697096298232355
# {'m': [24], 'n': [67], 'window': [75]} 	 -0.10558780508479337
# {'m': [53], 'n': [31], 'window': [79]} 	 -0.5297570174215722
# {'m': [39], 'n': [76], 'window': [118]} 	 0.001956695581827317
# {'m': [25], 'n': [4], 'window': [70]} 	 -0.971450638302878
# {'m': [16], 'n': [118], 'window': [22]} 	 0.19107709688704455
# {'m': [107], 'n': [84], 'window': [110]} 	 -0.309091252774365
# {'m': [71], 'n': [61], 'window': [100]} 	 0.2610028197127594
# {'m': [104], 'n': [25], 'window': [18]} 	 -0.09640099805893443
# {'m': [75], 'n': [32], 'window': [31]} 	 -0.4922666298252045
# {'m': [91], 'n': [43], 'window': [45]} 	 -0.486439067441621
# {'m': [27], 'n': [2], 'window': [8]} 	 0.2569679243365496
# {'m': [36], 'n': [20], 'window': [9]} 	 -0.8304292644457312
# {'m': [116], 'n': [113], 'window': [71]} 	 0.2625152616856421
# {'m': [26], 'n': [15], 'window': [112]} 	 -0.14812664716469404
# {'m': [9], 'n': [98], 'window': [111]} 	 0.23212925246076432
# {'m': [41], 'n': [41], 'window': [54]} 	 -0.4447624544311961
# {'m': [57], 'n': [44], 'window': [61]} 	 -0.5832738461138631
# {'m': [96], 'n': [104], 'window': [47]} 	 -0.5141439093583342
# {'m': [84], 'n': [56], 'window': [117]} 	 0.10916408530552724
# {'m': [50], 'n': [71], 'window': [64]} 	 0.021794687317802985
# {'m': [61], 'n': [6], 'window': [60]} 	 -0.8074875934365315
# {'m': [18], 'n': [47], 'window': [36]} 	 -0.2676242732915788
# {'m': [77], 'n': [83], 'window': [78]} 	 -0.5575698271033649
# {'m': [83], 'n': [88], 'window': [0]} 	 1.0
# {'m': [119], 'n': [68], 'window': [52]} 	 0.030559884941252613
# {'m': [59], 'n': [17], 'window': [113]} 	 -0.15118751880045989

# %%
f, ax = plt.subplots(1,3, figsize = (16, 8))
xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['window'] for t in trials.trials]
ax[0].set_xlim(xs[0]-10, xs[-1]+10)
ax[0].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[0].set_title('$window$ $vs$ $t$ ', fontsize=18)
ax[0].set_xlabel('$t$', fontsize=16)
ax[0].set_ylabel('$window$', fontsize=16)
ax[0].hlines(best['window'], 0, 150,color='blue',linestyle="--")

xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['n'] for t in trials.trials]
ax[1].set_xlim(xs[0]-10, xs[-1]+10)
ax[1].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[1].set_title('$n$ $vs$ $t$ ', fontsize=18)
ax[1].set_xlabel('$t$', fontsize=16)
ax[1].set_ylabel('$n$', fontsize=16)
ax[1].hlines(best['n'], 0, 150,color='blue',linestyle="--")

xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['m'] for t in trials.trials]
ax[2].set_xlim(xs[0]-10, xs[-1]+10)
ax[2].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[2].set_title('$m$ $vs$ $t$ ', fontsize=18)
ax[2].set_xlabel('$t$', fontsize=16)
ax[2].set_ylabel('$m$', fontsize=16)
ax[2].hlines(best['m'], 0, 150,color='blue',linestyle="--")

# %%
f, ax = plt.subplots(1,3, figsize = (16, 8))
xs = [t['misc']['vals']['window'] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[0].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[0].set_title('$val$ $vs$ $window$ ', fontsize=18)
ax[0].set_xlabel('$window$', fontsize=16)
ax[0].set_ylabel('$val$', fontsize=16)
ax[0].hlines(0, 0, 120, color='black',linestyle="--")
ax[0].hlines(-1, 0, 120, color='black',linestyle="--")
ax[0].hlines(1, 0, 120, color='black',linestyle="--")
ax[0].vlines(best['window'], -1.2, 2, color='blue',linestyle="--")

xs = [t['misc']['vals']['n'] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[1].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[1].set_title('$val$ $vs$ $n$ ', fontsize=18)
ax[1].set_xlabel('$n$', fontsize=16)
ax[1].set_ylabel('$val$', fontsize=16)
ax[1].hlines(0, 0, 120,color='black',linestyle="--")
ax[1].hlines(-1, 0, 120, color='black',linestyle="--")
ax[1].hlines(1, 0, 120,color='black',linestyle="--")
ax[1].vlines(best['n'], -1.2, 2, color='blue',linestyle="--")

xs = [t['misc']['vals']['m'] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[2].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[2].set_title('$val$ $vs$ $m$ ', fontsize=18)
ax[2].set_xlabel('$m$', fontsize=16)
ax[2].set_ylabel('$val$', fontsize=16)
ax[2].hlines(0, 0, 120,color='black',linestyle="--")
ax[2].hlines(-1, 0, 120, color='black',linestyle="--")
ax[2].hlines(1, 0, 120,color='black',linestyle="--")
ax[2].vlines(best['m'], -1.2, 2, color='blue',linestyle="--")
