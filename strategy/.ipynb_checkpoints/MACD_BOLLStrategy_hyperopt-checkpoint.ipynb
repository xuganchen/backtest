# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, r'..')

from Backtest import *
from Backtest.data import OHLCDataHandler
from MACD_BOLLStrategy import MACD_BOLLStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import hyperopt.pyll.stochastic

# %%
def run_backtest(config, trading_data, ohlc_data, short_window, delta_window, window, a):
    short_window = int(short_window)
    long_window = short_window + int(delta_window)
    window = int(window)
    config['title'] = "MACD_BOLLStrategy" + "_" +  str(short_window) + "_" + str(long_window) + "_" + str(window) + "_" + str(a)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")
    
    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data = trading_data, ohlc_data = ohlc_data
    )
    strategy = MACD_BOLLStrategy(config, events_queue, data_handler,
                            short_window=short_window, long_window=long_window,
                            window = window, a = a)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler= data_handler)

    results = backtest.start_trading()
    
    # dict_ans = {
    #     "short_window": [short_window],
    #     "long_window": [long_window],
    #     "Sharpe Ratio": [results['sharpe']],
    #     "Total Returns": [(results['cum_returns'][-1] - 1)],
    #     "Max Drawdown": [(results["max_drawdown"] * 100.0)],
    #     "Max Drawdown Duration": [(results['max_drawdown_duration'])],
    #     "Trades": [results['trade_info']['trading_num']],
    #     "Trade Winning": [results['trade_info']['win_pct']],
    #     "Average Trade": [results['trade_info']['avg_trd_pct']],
    #     "Average Win": [results['trade_info']['avg_win_pct']],
    #     "Average Loss": [results['trade_info']['avg_loss_pct']],
    #     "Best Trade": [results['trade_info']['max_win_pct']],
    #     "Worst Trade": [results['trade_info']['max_loss_pct']],
    #     "Worst Trade Date": [results['trade_info']['max_loss_dt']],
    #     "Avg Days in Trade": [results['trade_info']['avg_dit']]
    # }
    # return pd.DataFrame(dict_ans)
    return -1 * (results['cum_returns'][-1] - 1)

# %%
def f(params):
    config = {
        "csv_dir": "../Binance",
        "out_dir": "../results/MACD_BOLLStrategy",
        "title": "MACD_BOLLStrategy",
        "is_plot": False,
        "save_plot": False,
        "save_tradelog": False,
        "start_date": pd.Timestamp("2018-02-01T00:0:00", freq = "30" + "T"),    # str(freq) + "T"
        "end_date": pd.Timestamp("2018-06-01T00:00:00", freq = "30" + "T"),
        "equity": 1.0,
        "freq": 30,      # min
        "commission_ratio": 0.001,
        "suggested_quantity": None,     # None or a value
        "max_quantity": None,           # None or a value, Maximum purchase quantity
        "min_quantity": None,           # None or a value, Minimum purchase quantity
        "min_handheld_cash": None,      # None or a value, Minimum handheld funds
        "exchange": "Binance",
        "tickers": ['BTCUSDT']
    }
    # trading_data = {}
    # for ticker in config['tickers']:
    #     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
    #     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

    ohlc_data = {}
    for ticker in config['tickers']:
        # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
        ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '_OHLC_30min.h5', key=ticker)

    trading_data = None
    
    short_window = params['short_window']
    delta_window = params['delta_window']
    window = params['window']
    a = params['a']
    val = run_backtest(config, trading_data, ohlc_data, short_window, delta_window, window, a)
    return {'loss': val, 'status': STATUS_OK}

# %%
space = {
    'short_window': hp.randint('short_window', 120),
    'delta_window': hp.randint('delta_window', 120),
    'window': hp.randint('window', 240),
    'a': hp.uniform('a', 0.1, 3)
}

# %%
# print(hyperopt.pyll.stochastic.sample(space))

# %%
trials = Trials()

# %%
best = fmin(fn=f, space=space, algo=tpe.suggest, max_evals=50, trials=trials)
# Out:
# ---------------------------------
# MACD_BOLLStrategy_39_158_211_0.4661922510625981
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# D:\Dev\test\backtest\Backtest\portfolio.py:288: RuntimeWarning: invalid value encountered in double_scalars
#   "commission_impact": (total_commission) / (closed_info['price'] * closed_info['quantity'])
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -21.1817834009
# Sortino Ratio: -42.8989017539
# Information Ratio: -10.9199153662
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1147700
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 424
# Trade Winning: 4.48%
# Average Trade: -74.25%
# Average Win: 56.24%
# Average Loss: -80.37%
# Best Trade: 227.05%
# Worst Trade: -98.88%
# Worst Trade Date: 23.0
# Avg Days in Trade: 7.023333333333333
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_82_147_160_1.8587492835066854
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -4.2465707446
# Sortino Ratio: -23.2766726978
# Information Ratio: -7.8068704855
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1136900
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 72
# Trade Winning: 1.39%
# Average Trade: -78.93%
# Average Win: 113.95%
# Average Loss: -81.64%
# Best Trade: 113.95%
# Worst Trade: -97.83%
# Worst Trade Date: 38.0
# Avg Days in Trade: 62.47222222222222
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_11_69_63_0.5551857458819492
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# D:\Dev\test\backtest\Backtest\performance.py:169: RuntimeWarning: invalid value encountered in double_scalars
#   res_rolling_return_week = res_equity.resample("W").apply(lambda x:x[-1] / x[0] - 1)
# D:\Dev\test\backtest\Backtest\performance.py:173: RuntimeWarning: invalid value encountered in double_scalars
#   res_rolling_return_month = res_equity.resample("M").apply(lambda x:x[-1] / x[0] - 1)
# Sharpe Ratio: -20.3821954244
# Sortino Ratio: -57.9834402976
# Information Ratio: -10.7853709903
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1150800
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 465
# Trade Winning: 8.60%
# Average Trade: -63.98%
# Average Win: 76.10%
# Average Loss: -77.17%
# Best Trade: 538.17%
# Worst Trade: -98.57%
# Worst Trade Date: 25.0
# Avg Days in Trade: 7.963333333333333
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_113_139_1_2.2131564243102178
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Information Ratio: -6.2784333906
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_35_53_69_1.0981569831772737
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -52.0715398184
# Sortino Ratio: -72.8380720551
# Information Ratio: -11.9475608122
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1145500
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 214
# Trade Winning: 2.80%
# Average Trade: -74.28%
# Average Win: 57.82%
# Average Loss: -78.09%
# Best Trade: 201.04%
# Worst Trade: -98.85%
# Worst Trade Date: 44.0
# Avg Days in Trade: 20.0
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_103_214_146_2.7629830220672598
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -1.5137105517
# Sortino Ratio: -7.2015975980
# Information Ratio: -7.1239039078
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1136900
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 45
# Trade Winning: 0.00%
# Average Trade: -87.24%
# Average Win: nan%
# Average Loss: -87.24%
# Best Trade: -12.04%
# Worst Trade: -98.33%
# Worst Trade Date: 12.0
# Avg Days in Trade: 0.6
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_108_224_195_1.219476126446562
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -1.1597165922
# Sortino Ratio: -6.0380488819
# Information Ratio: -7.2835297950
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1136900
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 61
# Trade Winning: 0.00%
# Average Trade: -81.56%
# Average Win: nan%
# Average Loss: -81.56%
# Best Trade: -17.26%
# Worst Trade: -99.85%
# Worst Trade Date: 87.0
# Avg Days in Trade: 78.96666666666667
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_34_35_229_2.333027092214373
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -29.4712528286
# Sortino Ratio: -66.5117149375
# Information Ratio: -10.6740274129
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1148300
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 199
# Trade Winning: 4.02%
# Average Trade: -69.97%
# Average Win: 21.09%
# Average Loss: -73.78%
# Best Trade: 43.88%
# Worst Trade: -98.39%
# Worst Trade Date: 3.0
# Avg Days in Trade: 6.305555555555555
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_76_192_54_0.628218696143325
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -33.3604813312
# Sortino Ratio: -83.4357832427
# Information Ratio: -11.1012972565
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1143900
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 338
# Trade Winning: 0.00%
# Average Trade: -82.61%
# Average Win: nan%
# Average Loss: -82.61%
# Best Trade: 0.00%
# Worst Trade: -99.66%
# Worst Trade Date: 3.0
# Avg Days in Trade: 7.067777777777778
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_117_232_49_0.6680460807647501
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -31.6638156975
# Sortino Ratio: -75.3828976292
# Information Ratio: -11.0666648328
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1140300
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 318
# Trade Winning: 0.31%
# Average Trade: -84.30%
# Average Win: 32.25%
# Average Loss: -84.67%
# Best Trade: 32.25%
# Worst Trade: -99.66%
# Worst Trade Date: 3.0
# Avg Days in Trade: 8.443333333333333
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_103_164_104_2.6838668515292126
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -2.7192418116
# Sortino Ratio: -13.5323809464
# Information Ratio: -7.4424262974
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1136900
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 57
# Trade Winning: 0.00%
# Average Trade: -84.00%
# Average Win: nan%
# Average Loss: -84.00%
# Best Trade: -42.06%
# Worst Trade: -98.46%
# Worst Trade Date: 28.0
# Avg Days in Trade: 69.68333333333334
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_84_131_72_0.20362932968180675
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# D:\Dev\test\backtest\Backtest\performance.py:139: RuntimeWarning: invalid value encountered in double_scalars
#   res_cagr = (res_cum_returns[-1] ** (1.0 / years)) - 1.0
# Sharpe Ratio: -20.5237238321
# Sortino Ratio: -26.1085321678
# Information Ratio: -10.5567541791
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1143500
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: nan
# ---------------------------------
# Trades: 640
# Trade Winning: 9.22%
# Average Trade: -55.81%
# Average Win: 63.97%
# Average Loss: -67.97%
# Best Trade: 359.13%
# Worst Trade: -97.73%
# Worst Trade Date: 4.0
# Avg Days in Trade: 4.952222222222222
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_16_89_101_0.34400084214996446
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -15.5338614292
# Sortino Ratio: -28.6774435157
# Information Ratio: -10.3093106428
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1148600
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 578
# Trade Winning: 9.52%
# Average Trade: -57.11%
# Average Win: 71.78%
# Average Loss: -70.66%
# Best Trade: 623.69%
# Worst Trade: -98.13%
# Worst Trade Date: 5.0
# Avg Days in Trade: 6.028888888888889
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_22_99_120_0.6519842768659323
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -50.5291380977
# Sortino Ratio: -100.0208462516
# Information Ratio: -12.1529587125
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1148700
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 355
# Trade Winning: 2.25%
# Average Trade: -79.92%
# Average Win: 98.45%
# Average Loss: -84.03%
# Best Trade: 288.35%
# Worst Trade: -98.99%
# Worst Trade Date: 23.0
# Avg Days in Trade: 9.591111111111111
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_74_106_38_0.6558130481108381
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -34.7596901526
# Sortino Ratio: -152.3918876653
# Information Ratio: -11.8022676618
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1143900
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 416
# Trade Winning: 4.33%
# Average Trade: -71.22%
# Average Win: 117.38%
# Average Loss: -79.75%
# Best Trade: 1031.82%
# Worst Trade: -98.39%
# Worst Trade Date: 3.0
# Avg Days in Trade: 6.54
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_0_64_201_1.9611423692273309
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Information Ratio: -6.2784333906
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_51_107_17_0.317580239551002
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -13.8868693533
# Sortino Ratio: -17.8356889329
# Information Ratio: -10.7010577164
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1146700
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: nan
# ---------------------------------
# Trades: 642
# Trade Winning: 11.21%
# Average Trade: -51.93%
# Average Win: 84.80%
# Average Loss: -69.20%
# Best Trade: 496.36%
# Worst Trade: -97.73%
# Worst Trade Date: 4.0
# Avg Days in Trade: 4.316666666666666
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_76_155_23_2.716456898872007
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -9.4230087553
# Sortino Ratio: -27.0212436501
# Information Ratio: -8.3459861221
# Max Drawdown: 1.0000000000
# Max Drawdown Duration: 1136900
# Total Returns: -1.0000000000
# Annualized Returns: -3.0416666667
# Compound Annual Growth Rate: -1.0000000000
# ---------------------------------
# Trades: 71
# Trade Winning: 1.41%
# Average Trade: -79.68%
# Average Win: 23.43%
# Average Loss: -81.15%
# Best Trade: 23.43%
# Worst Trade: -97.93%
# Worst Trade Date: 76.0
# Avg Days in Trade: 56.84444444444444
# ---------------------------------
# ---------------------------------
# MACD_BOLLStrategy_51_71_190_1.1919429354717561
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-214ea1828431> in <module>()
# ----> 1 best = fmin(fn=f, space=space, algo=tpe.suggest, max_evals=50, trials=trials)
#
# d:\dev\python36\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len)
#     365             verbose=verbose,
#     366             catch_eval_exceptions=catch_eval_exceptions,
# --> 367             return_argmin=return_argmin,
#     368         )
#     369
#
# d:\dev\python36\lib\site-packages\hyperopt\base.py in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin)
#     633             pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     634             catch_eval_exceptions=catch_eval_exceptions,
# --> 635             return_argmin=return_argmin)
#     636
#     637
#
# d:\dev\python36\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len)
#     383                     max_queue_len=max_queue_len)
#     384     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 385     rval.exhaust()
#     386     if return_argmin:
#     387         return trials.argmin
#
# d:\dev\python36\lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     242     def exhaust(self):
#     243         n_done = len(self.trials)
# --> 244         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     245         self.trials.refresh()
#     246         return self
#
# d:\dev\python36\lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     216             else:
#     217                 # -- loop over trials and do the jobs directly
# --> 218                 self.serial_evaluate()
#     219
#     220             if stopped:
#
# d:\dev\python36\lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     135                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     136                 try:
# --> 137                     result = self.domain.evaluate(spec, ctrl)
#     138                 except Exception as e:
#     139                     logger.info('job exception: %s' % str(e))
#
# d:\dev\python36\lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     838                 memo=memo,
#     839                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 840             rval = self.fn(pyll_rval)
#     841
#     842         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-59-98ca35b1f12d> in f(params)
#      35     window = params['window']
#      36     a = params['a']
# ---> 37     val = run_backtest(config, trading_data, ohlc_data, short_window, delta_window, window, a)
#      38     return {'loss': val, 'status': STATUS_OK}
#
# <ipython-input-43-4d565d95c3ac> in run_backtest(config, trading_data, ohlc_data, short_window, delta_window, window, a)
#      21                         data_handler= data_handler)
#      22
# ---> 23     results = backtest.start_trading()
#      24
#      25     # dict_ans = {
#
# D:\Dev\test\backtest\Backtest\backtest.py in start_trading(self)
#     215         Start trading()
#     216         '''
# --> 217         self._run_backtest()
#     218         results = self._output_performance()
#     219         return results
#
# D:\Dev\test\backtest\Backtest\backtest.py in _run_backtest(self)
#     136                               and generate the SIGNAL event
#     137                             '''
# --> 138                             self.strategy.generate_signals(event)
#     139
#     140                         if event.type == EventType.SIGNAL:
#
# D:\Dev\test\backtest\strategy\MACD_BOLLStrategy.py in generate_signals(self, event)
#      47             )
#      48             bars_BOLL = self.data_handler.get_latest_bars_values(
# ---> 49                 ticker, "close", N=self.window
#      50             )
#      51
#
# D:\Dev\test\backtest\Backtest\data.py in get_latest_bars_values(self, ticker, val_type, N)
#     221         '''
#     222         bars_list = self.get_latest_bars(ticker, N)
# --> 223         return np.array([getattr(bar[1], val_type) for bar in bars_list])
#     224
#     225
#
# D:\Dev\test\backtest\Backtest\data.py in <listcomp>(.0)
#     221         '''
#     222         bars_list = self.get_latest_bars(ticker, N)
# --> 223         return np.array([getattr(bar[1], val_type) for bar in bars_list])
#     224
#     225
#
# d:\dev\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3610             return object.__getattribute__(self, name)
#    3611         else:
# -> 3612             if name in self._info_axis:
#    3613                 return self[name]
#    3614             return object.__getattribute__(self, name)
#
# d:\dev\python36\lib\site-packages\pandas\core\generic.py in _info_axis(self)
#     418         return d
#     419
# --> 420     @property
#     421     def _info_axis(self):
#     422         return getattr(self, self._info_axis_name)
#
# KeyboardInterrupt:

# %%
best
# Out:
# {'a': 0.4579584706575391, 'delta_window': 6, 'short_window': 20, 'window': 119}

# %%
for trial in trials.trials:
    print(trial['misc']['vals'], "\t",trial['result']['loss'])
# Out:
# {'a': [0.48425029354827553], 'delta_window': [102], 'short_window': [48], 'window': [118]} 	 -0.4385160450041241
# {'a': [0.7461370489501851], 'delta_window': [95], 'short_window': [105], 'window': [116]} 	 -0.4196963226330406
# {'a': [2.3588136837823903], 'delta_window': [57], 'short_window': [17], 'window': [141]} 	 -0.6369132726126034
# {'a': [0.2515466216882182], 'delta_window': [110], 'short_window': [39], 'window': [178]} 	 -0.9584124671963701
# {'a': [1.796043974939789], 'delta_window': [46], 'short_window': [62], 'window': [209]} 	 -0.9170593382570671
# {'a': [2.2631373944155597], 'delta_window': [8], 'short_window': [48], 'window': [20]} 	 -0.263449652097246
# {'a': [0.1825937410540395], 'delta_window': [51], 'short_window': [25], 'window': [3]} 	 0.7132081933343475
# {'a': [2.6275085760290398], 'delta_window': [55], 'short_window': [32], 'window': [165]} 	 -0.292587845732452
# {'a': [1.1865942687061681], 'delta_window': [71], 'short_window': [40], 'window': [165]} 	 -0.6269985746801854
# {'a': [1.2375489023837074], 'delta_window': [49], 'short_window': [2], 'window': [205]} 	 -0.35369717492658936
# {'a': [1.8711464338197987], 'delta_window': [94], 'short_window': [16], 'window': [87]} 	 -0.2892404919040237
# {'a': [0.23093834435066468], 'delta_window': [24], 'short_window': [3], 'window': [198]} 	 -0.49923767330377045
# {'a': [2.402901899183489], 'delta_window': [78], 'short_window': [117], 'window': [225]} 	 -0.20502075838895606
# {'a': [1.7583785354944002], 'delta_window': [72], 'short_window': [108], 'window': [126]} 	 -0.9339662473660162
# {'a': [1.3829860958104763], 'delta_window': [75], 'short_window': [15], 'window': [186]} 	 -1.1165001462180388
# {'a': [2.3201908938655733], 'delta_window': [40], 'short_window': [29], 'window': [112]} 	 -0.5430176107878466
# {'a': [2.553284272338169], 'delta_window': [11], 'short_window': [101], 'window': [51]} 	 -0.13214949199638837
# {'a': [2.1419106646432633], 'delta_window': [37], 'short_window': [68], 'window': [229]} 	 -0.5467388057031755
# {'a': [2.0240114868675123], 'delta_window': [69], 'short_window': [21], 'window': [16]} 	 -0.37435972259655115
# {'a': [2.2401239170384937], 'delta_window': [94], 'short_window': [25], 'window': [19]} 	 -0.6319895744774804
# {'a': [2.8772070925895745], 'delta_window': [75], 'short_window': [15], 'window': [2]} 	 -0.0
# {'a': [1.143921382254002], 'delta_window': [15], 'short_window': [75], 'window': [186]} 	 -0.680520578779606
# {'a': [0.8502231624479579], 'delta_window': [112], 'short_window': [13], 'window': [23]} 	 -1.1569199524908536
# {'a': [0.8135664268150705], 'delta_window': [18], 'short_window': [13], 'window': [137]} 	 -1.4135036274948045
# {'a': [0.8812398639332886], 'delta_window': [18], 'short_window': [13], 'window': [137]} 	 -1.4933699980532973
# {'a': [0.8396333434813188], 'delta_window': [34], 'short_window': [13], 'window': [167]} 	 -1.6360003516134696
# {'a': [0.5364298792280349], 'delta_window': [34], 'short_window': [13], 'window': [0]} 	 -1.4321678853199797
# {'a': [1.0069925194171505], 'delta_window': [85], 'short_window': [65], 'window': [88]} 	 -0.4519241466689443
# {'a': [1.5031836324047179], 'delta_window': [52], 'short_window': [113], 'window': [78]} 	 -0.32892435901374806
# {'a': [0.5549768392175894], 'delta_window': [18], 'short_window': [49], 'window': [235]} 	 -0.49539523303871724
# {'a': [0.4224702005629191], 'delta_window': [82], 'short_window': [66], 'window': [133]} 	 -0.5705148492545922
# {'a': [0.7133603100089942], 'delta_window': [21], 'short_window': [36], 'window': [64]} 	 -0.4306555483539387
# {'a': [0.9301598055081619], 'delta_window': [53], 'short_window': [28], 'window': [9]} 	 0.19310834829682022
# {'a': [1.573285982792886], 'delta_window': [61], 'short_window': [18], 'window': [167]} 	 -1.1369415375653134
# {'a': [0.37698267309437905], 'delta_window': [2], 'short_window': [95], 'window': [179]} 	 -0.7141781375101623
# {'a': [0.663699234817049], 'delta_window': [79], 'short_window': [56], 'window': [11]} 	 0.18545323674258085
# {'a': [1.0813958715980152], 'delta_window': [34], 'short_window': [73], 'window': [152]} 	 -1.0026212753705068
# {'a': [1.3573635511913262], 'delta_window': [65], 'short_window': [96], 'window': [95]} 	 -0.4186464734259778
# {'a': [0.10587110901716268], 'delta_window': [66], 'short_window': [67], 'window': [93]} 	 -0.28917835049059337
# {'a': [0.3454400188188407], 'delta_window': [92], 'short_window': [54], 'window': [28]} 	 -0.6030988547159801
# {'a': [1.2722888121640732], 'delta_window': [54], 'short_window': [34], 'window': [210]} 	 -0.7586927549495759
# {'a': [1.6493996751423352], 'delta_window': [119], 'short_window': [79], 'window': [155]} 	 -0.8050482307688027
# {'a': [0.6440251240561158], 'delta_window': [0], 'short_window': [12], 'window': [137]} 	 -0.0
# {'a': [0.9424556357165724], 'delta_window': [47], 'short_window': [87], 'window': [62]} 	 -0.6161184387100798
# {'a': [0.2527350773529532], 'delta_window': [107], 'short_window': [116], 'window': [49]} 	 -0.41711024842315614
# {'a': [1.4436871783902672], 'delta_window': [97], 'short_window': [22], 'window': [153]} 	 -0.577449141057607
# {'a': [1.9219467853861978], 'delta_window': [90], 'short_window': [50], 'window': [151]} 	 -0.9987194243945285
# {'a': [1.696460831221021], 'delta_window': [4], 'short_window': [112], 'window': [89]} 	 0.025532135944724255
# {'a': [1.299634143419907], 'delta_window': [77], 'short_window': [80], 'window': [150]} 	 -1.1873280770733992
# {'a': [2.9651810711684647], 'delta_window': [86], 'short_window': [115], 'window': [63]} 	 -0.9266014889254446
# {'a': [1.1017429507643097], 'delta_window': [104], 'short_window': [111], 'window': [190]} 	 -0.8897628236671937
# {'a': [0.1325751285919835], 'delta_window': [44], 'short_window': [27], 'window': [15]} 	 -0.05445384978296408
# {'a': [0.8290629088642681], 'delta_window': [81], 'short_window': [10], 'window': [40]} 	 -1.615943503546064
# {'a': [0.8122560931206906], 'delta_window': [42], 'short_window': [10], 'window': [57]} 	 -1.0001067141335271
# {'a': [0.5792114812402838], 'delta_window': [81], 'short_window': [45], 'window': [219]} 	 -1.4008972084458988
# {'a': [1.2032669839671863], 'delta_window': [115], 'short_window': [90], 'window': [140]} 	 -1.0709103438559668
# {'a': [0.28670893497688354], 'delta_window': [106], 'short_window': [44], 'window': [181]} 	 -1.11155057041106
# {'a': [2.0596381341565024], 'delta_window': [38], 'short_window': [83], 'window': [72]} 	 0.1526434276309706
# {'a': [0.4798360067826308], 'delta_window': [36], 'short_window': [8], 'window': [212]} 	 -1.4752898900104778
# {'a': [1.0346837069258519], 'delta_window': [111], 'short_window': [110], 'window': [127]} 	 -1.3683314824714494
# {'a': [1.9066531174425347], 'delta_window': [41], 'short_window': [6], 'window': [40]} 	 -0.6547357524639297
# {'a': [2.5164134093247554], 'delta_window': [81], 'short_window': [86], 'window': [58]} 	 -0.4599111635124362
# {'a': [0.7491964876024169], 'delta_window': [17], 'short_window': [119], 'window': [54]} 	 -0.5971571632631156
# {'a': [1.5288121519433011], 'delta_window': [43], 'short_window': [70], 'window': [201]} 	 -1.2747698551287354
# {'a': [0.9951258132702883], 'delta_window': [56], 'short_window': [84], 'window': [35]} 	 -0.8431185342266532
# {'a': [0.8777605088045746], 'delta_window': [84], 'short_window': [13], 'window': [115]} 	 -0.8262920484176588
# {'a': [0.48126833517001844], 'delta_window': [64], 'short_window': [37], 'window': [167]} 	 -0.3323697909205625
# {'a': [0.7655901948415318], 'delta_window': [29], 'short_window': [55], 'window': [239]} 	 -0.5858659011236755
# {'a': [0.6259197918600845], 'delta_window': [74], 'short_window': [88], 'window': [125]} 	 -0.6474735920435872
# {'a': [1.1768222361495524], 'delta_window': [76], 'short_window': [42], 'window': [207]} 	 -0.8962369197194637
# {'a': [1.38218167882198], 'delta_window': [60], 'short_window': [35], 'window': [132]} 	 -0.5291881320693879
# {'a': [0.18011199053550275], 'delta_window': [27], 'short_window': [91], 'window': [66]} 	 -0.06280972422433884
# {'a': [0.9079654088497824], 'delta_window': [73], 'short_window': [0], 'window': [94]} 	 -0.0
# {'a': [0.38952424119796025], 'delta_window': [103], 'short_window': [64], 'window': [113]} 	 -0.8513163966603234
# {'a': [1.757142255397084], 'delta_window': [63], 'short_window': [92], 'window': [169]} 	 -0.9174489970345638
# {'a': [1.0874263572147802], 'delta_window': [16], 'short_window': [53], 'window': [107]} 	 -0.11857838982578395
# {'a': [0.69687209029918], 'delta_window': [62], 'short_window': [77], 'window': [91]} 	 -0.31375169813948056
# {'a': [1.5990705055647223], 'delta_window': [80], 'short_window': [10], 'window': [187]} 	 -1.0776834957908497
# {'a': [1.279541302904552], 'delta_window': [88], 'short_window': [26], 'window': [44]} 	 -0.6183034522811739
# {'a': [1.4319672718013843], 'delta_window': [67], 'short_window': [97], 'window': [159]} 	 -0.9612080047919043
# {'a': [0.9810330222233535], 'delta_window': [83], 'short_window': [46], 'window': [43]} 	 -1.1472116633435294
# {'a': [2.7878687086837814], 'delta_window': [33], 'short_window': [5], 'window': [36]} 	 -0.4528511641472426
# {'a': [0.30017454047993897], 'delta_window': [45], 'short_window': [11], 'window': [160]} 	 -1.8289325231263143
# {'a': [0.3229187944130673], 'delta_window': [10], 'short_window': [11], 'window': [160]} 	 -0.8629697260718776
# {'a': [0.21237132633844366], 'delta_window': [58], 'short_window': [94], 'window': [160]} 	 -0.5074642944019394
# {'a': [0.48132816034365844], 'delta_window': [22], 'short_window': [71], 'window': [120]} 	 -0.02832607591454095
# {'a': [0.5779555679954154], 'delta_window': [5], 'short_window': [1], 'window': [121]} 	 0.3118680945328356
# {'a': [0.131907255909332], 'delta_window': [45], 'short_window': [114], 'window': [34]} 	 -0.29297828177277685
# {'a': [0.8201265648821247], 'delta_window': [31], 'short_window': [76], 'window': [53]} 	 -0.5354420157505135
# {'a': [0.4197533918157024], 'delta_window': [35], 'short_window': [33], 'window': [40]} 	 -0.6776896096147202
# {'a': [0.2994000431146151], 'delta_window': [34], 'short_window': [30], 'window': [50]} 	 -0.35904665341596353
# {'a': [0.5359543709591328], 'delta_window': [118], 'short_window': [47], 'window': [1]} 	 -0.0
# {'a': [0.651139466799777], 'delta_window': [26], 'short_window': [41], 'window': [17]} 	 -0.7265994437140344
# {'a': [0.7514592294904545], 'delta_window': [91], 'short_window': [99], 'window': [60]} 	 -0.8467294264859182
# {'a': [1.1235219739599915], 'delta_window': [19], 'short_window': [74], 'window': [26]} 	 -1.0588438293310074
# {'a': [0.19058232452673773], 'delta_window': [45], 'short_window': [31], 'window': [114]} 	 -0.6009295567698241
# {'a': [1.827652206121971], 'delta_window': [23], 'short_window': [11], 'window': [48]} 	 -0.5881761492496727
# {'a': [1.055780440326663], 'delta_window': [7], 'short_window': [103], 'window': [30]} 	 -0.6886688394058322
# {'a': [1.3472780337624277], 'delta_window': [116], 'short_window': [85], 'window': [6]} 	 0.337045306846549
# {'a': [1.2280340301533719], 'delta_window': [12], 'short_window': [82], 'window': [166]} 	 -1.1893595537816797
# {'a': [0.852262576674887], 'delta_window': [70], 'short_window': [98], 'window': [14]} 	 -0.2445690367909139
# {'a': [0.10100020826416989], 'delta_window': [114], 'short_window': [61], 'window': [180]} 	 -0.5542234256709395
# {'a': [1.9825776604922243], 'delta_window': [50], 'short_window': [9], 'window': [105]} 	 -0.8326601943443512
# {'a': [0.9488762548456379], 'delta_window': [117], 'short_window': [106], 'window': [226]} 	 -0.7367021335076531
# {'a': [1.446581428696709], 'delta_window': [68], 'short_window': [38], 'window': [148]} 	 -0.46210514740472597
# {'a': [0.25548852160164987], 'delta_window': [109], 'short_window': [107], 'window': [13]} 	 0.1810846131393351
# {'a': [2.1498133919156204], 'delta_window': [25], 'short_window': [43], 'window': [175]} 	 -0.856270846129388
# {'a': [0.3531535704811384], 'delta_window': [99], 'short_window': [52], 'window': [52]} 	 -0.6202187661661416
# {'a': [0.6073635838606279], 'delta_window': [39], 'short_window': [109], 'window': [196]} 	 -0.7475164175514313
# {'a': [0.43862741829715146], 'delta_window': [89], 'short_window': [19], 'window': [232]} 	 -0.8773068468367078
# {'a': [0.5193628476345704], 'delta_window': [20], 'short_window': [93], 'window': [25]} 	 -0.4872578378367798
# {'a': [0.7144931356458684], 'delta_window': [6], 'short_window': [58], 'window': [217]} 	 -0.7300825936528148
# {'a': [1.1874714695074926], 'delta_window': [113], 'short_window': [69], 'window': [129]} 	 -1.428043494555821
# {'a': [1.6902469930866935], 'delta_window': [3], 'short_window': [81], 'window': [21]} 	 -0.8490006815701976
# {'a': [0.7846431221116353], 'delta_window': [32], 'short_window': [100], 'window': [68]} 	 -0.5629715077133111
# {'a': [1.482869503302262], 'delta_window': [59], 'short_window': [24], 'window': [164]} 	 -0.7781458763632598
# {'a': [1.3081268377727189], 'delta_window': [98], 'short_window': [60], 'window': [117]} 	 -1.2576408068890177
# {'a': [0.15357491530218692], 'delta_window': [28], 'short_window': [14], 'window': [213]} 	 -1.8366941234037544
# {'a': [0.1460297727683052], 'delta_window': [28], 'short_window': [59], 'window': [213]} 	 -0.26413234994204937
# {'a': [0.37778491866334335], 'delta_window': [9], 'short_window': [72], 'window': [208]} 	 -0.3090660073476301
# {'a': [0.25042602734263936], 'delta_window': [1], 'short_window': [14], 'window': [193]} 	 -0.6139236415017137
# {'a': [2.3438192571078447], 'delta_window': [102], 'short_window': [89], 'window': [8]} 	 -0.8978257167767636
# {'a': [0.6849361936086313], 'delta_window': [105], 'short_window': [51], 'window': [55]} 	 -0.7336470447929848
# {'a': [0.10825859858992926], 'delta_window': [93], 'short_window': [102], 'window': [22]} 	 -0.11646577268203573
# {'a': [0.4268920117620799], 'delta_window': [78], 'short_window': [104], 'window': [154]} 	 -1.3864548092295297
# {'a': [0.50162011040402], 'delta_window': [96], 'short_window': [20], 'window': [67]} 	 -0.6843284115414741
# {'a': [2.467646649720728], 'delta_window': [30], 'short_window': [57], 'window': [45]} 	 -0.3113030917964015
# {'a': [0.18817265002498618], 'delta_window': [101], 'short_window': [23], 'window': [61]} 	 -0.42693869189154277
# {'a': [0.3149647211028047], 'delta_window': [48], 'short_window': [78], 'window': [144]} 	 -0.38620956244665083
# {'a': [2.6815898532689593], 'delta_window': [28], 'short_window': [16], 'window': [147]} 	 -0.7365408667450692
# {'a': [0.5779936659784379], 'delta_window': [100], 'short_window': [7], 'window': [215]} 	 -0.7891998320652638
# {'a': [0.8987835200925666], 'delta_window': [13], 'short_window': [4], 'window': [39]} 	 -0.4175216785433842
# {'a': [0.6249461225594963], 'delta_window': [14], 'short_window': [113], 'window': [213]} 	 -1.122779253630049
# {'a': [0.9963336063768982], 'delta_window': [46], 'short_window': [48], 'window': [123]} 	 -0.5464177166349073
# {'a': [0.2576932116172064], 'delta_window': [110], 'short_window': [14], 'window': [228]} 	 -1.0204113873646623
# {'a': [0.45384018232674883], 'delta_window': [55], 'short_window': [118], 'window': [199]} 	 -0.9021630544287609
# {'a': [0.3597747977459277], 'delta_window': [34], 'short_window': [3], 'window': [59]} 	 -0.5011167222442123
# {'a': [1.1374902016763637], 'delta_window': [57], 'short_window': [17], 'window': [134]} 	 -1.0975429120799234
# {'a': [2.2702709822102727], 'delta_window': [11], 'short_window': [63], 'window': [142]} 	 -0.5385441414371157
# {'a': [1.6159015077920231], 'delta_window': [8], 'short_window': [39], 'window': [189]} 	 -0.8549863750585807
# {'a': [0.713044197158848], 'delta_window': [87], 'short_window': [29], 'window': [71]} 	 -0.7837381335480413
# {'a': [2.9842125266049333], 'delta_window': [51], 'short_window': [105], 'window': [182]} 	 -0.9019357323793136
# {'a': [0.536376627025859], 'delta_window': [108], 'short_window': [32], 'window': [174]} 	 -1.043848012849974
# {'a': [0.14965308231669083], 'delta_window': [71], 'short_window': [62], 'window': [192]} 	 -0.8150719960084107
# {'a': [0.8476115318361253], 'delta_window': [49], 'short_window': [40], 'window': [83]} 	 -0.25411021396030153
# {'a': [0.7926531960195986], 'delta_window': [112], 'short_window': [117], 'window': [92]} 	 -0.5639689776881378
# {'a': [1.0701369666052694], 'delta_window': [53], 'short_window': [10], 'window': [236]} 	 -1.7153026664453495
# {'a': [1.0678314379413882], 'delta_window': [95], 'short_window': [101], 'window': [156]} 	 -0.9619839815608149
# {'a': [1.2437033412202567], 'delta_window': [53], 'short_window': [73], 'window': [42]} 	 -0.44860438921190315
# {'a': [1.3293558969338166], 'delta_window': [52], 'short_window': [2], 'window': [203]} 	 -0.33310229118656154
# {'a': [1.5314416325864515], 'delta_window': [40], 'short_window': [13], 'window': [161]} 	 -1.227087579507557
# {'a': [0.6641930339633502], 'delta_window': [24], 'short_window': [68], 'window': [234]} 	 -0.9471645329348313
# {'a': [1.0080622929502072], 'delta_window': [15], 'short_window': [21], 'window': [162]} 	 -1.6028302868778175
# {'a': [1.425603820946765], 'delta_window': [82], 'short_window': [75], 'window': [136]} 	 -0.782363383027475
# {'a': [0.9382942382273227], 'delta_window': [72], 'short_window': [108], 'window': [138]} 	 -1.2776751812548688
# {'a': [1.156863371835055], 'delta_window': [92], 'short_window': [11], 'window': [122]} 	 -0.788944200834627
# {'a': [0.7552094692520089], 'delta_window': [53], 'short_window': [15], 'window': [200]} 	 -1.411212874564126
# {'a': [1.765006641663146], 'delta_window': [61], 'short_window': [50], 'window': [236]} 	 -0.7542055856132519
# {'a': [0.3045664233091889], 'delta_window': [94], 'short_window': [65], 'window': [33]} 	 -0.8002289845163604
# {'a': [0.8950626070084647], 'delta_window': [45], 'short_window': [67], 'window': [197]} 	 -1.0243602818924504
# {'a': [1.2306500754994918], 'delta_window': [79], 'short_window': [25], 'window': [167]} 	 -0.6835610602794202
# {'a': [0.607303473407853], 'delta_window': [2], 'short_window': [66], 'window': [100]} 	 -0.22808839585165286
# {'a': [1.3800502572498727], 'delta_window': [85], 'short_window': [10], 'window': [10]} 	 -0.4486333555281221
# {'a': [1.0338229036303637], 'delta_window': [106], 'short_window': [49], 'window': [233]} 	 -1.3658670885234043
# {'a': [0.40279693645616454], 'delta_window': [37], 'short_window': [12], 'window': [47]} 	 -1.0118862074660329
# {'a': [0.481069759076673], 'delta_window': [21], 'short_window': [56], 'window': [37]} 	 -0.7295125522386727
# {'a': [1.0932435809462178], 'delta_window': [107], 'short_window': [87], 'window': [130]} 	 -1.4236034609922492
# {'a': [0.2107972958401122], 'delta_window': [54], 'short_window': [115], 'window': [183]} 	 -0.6987324118087073
# {'a': [1.6881641925565818], 'delta_window': [66], 'short_window': [79], 'window': [128]} 	 -0.6739187890067659
# {'a': [0.9424702320989916], 'delta_window': [75], 'short_window': [96], 'window': [206]} 	 -0.8997432318222893
# {'a': [1.8366180583570317], 'delta_window': [119], 'short_window': [18], 'window': [85]} 	 -0.0824606730055304
# {'a': [0.5532041365625825], 'delta_window': [0], 'short_window': [28], 'window': [69]} 	 -0.0
# {'a': [0.7258004755227183], 'delta_window': [104], 'short_window': [95], 'window': [146]} 	 -1.4359491663249049
# {'a': [0.8256554661856088], 'delta_window': [69], 'short_window': [34], 'window': [75]} 	 -0.6841545744923525
# {'a': [2.097657290070134], 'delta_window': [29], 'short_window': [112], 'window': [65]} 	 -0.24898145680653339
# {'a': [0.6616052346939438], 'delta_window': [90], 'short_window': [27], 'window': [194]} 	 -0.48882721189630596
# {'a': [0.35933553389800915], 'delta_window': [4], 'short_window': [14], 'window': [73]} 	 -0.5405439661788654
# {'a': [1.942009660920912], 'delta_window': [47], 'short_window': [80], 'window': [109]} 	 -0.7294573486891327
# {'a': [0.10628258101605202], 'delta_window': [77], 'short_window': [44], 'window': [12]} 	 0.30219555009357335
# {'a': [1.2858279621381443], 'delta_window': [28], 'short_window': [54], 'window': [238]} 	 -0.5894633189242666
# {'a': [0.26950021116593703], 'delta_window': [97], 'short_window': [110], 'window': [139]} 	 -0.6355235278211719
# {'a': [1.1236620854717827], 'delta_window': [36], 'short_window': [111], 'window': [230]} 	 -0.5681353599597432
# {'a': [0.8500271731182525], 'delta_window': [38], 'short_window': [8], 'window': [32]} 	 -0.718561820324372
# {'a': [1.5058818725798524], 'delta_window': [86], 'short_window': [22], 'window': [221]} 	 -0.9901112497217393
# {'a': [1.2008309504574752], 'delta_window': [111], 'short_window': [90], 'window': [145]} 	 -1.0432191647692672
# {'a': [0.10060900648951171], 'delta_window': [34], 'short_window': [70], 'window': [236]} 	 -0.6678626013101074
# {'a': [0.981092713978243], 'delta_window': [84], 'short_window': [116], 'window': [195]} 	 -0.7722958294146522
# {'a': [1.5687054966950729], 'delta_window': [44], 'short_window': [45], 'window': [5]} 	 0.3757689629400903
# {'a': [0.44413888929762096], 'delta_window': [65], 'short_window': [6], 'window': [163]} 	 -1.4566665948040463
# {'a': [0.7793178109553938], 'delta_window': [103], 'short_window': [42], 'window': [202]} 	 -1.2135595416757363
# {'a': [0.6012617808296095], 'delta_window': [42], 'short_window': [55], 'window': [79]} 	 -0.5240200321384225
# {'a': [0.5019031851050844], 'delta_window': [74], 'short_window': [84], 'window': [227]} 	 -1.03434848966553
# {'a': [0.18834576439534206], 'delta_window': [63], 'short_window': [37], 'window': [18]} 	 -0.06976854218409456
# {'a': [1.0405953569930861], 'delta_window': [64], 'short_window': [13], 'window': [103]} 	 -1.0627348608248273
# {'a': [1.4435227531414607], 'delta_window': [27], 'short_window': [86], 'window': [160]} 	 -0.41024349401846716
# {'a': [0.9008627434440779], 'delta_window': [80], 'short_window': [64], 'window': [173]} 	 -0.8940838519027725
# {'a': [0.32460201753489604], 'delta_window': [115], 'short_window': [35], 'window': [70]} 	 -0.7682030305375229
# {'a': [0.6812382661634007], 'delta_window': [41], 'short_window': [119], 'window': [108]} 	 -0.23238528220796395
# {'a': [2.8723015410096844], 'delta_window': [43], 'short_window': [53], 'window': [131]} 	 -0.2239513684120007
# {'a': [0.42343377801765253], 'delta_window': [62], 'short_window': [83], 'window': [185]} 	 -0.975196358989521
# {'a': [0.5608888991918936], 'delta_window': [76], 'short_window': [30], 'window': [237]} 	 -0.4036751393764646
# {'a': [1.6532413803864836], 'delta_window': [17], 'short_window': [97], 'window': [168]} 	 -0.7935557152848078
# {'a': [1.3492357642364303], 'delta_window': [16], 'short_window': [36], 'window': [102]} 	 -0.46130865891429873
# {'a': [0.2143885246887125], 'delta_window': [88], 'short_window': [0], 'window': [99]} 	 -0.0
# {'a': [1.2789904328694173], 'delta_window': [73], 'short_window': [88], 'window': [158]} 	 -1.024776824184567
# {'a': [1.1349937579700187], 'delta_window': [53], 'short_window': [11], 'window': [171]} 	 -0.8243225032392085
# {'a': [0.7410395436046618], 'delta_window': [18], 'short_window': [5], 'window': [7]} 	 0.34085437808945196
# {'a': [0.9591951430813833], 'delta_window': [67], 'short_window': [10], 'window': [222]} 	 -1.7321300091698522
# {'a': [2.423237532179317], 'delta_window': [45], 'short_window': [10], 'window': [76]} 	 -0.8410369165103355
# {'a': [2.0120998327836603], 'delta_window': [31], 'short_window': [10], 'window': [223]} 	 -0.7661430823835065
# {'a': [1.7431590092186808], 'delta_window': [67], 'short_window': [94], 'window': [80]} 	 -0.20454203219721534
# {'a': [1.8722528067452795], 'delta_window': [83], 'short_window': [77], 'window': [231]} 	 -0.9036697016589914
# {'a': [2.1760081615197575], 'delta_window': [118], 'short_window': [41], 'window': [177]} 	 -1.6119510492000515
# {'a': [2.6186664393048704], 'delta_window': [22], 'short_window': [47], 'window': [111]} 	 -0.6017668073200628
# {'a': [1.6074646318368724], 'delta_window': [5], 'short_window': [76], 'window': [56]} 	 -0.2828231386002771
# {'a': [1.1978238143609674], 'delta_window': [58], 'short_window': [1], 'window': [222]} 	 -0.6087099717375126
# {'a': [0.9505331358897269], 'delta_window': [67], 'short_window': [92], 'window': [157]} 	 -0.8294371677542443
# {'a': [1.0471472130797719], 'delta_window': [60], 'short_window': [91], 'window': [191]} 	 -1.0227972477730494
# {'a': [1.4995020851532974], 'delta_window': [33], 'short_window': [71], 'window': [81]} 	 0.011651488680807676
# {'a': [0.3701108454797777], 'delta_window': [26], 'short_window': [26], 'window': [27]} 	 -0.24721143406033108
# {'a': [0.28278473751597555], 'delta_window': [19], 'short_window': [74], 'window': [31]} 	 -0.4402066113381624
# {'a': [1.4240152552049117], 'delta_window': [12], 'short_window': [85], 'window': [29]} 	 -0.7253948217135053
# {'a': [0.6373918441504722], 'delta_window': [70], 'short_window': [58], 'window': [101]} 	 -0.6531742004456844
# {'a': [0.8477302470225344], 'delta_window': [10], 'short_window': [46], 'window': [96]} 	 -0.6666466198288301
# {'a': [0.14478901550349504], 'delta_window': [114], 'short_window': [33], 'window': [106]} 	 -0.47841821673463114
# {'a': [1.3721677511381078], 'delta_window': [117], 'short_window': [38], 'window': [222]} 	 -1.2026156384155255
# {'a': [0.5326226697381116], 'delta_window': [109], 'short_window': [114], 'window': [84]} 	 -0.5036164925962334
# {'a': [0.9996900316855692], 'delta_window': [116], 'short_window': [31], 'window': [104]} 	 -0.36308917839898913
# {'a': [1.1018455226184993], 'delta_window': [23], 'short_window': [98], 'window': [124]} 	 -1.0218771403926539
# {'a': [1.5590564698217242], 'delta_window': [7], 'short_window': [99], 'window': [90]} 	 0.02489204072694029
# {'a': [0.7679855756007284], 'delta_window': [35], 'short_window': [43], 'window': [98]} 	 -0.33559559584804344
# {'a': [1.3006095000768845], 'delta_window': [25], 'short_window': [81], 'window': [211]} 	 -1.0241443307433635
# {'a': [0.10145525051158], 'delta_window': [28], 'short_window': [103], 'window': [82]} 	 -0.3991296422638826
# {'a': [0.46599956317554936], 'delta_window': [6], 'short_window': [20], 'window': [214]} 	 -1.804596388554892
# {'a': [0.23724779482563446], 'delta_window': [6], 'short_window': [20], 'window': [77]} 	 -1.2272968313324921
# {'a': [0.4579584706575391], 'delta_window': [6], 'short_window': [20], 'window': [119]} 	 -1.9183429083919843
# {'a': [0.32816218819268916], 'delta_window': [6], 'short_window': [107], 'window': [188]} 	 -0.6188677099815474
# {'a': [0.45668976788535165], 'delta_window': [6], 'short_window': [20], 'window': [119]} 	 -1.9183429083919843
# {'a': [0.18599400541419958], 'delta_window': [99], 'short_window': [82], 'window': [4]} 	 0.6879042040751875
# {'a': [0.3872567925637925], 'delta_window': [32], 'short_window': [61], 'window': [110]} 	 -0.309721619296653
# {'a': [0.15352267584819412], 'delta_window': [6], 'short_window': [109], 'window': [119]} 	 0.04175854749036201
# {'a': [0.29049861041331626], 'delta_window': [3], 'short_window': [20], 'window': [135]} 	 -1.453240676195609
# {'a': [0.487610721989504], 'delta_window': [39], 'short_window': [9], 'window': [119]} 	 -1.332064023853687
# {'a': [0.5948652666450227], 'delta_window': [1], 'short_window': [51], 'window': [224]} 	 -0.5295893219681294
# {'a': [0.41294559013687054], 'delta_window': [93], 'short_window': [59], 'window': [46]} 	 -0.5796025817688706
# {'a': [0.10298342142587918], 'delta_window': [50], 'short_window': [20], 'window': [38]} 	 -0.9443357335060938
# {'a': [0.26932212735561123], 'delta_window': [68], 'short_window': [14], 'window': [97]} 	 -1.1792586155205225
# {'a': [0.23196342823260674], 'delta_window': [20], 'short_window': [52], 'window': [143]} 	 -0.11874058221661787
# {'a': [0.6771337750599404], 'delta_window': [100], 'short_window': [93], 'window': [119]} 	 -0.7355999958240902
# {'a': [0.10002654596504304], 'delta_window': [89], 'short_window': [19], 'window': [24]} 	 -0.8614164351618225

# %%
f, ax = plt.subplots(2, 2, figsize = (16, 16))
xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['short_window'] for t in trials.trials]
ax[0,0].set_xlim(xs[0]-10, xs[-1]+10)
ax[0,0].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[0,0].set_title('$short\_window$ $vs$ $t$ ', fontsize=18)
ax[0,0].set_xlabel('$t$', fontsize=16)
ax[0,0].set_ylabel('$short\_window$', fontsize=16)
ax[0,0].hlines(best['short_window'], 0, 250,color='blue',linestyle="--")

xs = [t['tid'] for t in trials.trials]
ys = [[t['misc']['vals']['delta_window'][0]+ t['misc']['vals']['short_window'][0]] for t in trials.trials]
ax[0,1].set_xlim(xs[0]-10, xs[-1]+10)
ax[0,1].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[0,1].set_title('$long\_window$ $vs$ $t$ ', fontsize=18)
ax[0,1].set_xlabel('$t$', fontsize=16)
ax[0,1].set_ylabel('$long\_window$', fontsize=16)
ax[0,1].hlines(best['delta_window'] + best['short_window'], 0, 250,color='blue',linestyle="--")

xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['window'] for t in trials.trials]
ax[1,0].set_xlim(xs[0]-10, xs[-1]+10)
ax[1,0].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[1,0].set_title('$window$ $vs$ $t$ ', fontsize=18)
ax[1,0].set_xlabel('$t$', fontsize=16)
ax[1,0].set_ylabel('$window$', fontsize=16)
ax[1,0].hlines(best['window'], 0, 250,color='blue',linestyle="--")

xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['a'] for t in trials.trials]
ax[1,1].set_xlim(xs[0]-10, xs[-1]+10)
ax[1,1].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[1,1].set_title('$a$ $vs$ $t$ ', fontsize=18)
ax[1,1].set_xlabel('$t$', fontsize=16)
ax[1,1].set_ylabel('$a$', fontsize=16)
ax[1,1].hlines(best['a'], 0, 250,color='blue',linestyle="--")

# %%
f, ax = plt.subplots(2,2, figsize = (16, 16))
xs = [t['misc']['vals']['short_window'] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[0,0].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[0,0].set_title('$val$ $vs$ $short\_window$ ', fontsize=18)
ax[0,0].set_xlabel('$short\_window$', fontsize=16)
ax[0,0].set_ylabel('$val$', fontsize=16)
ax[0,0].hlines(0, 0, 120, color='black',linestyle="--")
ax[0,0].hlines(-1, 0, 120, color='black',linestyle="--")
ax[0,0].hlines(1, 0, 120, color='black',linestyle="--")
ax[0,0].vlines(best['short_window'], -1.2, 2, color='blue',linestyle="--")

xs = [[t['misc']['vals']['delta_window'][0]+ t['misc']['vals']['short_window'][0]] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[0,1].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[0,1].set_title('$val$ $vs$ $long\_window$ ', fontsize=18)
ax[0,1].set_xlabel('$long\_window$', fontsize=16)
ax[0,1].set_ylabel('$val$', fontsize=16)
ax[0,1].hlines(0, 0, 240,color='black',linestyle="--")
ax[0,1].hlines(-1, 0, 240, color='black',linestyle="--")
ax[0,1].hlines(1, 0, 240,color='black',linestyle="--")
ax[0,1].vlines(best['delta_window'] + best['short_window'], -1.2, 2, color='blue',linestyle="--")

xs = [t['misc']['vals']['window'] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[1,0].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[1,0].set_title('$val$ $vs$ $window$ ', fontsize=18)
ax[1,0].set_xlabel('$window$', fontsize=16)
ax[1,0].set_ylabel('$val$', fontsize=16)
ax[1,0].hlines(0, 0, 240,color='black',linestyle="--")
ax[1,0].hlines(-1, 0, 240, color='black',linestyle="--")
ax[1,0].hlines(1, 0, 240,color='black',linestyle="--")
ax[1,0].vlines(best['window'], -1.2, 2, color='blue',linestyle="--")

xs = [t['misc']['vals']['a'] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[1,1].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[1,1].set_title('$val$ $vs$ $a$ ', fontsize=18)
ax[1,1].set_xlabel('$a$', fontsize=16)
ax[1,1].set_ylabel('$val$', fontsize=16)
ax[1,1].hlines(0, 0, 3,color='black',linestyle="--")
ax[1,1].hlines(-1, 0, 3, color='black',linestyle="--")
ax[1,1].hlines(1, 0, 3,color='black',linestyle="--")
ax[1,1].vlines(best['a'], -1.2, 2, color='blue',linestyle="--")
