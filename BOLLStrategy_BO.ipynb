# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

from BayesianOptimization.bayesian_optimization import BayesianOptimization

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from BOLLStrategy import BOLLStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
def run_backtest(config, trading_data, ohlc_data, window, a):
    window = int(window)
    config['title'] = "BOLLStrategy" + "_" + str(window) + "_" + str(a)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")

    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data=trading_data, ohlc_data=ohlc_data
    )
    strategy = BOLLStrategy(config, events_queue, data_handler,
                            window = window, a = a)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler=data_handler)

    results = backtest.start_trading()

    # dict_ans = {
    #     "window": [window],
    #     "a": [a],
    #     "Sharpe Ratio": [results['sharpe']],
    #     "Total Returns": [(results['cum_returns'][-1] - 1)],
    #     "Max Drawdown": [(results["max_drawdown"] * 100.0)],
    #     "Max Drawdown Duration": [(results['max_drawdown_duration'])],
    #     "Trades": [results['trade_info']['trading_num']],
    #     "Trade Winning": [results['trade_info']['win_pct']],
    #     "Average Trade": [results['trade_info']['avg_trd_pct']],
    #     "Average Win": [results['trade_info']['avg_win_pct']],
    #     "Average Loss": [results['trade_info']['avg_loss_pct']],
    #     "Best Trade": [results['trade_info']['max_win_pct']],
    #     "Worst Trade": [results['trade_info']['max_loss_pct']],
    #     "Worst Trade Date": [results['trade_info']['max_loss_dt']],
    #     "Avg Days in Trade": [results['trade_info']['avg_dit']]
    # }
    # return pd.DataFrame(dict_ans)
    return (results['cum_returns'][-1] - 1)

# %% [markdown]
# ## Setting

# %%
config = {
    "csv_dir": "C:/backtest/Binance",
    "out_dir": "C:/backtest/results/BOLLStrategy",
    "title": "BOLLStrategy",
    "is_plot": False,
    "save_plot": False,
    "save_tradelog": False,
    "start_date": pd.Timestamp("2017-07-01T00:0:00", freq="60" + "T"),  # str(freq) + "T"
    "end_date": pd.Timestamp("2018-09-01T00:00:00", freq="60" + "T"),
    "equity": 1.0,
    "freq": 60,  # min
    "commission_ratio": 0.001,
    "suggested_quantity": None,  # None or a value
    "max_quantity": None,  # None or a value, Maximum purchase quantity
    "min_quantity": None,  # None or a value, Minimum purchase quantity
    "min_handheld_cash": None,  # None or a value, Minimum handheld funds
    "exchange": "Binance",
    "tickers": ['BTCUSDT']
}

# %%
# trading_data = {}
# for ticker in config['tickers']:
#     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
#     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

ohlc_data = {}
for ticker in config['tickers']:
    # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
    ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker +'_OHLC_60min.h5', key=ticker)

trading_data = None

# %%
gp_params = {"alpha": 1e-5}

# %% [markdown]
# ## Acquisition Function "Upper Confidence Bound"

# %% [markdown]
# * Prefer exploitation (kappa=1.0)
#
# * Prefer exploration (kappa=10)

# %%
BO = BayesianOptimization(
    run_backtest,
    pbounds = {'window': (1, 240),
                'a': (0.1, 3)},
    is_int=[1, 0],
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
BO.explore({
        'window': np.arange(1, 240, 24),
        'a': np.arange(0.1, 3, 0.3)
    },
    eager=True)
BO.maximize(init_points=0, n_iter=10, acq='ucb', kappa=5, **gp_params)
# Out:
# ---------------------------------
# BOLLStrategy_1_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: N/A
# Average Trade: N/A
# Average Win: N/A
# Average Loss: N/A
# Best Trade: N/A
# Worst Trade: N/A
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     1 | 00m02s |    0.00000 | 0.100000 | 1.000000 |
# ---------------------------------
# BOLLStrategy_25_0.4
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8912169212
# Max Drawdown: 44.3071087615
# Max Drawdown Duration: 5604
# Total Returns: 0.3607543829
# ---------------------------------
# Trades: 186
# Trade Winning: 29%
# Average Trade: 0.48%
# Average Win: 6.02%
# Average Loss: -1.79%
# Best Trade: 30.83%
# Worst Trade: -10.28%
# Worst Trade Date: 0 days 12:00:00
# Avg Days in Trade: 0 days 19:06:08
# ---------------------------------
#     2 | 00m06s |    0.36075 | 0.400000 | 25.000000 |
# ---------------------------------
# BOLLStrategy_49_0.7000000000000001
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3904384345
# Max Drawdown: 39.8782511537
# Max Drawdown Duration: 5604
# Total Returns: 0.8445552349
# ---------------------------------
# Trades: 69
# Trade Winning: 36%
# Average Trade: 1.40%
# Average Win: 9.23%
# Average Loss: -3.05%
# Best Trade: 39.78%
# Worst Trade: -13.33%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 2 days 03:53:03
# ---------------------------------
#     3 | 00m07s |    0.84456 | 0.700000 | 49.000000 |
# ---------------------------------
# BOLLStrategy_73_1.0000000000000002
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3875335218
# Max Drawdown: 40.9794866110
# Max Drawdown Duration: 5830
# Total Returns: 0.8161700081
# ---------------------------------
# Trades: 42
# Trade Winning: 33%
# Average Trade: 2.02%
# Average Win: 13.30%
# Average Loss: -3.61%
# Best Trade: 24.98%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 3 days 07:24:17
# ---------------------------------
#     4 | 00m09s |    0.81617 | 1.000000 | 73.000000 |
# ---------------------------------
# BOLLStrategy_97_1.3000000000000003
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9774932568
# Max Drawdown: 52.2379305497
# Max Drawdown Duration: 5830
# Total Returns: 0.4222728303
# ---------------------------------
# Trades: 28
# Trade Winning: 43%
# Average Trade: 2.00%
# Average Win: 12.21%
# Average Loss: -5.66%
# Best Trade: 24.67%
# Worst Trade: -14.75%
# Worst Trade Date: 2 days 09:00:00
# Avg Days in Trade: 5 days 05:06:26
# ---------------------------------
#     5 | 00m12s |    0.42227 | 1.300000 | 97.000000 |
# ---------------------------------
# BOLLStrategy_121_1.6000000000000003
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0177390511
# Max Drawdown: 49.0568299851
# Max Drawdown Duration: 5604
# Total Returns: 1.5564147597
# ---------------------------------
# Trades: 16
# Trade Winning: 44%
# Average Trade: 10.04%
# Average Win: 31.78%
# Average Loss: -6.88%
# Best Trade: 140.39%
# Worst Trade: -18.40%
# Worst Trade Date: 3 days 14:00:00
# Avg Days in Trade: 9 days 04:48:45
# ---------------------------------
#     6 | 00m13s |    1.55641 | 1.600000 | 121.000000 |
# ---------------------------------
# BOLLStrategy_145_1.9000000000000004
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0957445381
# Max Drawdown: 37.8251214067
# Max Drawdown Duration: 5604
# Total Returns: 1.4697293372
# ---------------------------------
# Trades: 12
# Trade Winning: 50%
# Average Trade: 11.69%
# Average Win: 30.42%
# Average Loss: -7.04%
# Best Trade: 119.62%
# Worst Trade: -10.28%
# Worst Trade Date: 2 days 09:00:00
# Avg Days in Trade: 11 days 14:55:00
# ---------------------------------
#     7 | 00m21s |    1.46973 | 1.900000 | 145.000000 |
# ---------------------------------
# BOLLStrategy_169_2.2000000000000006
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0326030464
# Max Drawdown: 44.3610985128
# Max Drawdown Duration: 5604
# Total Returns: 1.3445433858
# ---------------------------------
# Trades: 8
# Trade Winning: 62%
# Average Trade: 15.59%
# Average Win: 31.30%
# Average Loss: -10.60%
# Best Trade: 101.85%
# Worst Trade: -15.66%
# Worst Trade Date: 4 days 23:00:00
# Avg Days in Trade: 16 days 03:37:30
# ---------------------------------
#     8 | 00m21s |    1.34454 | 2.200000 | 169.000000 |
# ---------------------------------
# BOLLStrategy_193_2.5000000000000004
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4934420993
# Max Drawdown: 42.3142842700
# Max Drawdown Duration: 5604
# Total Returns: 0.7965731069
# ---------------------------------
# Trades: 7
# Trade Winning: 71%
# Average Trade: 11.33%
# Average Win: 20.55%
# Average Loss: -11.72%
# Best Trade: 65.52%
# Worst Trade: -19.94%
# Worst Trade Date: 5 days 17:00:00
# Avg Days in Trade: 16 days 09:51:26
# ---------------------------------
#     9 | 00m28s |    0.79657 | 2.500000 | 193.000000 |
# ---------------------------------
# BOLLStrategy_217_2.8000000000000003
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4671821627
# Max Drawdown: 58.9358830556
# Max Drawdown Duration: 5604
# Total Returns: 0.0696521272
# ---------------------------------
# Trades: 5
# Trade Winning: 60%
# Average Trade: 6.63%
# Average Win: 23.66%
# Average Loss: -18.91%
# Best Trade: 51.66%
# Worst Trade: -34.53%
# Worst Trade Date: 10 days 16:00:00
# Avg Days in Trade: 19 days 14:00:00
# ---------------------------------
#    10 | 00m29s |    0.06965 | 2.800000 | 217.000000 |
# Initialization
# -----------------------------------------------------
#  Step |   Time |      Value |         a |    window |
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         a |    window |
# ---------------------------------
# BOLLStrategy_132_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1309545969
# Max Drawdown: 53.4794344911
# Max Drawdown Duration: 5830
# Total Returns: 0.5624907279
# ---------------------------------
# Trades: 79
# Trade Winning: 25%
# Average Trade: 1.03%
# Average Win: 10.42%
# Average Loss: -2.15%
# Best Trade: 36.97%
# Worst Trade: -9.40%
# Worst Trade Date: 1 days 12:00:00
# Avg Days in Trade: 1 days 21:40:15
# ---------------------------------
#    11 | 00m13s |    0.56249 | 0.100000 | 132.000000 |
# ---------------------------------
# BOLLStrategy_180_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6236176503
# Max Drawdown: 55.0785667380
# Max Drawdown Duration: 5604
# Total Returns: 1.0583022310
# ---------------------------------
# Trades: 52
# Trade Winning: 25%
# Average Trade: 2.03%
# Average Win: 15.51%
# Average Loss: -2.47%
# Best Trade: 34.74%
# Worst Trade: -8.34%
# Worst Trade Date: 1 days 13:00:00
# Avg Days in Trade: 2 days 20:39:14
# ---------------------------------
#    12 | 00m14s |    1.05830 | 0.100000 | 180.000000 |
# ---------------------------------
# BOLLStrategy_175_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7375175677
# Max Drawdown: 29.1690662155
# Max Drawdown Duration: 5604
# Total Returns: 0.9831761246
# ---------------------------------
# Trades: 5
# Trade Winning: 80%
# Average Trade: 16.96%
# Average Win: 21.20%
# Average Loss: -0.03%
# Best Trade: 63.53%
# Worst Trade: -0.03%
# Worst Trade Date: 41 days 04:00:00
# Avg Days in Trade: 22 days 14:12:00
# ---------------------------------
#    13 | 00m14s |    0.98318 | 3.000000 | 175.000000 |
# ---------------------------------
# BOLLStrategy_60_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1304962756
# Max Drawdown: 59.4467593960
# Max Drawdown Duration: 5604
# Total Returns: 0.5765437509
# ---------------------------------
# Trades: 9
# Trade Winning: 56%
# Average Trade: 10.64%
# Average Win: 31.00%
# Average Loss: -14.82%
# Best Trade: 101.01%
# Worst Trade: -40.43%
# Worst Trade Date: 67 days 23:00:00
# Avg Days in Trade: 18 days 04:00:00
# ---------------------------------
#    14 | 00m07s |    0.57654 | 3.000000 | 60.000000 |
# ---------------------------------
# BOLLStrategy_66_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7524432269
# Max Drawdown: 56.7078972727
# Max Drawdown Duration: 5830
# Total Returns: 0.2509390661
# ---------------------------------
# Trades: 133
# Trade Winning: 27%
# Average Trade: 0.55%
# Average Win: 7.37%
# Average Loss: -1.97%
# Best Trade: 41.88%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 03:20:18
# ---------------------------------
#    15 | 00m08s |    0.25094 | 0.100000 | 66.000000 |
# ---------------------------------
# BOLLStrategy_13_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5412452588
# Max Drawdown: 37.5869503708
# Max Drawdown Duration: 2587
# Total Returns: 0.9956348223
# ---------------------------------
# Trades: 19
# Trade Winning: 42%
# Average Trade: 4.68%
# Average Win: 16.63%
# Average Loss: -4.02%
# Best Trade: 32.70%
# Worst Trade: -10.79%
# Worst Trade Date: 7 days 10:00:00
# Avg Days in Trade: 7 days 20:53:41
# ---------------------------------
#    16 | 00m04s |    0.99563 | 3.000000 | 13.000000 |
# ---------------------------------
# BOLLStrategy_156_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9757605346
# Max Drawdown: 27.7938177643
# Max Drawdown Duration: 3338
# Total Returns: 1.2409570048
# ---------------------------------
# Trades: 5
# Trade Winning: 80%
# Average Trade: 19.78%
# Average Win: 25.03%
# Average Loss: -1.20%
# Best Trade: 65.52%
# Worst Trade: -1.20%
# Worst Trade Date: 41 days 05:00:00
# Avg Days in Trade: 22 days 22:00:00
# ---------------------------------
#    17 | 00m14s |    1.24096 | 3.000000 | 156.000000 |
# ---------------------------------
# BOLLStrategy_110_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6958044559
# Max Drawdown: 62.7058276818
# Max Drawdown Duration: 5604
# Total Returns: 0.2078457017
# ---------------------------------
# Trades: 6
# Trade Winning: 67%
# Average Trade: 9.08%
# Average Win: 27.17%
# Average Loss: -27.08%
# Best Trade: 69.43%
# Worst Trade: -45.15%
# Worst Trade Date: 8 days 13:00:00
# Avg Days in Trade: 17 days 03:10:00
# ---------------------------------
#    18 | 00m11s |    0.20785 | 3.000000 | 110.000000 |
# ---------------------------------
# BOLLStrategy_9_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -2.5442524313
# Max Drawdown: 89.5959668363
# Max Drawdown Duration: 5830
# Total Returns: -0.8212206843
# ---------------------------------
# Trades: 606
# Trade Winning: 28%
# Average Trade: -0.05%
# Average Win: 2.67%
# Average Loss: -1.11%
# Best Trade: 14.31%
# Worst Trade: -8.80%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 06:03:22
# ---------------------------------
#    19 | 00m04s |   -0.82122 | 0.100000 | 9.000000 |
# ---------------------------------
# BOLLStrategy_84_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9939743949
# Max Drawdown: 35.9661093953
# Max Drawdown Duration: 5604
# Total Returns: 1.2271243292
# ---------------------------------
# Trades: 8
# Trade Winning: 50%
# Average Trade: 14.57%
# Average Win: 36.15%
# Average Loss: -7.01%
# Best Trade: 97.70%
# Worst Trade: -15.48%
# Worst Trade Date: 2 days 09:00:00
# Avg Days in Trade: 12 days 18:22:30
# ---------------------------------
#    20 | 00m09s |    1.22712 | 3.000000 | 84.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 1.5564147596551323, 'max_params': {'window': 121.0, 'a': 1.6000000000000003}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
Target.to_csv(config['out_dir'] + "/target_ucb.csv")
Target.sort_values(by = "Target")
# Out:
#                      Parameters    Target
# 18                   [9.0, 0.1] -0.821221
# 0                    [1.0, 0.1]  0.000000
# 9   [217.0, 2.8000000000000003]  0.069652
# 17                 [110.0, 3.0]  0.207846
# 14                  [66.0, 0.1]  0.250939
# 1                   [25.0, 0.4]  0.360754
# 4    [97.0, 1.3000000000000003]  0.422273
# 10                 [132.0, 0.1]  0.562491
# 13                  [60.0, 3.0]  0.576544
# 8   [193.0, 2.5000000000000004]  0.796573
# 3    [73.0, 1.0000000000000002]  0.816170
# 2    [49.0, 0.7000000000000001]  0.844555
# 12                 [175.0, 3.0]  0.983176
# 15                  [13.0, 3.0]  0.995635
# 11                 [180.0, 0.1]  1.058302
# 19                  [84.0, 3.0]  1.227124
# 16                 [156.0, 3.0]  1.240957
# 7   [169.0, 2.2000000000000006]  1.344543
# 6   [145.0, 1.9000000000000004]  1.469729
# 5   [121.0, 1.6000000000000003]  1.556415

# %% [markdown]
# ## Acquisition Function "Expected Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)

# %%
BO = BayesianOptimization(
    run_backtest,
    pbounds = {'window': (1, 240),
                'a': (0.1, 3)},
    is_int=[1, 0],
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
BO.explore({
        'window': np.arange(1, 240, 24),
        'a': np.arange(0.1, 3, 0.3)
    },
    eager=True)
BO.maximize(init_points=0, n_iter=10, acq="ei", xi=0.01, **gp_params)
# Out:
# ---------------------------------
# ADXStrategy_1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -6.9007275153
# Max Drawdown: 98.8338690249
# Max Drawdown Duration: 6661
# Total Returns: -0.9866560406
# ---------------------------------
# Trades: 1231
# Trade Winning: 38%
# Average Trade: -0.13%
# Average Win: 1.35%
# Average Loss: -1.04%
# Best Trade: 11.71%
# Worst Trade: -7.69%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 02:49:49
# ---------------------------------
#     1 | 00m04s |   -0.98666 | 1.000000 |
# ---------------------------------
# ADXStrategy_21
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5715412195
# Max Drawdown: 44.0459039139
# Max Drawdown Duration: 3858
# Total Returns: 0.9908953916
# ---------------------------------
# Trades: 234
# Trade Winning: 42%
# Average Trade: 0.59%
# Average Win: 3.44%
# Average Loss: -1.47%
# Best Trade: 31.17%
# Worst Trade: -9.52%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 0 days 13:16:09
# ---------------------------------
#     2 | 00m04s |    0.99090 | 21.000000 |
# ---------------------------------
# ADXStrategy_41
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5875275955
# Max Drawdown: 59.9307265688
# Max Drawdown Duration: 5371
# Total Returns: 0.1443933318
# ---------------------------------
# Trades: 175
# Trade Winning: 39%
# Average Trade: 0.37%
# Average Win: 3.36%
# Average Loss: -1.54%
# Best Trade: 25.07%
# Worst Trade: -6.98%
# Worst Trade Date: 0 days 18:00:00
# Avg Days in Trade: 0 days 17:49:22
# ---------------------------------
#     3 | 00m04s |    0.14439 | 41.000000 |
# ---------------------------------
# ADXStrategy_61
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8688237540
# Max Drawdown: 52.5145313917
# Max Drawdown Duration: 5830
# Total Returns: 0.3291361075
# ---------------------------------
# Trades: 125
# Trade Winning: 34%
# Average Trade: 0.56%
# Average Win: 5.17%
# Average Loss: -1.86%
# Best Trade: 27.06%
# Worst Trade: -9.55%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 0 days 23:57:36
# ---------------------------------
#     4 | 00m04s |    0.32914 | 61.000000 |
# ---------------------------------
# ADXStrategy_81
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5021898490
# Max Drawdown: 57.3275218982
# Max Drawdown Duration: 5830
# Total Returns: 0.0938114060
# ---------------------------------
# Trades: 119
# Trade Winning: 35%
# Average Trade: 0.42%
# Average Win: 4.82%
# Average Loss: -1.98%
# Best Trade: 30.15%
# Worst Trade: -10.43%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 1 days 00:41:21
# ---------------------------------
#     5 | 00m04s |    0.09381 | 81.000000 |
# ---------------------------------
# ADXStrategy_101
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7445200130
# Max Drawdown: 53.1600102521
# Max Drawdown Duration: 5830
# Total Returns: 0.2389377347
# ---------------------------------
# Trades: 105
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 4.22%
# Average Loss: -2.02%
# Best Trade: 24.74%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 03:27:26
# ---------------------------------
#     6 | 00m04s |    0.23894 | 101.000000 |
# ---------------------------------
# ADXStrategy_121
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5420596438
# Max Drawdown: 56.5896951304
# Max Drawdown Duration: 5830
# Total Returns: 0.1155193189
# ---------------------------------
# Trades: 100
# Trade Winning: 46%
# Average Trade: 0.46%
# Average Win: 3.40%
# Average Loss: -2.05%
# Best Trade: 29.30%
# Worst Trade: -12.39%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 1 days 04:06:00
# ---------------------------------
#     7 | 00m04s |    0.11552 | 121.000000 |
# ---------------------------------
# ADXStrategy_141
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3067396204
# Max Drawdown: 40.3329394527
# Max Drawdown Duration: 5830
# Total Returns: 0.6482326740
# ---------------------------------
# Trades: 86
# Trade Winning: 41%
# Average Trade: 0.95%
# Average Win: 4.82%
# Average Loss: -1.70%
# Best Trade: 27.98%
# Worst Trade: -9.79%
# Worst Trade Date: 0 days 12:00:00
# Avg Days in Trade: 1 days 07:30:42
# ---------------------------------
#     8 | 00m04s |    0.64823 | 141.000000 |
# ---------------------------------
# ADXStrategy_161
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7708650272
# Max Drawdown: 40.7294677642
# Max Drawdown Duration: 5830
# Total Returns: 0.2508738221
# ---------------------------------
# Trades: 83
# Trade Winning: 33%
# Average Trade: 0.64%
# Average Win: 5.60%
# Average Loss: -1.76%
# Best Trade: 29.49%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 08:28:55
# ---------------------------------
#     9 | 00m04s |    0.25087 | 161.000000 |
# ---------------------------------
# ADXStrategy_181
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9320243863
# Max Drawdown: 42.8976564485
# Max Drawdown Duration: 5830
# Total Returns: 0.3231417558
# ---------------------------------
# Trades: 68
# Trade Winning: 38%
# Average Trade: 0.75%
# Average Win: 4.77%
# Average Loss: -1.74%
# Best Trade: 23.84%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 14:57:21
# ---------------------------------
#    10 | 00m05s |    0.32314 | 181.000000 |
# ---------------------------------
# ADXStrategy_201
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6836614752
# Max Drawdown: 51.4784866060
# Max Drawdown Duration: 5830
# Total Returns: 0.2013883465
# ---------------------------------
# Trades: 70
# Trade Winning: 43%
# Average Trade: 0.60%
# Average Win: 4.27%
# Average Loss: -2.14%
# Best Trade: 20.71%
# Worst Trade: -10.11%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 1 days 13:54:00
# ---------------------------------
#    11 | 00m04s |    0.20139 | 201.000000 |
# ---------------------------------
# ADXStrategy_221
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2138615878
# Max Drawdown: 61.4626828553
# Max Drawdown Duration: 5830
# Total Returns: -0.0525022310
# ---------------------------------
# Trades: 68
# Trade Winning: 43%
# Average Trade: 0.35%
# Average Win: 4.51%
# Average Loss: -2.75%
# Best Trade: 39.17%
# Worst Trade: -15.78%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 1 days 14:11:28
# ---------------------------------
#    12 | 00m05s |   -0.05250 | 221.000000 |
# Initialization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# ---------------------------------
# ADXStrategy_22
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4364670989
# Max Drawdown: 36.0111502612
# Max Drawdown Duration: 3774
# Total Returns: 0.8445350169
# ---------------------------------
# Trades: 233
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 3.34%
# Average Loss: -1.42%
# Best Trade: 29.88%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 13:23:57
# ---------------------------------
#    13 | 00m06s |    0.84454 | 22.000000 |
# ---------------------------------
# ADXStrategy_17
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1563748685
# Max Drawdown: 42.8518722323
# Max Drawdown Duration: 3814
# Total Returns: 0.5808737331
# ---------------------------------
# Trades: 277
# Trade Winning: 43%
# Average Trade: 0.44%
# Average Win: 3.13%
# Average Loss: -1.58%
# Best Trade: 28.99%
# Worst Trade: -13.33%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 11:30:58
# ---------------------------------
#    14 | 00m06s |    0.58087 | 17.000000 |
# ---------------------------------
# ADXStrategy_38
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2963516724
# Max Drawdown: 60.2835713561
# Max Drawdown Duration: 5604
# Total Returns: -0.0188880136
# ---------------------------------
# Trades: 190
# Trade Winning: 38%
# Average Trade: 0.28%
# Average Win: 3.46%
# Average Loss: -1.70%
# Best Trade: 25.56%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 16:25:54
# ---------------------------------
#    15 | 00m06s |   -0.01889 | 38.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_149
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5190089079
# Max Drawdown: 52.9612173594
# Max Drawdown Duration: 5830
# Total Returns: 0.1079459960
# ---------------------------------
# Trades: 83
# Trade Winning: 30%
# Average Trade: 0.47%
# Average Win: 5.79%
# Average Loss: -1.82%
# Best Trade: 24.63%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 08:39:02
# ---------------------------------
#    16 | 00m06s |    0.10795 | 149.000000 |
# ---------------------------------
# ADXStrategy_110
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6737333525
# Max Drawdown: 52.0433752448
# Max Drawdown Duration: 5830
# Total Returns: 0.1967648199
# ---------------------------------
# Trades: 98
# Trade Winning: 32%
# Average Trade: 0.55%
# Average Win: 5.69%
# Average Loss: -1.83%
# Best Trade: 29.59%
# Worst Trade: -7.82%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 1 days 05:05:31
# ---------------------------------
#    17 | 00m06s |    0.19676 | 110.000000 |
# ---------------------------------
# ADXStrategy_236
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2293450394
# Max Drawdown: 39.2840697707
# Max Drawdown Duration: 4035
# Total Returns: 0.5468089025
# ---------------------------------
# Trades: 67
# Trade Winning: 43%
# Average Trade: 1.09%
# Average Win: 5.56%
# Average Loss: -2.32%
# Best Trade: 39.78%
# Worst Trade: -12.41%
# Worst Trade Date: 4 days 19:00:00
# Avg Days in Trade: 1 days 15:11:39
# ---------------------------------
#    18 | 00m06s |    0.54681 | 236.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_190
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4023495362
# Max Drawdown: 56.0101305368
# Max Drawdown Duration: 5830
# Total Returns: 0.0513166071
# ---------------------------------
# Trades: 65
# Trade Winning: 32%
# Average Trade: 0.43%
# Average Win: 5.72%
# Average Loss: -2.09%
# Best Trade: 22.11%
# Worst Trade: -10.14%
# Worst Trade Date: 2 days 04:00:00
# Avg Days in Trade: 1 days 16:14:46
# ---------------------------------
#    19 | 00m06s |    0.05132 | 190.000000 |
# ---------------------------------
# ADXStrategy_4
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -4.2798058076
# Max Drawdown: 94.8527064307
# Max Drawdown Duration: 5830
# Total Returns: -0.9271940982
# ---------------------------------
# Trades: 687
# Trade Winning: 34%
# Average Trade: -0.15%
# Average Win: 1.89%
# Average Loss: -1.23%
# Best Trade: 12.10%
# Worst Trade: -10.67%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 04:52:35
# ---------------------------------
#    20 | 00m06s |   -0.92719 | 4.000000 |
# ---------------------------------
# ADXStrategy_115
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6361060010
# Max Drawdown: 57.4643048709
# Max Drawdown Duration: 5830
# Total Returns: 0.1731259774
# ---------------------------------
# Trades: 101
# Trade Winning: 36%
# Average Trade: 0.52%
# Average Win: 5.10%
# Average Loss: -2.01%
# Best Trade: 30.51%
# Worst Trade: -16.16%
# Worst Trade Date: 1 days 03:00:00
# Avg Days in Trade: 1 days 04:08:19
# ---------------------------------
#    21 | 00m07s |    0.17313 | 115.000000 |
# ---------------------------------
# ADXStrategy_51
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2380120571
# Max Drawdown: 38.5596793090
# Max Drawdown Duration: 5830
# Total Returns: 0.6093880101
# ---------------------------------
# Trades: 151
# Trade Winning: 39%
# Average Trade: 0.62%
# Average Win: 3.98%
# Average Loss: -1.53%
# Best Trade: 25.56%
# Worst Trade: -7.27%
# Worst Trade Date: 1 days 08:00:00
# Avg Days in Trade: 0 days 19:58:01
# ---------------------------------
#    22 | 00m06s |    0.60939 | 51.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 0.9908953915556202, 'max_params': {'window': 21.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
# Target.to_csv(config['out_dir'] + "/target_ei.csv")
Target.sort_values(by = "Target")
# Out:
#    Parameters    Target
# 0       [1.0] -0.986656
# 19      [4.0] -0.927194
# 11    [221.0] -0.052502
# 14     [38.0] -0.018888
# 18    [190.0]  0.051317
# 4      [81.0]  0.093811
# 15    [149.0]  0.107946
# 6     [121.0]  0.115519
# 2      [41.0]  0.144393
# 20    [115.0]  0.173126
# 16    [110.0]  0.196765
# 10    [201.0]  0.201388
# 5     [101.0]  0.238938
# 8     [161.0]  0.250874
# 9     [181.0]  0.323142
# 3      [61.0]  0.329136
# 17    [236.0]  0.546809
# 13     [17.0]  0.580874
# 21     [51.0]  0.609388
# 7     [141.0]  0.648233
# 12     [22.0]  0.844535
# 1      [21.0]  0.990895

# %%
BO.maximize(init_points=0, n_iter=10, acq="ei", xi=0.0001, **gp_params)
# Out:
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# ---------------------------------
# ADXStrategy_70
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6488930882
# Max Drawdown: 34.2953464468
# Max Drawdown Duration: 5830
# Total Returns: 1.0160987241
# ---------------------------------
# Trades: 119
# Trade Winning: 38%
# Average Trade: 0.92%
# Average Win: 4.89%
# Average Loss: -1.49%
# Best Trade: 27.64%
# Worst Trade: -9.62%
# Worst Trade Date: 1 days 17:00:00
# Avg Days in Trade: 1 days 00:38:49
# ---------------------------------
#    23 | 00m06s |    1.01610 | 70.000000 |
# ---------------------------------
# ADXStrategy_133
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2030790992
# Max Drawdown: 51.1328806398
# Max Drawdown Duration: 5830
# Total Returns: 0.5894124807
# ---------------------------------
# Trades: 79
# Trade Winning: 42%
# Average Trade: 0.97%
# Average Win: 4.94%
# Average Loss: -1.89%
# Best Trade: 28.46%
# Worst Trade: -10.39%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 1 days 10:36:27
# ---------------------------------
#    24 | 00m06s |    0.58941 | 133.000000 |
# ---------------------------------
# ADXStrategy_171
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7451914441
# Max Drawdown: 43.6447459039
# Max Drawdown Duration: 5830
# Total Returns: 0.2322777431
# ---------------------------------
# Trades: 71
# Trade Winning: 35%
# Average Trade: 0.63%
# Average Win: 5.03%
# Average Loss: -1.76%
# Best Trade: 24.84%
# Worst Trade: -9.22%
# Worst Trade Date: 2 days 23:00:00
# Avg Days in Trade: 1 days 13:27:53
# ---------------------------------
#    25 | 00m06s |    0.23228 | 171.000000 |
# ---------------------------------
# ADXStrategy_73
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8653665522
# Max Drawdown: 50.8218232029
# Max Drawdown Duration: 5830
# Total Returns: 0.3170209232
# ---------------------------------
# Trades: 127
# Trade Winning: 40%
# Average Trade: 0.53%
# Average Win: 3.60%
# Average Loss: -1.54%
# Best Trade: 28.07%
# Worst Trade: -16.62%
# Worst Trade Date: 1 days 20:00:00
# Avg Days in Trade: 0 days 23:14:10
# ---------------------------------
#    26 | 00m06s |    0.31702 | 73.000000 |
# ---------------------------------
# ADXStrategy_68
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4264329934
# Max Drawdown: 41.7933314453
# Max Drawdown Duration: 5830
# Total Returns: 0.8129727390
# ---------------------------------
# Trades: 128
# Trade Winning: 37%
# Average Trade: 0.80%
# Average Win: 4.88%
# Average Loss: -1.57%
# Best Trade: 28.67%
# Worst Trade: -10.13%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 0 days 23:14:32
# ---------------------------------
#    27 | 00m06s |    0.81297 | 68.000000 |
# ---------------------------------
# ADXStrategy_91
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7798202755
# Max Drawdown: 51.8123766908
# Max Drawdown Duration: 5830
# Total Returns: 0.2629148580
# ---------------------------------
# Trades: 110
# Trade Winning: 35%
# Average Trade: 0.57%
# Average Win: 5.09%
# Average Loss: -1.81%
# Best Trade: 29.70%
# Worst Trade: -10.21%
# Worst Trade Date: 1 days 03:00:00
# Avg Days in Trade: 1 days 02:09:49
# ---------------------------------
#    28 | 00m06s |    0.26291 | 91.000000 |
# ---------------------------------
# ADXStrategy_36
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6272251114
# Max Drawdown: 55.8328247810
# Max Drawdown Duration: 5371
# Total Returns: 0.1675062830
# ---------------------------------
# Trades: 190
# Trade Winning: 38%
# Average Trade: 0.38%
# Average Win: 3.63%
# Average Loss: -1.60%
# Best Trade: 27.23%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 16:38:13
# ---------------------------------
#    29 | 00m06s |    0.16751 | 36.000000 |
# ---------------------------------
# ADXStrategy_185
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7604143547
# Max Drawdown: 46.3124508389
# Max Drawdown Duration: 5830
# Total Returns: 0.2325964670
# ---------------------------------
# Trades: 69
# Trade Winning: 42%
# Average Trade: 0.65%
# Average Win: 4.62%
# Average Loss: -2.23%
# Best Trade: 22.11%
# Worst Trade: -7.75%
# Worst Trade Date: 3 days 00:00:00
# Avg Days in Trade: 1 days 13:54:47
# ---------------------------------
#    30 | 00m06s |    0.23260 | 185.000000 |
# ---------------------------------
# ADXStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6548398811
# Max Drawdown: 59.6558552739
# Max Drawdown Duration: 5830
# Total Returns: 0.1840274616
# ---------------------------------
# Trades: 81
# Trade Winning: 28%
# Average Trade: 0.63%
# Average Win: 7.48%
# Average Loss: -2.09%
# Best Trade: 28.61%
# Worst Trade: -10.06%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 1 days 09:31:07
# ---------------------------------
#    31 | 00m06s |    0.18403 | 138.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_155
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6633756004
# Max Drawdown: 48.5414742562
# Max Drawdown Duration: 5830
# Total Returns: 0.1896251462
# ---------------------------------
# Trades: 84
# Trade Winning: 36%
# Average Trade: 0.55%
# Average Win: 5.27%
# Average Loss: -2.06%
# Best Trade: 23.67%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 07:57:09
# ---------------------------------
#    32 | 00m06s |    0.18963 | 155.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 1.0160987241398645, 'max_params': {'window': 70.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
Target.to_csv(config['out_dir'] + "/target_ei.csv")
Target.sort_values(by = "Target")
# Out:
#    Parameters    Target
# 0       [1.0] -0.986656
# 19     [11.0] -0.421099
# 11    [221.0] -0.052502
# 4      [81.0]  0.093811
# 6     [121.0]  0.115519
# 2      [41.0]  0.144393
# 16    [138.0]  0.184027
# 10    [201.0]  0.201388
# 18     [48.0]  0.210086
# 15    [144.0]  0.232713
# 5     [101.0]  0.238938
# 8     [161.0]  0.250874
# 20    [108.0]  0.296877
# 21    [174.0]  0.298496
# 9     [181.0]  0.323142
# 3      [61.0]  0.329136
# 17     [56.0]  0.506941
# 13     [52.0]  0.595981
# 7     [141.0]  0.648233
# 14     [20.0]  0.831492
# 12     [22.0]  0.844535
# 1      [21.0]  0.990895

# %% [markdown]
# ## Acquisition Function "Probability of Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)

# %%
BO = BayesianOptimization(
    run_backtest,
    pbounds = {'window': (1, 240),
                'a': (0.1, 3)},
    is_int=[1, 0],
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
BO.explore({
        'window': np.arange(1, 240, 24),
        'a': np.arange(0.1, 3, 0.3)
    },
    eager=True)
BO.maximize(init_points=0, n_iter=10, acq="poi", xi=0.01, **gp_params)
# Out:
# ---------------------------------
# ADXStrategy_1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -6.9007275153
# Max Drawdown: 98.8338690249
# Max Drawdown Duration: 6661
# Total Returns: -0.9866560406
# ---------------------------------
# Trades: 1231
# Trade Winning: 38%
# Average Trade: -0.13%
# Average Win: 1.35%
# Average Loss: -1.04%
# Best Trade: 11.71%
# Worst Trade: -7.69%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 02:49:49
# ---------------------------------
#     1 | 00m05s |   -0.98666 | 1.000000 |
# ---------------------------------
# ADXStrategy_21
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5715412195
# Max Drawdown: 44.0459039139
# Max Drawdown Duration: 3858
# Total Returns: 0.9908953916
# ---------------------------------
# Trades: 234
# Trade Winning: 42%
# Average Trade: 0.59%
# Average Win: 3.44%
# Average Loss: -1.47%
# Best Trade: 31.17%
# Worst Trade: -9.52%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 0 days 13:16:09
# ---------------------------------
#     2 | 00m05s |    0.99090 | 21.000000 |
# ---------------------------------
# ADXStrategy_41
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5875275955
# Max Drawdown: 59.9307265688
# Max Drawdown Duration: 5371
# Total Returns: 0.1443933318
# ---------------------------------
# Trades: 175
# Trade Winning: 39%
# Average Trade: 0.37%
# Average Win: 3.36%
# Average Loss: -1.54%
# Best Trade: 25.07%
# Worst Trade: -6.98%
# Worst Trade Date: 0 days 18:00:00
# Avg Days in Trade: 0 days 17:49:22
# ---------------------------------
#     3 | 00m05s |    0.14439 | 41.000000 |
# ---------------------------------
# ADXStrategy_61
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8688237540
# Max Drawdown: 52.5145313917
# Max Drawdown Duration: 5830
# Total Returns: 0.3291361075
# ---------------------------------
# Trades: 125
# Trade Winning: 34%
# Average Trade: 0.56%
# Average Win: 5.17%
# Average Loss: -1.86%
# Best Trade: 27.06%
# Worst Trade: -9.55%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 0 days 23:57:36
# ---------------------------------
#     4 | 00m05s |    0.32914 | 61.000000 |
# ---------------------------------
# ADXStrategy_81
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5021898490
# Max Drawdown: 57.3275218982
# Max Drawdown Duration: 5830
# Total Returns: 0.0938114060
# ---------------------------------
# Trades: 119
# Trade Winning: 35%
# Average Trade: 0.42%
# Average Win: 4.82%
# Average Loss: -1.98%
# Best Trade: 30.15%
# Worst Trade: -10.43%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 1 days 00:41:21
# ---------------------------------
#     5 | 00m05s |    0.09381 | 81.000000 |
# ---------------------------------
# ADXStrategy_101
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7445200130
# Max Drawdown: 53.1600102521
# Max Drawdown Duration: 5830
# Total Returns: 0.2389377347
# ---------------------------------
# Trades: 105
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 4.22%
# Average Loss: -2.02%
# Best Trade: 24.74%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 03:27:26
# ---------------------------------
#     6 | 00m04s |    0.23894 | 101.000000 |
# ---------------------------------
# ADXStrategy_121
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5420596438
# Max Drawdown: 56.5896951304
# Max Drawdown Duration: 5830
# Total Returns: 0.1155193189
# ---------------------------------
# Trades: 100
# Trade Winning: 46%
# Average Trade: 0.46%
# Average Win: 3.40%
# Average Loss: -2.05%
# Best Trade: 29.30%
# Worst Trade: -12.39%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 1 days 04:06:00
# ---------------------------------
#     7 | 00m04s |    0.11552 | 121.000000 |
# ---------------------------------
# ADXStrategy_141
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3067396204
# Max Drawdown: 40.3329394527
# Max Drawdown Duration: 5830
# Total Returns: 0.6482326740
# ---------------------------------
# Trades: 86
# Trade Winning: 41%
# Average Trade: 0.95%
# Average Win: 4.82%
# Average Loss: -1.70%
# Best Trade: 27.98%
# Worst Trade: -9.79%
# Worst Trade Date: 0 days 12:00:00
# Avg Days in Trade: 1 days 07:30:42
# ---------------------------------
#     8 | 00m05s |    0.64823 | 141.000000 |
# ---------------------------------
# ADXStrategy_161
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7708650272
# Max Drawdown: 40.7294677642
# Max Drawdown Duration: 5830
# Total Returns: 0.2508738221
# ---------------------------------
# Trades: 83
# Trade Winning: 33%
# Average Trade: 0.64%
# Average Win: 5.60%
# Average Loss: -1.76%
# Best Trade: 29.49%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 08:28:55
# ---------------------------------
#     9 | 00m04s |    0.25087 | 161.000000 |
# ---------------------------------
# ADXStrategy_181
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9320243863
# Max Drawdown: 42.8976564485
# Max Drawdown Duration: 5830
# Total Returns: 0.3231417558
# ---------------------------------
# Trades: 68
# Trade Winning: 38%
# Average Trade: 0.75%
# Average Win: 4.77%
# Average Loss: -1.74%
# Best Trade: 23.84%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 14:57:21
# ---------------------------------
#    10 | 00m04s |    0.32314 | 181.000000 |
# ---------------------------------
# ADXStrategy_201
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6836614752
# Max Drawdown: 51.4784866060
# Max Drawdown Duration: 5830
# Total Returns: 0.2013883465
# ---------------------------------
# Trades: 70
# Trade Winning: 43%
# Average Trade: 0.60%
# Average Win: 4.27%
# Average Loss: -2.14%
# Best Trade: 20.71%
# Worst Trade: -10.11%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 1 days 13:54:00
# ---------------------------------
#    11 | 00m04s |    0.20139 | 201.000000 |
# ---------------------------------
# ADXStrategy_221
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2138615878
# Max Drawdown: 61.4626828553
# Max Drawdown Duration: 5830
# Total Returns: -0.0525022310
# ---------------------------------
# Trades: 68
# Trade Winning: 43%
# Average Trade: 0.35%
# Average Win: 4.51%
# Average Loss: -2.75%
# Best Trade: 39.17%
# Worst Trade: -15.78%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 1 days 14:11:28
# ---------------------------------
#    12 | 00m04s |   -0.05250 | 221.000000 |
# Initialization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# ---------------------------------
# ADXStrategy_22
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4364670989
# Max Drawdown: 36.0111502612
# Max Drawdown Duration: 3774
# Total Returns: 0.8445350169
# ---------------------------------
# Trades: 233
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 3.34%
# Average Loss: -1.42%
# Best Trade: 29.88%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 13:23:57
# ---------------------------------
#    13 | 00m05s |    0.84454 | 22.000000 |
# ---------------------------------
# ADXStrategy_52
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2047532899
# Max Drawdown: 40.0044633116
# Max Drawdown Duration: 4781
# Total Returns: 0.5959807336
# ---------------------------------
# Trades: 152
# Trade Winning: 38%
# Average Trade: 0.62%
# Average Win: 4.18%
# Average Loss: -1.58%
# Best Trade: 25.07%
# Worst Trade: -5.73%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 19:52:30
# ---------------------------------
#    14 | 00m05s |    0.59598 | 52.000000 |
# ---------------------------------
# ADXStrategy_20
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4153726655
# Max Drawdown: 44.2268949807
# Max Drawdown Duration: 3724
# Total Returns: 0.8314923847
# ---------------------------------
# Trades: 241
# Trade Winning: 40%
# Average Trade: 0.53%
# Average Win: 3.43%
# Average Loss: -1.42%
# Best Trade: 31.17%
# Worst Trade: -7.86%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 12:57:31
# ---------------------------------
#    15 | 00m05s |    0.83149 | 20.000000 |
# ---------------------------------
# ADXStrategy_144
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7270559361
# Max Drawdown: 52.5703341320
# Max Drawdown Duration: 5830
# Total Returns: 0.2327131467
# ---------------------------------
# Trades: 86
# Trade Winning: 35%
# Average Trade: 0.61%
# Average Win: 5.06%
# Average Loss: -1.78%
# Best Trade: 25.27%
# Worst Trade: -9.13%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 07:36:59
# ---------------------------------
#    16 | 00m06s |    0.23271 | 144.000000 |
# ---------------------------------
# ADXStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6548398811
# Max Drawdown: 59.6558552739
# Max Drawdown Duration: 5830
# Total Returns: 0.1840274616
# ---------------------------------
# Trades: 81
# Trade Winning: 28%
# Average Trade: 0.63%
# Average Win: 7.48%
# Average Loss: -2.09%
# Best Trade: 28.61%
# Worst Trade: -10.06%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 1 days 09:31:07
# ---------------------------------
#    17 | 00m06s |    0.18403 | 138.000000 |
# ---------------------------------
# ADXStrategy_56
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1103352735
# Max Drawdown: 42.0946006265
# Max Drawdown Duration: 5830
# Total Returns: 0.5069405657
# ---------------------------------
# Trades: 141
# Trade Winning: 35%
# Average Trade: 0.61%
# Average Win: 4.66%
# Average Loss: -1.55%
# Best Trade: 23.29%
# Worst Trade: -8.76%
# Worst Trade Date: 1 days 20:00:00
# Avg Days in Trade: 0 days 21:22:33
# ---------------------------------
#    18 | 00m06s |    0.50694 | 56.000000 |
# ---------------------------------
# ADXStrategy_48
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6922403360
# Max Drawdown: 54.0822412554
# Max Drawdown Duration: 5830
# Total Returns: 0.2100855978
# ---------------------------------
# Trades: 161
# Trade Winning: 37%
# Average Trade: 0.42%
# Average Win: 3.92%
# Average Loss: -1.60%
# Best Trade: 26.55%
# Worst Trade: -9.40%
# Worst Trade Date: 1 days 12:00:00
# Avg Days in Trade: 0 days 19:00:22
# ---------------------------------
#    19 | 00m06s |    0.21009 | 48.000000 |
# ---------------------------------
# ADXStrategy_11
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.6883505718
# Max Drawdown: 71.2006353477
# Max Drawdown Duration: 5604
# Total Returns: -0.4210990306
# ---------------------------------
# Trades: 376
# Trade Winning: 36%
# Average Trade: 0.10%
# Average Win: 2.74%
# Average Loss: -1.37%
# Best Trade: 16.35%
# Worst Trade: -8.72%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 08:35:16
# ---------------------------------
#    20 | 00m05s |   -0.42110 | 11.000000 |
# ---------------------------------
# ADXStrategy_108
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8457720252
# Max Drawdown: 49.2165116646
# Max Drawdown Duration: 5830
# Total Returns: 0.2968767811
# ---------------------------------
# Trades: 101
# Trade Winning: 39%
# Average Trade: 0.60%
# Average Win: 4.33%
# Average Loss: -1.75%
# Best Trade: 29.63%
# Worst Trade: -7.51%
# Worst Trade Date: 2 days 21:00:00
# Avg Days in Trade: 1 days 04:24:21
# ---------------------------------
#    21 | 00m05s |    0.29688 | 108.000000 |
# ---------------------------------
# ADXStrategy_174
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8579634914
# Max Drawdown: 43.9820447360
# Max Drawdown Duration: 5830
# Total Returns: 0.2984961355
# ---------------------------------
# Trades: 81
# Trade Winning: 43%
# Average Trade: 0.65%
# Average Win: 3.90%
# Average Loss: -1.83%
# Best Trade: 25.12%
# Worst Trade: -6.34%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 08:34:49
# ---------------------------------
#    22 | 00m05s |    0.29850 | 174.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 0.9908953915556202, 'max_params': {'window': 21.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
# Target.to_csv(config['out_dir'] + "/target_pi.csv")
Target.sort_values(by = "Target")
# Out:
#    Parameters    Target
# 0       [1.0] -0.986656
# 19     [11.0] -0.421099
# 11    [221.0] -0.052502
# 4      [81.0]  0.093811
# 6     [121.0]  0.115519
# 2      [41.0]  0.144393
# 16    [138.0]  0.184027
# 10    [201.0]  0.201388
# 18     [48.0]  0.210086
# 15    [144.0]  0.232713
# 5     [101.0]  0.238938
# 8     [161.0]  0.250874
# 20    [108.0]  0.296877
# 21    [174.0]  0.298496
# 9     [181.0]  0.323142
# 3      [61.0]  0.329136
# 17     [56.0]  0.506941
# 13     [52.0]  0.595981
# 7     [141.0]  0.648233
# 14     [20.0]  0.831492
# 12     [22.0]  0.844535
# 1      [21.0]  0.990895

# %%
BO.maximize(init_points=0, n_iter=10, acq="poi", xi=0.0001, **gp_params)
# Out:
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# ---------------------------------
# ADXStrategy_69
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2325719271
# Max Drawdown: 41.3920074235
# Max Drawdown Duration: 5830
# Total Returns: 0.6258643073
# ---------------------------------
# Trades: 132
# Trade Winning: 33%
# Average Trade: 0.69%
# Average Win: 4.85%
# Average Loss: -1.39%
# Best Trade: 27.78%
# Worst Trade: -10.13%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 0 days 22:25:00
# ---------------------------------
#    23 | 00m06s |    0.62586 | 69.000000 |
# ---------------------------------
# ADXStrategy_208
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2793460039
# Max Drawdown: 61.6215017084
# Max Drawdown Duration: 5830
# Total Returns: -0.0173045717
# ---------------------------------
# Trades: 68
# Trade Winning: 40%
# Average Trade: 0.33%
# Average Win: 4.45%
# Average Loss: -2.38%
# Best Trade: 24.35%
# Worst Trade: -11.88%
# Worst Trade Date: 2 days 19:00:00
# Avg Days in Trade: 1 days 14:51:11
# ---------------------------------
#    24 | 00m06s |   -0.01730 | 208.000000 |
# ---------------------------------
# ADXStrategy_38
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2963516724
# Max Drawdown: 60.2835713561
# Max Drawdown Duration: 5604
# Total Returns: -0.0188880136
# ---------------------------------
# Trades: 190
# Trade Winning: 38%
# Average Trade: 0.28%
# Average Win: 3.46%
# Average Loss: -1.70%
# Best Trade: 25.56%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 16:25:54
# ---------------------------------
#    25 | 00m06s |   -0.01889 | 38.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_236
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2293450394
# Max Drawdown: 39.2840697707
# Max Drawdown Duration: 4035
# Total Returns: 0.5468089025
# ---------------------------------
# Trades: 67
# Trade Winning: 43%
# Average Trade: 1.09%
# Average Win: 5.56%
# Average Loss: -2.32%
# Best Trade: 39.78%
# Worst Trade: -12.41%
# Worst Trade Date: 4 days 19:00:00
# Avg Days in Trade: 1 days 15:11:39
# ---------------------------------
#    26 | 00m06s |    0.54681 | 236.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_73
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8653665522
# Max Drawdown: 50.8218232029
# Max Drawdown Duration: 5830
# Total Returns: 0.3170209232
# ---------------------------------
# Trades: 127
# Trade Winning: 40%
# Average Trade: 0.53%
# Average Win: 3.60%
# Average Loss: -1.54%
# Best Trade: 28.07%
# Worst Trade: -16.62%
# Worst Trade Date: 1 days 20:00:00
# Avg Days in Trade: 0 days 23:14:10
# ---------------------------------
#    27 | 00m05s |    0.31702 | 73.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_204
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3546787980
# Max Drawdown: 61.5111994147
# Max Drawdown Duration: 5830
# Total Returns: 0.0263514878
# ---------------------------------
# Trades: 63
# Trade Winning: 38%
# Average Trade: 0.41%
# Average Win: 5.12%
# Average Loss: -2.49%
# Best Trade: 24.35%
# Worst Trade: -12.32%
# Worst Trade Date: 2 days 15:00:00
# Avg Days in Trade: 1 days 18:02:51
# ---------------------------------
#    28 | 00m05s |    0.02635 | 204.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_30
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5687069724
# Max Drawdown: 59.3062769981
# Max Drawdown Duration: 5604
# Total Returns: 0.1343118818
# ---------------------------------
# Trades: 204
# Trade Winning: 35%
# Average Trade: 0.35%
# Average Win: 3.78%
# Average Loss: -1.48%
# Best Trade: 26.63%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 15:26:46
# ---------------------------------
#    29 | 00m05s |    0.13431 | 30.000000 |
# ---------------------------------
# ADXStrategy_191
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3643963576
# Max Drawdown: 55.4176517757
# Max Drawdown Duration: 5830
# Total Returns: 0.0348292399
# ---------------------------------
# Trades: 66
# Trade Winning: 33%
# Average Trade: 0.42%
# Average Win: 5.84%
# Average Loss: -2.29%
# Best Trade: 22.11%
# Worst Trade: -11.48%
# Worst Trade Date: 2 days 03:00:00
# Avg Days in Trade: 1 days 15:40:00
# ---------------------------------
#    30 | 00m05s |    0.03483 | 191.000000 |
# ---------------------------------
# ADXStrategy_134
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0607317746
# Max Drawdown: 58.0646124984
# Max Drawdown Duration: 5830
# Total Returns: 0.4731033513
# ---------------------------------
# Trades: 84
# Trade Winning: 42%
# Average Trade: 0.85%
# Average Win: 4.73%
# Average Loss: -1.92%
# Best Trade: 30.72%
# Worst Trade: -9.74%
# Worst Trade Date: 0 days 19:00:00
# Avg Days in Trade: 1 days 08:27:51
# ---------------------------------
#    31 | 00m05s |    0.47310 | 134.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_80
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6597534293
# Max Drawdown: 54.5557019737
# Max Drawdown Duration: 5830
# Total Returns: 0.1880745344
# ---------------------------------
# Trades: 117
# Trade Winning: 38%
# Average Trade: 0.48%
# Average Win: 4.53%
# Average Loss: -1.96%
# Best Trade: 29.79%
# Worst Trade: -9.57%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 1 days 01:13:20
# ---------------------------------
#    32 | 00m05s |    0.18807 | 80.000000 | Warning: Test point chose at random due to repeated sample.

# %%
print(BO.res['max'])
# Out:
# {'max_val': 0.9908953915556202, 'max_params': {'window': 21.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
Target.to_csv(config['out_dir'] + "/target_pi.csv")
Target.sort_values(by = "Target")
# Out:
#    Parameters    Target
# 0       [1.0] -0.986656
# 19     [11.0] -0.421099
# 11    [221.0] -0.052502
# 24     [38.0] -0.018888
# 23    [208.0] -0.017305
# 27    [204.0]  0.026351
# 29    [191.0]  0.034829
# 4      [81.0]  0.093811
# 6     [121.0]  0.115519
# 28     [30.0]  0.134312
# 2      [41.0]  0.144393
# 16    [138.0]  0.184027
# 31     [80.0]  0.188075
# 10    [201.0]  0.201388
# 18     [48.0]  0.210086
# 15    [144.0]  0.232713
# 5     [101.0]  0.238938
# 8     [161.0]  0.250874
# 20    [108.0]  0.296877
# 21    [174.0]  0.298496
# 26     [73.0]  0.317021
# 9     [181.0]  0.323142
# 3      [61.0]  0.329136
# 30    [134.0]  0.473103
# 17     [56.0]  0.506941
# 25    [236.0]  0.546809
# 13     [52.0]  0.595981
# 22     [69.0]  0.625864
# 7     [141.0]  0.648233
# 14     [20.0]  0.831492
# 12     [22.0]  0.844535
# 1      [21.0]  0.990895
