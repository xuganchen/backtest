# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

from BayesianOptimization.bayesian_optimization import BayesianOptimization

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from KDJStrategy import KDJStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
def run_backtest(config, trading_data, ohlc_data,
                 window = 10, sK=20, bK=80, delta = 10):
    window = int(window)
    sK = int(sK)
    sD = sK
    sJ = sK - delta
    bK = int(bK)
    bD = bK
    bJ = bK + delta
    config['title'] = "EMVStrategy" + "_" + str(window) + "_" + str(sK) + "_" + str(bK) + "_" + str(delta)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")
    
    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data = trading_data, ohlc_data = ohlc_data
    )
    strategy = KDJStrategy(config, events_queue, data_handler,
                         window = window, sK=sK, sD=sD, sJ=sJ, bK=bK, bD=bD, bJ=bJ)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler= data_handler)

    results = backtest.start_trading()
    
    # dict_ans = {
    #     "window": [window],
    #     "sK/sD/sJ": [(sK, sD, sJ)],
    #     "bK/bD/bJ": [(bK, bD, bJ)],
    #     "Sharpe Ratio": [results['sharpe']],
    #     "Total Returns": [(results['cum_returns'][-1] - 1)],
    #     "Max Drawdown": [(results["max_drawdown"] * 100.0)],
    #     "Max Drawdown Duration": [(results['max_drawdown_duration'])],
    #     "Trades": [results['trade_info']['trading_num']],
    #     "Trade Winning": [results['trade_info']['win_pct']],
    #     "Average Trade": [results['trade_info']['avg_trd_pct']],
    #     "Average Win": [results['trade_info']['avg_win_pct']],
    #     "Average Loss": [results['trade_info']['avg_loss_pct']],
    #     "Best Trade": [results['trade_info']['max_win_pct']],
    #     "Worst Trade": [results['trade_info']['max_loss_pct']],
    #     "Worst Trade Date": [results['trade_info']['max_loss_dt']],
    #     "Avg Days in Trade": [results['trade_info']['avg_dit']]
    # }
    # return pd.DataFrame(dict_ans)
    return (results['cum_returns'][-1] - 1)

# %% [markdown]
# ## Setting

# %%
config = {
    "csv_dir": "C:/backtest/Binance",
    "out_dir": "C:/backtest/results/KDJStrategy",
    "title": "KDJStrategy",
    "is_plot": False,
    "save_plot": False,
    "save_tradelog": False,
    "start_date": pd.Timestamp("2017-07-01T00:0:00", freq = "60" + "T"),    # str(freq) + "T"
    "end_date": pd.Timestamp("2018-04-01T00:00:00", freq = "60" + "T"),
    "equity": 1.0,
    "freq": 60,      # min
    "commission_ratio": 0.001,
    "suggested_quantity": None,     # None or a value
    "max_quantity": None,           # None or a value, Maximum purchase quantity
    "min_quantity": None,           # None or a value, Minimum purchase quantity
    "min_handheld_cash": None,      # None or a value, Minimum handheld funds
    "exchange": "Binance",
    "tickers": ['BTCUSDT']
}

# %%
# trading_data = {}
# for ticker in config['tickers']:
#     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
#     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

ohlc_data = {}
for ticker in config['tickers']:
    # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
    ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker +'_OHLC_60min.h5', key=ticker)

trading_data = None

# %%
gp_params = {"alpha": 1e-5}

# %% [markdown]
# ## Acquisition Function "Upper Confidence Bound"

# %% [markdown]
# * Prefer exploitation (kappa=1.0)
#
# * Prefer exploration (kappa=10)

# %% [markdown]
# ## Acquisition Function "Expected Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)

# %%
BO = BayesianOptimization(
    run_backtest,
    pbounds = {'window': (1, 120),
              'sK': (10, 30),
              'bK': (70, 90),
              'delta': (0, 20)},
    is_int = [1, 1, 1, 1], 
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
# BO.explore({
#     'window': np.arange(1, 120, 12),
#     'sK': np.arange(10, 30, 2),
#     'bK': np.arange(90, 70, -1),
#     'delta': np.repeat(10, 10)
#     },
#     eager=True)
BO.maximize(init_points=50, n_iter=100, acq="ei", xi=0.01, **gp_params)
# Out:
# Initialization
# -----------------------------------------------------------------------------
#  Step |   Time |      Value |        bK |     delta |        sK |    window |
# ---------------------------------
# EMVStrategy_38_29_76_17.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9184861552
# Max Drawdown: 49.8185361388
# Max Drawdown Duration: 2510
# Total Returns: 0.3701700822
# ---------------------------------
# Trades: 26
# Trade Winning: 42%
# Average Trade: 2.13%
# Average Win: 13.87%
# Average Loss: -6.48%
# Best Trade: 34.19%
# Worst Trade: -16.67%
# Worst Trade Date: 0 days 21:00:00
# Avg Days in Trade: 3 days 11:43:51
# ---------------------------------
#     1 | 00m04s |    0.37017 | 76.000000 | 17.000000 | 29.000000 | 38.000000 |
# ---------------------------------
# EMVStrategy_108_25_72_18.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2329698958
# Max Drawdown: 56.5410169283
# Max Drawdown Duration: 2510
# Total Returns: 0.5971772836
# ---------------------------------
# Trades: 12
# Trade Winning: 33%
# Average Trade: 9.59%
# Average Win: 48.51%
# Average Loss: -9.87%
# Best Trade: 147.18%
# Worst Trade: -14.93%
# Worst Trade Date: 2 days 02:00:00
# Avg Days in Trade: 7 days 18:30:00
# ---------------------------------
#     2 | 00m10s |    0.59718 | 72.000000 | 18.000000 | 25.000000 | 108.000000 |
# ---------------------------------
# EMVStrategy_13_20_82_1.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3666196363
# Max Drawdown: 61.0662520490
# Max Drawdown Duration: 2510
# Total Returns: -0.0106674482
# ---------------------------------
# Trades: 26
# Trade Winning: 42%
# Average Trade: 0.94%
# Average Win: 12.99%
# Average Loss: -7.89%
# Best Trade: 34.19%
# Worst Trade: -22.43%
# Worst Trade Date: 1 days 14:00:00
# Avg Days in Trade: 3 days 21:48:28
# ---------------------------------
#     3 | 00m02s |   -0.01067 | 82.000000 | 1.000000 | 20.000000 | 13.000000 |
# ---------------------------------
# EMVStrategy_73_18_81_10.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7849926339
# Max Drawdown: 65.2133938099
# Max Drawdown Duration: 2510
# Total Returns: 0.2705853579
# ---------------------------------
# Trades: 12
# Trade Winning: 33%
# Average Trade: 6.33%
# Average Win: 37.80%
# Average Loss: -9.41%
# Best Trade: 121.79%
# Worst Trade: -23.19%
# Worst Trade Date: 2 days 07:00:00
# Avg Days in Trade: 7 days 17:10:00
# ---------------------------------
#     4 | 00m07s |    0.27059 | 81.000000 | 10.000000 | 18.000000 | 73.000000 |
# ---------------------------------
# EMVStrategy_10_17_77_0.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.0663079608
# Max Drawdown: 70.5924031245
# Max Drawdown Duration: 2510
# Total Returns: -0.2904011497
# ---------------------------------
# Trades: 27
# Trade Winning: 41%
# Average Trade: 0.04%
# Average Win: 12.96%
# Average Loss: -8.84%
# Best Trade: 34.70%
# Worst Trade: -39.92%
# Worst Trade Date: 8 days 14:00:00
# Avg Days in Trade: 4 days 11:11:07
# ---------------------------------
#     5 | 00m01s |   -0.29040 | 77.000000 | 0.000000 | 17.000000 | 10.000000 |
# ---------------------------------
# EMVStrategy_76_13_83_7.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5307499573
# Max Drawdown: 69.6265584338
# Max Drawdown Duration: 2510
# Total Returns: 0.0918834141
# ---------------------------------
# Trades: 10
# Trade Winning: 40%
# Average Trade: 4.85%
# Average Win: 31.71%
# Average Loss: -13.06%
# Best Trade: 93.09%
# Worst Trade: -26.95%
# Worst Trade Date: 14 days 02:00:00
# Avg Days in Trade: 10 days 10:42:00
# ---------------------------------
#     6 | 00m07s |    0.09188 | 83.000000 | 7.000000 | 13.000000 | 76.000000 |
# ---------------------------------
# EMVStrategy_6_16_78_0.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4510431138
# Max Drawdown: 66.7188010363
# Max Drawdown Duration: 2510
# Total Returns: 0.0186063779
# ---------------------------------
# Trades: 14
# Trade Winning: 21%
# Average Trade: 4.63%
# Average Win: 56.84%
# Average Loss: -9.61%
# Best Trade: 129.73%
# Worst Trade: -19.30%
# Worst Trade Date: 42 days 07:00:00
# Avg Days in Trade: 9 days 13:25:43
# ---------------------------------
#     7 | 00m01s |    0.01861 | 78.000000 | 0.000000 | 16.000000 | 6.000000 |
# ---------------------------------
# EMVStrategy_80_27_81_19.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4929939007
# Max Drawdown: 47.7397836707
# Max Drawdown Duration: 2736
# Total Returns: 0.8036478442
# ---------------------------------
# Trades: 12
# Trade Winning: 50%
# Average Trade: 7.71%
# Average Win: 22.05%
# Average Loss: -6.63%
# Best Trade: 92.50%
# Worst Trade: -10.47%
# Worst Trade Date: 2 days 10:00:00
# Avg Days in Trade: 6 days 15:00:00
# ---------------------------------
#     8 | 00m07s |    0.80365 | 81.000000 | 19.000000 | 27.000000 | 80.000000 |
# ---------------------------------
# EMVStrategy_65_13_82_17.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7148254750
# Max Drawdown: 64.8758114640
# Max Drawdown Duration: 2510
# Total Returns: 0.2182927359
# ---------------------------------
# Trades: 8
# Trade Winning: 50%
# Average Trade: 6.50%
# Average Win: 26.73%
# Average Loss: -13.73%
# Best Trade: 79.64%
# Worst Trade: -31.75%
# Worst Trade Date: 19 days 13:00:00
# Avg Days in Trade: 14 days 12:37:30
# ---------------------------------
#     9 | 00m06s |    0.21829 | 82.000000 | 17.000000 | 13.000000 | 65.000000 |
# ---------------------------------
# EMVStrategy_17_14_81_14.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2823282489
# Max Drawdown: 71.3999561860
# Max Drawdown Duration: 2510
# Total Returns: -0.0909369810
# ---------------------------------
# Trades: 13
# Trade Winning: 54%
# Average Trade: 0.92%
# Average Win: 12.21%
# Average Loss: -12.25%
# Best Trade: 58.45%
# Worst Trade: -19.36%
# Worst Trade Date: 4 days 15:00:00
# Avg Days in Trade: 9 days 12:04:37
# ---------------------------------
#    10 | 00m02s |   -0.09094 | 81.000000 | 14.000000 | 14.000000 | 17.000000 |
# ---------------------------------
# EMVStrategy_2_27_74_13.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2575796672
# Max Drawdown: 70.1603821236
# Max Drawdown Duration: 2510
# Total Returns: -0.0976604198
# ---------------------------------
# Trades: 31
# Trade Winning: 39%
# Average Trade: 1.04%
# Average Win: 13.68%
# Average Loss: -6.94%
# Best Trade: 74.91%
# Worst Trade: -27.44%
# Worst Trade Date: 4 days 18:00:00
# Avg Days in Trade: 3 days 09:27:06
# ---------------------------------
#    11 | 00m01s |   -0.09766 | 74.000000 | 13.000000 | 27.000000 | 2.000000 |
# ---------------------------------
# EMVStrategy_77_21_77_11.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9559558115
# Max Drawdown: 61.3324954795
# Max Drawdown Duration: 2736
# Total Returns: 0.3915656184
# ---------------------------------
# Trades: 13
# Trade Winning: 31%
# Average Trade: 5.26%
# Average Win: 33.25%
# Average Loss: -7.18%
# Best Trade: 91.62%
# Worst Trade: -13.53%
# Worst Trade Date: 2 days 19:00:00
# Avg Days in Trade: 6 days 21:50:46
# ---------------------------------
#    12 | 00m07s |    0.39157 | 77.000000 | 11.000000 | 21.000000 | 77.000000 |
# ---------------------------------
# EMVStrategy_72_22_77_6.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1283179153
# Max Drawdown: 52.1611895658
# Max Drawdown Duration: 2736
# Total Returns: 0.5288278672
# ---------------------------------
# Trades: 14
# Trade Winning: 43%
# Average Trade: 5.60%
# Average Win: 23.82%
# Average Loss: -8.07%
# Best Trade: 91.30%
# Worst Trade: -13.53%
# Worst Trade Date: 2 days 19:00:00
# Avg Days in Trade: 6 days 10:55:43
# ---------------------------------
#    13 | 00m07s |    0.52883 | 77.000000 | 6.000000 | 22.000000 | 72.000000 |
# ---------------------------------
# EMVStrategy_110_26_83_13.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3692858250
# Max Drawdown: 54.4933137185
# Max Drawdown Duration: 2510
# Total Returns: 0.6773345330
# ---------------------------------
# Trades: 10
# Trade Winning: 50%
# Average Trade: 7.68%
# Average Win: 26.09%
# Average Loss: -10.73%
# Best Trade: 52.84%
# Worst Trade: -17.42%
# Worst Trade Date: 1 days 21:00:00
# Avg Days in Trade: 8 days 05:54:00
# ---------------------------------
#    14 | 00m10s |    0.67733 | 83.000000 | 13.000000 | 26.000000 | 110.000000 |
# ---------------------------------
# EMVStrategy_7_23_74_15.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7893244365
# Max Drawdown: 58.4483165152
# Max Drawdown Duration: 2510
# Total Returns: 0.2735043756
# ---------------------------------
# Trades: 38
# Trade Winning: 42%
# Average Trade: 1.75%
# Average Win: 13.30%
# Average Loss: -6.66%
# Best Trade: 48.69%
# Worst Trade: -32.56%
# Worst Trade Date: 8 days 01:00:00
# Avg Days in Trade: 2 days 21:15:47
# ---------------------------------
#    15 | 00m01s |    0.27350 | 74.000000 | 15.000000 | 23.000000 | 7.000000 |
# ---------------------------------
# EMVStrategy_26_29_86_9.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7946214942
# Max Drawdown: 46.2091392281
# Max Drawdown Duration: 2510
# Total Returns: 0.2749968237
# ---------------------------------
# Trades: 28
# Trade Winning: 50%
# Average Trade: 1.52%
# Average Win: 8.56%
# Average Loss: -5.51%
# Best Trade: 33.24%
# Worst Trade: -14.71%
# Worst Trade Date: 0 days 14:00:00
# Avg Days in Trade: 2 days 12:19:17
# ---------------------------------
#    16 | 00m03s |    0.27500 | 86.000000 | 9.000000 | 29.000000 | 26.000000 |
# ---------------------------------
# EMVStrategy_51_19_88_2.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5806566693
# Max Drawdown: 59.0857515994
# Max Drawdown Duration: 2736
# Total Returns: 0.1403721914
# ---------------------------------
# Trades: 15
# Trade Winning: 33%
# Average Trade: 2.49%
# Average Win: 23.64%
# Average Loss: -8.08%
# Best Trade: 56.75%
# Worst Trade: -14.81%
# Worst Trade Date: 10 days 20:00:00
# Avg Days in Trade: 5 days 12:48:00
# ---------------------------------
#    17 | 00m05s |    0.14037 | 88.000000 | 2.000000 | 19.000000 | 51.000000 |
# ---------------------------------
# EMVStrategy_21_28_70_7.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8724530550
# Max Drawdown: 44.7192776304
# Max Drawdown Duration: 2510
# Total Returns: 1.3273692668
# ---------------------------------
# Trades: 37
# Trade Winning: 46%
# Average Trade: 3.20%
# Average Win: 13.07%
# Average Loss: -5.19%
# Best Trade: 43.80%
# Worst Trade: -12.90%
# Worst Trade Date: 1 days 11:00:00
# Avg Days in Trade: 2 days 12:47:02
# ---------------------------------
#    18 | 00m02s |    1.32737 | 70.000000 | 7.000000 | 28.000000 | 21.000000 |
# ---------------------------------
# EMVStrategy_102_25_83_5.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8962185934
# Max Drawdown: 52.7633514347
# Max Drawdown Duration: 2510
# Total Returns: 1.1882366270
# ---------------------------------
# Trades: 9
# Trade Winning: 44%
# Average Trade: 16.13%
# Average Win: 48.91%
# Average Loss: -10.09%
# Best Trade: 148.58%
# Worst Trade: -15.68%
# Worst Trade Date: 2 days 04:00:00
# Avg Days in Trade: 9 days 12:26:40
# ---------------------------------
#    19 | 00m10s |    1.18824 | 83.000000 | 5.000000 | 25.000000 | 102.000000 |
# ---------------------------------
# EMVStrategy_19_10_80_4.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6540397386
# Max Drawdown: 63.4997887092
# Max Drawdown Duration: 2510
# Total Returns: 0.1664166525
# ---------------------------------
# Trades: 9
# Trade Winning: 56%
# Average Trade: 3.16%
# Average Win: 13.81%
# Average Loss: -10.16%
# Best Trade: 43.52%
# Worst Trade: -16.85%
# Worst Trade Date: 1 days 21:00:00
# Avg Days in Trade: 14 days 22:20:00
# ---------------------------------
#    20 | 00m02s |    0.16642 | 80.000000 | 4.000000 | 10.000000 | 19.000000 |
# ---------------------------------
# EMVStrategy_85_14_87_5.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4635645740
# Max Drawdown: 68.7599108553
# Max Drawdown Duration: 2510
# Total Returns: 0.0596395350
# ---------------------------------
# Trades: 10
# Trade Winning: 40%
# Average Trade: 5.80%
# Average Win: 36.23%
# Average Loss: -14.48%
# Best Trade: 114.42%
# Worst Trade: -30.13%
# Worst Trade Date: 13 days 14:00:00
# Avg Days in Trade: 10 days 04:42:00
# ---------------------------------
#    21 | 00m07s |    0.05964 | 87.000000 | 5.000000 | 14.000000 | 85.000000 |
# ---------------------------------
# EMVStrategy_12_25_77_8.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5719620175
# Max Drawdown: 67.5963684856
# Max Drawdown Duration: 2510
# Total Returns: 0.1184715671
# ---------------------------------
# Trades: 39
# Trade Winning: 41%
# Average Trade: 1.19%
# Average Win: 12.48%
# Average Loss: -6.66%
# Best Trade: 41.17%
# Worst Trade: -19.11%
# Worst Trade Date: 1 days 10:00:00
# Avg Days in Trade: 2 days 12:33:51
# ---------------------------------
#    22 | 00m02s |    0.11847 | 77.000000 | 8.000000 | 25.000000 | 12.000000 |
# ---------------------------------
# EMVStrategy_107_12_80_13.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7264598974
# Max Drawdown: 67.8165395097
# Max Drawdown Duration: 2510
# Total Returns: 0.2232872926
# ---------------------------------
# Trades: 7
# Trade Winning: 57%
# Average Trade: 8.03%
# Average Win: 28.33%
# Average Loss: -19.03%
# Best Trade: 85.20%
# Worst Trade: -32.19%
# Worst Trade Date: 13 days 18:00:00
# Avg Days in Trade: 15 days 14:51:26
# ---------------------------------
#    23 | 00m09s |    0.22329 | 80.000000 | 13.000000 | 12.000000 | 107.000000 |
# ---------------------------------
# EMVStrategy_29_17_70_17.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7637152125
# Max Drawdown: 64.2745848593
# Max Drawdown Duration: 2510
# Total Returns: 0.2484677522
# ---------------------------------
# Trades: 18
# Trade Winning: 44%
# Average Trade: 4.68%
# Average Win: 23.55%
# Average Loss: -10.41%
# Best Trade: 115.70%
# Worst Trade: -32.59%
# Worst Trade Date: 5 days 22:00:00
# Avg Days in Trade: 6 days 10:06:40
# ---------------------------------
#    24 | 00m03s |    0.24847 | 70.000000 | 17.000000 | 17.000000 | 29.000000 |
# ---------------------------------
# EMVStrategy_30_18_82_17.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7651181848
# Max Drawdown: 61.4185574366
# Max Drawdown Duration: 2510
# Total Returns: 0.2579508787
# ---------------------------------
# Trades: 19
# Trade Winning: 42%
# Average Trade: 3.76%
# Average Win: 20.57%
# Average Loss: -8.46%
# Best Trade: 106.96%
# Worst Trade: -24.39%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 5 days 11:28:25
# ---------------------------------
#    25 | 00m03s |    0.25795 | 82.000000 | 17.000000 | 18.000000 | 30.000000 |
# ---------------------------------
# EMVStrategy_15_19_71_15.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2841372972
# Max Drawdown: 66.2048318742
# Max Drawdown Duration: 2510
# Total Returns: -0.0867257757
# ---------------------------------
# Trades: 26
# Trade Winning: 42%
# Average Trade: 0.83%
# Average Win: 14.07%
# Average Loss: -8.88%
# Best Trade: 34.70%
# Worst Trade: -30.14%
# Worst Trade Date: 7 days 20:00:00
# Avg Days in Trade: 4 days 15:13:51
# ---------------------------------
#    26 | 00m02s |   -0.08673 | 71.000000 | 15.000000 | 19.000000 | 15.000000 |
# ---------------------------------
# EMVStrategy_51_13_79_13.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7709282956
# Max Drawdown: 64.1672749770
# Max Drawdown Duration: 2510
# Total Returns: 0.2603290978
# ---------------------------------
# Trades: 11
# Trade Winning: 45%
# Average Trade: 4.11%
# Average Win: 19.93%
# Average Loss: -9.07%
# Best Trade: 61.39%
# Worst Trade: -17.00%
# Worst Trade Date: 1 days 14:00:00
# Avg Days in Trade: 10 days 17:27:16
# ---------------------------------
#    27 | 00m05s |    0.26033 | 79.000000 | 13.000000 | 13.000000 | 51.000000 |
# ---------------------------------
# EMVStrategy_69_17_88_8.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9850018957
# Max Drawdown: 55.4795205335
# Max Drawdown Duration: 2510
# Total Returns: 0.3967249467
# ---------------------------------
# Trades: 11
# Trade Winning: 36%
# Average Trade: 7.49%
# Average Win: 35.41%
# Average Loss: -8.47%
# Best Trade: 123.15%
# Worst Trade: -14.24%
# Worst Trade Date: 3 days 19:00:00
# Avg Days in Trade: 7 days 12:38:11
# ---------------------------------
#    28 | 00m07s |    0.39672 | 88.000000 | 8.000000 | 17.000000 | 69.000000 |
# ---------------------------------
# EMVStrategy_88_14_89_14.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.0088011233
# Max Drawdown: 73.6291479406
# Max Drawdown Duration: 2510
# Total Returns: -0.1961219587
# ---------------------------------
# Trades: 9
# Trade Winning: 44%
# Average Trade: 2.30%
# Average Win: 28.77%
# Average Loss: -18.88%
# Best Trade: 88.82%
# Worst Trade: -33.86%
# Worst Trade Date: 11 days 06:00:00
# Avg Days in Trade: 10 days 16:13:20
# ---------------------------------
#    29 | 00m08s |   -0.19612 | 89.000000 | 14.000000 | 14.000000 | 88.000000 |
# ---------------------------------
# EMVStrategy_88_15_71_13.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8088818626
# Max Drawdown: 64.4571704609
# Max Drawdown Duration: 2510
# Total Returns: 0.2892978531
# ---------------------------------
# Trades: 10
# Trade Winning: 40%
# Average Trade: 6.75%
# Average Win: 33.72%
# Average Loss: -11.24%
# Best Trade: 102.63%
# Worst Trade: -22.71%
# Worst Trade Date: 14 days 03:00:00
# Avg Days in Trade: 10 days 19:24:00
# ---------------------------------
#    30 | 00m07s |    0.28930 | 71.000000 | 13.000000 | 15.000000 | 88.000000 |
# ---------------------------------
# EMVStrategy_106_29_72_16.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9506875560
# Max Drawdown: 55.9984529408
# Max Drawdown Duration: 2510
# Total Returns: 0.3820621770
# ---------------------------------
# Trades: 13
# Trade Winning: 38%
# Average Trade: 4.60%
# Average Win: 27.42%
# Average Loss: -9.67%
# Best Trade: 54.17%
# Worst Trade: -15.68%
# Worst Trade Date: 2 days 04:00:00
# Avg Days in Trade: 6 days 21:27:42
# ---------------------------------
#    31 | 00m09s |    0.38206 | 72.000000 | 16.000000 | 29.000000 | 106.000000 |
# ---------------------------------
# EMVStrategy_114_16_82_10.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7518532994
# Max Drawdown: 68.6365198101
# Max Drawdown Duration: 2510
# Total Returns: 0.2472890922
# ---------------------------------
# Trades: 9
# Trade Winning: 44%
# Average Trade: 8.25%
# Average Win: 37.20%
# Average Loss: -14.92%
# Best Trade: 115.92%
# Worst Trade: -27.28%
# Worst Trade Date: 13 days 04:00:00
# Avg Days in Trade: 10 days 19:33:20
# ---------------------------------
#    32 | 00m09s |    0.24729 | 82.000000 | 10.000000 | 16.000000 | 114.000000 |
# ---------------------------------
# EMVStrategy_95_18_77_13.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7400661989
# Max Drawdown: 65.0414979427
# Max Drawdown Duration: 2510
# Total Returns: 0.2396967376
# ---------------------------------
# Trades: 10
# Trade Winning: 40%
# Average Trade: 7.83%
# Average Win: 40.03%
# Average Loss: -13.63%
# Best Trade: 125.34%
# Worst Trade: -26.22%
# Worst Trade Date: 13 days 09:00:00
# Avg Days in Trade: 10 days 05:30:00
# ---------------------------------
#    33 | 00m08s |    0.23970 | 77.000000 | 13.000000 | 18.000000 | 95.000000 |
# ---------------------------------
# EMVStrategy_97_10_72_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6226663490
# Max Drawdown: 65.8575199451
# Max Drawdown Duration: 2510
# Total Returns: 0.1471413366
# ---------------------------------
# Trades: 8
# Trade Winning: 50%
# Average Trade: 7.14%
# Average Win: 31.51%
# Average Loss: -17.23%
# Best Trade: 98.89%
# Worst Trade: -31.08%
# Worst Trade Date: 14 days 03:00:00
# Avg Days in Trade: 14 days 08:22:30
# ---------------------------------
#    34 | 00m08s |    0.14714 | 72.000000 | 3.000000 | 10.000000 | 97.000000 |
# ---------------------------------
# EMVStrategy_87_12_80_2.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4889484302
# Max Drawdown: 68.8214310616
# Max Drawdown Duration: 2510
# Total Returns: 0.0629336357
# ---------------------------------
# Trades: 10
# Trade Winning: 40%
# Average Trade: 4.57%
# Average Win: 30.76%
# Average Loss: -12.89%
# Best Trade: 94.83%
# Worst Trade: -26.95%
# Worst Trade Date: 14 days 02:00:00
# Avg Days in Trade: 10 days 15:24:00
# ---------------------------------
#    35 | 00m08s |    0.06293 | 80.000000 | 2.000000 | 12.000000 | 87.000000 |
# ---------------------------------
# EMVStrategy_14_20_70_14.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3526905150
# Max Drawdown: 66.1017989030
# Max Drawdown Duration: 2510
# Total Returns: -0.0412681711
# ---------------------------------
# Trades: 30
# Trade Winning: 37%
# Average Trade: 1.01%
# Average Win: 15.65%
# Average Loss: -7.47%
# Best Trade: 41.88%
# Worst Trade: -30.14%
# Worst Trade Date: 7 days 20:00:00
# Avg Days in Trade: 4 days 00:54:00
# ---------------------------------
#    36 | 00m02s |   -0.04127 | 70.000000 | 14.000000 | 20.000000 | 14.000000 |
# ---------------------------------
# EMVStrategy_106_25_79_14.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0426085529
# Max Drawdown: 49.7437660292
# Max Drawdown Duration: 2510
# Total Returns: 1.3402907080
# ---------------------------------
# Trades: 9
# Trade Winning: 44%
# Average Trade: 16.72%
# Average Win: 48.53%
# Average Loss: -8.73%
# Best Trade: 147.18%
# Worst Trade: -15.78%
# Worst Trade Date: 2 days 00:00:00
# Avg Days in Trade: 9 days 13:06:40
# ---------------------------------
#    37 | 00m09s |    1.34029 | 79.000000 | 14.000000 | 25.000000 | 106.000000 |
# ---------------------------------
# EMVStrategy_10_25_88_0.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7167804867
# Max Drawdown: 43.5370766120
# Max Drawdown Duration: 2736
# Total Returns: 0.2103763422
# ---------------------------------
# Trades: 20
# Trade Winning: 45%
# Average Trade: 1.72%
# Average Win: 10.70%
# Average Loss: -5.63%
# Best Trade: 36.30%
# Worst Trade: -12.63%
# Worst Trade Date: 0 days 22:00:00
# Avg Days in Trade: 2 days 09:18:00
# ---------------------------------
#    38 | 00m01s |    0.21038 | 88.000000 | 0.000000 | 25.000000 | 10.000000 |
# ---------------------------------
# EMVStrategy_8_17_76_11.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2334027102
# Max Drawdown: 71.0246219714
# Max Drawdown Duration: 2510
# Total Returns: -0.1322713559
# ---------------------------------
# Trades: 23
# Trade Winning: 35%
# Average Trade: 1.63%
# Average Win: 21.88%
# Average Loss: -9.17%
# Best Trade: 85.51%
# Worst Trade: -34.98%
# Worst Trade Date: 25 days 18:00:00
# Avg Days in Trade: 5 days 10:36:31
# ---------------------------------
#    39 | 00m01s |   -0.13227 | 76.000000 | 11.000000 | 17.000000 | 8.000000 |
# ---------------------------------
# EMVStrategy_64_29_72_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9926852665
# Max Drawdown: 44.7736792136
# Max Drawdown Duration: 2736
# Total Returns: 0.4191852036
# ---------------------------------
# Trades: 19
# Trade Winning: 47%
# Average Trade: 2.67%
# Average Win: 12.99%
# Average Loss: -6.62%
# Best Trade: 24.50%
# Worst Trade: -10.85%
# Worst Trade Date: 0 days 13:00:00
# Avg Days in Trade: 4 days 15:31:35
# ---------------------------------
#    40 | 00m05s |    0.41919 | 72.000000 | 3.000000 | 29.000000 | 64.000000 |
# ---------------------------------
# EMVStrategy_62_20_77_1.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7964974263
# Max Drawdown: 56.3356628616
# Max Drawdown Duration: 2736
# Total Returns: 0.2784770164
# ---------------------------------
# Trades: 16
# Trade Winning: 44%
# Average Trade: 3.14%
# Average Win: 18.99%
# Average Loss: -9.20%
# Best Trade: 51.57%
# Worst Trade: -23.12%
# Worst Trade Date: 2 days 22:00:00
# Avg Days in Trade: 5 days 19:41:15
# ---------------------------------
#    41 | 00m05s |    0.27848 | 77.000000 | 1.000000 | 20.000000 | 62.000000 |
# ---------------------------------
# EMVStrategy_23_24_77_2.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3456893695
# Max Drawdown: 46.8921019008
# Max Drawdown Duration: 2510
# Total Returns: 0.7472685592
# ---------------------------------
# Trades: 28
# Trade Winning: 46%
# Average Trade: 3.40%
# Average Win: 14.49%
# Average Loss: -6.21%
# Best Trade: 73.98%
# Worst Trade: -11.55%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 3 days 11:32:09
# ---------------------------------
#    42 | 00m03s |    0.74727 | 77.000000 | 2.000000 | 24.000000 | 23.000000 |
# ---------------------------------
# EMVStrategy_58_10_86_19.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9639710877
# Max Drawdown: 53.5248484233
# Max Drawdown Duration: 2510
# Total Returns: 0.4253466373
# ---------------------------------
# Trades: 6
# Trade Winning: 50%
# Average Trade: 8.69%
# Average Win: 26.26%
# Average Loss: -8.88%
# Best Trade: 56.62%
# Worst Trade: -15.70%
# Worst Trade Date: 2 days 09:00:00
# Avg Days in Trade: 20 days 09:10:00
# ---------------------------------
#    43 | 00m05s |    0.42535 | 86.000000 | 19.000000 | 10.000000 | 58.000000 |
# ---------------------------------
# EMVStrategy_2_11_85_16.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3322996077
# Max Drawdown: 69.3396585403
# Max Drawdown Duration: 2510
# Total Returns: -0.0758912628
# ---------------------------------
# Trades: 0
# Trade Winning: N/A
# Average Trade: N/A
# Average Win: N/A
# Average Loss: N/A
# Best Trade: N/A
# Worst Trade: N/A
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#    44 | 00m01s |   -0.07589 | 85.000000 | 16.000000 | 11.000000 | 2.000000 |
# ---------------------------------
# EMVStrategy_1_27_75_0.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0664269456
# Max Drawdown: 71.4979412192
# Max Drawdown Duration: 2736
# Total Returns: -0.1733878744
# ---------------------------------
# Trades: 23
# Trade Winning: 48%
# Average Trade: 0.84%
# Average Win: 13.61%
# Average Loss: -10.86%
# Best Trade: 67.06%
# Worst Trade: -30.83%
# Worst Trade Date: 3 days 08:00:00
# Avg Days in Trade: 4 days 00:41:44
# ---------------------------------
#    45 | 00m00s |   -0.17339 | 75.000000 | 0.000000 | 27.000000 | 1.000000 |
# ---------------------------------
# EMVStrategy_61_23_87_18.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8498785005
# Max Drawdown: 56.7682217236
# Max Drawdown Duration: 2736
# Total Returns: 0.3010991238
# ---------------------------------
# Trades: 13
# Trade Winning: 38%
# Average Trade: 3.48%
# Average Win: 21.18%
# Average Loss: -7.58%
# Best Trade: 48.99%
# Worst Trade: -11.19%
# Worst Trade Date: 2 days 00:00:00
# Avg Days in Trade: 5 days 16:32:18
# ---------------------------------
#    46 | 00m05s |    0.30110 | 87.000000 | 18.000000 | 23.000000 | 61.000000 |
# ---------------------------------
# EMVStrategy_82_13_80_10.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9225004392
# Max Drawdown: 61.0868920788
# Max Drawdown Duration: 2510
# Total Returns: 0.3826115503
# ---------------------------------
# Trades: 9
# Trade Winning: 44%
# Average Trade: 7.80%
# Average Win: 32.08%
# Average Loss: -11.62%
# Best Trade: 95.57%
# Worst Trade: -22.20%
# Worst Trade Date: 14 days 05:00:00
# Avg Days in Trade: 12 days 11:33:20
# ---------------------------------
#    47 | 00m07s |    0.38261 | 80.000000 | 10.000000 | 13.000000 | 82.000000 |
# ---------------------------------
# EMVStrategy_9_10_86_8.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3923324468
# Max Drawdown: 71.4389406247
# Max Drawdown Duration: 2510
# Total Returns: -0.0376031686
# ---------------------------------
# Trades: 1
# Trade Winning: 100%
# Average Trade: 14.46%
# Average Win: 14.46%
# Average Loss: nan%
# Best Trade: 14.46%
# Worst Trade: 14.46%
# Worst Trade Date: 98 days 23:00:00
# Avg Days in Trade: 98 days 23:00:00
# ---------------------------------
#    48 | 00m01s |   -0.03760 | 86.000000 | 8.000000 | 10.000000 | 9.000000 |
# ---------------------------------
# EMVStrategy_89_23_75_13.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7215120823
# Max Drawdown: 50.8376261270
# Max Drawdown Duration: 2510
# Total Returns: 1.0923967190
# ---------------------------------
# Trades: 11
# Trade Winning: 36%
# Average Trade: 13.15%
# Average Win: 50.73%
# Average Loss: -8.32%
# Best Trade: 155.05%
# Worst Trade: -12.91%
# Worst Trade Date: 2 days 20:00:00
# Avg Days in Trade: 8 days 05:10:55
# ---------------------------------
#    49 | 00m07s |    1.09240 | 75.000000 | 13.000000 | 23.000000 | 89.000000 |
# ---------------------------------
# EMVStrategy_14_16_83_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1170044867
# Max Drawdown: 69.0032338346
# Max Drawdown Duration: 2510
# Total Returns: -0.1674404934
# ---------------------------------
# Trades: 19
# Trade Winning: 47%
# Average Trade: 0.62%
# Average Win: 14.18%
# Average Loss: -11.59%
# Best Trade: 43.78%
# Worst Trade: -28.08%
# Worst Trade Date: 16 days 01:00:00
# Avg Days in Trade: 5 days 16:22:06
# ---------------------------------
#    50 | 00m01s |   -0.16744 | 83.000000 | 3.000000 | 16.000000 | 14.000000 |
# Bayesian Optimization
# -----------------------------------------------------------------------------
#  Step |   Time |      Value |        bK |     delta |        sK |    window |
# ---------------------------------
# EMVStrategy_44_30_90_20.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.1498628066
# Max Drawdown: 59.4225485853
# Max Drawdown Duration: 2736
# Total Returns: -0.1801822521
# ---------------------------------
# Trades: 18
# Trade Winning: 28%
# Average Trade: -0.17%
# Average Win: 18.18%
# Average Loss: -7.22%
# Best Trade: 30.37%
# Worst Trade: -14.48%
# Worst Trade Date: 1 days 15:00:00
# Avg Days in Trade: 3 days 09:33:20
# ---------------------------------
#    51 | 00m23s |   -0.18018 | 90.000000 | 20.000000 | 30.000000 | 44.000000 |
# ---------------------------------
# EMVStrategy_18_13_85_4.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4863905281
# Max Drawdown: 65.8748711639
# Max Drawdown Duration: 2510
# Total Returns: 0.0463429401
# ---------------------------------
# Trades: 12
# Trade Winning: 42%
# Average Trade: 1.98%
# Average Win: 15.84%
# Average Loss: -7.91%
# Best Trade: 57.07%
# Worst Trade: -17.06%
# Worst Trade Date: 10 days 13:00:00
# Avg Days in Trade: 10 days 03:15:00
# ---------------------------------
#    52 | 00m21s |    0.04634 | 85.000000 | 4.000000 | 13.000000 | 18.000000 |
# ---------------------------------
# EMVStrategy_92_30_79_9.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7588304822
# Max Drawdown: 56.6971891740
# Max Drawdown Duration: 2736
# Total Returns: 0.2489289482
# ---------------------------------
# Trades: 14
# Trade Winning: 43%
# Average Trade: 2.73%
# Average Win: 15.94%
# Average Loss: -7.18%
# Best Trade: 36.57%
# Worst Trade: -17.50%
# Worst Trade Date: 2 days 08:00:00
# Avg Days in Trade: 5 days 18:38:34
# ---------------------------------
#    53 | 00m29s |    0.24893 | 79.000000 | 9.000000 | 30.000000 | 92.000000 |
# ---------------------------------
# EMVStrategy_11_16_75_18.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1873360518
# Max Drawdown: 74.8046974982
# Max Drawdown Duration: 2510
# Total Returns: -0.1738763706
# ---------------------------------
# Trades: 16
# Trade Winning: 44%
# Average Trade: 1.97%
# Average Win: 22.29%
# Average Loss: -13.83%
# Best Trade: 85.32%
# Worst Trade: -37.59%
# Worst Trade Date: 38 days 01:00:00
# Avg Days in Trade: 8 days 12:26:15
# ---------------------------------
#    54 | 00m21s |   -0.17388 | 75.000000 | 18.000000 | 16.000000 | 11.000000 |

# %%
print(BO.res['max'])

# %%
BO.maximize(init_points=0, n_iter=100, acq="ei", xi=0.0001, **gp_params)

# %%
print(BO.res['max'])

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
# Target.to_csv(config['out_dir'] + "/target_ei.csv")
Target.sort_values(by = "Target")

# %%
f, ax = plt.subplots(2,2, figsize = (16, 8))
ax[0,0].scatter(BO.X[:,0].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[0,0].set_title('$val$ $vs$ $window$ ', fontsize=18)
ax[0,0].set_xlabel('$window$', fontsize=16)
ax[0,0].set_ylabel('$val$', fontsize=16)
ax[0,0].hlines(0, 0, 120, color='black',linestyle="--")
ax[0,0].hlines(-1, 0, 120, color='black',linestyle="--")
ax[0,0].hlines(1, 0, 120, color='black',linestyle="--")
ax[0,0].vlines(BO.res['max']['max_params']['window'], -1.2, 2, color='blue',linestyle="--")

ax[0,1].scatter(BO.X[:,1].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[0,1].set_title('$val$ $vs$ $sK$ ', fontsize=18)
ax[0,1].set_xlabel('$sK$', fontsize=16)
ax[0,1].set_ylabel('$val$', fontsize=16)
ax[0,1].hlines(0, 0, 240,color='black',linestyle="--")
ax[0,1].hlines(-1, 0, 240, color='black',linestyle="--")
ax[0,1].hlines(1, 0, 240,color='black',linestyle="--")
ax[0,1].vlines(BO.res['max']['max_params']['sK'], -1.2, 2, color='blue',linestyle="--")

ax[1,0].scatter(BO.X[:,2].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[1,0].set_title('$val$ $vs$ $bK$ ', fontsize=18)
ax[1,0].set_xlabel('$bK$', fontsize=16)
ax[1,0].set_ylabel('$val$', fontsize=16)
ax[1,0].hlines(0, 0, 240,color='black',linestyle="--")
ax[1,0].hlines(-1, 0, 240, color='black',linestyle="--")
ax[1,0].hlines(1, 0, 240,color='black',linestyle="--")
ax[1,0].vlines(BO.res['max']['max_params']['bK'], -1.2, 2, color='blue',linestyle="--")

ax[1,1].scatter(BO.X[:,3].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[1,1].set_title('$val$ $vs$ $delta$ ', fontsize=18)
ax[1,1].set_xlabel('$delta$', fontsize=16)
ax[1,1].set_ylabel('$val$', fontsize=16)
ax[1,1].hlines(0, 0, 240,color='black',linestyle="--")
ax[1,1].hlines(-1, 0, 240, color='black',linestyle="--")
ax[1,1].hlines(1, 0, 240,color='black',linestyle="--")
ax[1,1].vlines(BO.res['max']['max_params']['delta'], -1.2, 2, color='blue',linestyle="--")

# %% [markdown]
# ## Acquisition Function "Probability of Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)
