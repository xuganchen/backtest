# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from ADXStrategy import ADXStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
import GPyOpt

# %%
def run_backtest(params):
    window = params[0,0]
    
    config = {
        "csv_dir": "C:/backtest/Binance",
        "out_dir": "C:/backtest/results/ADXStrategy",
        "title": "ADXStrategy",
        "is_plot": False,
        "save_plot": False,
        "save_tradelog": False,
        "start_date": pd.Timestamp("2017-07-01T00:0:00", freq="60" + "T"),  # str(freq) + "T"
        "end_date": pd.Timestamp("2018-04-01T00:00:00", freq="60" + "T"),
        "equity": 1.0,
        "freq": 60,  # min
        "commission_ratio": 0.001,
        "suggested_quantity": None,  # None or a value
        "max_quantity": None,  # None or a value, Maximum purchase quantity
        "min_quantity": None,  # None or a value, Minimum purchase quantity
        "min_handheld_cash": None,  # None or a value, Minimum handheld funds
        "exchange": "Binance",
        "tickers": ['BTCUSDT']
    }
    
    # trading_data = {}
    # for ticker in config['tickers']:
    #     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
    #     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

    ohlc_data = {}
    for ticker in config['tickers']:
        # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
        ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '_OHLC_60min.h5', key=ticker)

    trading_data = None

    
    config['title'] = "ADXStrategy" + "_" + str(window)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")

    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data=trading_data, ohlc_data=ohlc_data
    )
    strategy = ADXStrategy(config, events_queue, data_handler,
                           window=window)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler=data_handler)

    results = backtest.start_trading()

    # dict_ans = {
    #     "window": window,
    #     "Sharpe Ratio": [results['sharpe']],
    #     "Total Returns": [(results['cum_returns'][-1] - 1)],
    #     "Max Drawdown": [(results["max_drawdown"] * 100.0)],
    #     "Max Drawdown Duration": [(results['max_drawdown_duration'])],
    #     "Trades": [results['trade_info']['trading_num']],
    #     "Trade Winning": [results['trade_info']['win_pct']],
    #     "Average Trade": [results['trade_info']['avg_trd_pct']],
    #     "Average Win": [results['trade_info']['avg_win_pct']],
    #     "Average Loss": [results['trade_info']['avg_loss_pct']],
    #     "Best Trade": [results['trade_info']['max_win_pct']],
    #     "Worst Trade": [results['trade_info']['max_loss_pct']],
    #     "Worst Trade Date": [results['trade_info']['max_loss_dt']],
    #     "Avg Days in Trade": [results['trade_info']['avg_dit']]
    # }
    # return pd.DataFrame(dict_ans)
    return np.array([(results['cum_returns'][-1] - 1)]).reshape(1, 1)

# %%
# mixed_domain =[{'name': 'var1', 'type': 'continuous', 'domain': (-5,5),'dimensionality': 3},
#                {'name': 'var3', 'type': 'discrete', 'domain': (3,8,10),'dimensionality': 2},
#                {'name': 'var4', 'type': 'categorical', 'domain': (0,1,2),'dimensionality': 1},
#                {'name': 'var5', 'type': 'continuous', 'domain': (-1,2)}]

domain = [
    {'name': 'window', 'type': 'discrete', 'domain': tuple(range(1, 240))}
]

# %%
# constraints = [{'name': 'constr_1', 'constraint': '-x[:,1] -.5 + abs(x[:,0]) - np.sqrt(1-x[:,0]**2)'},
#               {'name': 'constr_2', 'constraint': 'x[:,1] +.5 - abs(x[:,0]) - np.sqrt(1-x[:,0]**2)'}]

constraints = None

# %%
X = np.arange(1, 240, 20)
X = X.reshape(len(X),1)

# %%
kwargs = {"acquisition_jitter": 0.01}

# %%
myBopt = GPyOpt.methods.BayesianOptimization(f = run_backtest,
                                             domain = domain,
                                             constraints = constraints,
                                             cost_withGradients = None,   # None or 'evaluation_time'
                                             model_type = 'GP',  # 'GP' or 'GP_MCMC'
                                             X = None, # 2d numpy array containing the initial inputs (one per row) of the model.
                                             Y = None, # 2d numpy array containing the initial outputs (one per row) of the model.
                                             acquisition_type = 'EI',  # 'EI', 'MPI', 'LCB' or 'EI_MCMC', 'MPI_MCMC', 'LCB_MCMC'
                                             initial_design_numdata = 12,
                                             initial_design_type = 'random',  # 'grid' or 'random' 
                                             exact_feval = True,
                                             evaluator_type = 'random', 
                                             batch_size = 1,  # size of the batch in which the objective is evaluated
                                             num_cores = 1,  # umber of cores used to evaluate the objective 
                                             verbosity = False,  # prints the models during the optimization
                                             maximize = True, # True: maximize; False: minimize
                                             **kwargs
                                             )
# Out:
# ---------------------------------
# ADXStrategy_36.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2717907557
# Max Drawdown: 39.5184143958
# Max Drawdown Duration: 2277
# Total Returns: 0.6106335939
# ---------------------------------
# Trades: 92
# Trade Winning: 43%
# Average Trade: 0.88%
# Average Win: 4.93%
# Average Loss: -2.23%
# Best Trade: 27.23%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 18:16:18
# ---------------------------------
# ---------------------------------
# ADXStrategy_77.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7224890558
# Max Drawdown: 54.2472881785
# Max Drawdown Duration: 2736
# Total Returns: 0.2241387128
# ---------------------------------
# Trades: 72
# Trade Winning: 40%
# Average Trade: 0.65%
# Average Win: 4.96%
# Average Loss: -2.26%
# Best Trade: 29.53%
# Worst Trade: -9.69%
# Worst Trade Date: 2 days 06:00:00
# Avg Days in Trade: 0 days 22:10:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_178.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4578114888
# Max Drawdown: 46.4899114904
# Max Drawdown Duration: 2736
# Total Returns: 0.0859701725
# ---------------------------------
# Trades: 43
# Trade Winning: 42%
# Average Trade: 0.57%
# Average Win: 5.10%
# Average Loss: -2.68%
# Best Trade: 24.50%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 07:57:13
# ---------------------------------
# ---------------------------------
# ADXStrategy_19.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7952775903
# Max Drawdown: 27.6577494123
# Max Drawdown Duration: 838
# Total Returns: 1.2040512464
# ---------------------------------
# Trades: 136
# Trade Winning: 43%
# Average Trade: 0.93%
# Average Win: 4.86%
# Average Loss: -2.00%
# Best Trade: 32.46%
# Worst Trade: -8.72%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 12:17:12
# ---------------------------------
# ---------------------------------
# ADXStrategy_206.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2310715689
# Max Drawdown: 63.7203844913
# Max Drawdown Duration: 2736
# Total Returns: -0.2126329886
# ---------------------------------
# Trades: 38
# Trade Winning: 37%
# Average Trade: -0.19%
# Average Win: 5.60%
# Average Loss: -3.56%
# Best Trade: 24.35%
# Worst Trade: -17.99%
# Worst Trade Date: 2 days 22:00:00
# Avg Days in Trade: 1 days 12:20:32
# ---------------------------------
# ---------------------------------
# ADXStrategy_120.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9970647473
# Max Drawdown: 48.9538922475
# Max Drawdown Duration: 2736
# Total Returns: 0.3903720401
# ---------------------------------
# Trades: 53
# Trade Winning: 40%
# Average Trade: 1.03%
# Average Win: 6.01%
# Average Loss: -2.24%
# Best Trade: 24.67%
# Worst Trade: -12.84%
# Worst Trade Date: 1 days 01:00:00
# Avg Days in Trade: 1 days 05:38:29
# ---------------------------------
# ---------------------------------
# ADXStrategy_60.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6303710805
# Max Drawdown: 49.8515339596
# Max Drawdown Duration: 2736
# Total Returns: 0.1677320044
# ---------------------------------
# Trades: 68
# Trade Winning: 35%
# Average Trade: 0.60%
# Average Win: 5.90%
# Average Loss: -2.29%
# Best Trade: 26.51%
# Worst Trade: -11.07%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 1 days 00:34:25
# ---------------------------------
# ---------------------------------
# ADXStrategy_97.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1837650804
# Max Drawdown: 49.3840978457
# Max Drawdown Duration: 2736
# Total Returns: 0.5011017861
# ---------------------------------
# Trades: 53
# Trade Winning: 45%
# Average Trade: 1.18%
# Average Win: 5.50%
# Average Loss: -2.40%
# Best Trade: 26.41%
# Worst Trade: -13.78%
# Worst Trade Date: 1 days 03:00:00
# Avg Days in Trade: 1 days 05:31:42
# ---------------------------------
# ---------------------------------
# ADXStrategy_132.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9176176136
# Max Drawdown: 47.4323748316
# Max Drawdown Duration: 2736
# Total Returns: 0.3358714712
# ---------------------------------
# Trades: 39
# Trade Winning: 46%
# Average Trade: 1.19%
# Average Win: 6.03%
# Average Loss: -2.95%
# Best Trade: 26.61%
# Worst Trade: -10.60%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 1 days 14:43:05
# ---------------------------------
# ---------------------------------
# ADXStrategy_227.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5317980368
# Max Drawdown: 48.0232897140
# Max Drawdown Duration: 2736
# Total Returns: 0.1146226193
# ---------------------------------
# Trades: 52
# Trade Winning: 50%
# Average Trade: 0.62%
# Average Win: 4.27%
# Average Loss: -3.03%
# Best Trade: 31.63%
# Worst Trade: -11.56%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 1 days 02:11:32
# ---------------------------------
# ---------------------------------
# ADXStrategy_41.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0092611591
# Max Drawdown: 39.2727903852
# Max Drawdown Duration: 2277
# Total Returns: 0.4040606257
# ---------------------------------
# Trades: 85
# Trade Winning: 39%
# Average Trade: 0.74%
# Average Win: 5.00%
# Average Loss: -1.96%
# Best Trade: 25.07%
# Worst Trade: -6.98%
# Worst Trade Date: 0 days 18:00:00
# Avg Days in Trade: 0 days 19:40:14
# ---------------------------------
# ---------------------------------
# ADXStrategy_60.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6303710805
# Max Drawdown: 49.8515339596
# Max Drawdown Duration: 2736
# Total Returns: 0.1677320044
# ---------------------------------
# Trades: 68
# Trade Winning: 35%
# Average Trade: 0.60%
# Average Win: 5.90%
# Average Loss: -2.29%
# Best Trade: 26.51%
# Worst Trade: -11.07%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 1 days 00:34:25
# ---------------------------------

# %%
max_iter = 40                 # evaluation budget
myBopt.run_optimization(max_iter)   # run optimization
# Out:
# ---------------------------------
# ADXStrategy_8
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -1.3093954034
# Max Drawdown: 69.4558890080
# Max Drawdown Duration: 2670
# Total Returns: -0.5462310528
# ---------------------------------
# Trades: 252
# Trade Winning: 38%
# Average Trade: -0.06%
# Average Win: 2.79%
# Average Loss: -1.82%
# Best Trade: 12.58%
# Worst Trade: -9.57%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 07:13:06
# ---------------------------------
# ---------------------------------
# ADXStrategy_20
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9037118035
# Max Drawdown: 25.8931899632
# Max Drawdown Duration: 965
# Total Returns: 1.3075170323
# ---------------------------------
# Trades: 125
# Trade Winning: 44%
# Average Trade: 1.02%
# Average Win: 4.84%
# Average Loss: -1.98%
# Best Trade: 31.17%
# Worst Trade: -7.86%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 13:12:58
# ---------------------------------
# ---------------------------------
# ADXStrategy_22
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7142072835
# Max Drawdown: 26.0032103294
# Max Drawdown Duration: 1031
# Total Returns: 1.0377140034
# ---------------------------------
# Trades: 122
# Trade Winning: 43%
# Average Trade: 0.92%
# Average Win: 4.59%
# Average Loss: -1.82%
# Best Trade: 29.88%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 13:41:19
# ---------------------------------
# ---------------------------------
# ADXStrategy_30
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3343192880
# Max Drawdown: 39.6110305363
# Max Drawdown Duration: 2510
# Total Returns: 0.6452578931
# ---------------------------------
# Trades: 105
# Trade Winning: 40%
# Average Trade: 0.83%
# Average Win: 4.89%
# Average Loss: -1.88%
# Best Trade: 26.63%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 15:56:34
# ---------------------------------
# ---------------------------------
# ADXStrategy_105
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0990874392
# Max Drawdown: 44.8359868720
# Max Drawdown Duration: 2736
# Total Returns: 0.4206430930
# ---------------------------------
# Trades: 55
# Trade Winning: 38%
# Average Trade: 1.02%
# Average Win: 6.06%
# Average Loss: -2.09%
# Best Trade: 26.13%
# Worst Trade: -8.76%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 04:41:27
# ---------------------------------
# ---------------------------------
# ADXStrategy_89
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9732774817
# Max Drawdown: 50.2168437105
# Max Drawdown Duration: 2736
# Total Returns: 0.3649843678
# ---------------------------------
# Trades: 62
# Trade Winning: 47%
# Average Trade: 0.87%
# Average Win: 4.62%
# Average Loss: -2.42%
# Best Trade: 26.50%
# Worst Trade: -9.56%
# Worst Trade Date: 0 days 12:00:00
# Avg Days in Trade: 1 days 01:06:46
# ---------------------------------
# ---------------------------------
# ADXStrategy_154
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4953576961
# Max Drawdown: 51.9014190734
# Max Drawdown Duration: 2736
# Total Returns: 0.1007957537
# ---------------------------------
# Trades: 48
# Trade Winning: 38%
# Average Trade: 0.60%
# Average Win: 6.19%
# Average Loss: -2.76%
# Best Trade: 23.67%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 05:40:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_239
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4314951606
# Max Drawdown: 37.0185312593
# Max Drawdown Duration: 1498
# Total Returns: 0.5971584400
# ---------------------------------
# Trades: 39
# Trade Winning: 46%
# Average Trade: 1.73%
# Average Win: 6.70%
# Average Loss: -2.54%
# Best Trade: 39.78%
# Worst Trade: -12.26%
# Worst Trade Date: 4 days 18:00:00
# Avg Days in Trade: 1 days 11:04:37
# ---------------------------------
# ---------------------------------
# ADXStrategy_191
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4827260314
# Max Drawdown: 45.9510164894
# Max Drawdown Duration: 2736
# Total Returns: 0.0939620664
# ---------------------------------
# Trades: 30
# Trade Winning: 37%
# Average Trade: 0.78%
# Average Win: 8.37%
# Average Loss: -3.61%
# Best Trade: 22.11%
# Worst Trade: -11.48%
# Worst Trade Date: 2 days 03:00:00
# Avg Days in Trade: 1 days 21:20:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_142
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4370962420
# Max Drawdown: 50.9491827196
# Max Drawdown Duration: 2736
# Total Returns: 0.0718788492
# ---------------------------------
# Trades: 50
# Trade Winning: 34%
# Average Trade: 0.56%
# Average Win: 6.58%
# Average Loss: -2.55%
# Best Trade: 23.71%
# Worst Trade: -10.63%
# Worst Trade Date: 0 days 11:00:00
# Avg Days in Trade: 1 days 05:30:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_112
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8304633980
# Max Drawdown: 50.0522627484
# Max Drawdown Duration: 2736
# Total Returns: 0.2784711178
# ---------------------------------
# Trades: 51
# Trade Winning: 45%
# Average Trade: 0.93%
# Average Win: 5.74%
# Average Loss: -3.02%
# Best Trade: 33.40%
# Worst Trade: -12.30%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 1 days 06:56:28
# ---------------------------------
# ---------------------------------
# ADXStrategy_166
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4532235352
# Max Drawdown: 35.3689946243
# Max Drawdown Duration: 2736
# Total Returns: 0.0791176460
# ---------------------------------
# Trades: 47
# Trade Winning: 43%
# Average Trade: 0.57%
# Average Win: 5.33%
# Average Loss: -2.96%
# Best Trade: 26.71%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 05:37:01
# ---------------------------------
# ---------------------------------
# ADXStrategy_49
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8754644950
# Max Drawdown: 40.0975285787
# Max Drawdown Duration: 2736
# Total Returns: 0.3142611645
# ---------------------------------
# Trades: 75
# Trade Winning: 37%
# Average Trade: 0.72%
# Average Win: 5.42%
# Average Loss: -2.08%
# Best Trade: 26.63%
# Worst Trade: -9.40%
# Worst Trade Date: 1 days 12:00:00
# Avg Days in Trade: 0 days 22:04:48
# ---------------------------------
# ---------------------------------
# ADXStrategy_234
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3357112878
# Max Drawdown: 48.6370089179
# Max Drawdown Duration: 2736
# Total Returns: 0.0291696295
# ---------------------------------
# Trades: 51
# Trade Winning: 31%
# Average Trade: 0.53%
# Average Win: 7.03%
# Average Loss: -2.44%
# Best Trade: 43.91%
# Worst Trade: -11.97%
# Worst Trade Date: 4 days 21:00:00
# Avg Days in Trade: 1 days 02:41:11
# ---------------------------------
# ---------------------------------
# ADXStrategy_26
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1617718416
# Max Drawdown: 31.4418544339
# Max Drawdown Duration: 2277
# Total Returns: 0.5188722377
# ---------------------------------
# Trades: 115
# Trade Winning: 44%
# Average Trade: 0.71%
# Average Win: 4.11%
# Average Loss: -2.00%
# Best Trade: 29.51%
# Worst Trade: -7.83%
# Worst Trade Date: 0 days 10:00:00
# Avg Days in Trade: 0 days 14:46:57
# ---------------------------------
# ---------------------------------
# ADXStrategy_217
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.3172906003
# Max Drawdown: 62.9572626205
# Max Drawdown Duration: 2736
# Total Returns: -0.2550521915
# ---------------------------------
# Trades: 46
# Trade Winning: 37%
# Average Trade: -0.14%
# Average Win: 6.32%
# Average Loss: -3.92%
# Best Trade: 39.17%
# Worst Trade: -12.40%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 1 days 05:41:44
# ---------------------------------
# ---------------------------------
# ADXStrategy_69
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4388068865
# Max Drawdown: 38.4618217593
# Max Drawdown Duration: 2736
# Total Returns: 0.7353959880
# ---------------------------------
# Trades: 67
# Trade Winning: 37%
# Average Trade: 1.21%
# Average Win: 6.33%
# Average Loss: -1.83%
# Best Trade: 27.78%
# Worst Trade: -10.13%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 1 days 00:25:04
# ---------------------------------
# ---------------------------------
# ADXStrategy_126
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5302053087
# Max Drawdown: 57.9659841313
# Max Drawdown Duration: 2736
# Total Returns: 0.1154327950
# ---------------------------------
# Trades: 44
# Trade Winning: 36%
# Average Trade: 0.68%
# Average Win: 6.86%
# Average Loss: -2.86%
# Best Trade: 25.94%
# Worst Trade: -9.31%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 11:09:33
# ---------------------------------
# ---------------------------------
# ADXStrategy_66
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1935382984
# Max Drawdown: 40.6771728417
# Max Drawdown Duration: 2736
# Total Returns: 0.5365556902
# ---------------------------------
# Trades: 65
# Trade Winning: 43%
# Average Trade: 1.08%
# Average Win: 5.77%
# Average Loss: -2.48%
# Best Trade: 27.81%
# Worst Trade: -10.13%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 1 days 01:24:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_83
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1918139387
# Max Drawdown: 51.7335516402
# Max Drawdown Duration: 2736
# Total Returns: 0.5252693127
# ---------------------------------
# Trades: 66
# Trade Winning: 44%
# Average Trade: 1.01%
# Average Win: 4.97%
# Average Loss: -2.09%
# Best Trade: 26.50%
# Worst Trade: -11.55%
# Worst Trade Date: 2 days 00:00:00
# Avg Days in Trade: 0 days 23:50:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_198
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1088849357
# Max Drawdown: 54.5872499847
# Max Drawdown Duration: 2736
# Total Returns: -0.0750461790
# ---------------------------------
# Trades: 40
# Trade Winning: 40%
# Average Trade: 0.20%
# Average Win: 5.06%
# Average Loss: -3.04%
# Best Trade: 22.11%
# Worst Trade: -17.99%
# Worst Trade Date: 2 days 22:00:00
# Avg Days in Trade: 1 days 10:00:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_185
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6369772926
# Max Drawdown: 45.7669577364
# Max Drawdown Duration: 2736
# Total Returns: 0.1599144886
# ---------------------------------
# Trades: 39
# Trade Winning: 49%
# Average Trade: 0.78%
# Average Win: 5.16%
# Average Loss: -3.38%
# Best Trade: 22.11%
# Worst Trade: -7.75%
# Worst Trade Date: 3 days 00:00:00
# Avg Days in Trade: 1 days 10:38:28
# ---------------------------------
# ---------------------------------
# ADXStrategy_1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -4.8390717978
# Max Drawdown: 94.8815128354
# Max Drawdown Duration: 3567
# Total Returns: -0.9407574143
# ---------------------------------
# Trades: 663
# Trade Winning: 39%
# Average Trade: -0.20%
# Average Win: 1.79%
# Average Loss: -1.49%
# Best Trade: 10.19%
# Worst Trade: -7.69%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 02:57:39
# ---------------------------------
# ---------------------------------
# ADXStrategy_54
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0604656343
# Max Drawdown: 34.1752249147
# Max Drawdown Duration: 2736
# Total Returns: 0.4346159875
# ---------------------------------
# Trades: 75
# Trade Winning: 44%
# Average Trade: 0.84%
# Average Win: 4.80%
# Average Loss: -2.28%
# Best Trade: 23.37%
# Worst Trade: -8.68%
# Worst Trade Date: 2 days 00:00:00
# Avg Days in Trade: 0 days 22:12:00
# ---------------------------------
# ---------------------------------
# ADXStrategy_160
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7246572432
# Max Drawdown: 37.9563369255
# Max Drawdown Duration: 2736
# Total Returns: 0.2138200655
# ---------------------------------
# Trades: 45
# Trade Winning: 38%
# Average Trade: 0.84%
# Average Win: 6.18%
# Average Loss: -2.40%
# Best Trade: 31.95%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 07:34:40
# ---------------------------------
# ---------------------------------
# ADXStrategy_172
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5626069591
# Max Drawdown: 43.2746693657
# Max Drawdown Duration: 2736
# Total Returns: 0.1328695041
# ---------------------------------
# Trades: 46
# Trade Winning: 39%
# Average Trade: 0.64%
# Average Win: 5.32%
# Average Loss: -2.36%
# Best Trade: 25.26%
# Worst Trade: -8.95%
# Worst Trade Date: 2 days 22:00:00
# Avg Days in Trade: 1 days 06:28:42
# ---------------------------------
# ---------------------------------
# ADXStrategy_148
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7318448417
# Max Drawdown: 46.1225824319
# Max Drawdown Duration: 2736
# Total Returns: 0.2277173224
# ---------------------------------
# Trades: 43
# Trade Winning: 35%
# Average Trade: 0.91%
# Average Win: 7.12%
# Average Loss: -2.42%
# Best Trade: 23.66%
# Worst Trade: -9.93%
# Worst Trade Date: 1 days 22:00:00
# Avg Days in Trade: 1 days 10:01:24
# ---------------------------------
# ---------------------------------
# ADXStrategy_101
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8713039528
# Max Drawdown: 53.1600102521
# Max Drawdown Duration: 2736
# Total Returns: 0.3058593252
# ---------------------------------
# Trades: 57
# Trade Winning: 46%
# Average Trade: 0.86%
# Average Win: 4.96%
# Average Loss: -2.58%
# Best Trade: 24.74%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 03:33:41
# ---------------------------------
# ---------------------------------
# ADXStrategy_15
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9288394851
# Max Drawdown: 46.6430801675
# Max Drawdown Duration: 2040
# Total Returns: 0.3633567554
# ---------------------------------
# Trades: 155
# Trade Winning: 43%
# Average Trade: 0.48%
# Average Win: 4.03%
# Average Loss: -2.15%
# Best Trade: 21.65%
# Worst Trade: -10.88%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 11:07:21
# ---------------------------------
# ---------------------------------
# ADXStrategy_137
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3931810548
# Max Drawdown: 58.6371144796
# Max Drawdown Duration: 2736
# Total Returns: 0.0420989739
# ---------------------------------
# Trades: 45
# Trade Winning: 36%
# Average Trade: 0.56%
# Average Win: 6.96%
# Average Loss: -2.97%
# Best Trade: 27.50%
# Worst Trade: -10.41%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 1 days 09:06:40
# ---------------------------------
# ---------------------------------
# ADXStrategy_72
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2799374667
# Max Drawdown: 38.6631201184
# Max Drawdown Duration: 2736
# Total Returns: 0.5804465180
# ---------------------------------
# Trades: 69
# Trade Winning: 38%
# Average Trade: 1.04%
# Average Win: 5.97%
# Average Loss: -1.94%
# Best Trade: 28.10%
# Worst Trade: -11.49%
# Worst Trade Date: 1 days 18:00:00
# Avg Days in Trade: 0 days 23:13:55
# ---------------------------------
# ---------------------------------
# ADXStrategy_93
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0618342412
# Max Drawdown: 51.2075926912
# Max Drawdown Duration: 2736
# Total Returns: 0.4146778463
# ---------------------------------
# Trades: 56
# Trade Winning: 39%
# Average Trade: 1.00%
# Average Win: 5.85%
# Average Loss: -2.13%
# Best Trade: 27.10%
# Worst Trade: -9.96%
# Worst Trade Date: 1 days 04:00:00
# Avg Days in Trade: 1 days 03:55:43
# ---------------------------------
# ---------------------------------
# ADXStrategy_116
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9355985795
# Max Drawdown: 55.2173034587
# Max Drawdown Duration: 2736
# Total Returns: 0.3555126778
# ---------------------------------
# Trades: 53
# Trade Winning: 42%
# Average Trade: 1.04%
# Average Win: 6.25%
# Average Loss: -2.66%
# Best Trade: 31.27%
# Worst Trade: -16.16%
# Worst Trade Date: 1 days 03:00:00
# Avg Days in Trade: 1 days 05:39:37
# ---------------------------------
# ---------------------------------
# ADXStrategy_222
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0928543600
# Max Drawdown: 58.4235880161
# Max Drawdown Duration: 2736
# Total Returns: -0.0852492209
# ---------------------------------
# Trades: 53
# Trade Winning: 32%
# Average Trade: 0.33%
# Average Win: 6.73%
# Average Loss: -2.70%
# Best Trade: 46.58%
# Worst Trade: -14.00%
# Worst Trade Date: 1 days 04:00:00
# Avg Days in Trade: 1 days 01:36:14
# ---------------------------------
# ---------------------------------
# ADXStrategy_33
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5480311968
# Max Drawdown: 39.7229692547
# Max Drawdown Duration: 2510
# Total Returns: 0.1282598653
# ---------------------------------
# Trades: 113
# Trade Winning: 35%
# Average Trade: 0.43%
# Average Win: 4.61%
# Average Loss: -1.86%
# Best Trade: 29.78%
# Worst Trade: -10.20%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 14:40:53
# ---------------------------------
# ---------------------------------
# ADXStrategy_45
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7186582507
# Max Drawdown: 49.0942456706
# Max Drawdown Duration: 2277
# Total Returns: 0.2226761436
# ---------------------------------
# Trades: 77
# Trade Winning: 39%
# Average Trade: 0.63%
# Average Win: 5.64%
# Average Loss: -2.56%
# Best Trade: 26.82%
# Worst Trade: -6.97%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 21:49:05
# ---------------------------------
# ---------------------------------
# ADXStrategy_211
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.1092852149
# Max Drawdown: 62.5978466207
# Max Drawdown Duration: 2736
# Total Returns: -0.1543641115
# ---------------------------------
# Trades: 44
# Trade Winning: 39%
# Average Trade: 0.10%
# Average Win: 5.91%
# Average Loss: -3.55%
# Best Trade: 28.45%
# Worst Trade: -16.22%
# Worst Trade Date: 0 days 19:00:00
# Avg Days in Trade: 1 days 07:08:11
# ---------------------------------
# ---------------------------------
# ADXStrategy_20
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9037118035
# Max Drawdown: 25.8931899632
# Max Drawdown Duration: 965
# Total Returns: 1.3075170323
# ---------------------------------
# Trades: 125
# Trade Winning: 44%
# Average Trade: 1.02%
# Average Win: 4.84%
# Average Loss: -1.98%
# Best Trade: 31.17%
# Worst Trade: -7.86%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 13:12:58
# ---------------------------------
# ---------------------------------
# ADXStrategy_20
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9037118035
# Max Drawdown: 25.8931899632
# Max Drawdown Duration: 965
# Total Returns: 1.3075170323
# ---------------------------------
# Trades: 125
# Trade Winning: 44%
# Average Trade: 1.02%
# Average Win: 4.84%
# Average Loss: -1.98%
# Best Trade: 31.17%
# Worst Trade: -7.86%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 13:12:58
# ---------------------------------

# %%
myBopt.plot_acquisition()

# %%
myBopt.plot_convergence()

# %%
myBopt.x_opt
# Out:
# array([20.])

# %%
myBopt.fx_opt
# Out:
# -1.3075170322687915

# %%
myBopt.X
# Out:
# array([[ 36.],
#        [ 77.],
#        [178.],
#        [ 19.],
#        [206.],
#        [120.],
#        [ 60.],
#        [ 97.],
#        [132.],
#        [227.],
#        [ 41.],
#        [ 60.],
#        [  8.],
#        [ 20.],
#        [ 22.],
#        [ 30.],
#        [105.],
#        [ 89.],
#        [154.],
#        [239.],
#        [191.],
#        [142.],
#        [112.],
#        [166.],
#        [ 49.],
#        [234.],
#        [ 26.],
#        [217.],
#        [ 69.],
#        [126.],
#        [ 66.],
#        [ 83.],
#        [198.],
#        [185.],
#        [  1.],
#        [ 54.],
#        [160.],
#        [172.],
#        [148.],
#        [101.],
#        [ 15.],
#        [137.],
#        [ 72.],
#        [ 93.],
#        [116.],
#        [222.],
#        [ 33.],
#        [ 45.],
#        [211.],
#        [ 20.],
#        [ 20.]])

# %%
myBopt.Y
# Out:
# array([[-0.61063359],
#        [-0.22413871],
#        [-0.08597017],
#        [-1.20405125],
#        [ 0.21263299],
#        [-0.39037204],
#        [-0.167732  ],
#        [-0.50110179],
#        [-0.33587147],
#        [-0.11462262],
#        [-0.40406063],
#        [-0.167732  ],
#        [ 0.54623105],
#        [-1.30751703],
#        [-1.037714  ],
#        [-0.64525789],
#        [-0.42064309],
#        [-0.36498437],
#        [-0.10079575],
#        [-0.59715844],
#        [-0.09396207],
#        [-0.07187885],
#        [-0.27847112],
#        [-0.07911765],
#        [-0.31426116],
#        [-0.02916963],
#        [-0.51887224],
#        [ 0.25505219],
#        [-0.73539599],
#        [-0.1154328 ],
#        [-0.53655569],
#        [-0.52526931],
#        [ 0.07504618],
#        [-0.15991449],
#        [ 0.94075741],
#        [-0.43461599],
#        [-0.21382007],
#        [-0.1328695 ],
#        [-0.22771732],
#        [-0.30585933],
#        [-0.36335676],
#        [-0.04209897],
#        [-0.58044652],
#        [-0.41467785],
#        [-0.35551268],
#        [ 0.08524922],
#        [-0.12825987],
#        [-0.22267614],
#        [ 0.15436411],
#        [-1.30751703],
#        [-1.30751703]])

# %%
myBopt.model.model
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 35.948297578072015<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 2<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>             value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  Mat52.variance         </td><td class=tg-right>0.7263691473796328</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Mat52.lengthscale      </td><td class=tg-right> 4.084670923680901</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>             1e-06</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# </table>
