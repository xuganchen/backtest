# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

from BayesianOptimization.bayesian_optimization import BayesianOptimization

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from MACD_RSIStrategy import MACD_RSIStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
def run_backtest(config, trading_data, ohlc_data, short_window, delta_window, window, s, b):
    short_window = int(short_window)
    long_window = short_window + int(delta_window)
    window = int(window)
    s = int(s)
    b = int(b)
    config['title'] = "MACD_RSIStrategy" + "_" + str(short_window) + "_" + str(long_window) + "_" + str(window) + "_" + str(s) + "_" + str(b)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")

    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data = trading_data, ohlc_data = ohlc_data
    )
    strategy = MACD_RSIStrategy(config, events_queue, data_handler,
                            short_window=short_window, long_window=long_window,
                            window=window, s=s, b=b)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler= data_handler)

    results = backtest.start_trading()
    
    return (results['cum_returns'][-1] - 1)

# %% [markdown]
# ## Setting

# %%
config = {
    "csv_dir": "C:/backtest/Binance",
    "out_dir": "C:/backtest/results/MACD_RSIStrategy",
    "title": "MACD_RSIStrategy",
    "is_plot": False,
    "save_plot": False,
    "save_tradelog": False,
    "start_date": pd.Timestamp("2017-07-01T00:0:00", freq = "60" + "T"),    # str(freq) + "T"
    "end_date": pd.Timestamp("2018-04-01T00:00:00", freq = "60" + "T"),
    "equity": 1.0,
    "freq": 60,      # min
    "commission_ratio": 0.001,
    "suggested_quantity": None,     # None or a value
    "max_quantity": None,           # None or a value, Maximum purchase quantity
    "min_quantity": None,           # None or a value, Minimum purchase quantity
    "min_handheld_cash": None,      # None or a value, Minimum handheld funds
    "exchange": "Binance",
    "tickers": ['BTCUSDT']
}

# %%
# trading_data = {}
# for ticker in config['tickers']:
#     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
#     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

ohlc_data = {}
for ticker in config['tickers']:
    # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
    ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker +'_OHLC_60min.h5', key=ticker)

trading_data = None

# %%
gp_params = {"alpha": 1e-5}

# %% [markdown]
# ## Acquisition Function "Upper Confidence Bound"

# %% [markdown]
# * Prefer exploitation (kappa=1.0)
#
# * Prefer exploration (kappa=10)

# %% [markdown]
# ## Acquisition Function "Expected Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)

# %%
BO = BayesianOptimization(
    run_backtest,
    {'short_window': (1, 120),
    'delta_window': (1, 120),
    'window': (1, 240),
   's': (55, 85),
  'b': (15, 45)},
    is_int = [1, 1, 1, 1, 1], 
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
# BO.explore({
#     'short_window': np.arange(1, 120, 20),
#     'delta_window': np.arange(1, 120, 20)
#     },
#     eager=True)
BO.maximize(init_points=80, n_iter=120, acq="ei", xi=0.01, **gp_params)
# Out:
# Initialization
# ---------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |         b |   delta_window |         s |   short_window |    window |
# ---------------------------------
# MACD_RSIStrategy_38_126_61_65_39
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5296220415
# Sortino Ratio: nan
# Max Drawdown: 0.1240292208
# Max Drawdown Duration: 198100
# Total Returns: 0.0150112969
# Annualized Returns: 0.0353301883
# Compound Annual Growth Rate: 0.0356897569
# ---------------------------------
# Trades: 1
# Trade Winning: 100.00%
# Average Trade: 1.70%
# Average Win: 1.70%
# Average Loss: nan%
# Best Trade: 1.70%
# Worst Trade: 1.70%
# Worst Trade Date: 0 days 11:00:00
# Avg Days in Trade: 0 days 11:00:00
# ---------------------------------
#     1 | 00m09s |    0.01501 | 39.000000 | 88.000000 | 65.000000 | 38.000000 | 61.000000 |
# ---------------------------------
# MACD_RSIStrategy_108_116_234_68_17
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     2 | 00m08s |    0.00000 | 17.000000 | 8.000000 | 68.000000 | 108.000000 | 234.000000 |
# ---------------------------------
# MACD_RSIStrategy_13_40_153_58_32
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     3 | 00m06s |    0.00000 | 32.000000 | 27.000000 | 58.000000 | 13.000000 | 153.000000 |
# ---------------------------------
# MACD_RSIStrategy_73_99_83_75_19
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     4 | 00m08s |    0.00000 | 19.000000 | 26.000000 | 75.000000 | 73.000000 | 83.000000 |
# ---------------------------------
# MACD_RSIStrategy_10_115_116_57_15
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     5 | 00m09s |    0.00000 | 15.000000 | 105.000000 | 57.000000 | 10.000000 | 116.000000 |
# ---------------------------------
# MACD_RSIStrategy_76_99_98_69_43
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6676630254
# Sortino Ratio: nan
# Max Drawdown: 0.0377456786
# Max Drawdown Duration: 326000
# Total Returns: 0.0412615928
# Annualized Returns: 0.0971121850
# Compound Annual Growth Rate: 0.0998371727
# ---------------------------------
# Trades: 2
# Trade Winning: 100.00%
# Average Trade: 2.25%
# Average Win: 2.25%
# Average Loss: nan%
# Best Trade: 3.17%
# Worst Trade: 1.33%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 0 days 08:30:00
# ---------------------------------
#     6 | 00m08s |    0.04126 | 43.000000 | 23.000000 | 69.000000 | 76.000000 | 98.000000 |
# ---------------------------------
# MACD_RSIStrategy_6_16_131_69_35
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     7 | 00m05s |    0.00000 | 35.000000 | 10.000000 | 69.000000 | 6.000000 | 131.000000 |
# ---------------------------------
# MACD_RSIStrategy_80_148_237_55_29
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     8 | 00m10s |    0.00000 | 29.000000 | 68.000000 | 55.000000 | 80.000000 | 237.000000 |
# ---------------------------------
# MACD_RSIStrategy_65_169_221_84_32
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-058453561779> in <module>()
#      19 #     },
#      20 #     eager=True)
# ---> 21 BO.maximize(init_points=80, n_iter=120, acq="ei", xi=0.01, **gp_params)
#
# C:\backtest\backtest\BayesianOptimization\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     254             if self.verbose:
#     255                 self.plog.print_header()
# --> 256             self.initialize_points(init_points)
#     257
#     258         y_max = self.space.Y.max()
#
# C:\backtest\backtest\BayesianOptimization\bayesian_optimization.py in initialize_points(self, init_points)
#      96         # Evaluate target function at all initialization points
#      97         for x in self.init_points:
# ---> 98             y = self._observe_point(x)
#      99
#     100         # Add the points from `self.initialize` to the observations
#
# C:\backtest\backtest\BayesianOptimization\bayesian_optimization.py in _observe_point(self, x)
#     111
#     112     def _observe_point(self, x):
# --> 113         y = self.space.observe_point(x)
#     114         if self.verbose:
#     115             self.plog.print_step(x, y)
#
# C:\backtest\backtest\BayesianOptimization\target_space.py in observe_point(self, x)
#     153             if self.invariant is not None:
#     154                 params.update(invariant)
# --> 155             y = self.target_func(**params)
#     156             self.add_observation(x, y)
#     157         return y
#
# <ipython-input-4-2e2a9338c760> in run_backtest(config, trading_data, ohlc_data, short_window, delta_window, window, s, b)
#      23                         data_handler= data_handler)
#      24
# ---> 25     results = backtest.start_trading()
#      26
#      27     return (results['cum_returns'][-1] - 1)
#
# C:\backtest\backtest\Backtest\backtest.py in start_trading(self)
#     212         Start trading()
#     213         '''
# --> 214         self._run_backtest()
#     215         results = self._output_performance()
#     216         return results
#
# C:\backtest\backtest\Backtest\backtest.py in _run_backtest(self)
#     134                               and generate the SIGNAL event
#     135                             '''
# --> 136                             self.strategy.generate_signals(event)
#     137
#     138                         if event.type == EventType.SIGNAL:
#
# C:\backtest\backtest\MACD_RSIStrategy.py in generate_signals(self, event)
#      59                 self.updown[bar_date] = bars[-1] - bars[-2]
#      60                 updown = self.updown[bar_date - self.window: bar_date]
# ---> 61                 up = np.sum(updown.loc[updown > 0])
#      62                 down = -1 * np.sum(updown.loc[updown < 0])
#      63                 if down == 0:
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1581             return self._get_slice_axis(key, axis=axis)
#    1582         elif is_bool_indexer(key):
# -> 1583             return self._getbool_axis(key, axis=axis)
#    1584         elif is_list_like_indexer(key):
#    1585
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#    1389         inds, = key.nonzero()
#    1390         try:
# -> 1391             return self.obj._take(inds, axis=axis, convert=False)
#    1392         except Exception as detail:
#    1393             raise self._exception(detail)
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in _take(self, indices, axis, convert, is_copy)
#    2738
#    2739         indices = _ensure_platform_int(indices)
# -> 2740         new_index = self.index.take(indices)
#    2741         new_values = self._values.take(indices)
#    2742
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\datetimelike.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#     402                                            allow_fill=allow_fill,
#     403                                            fill_value=fill_value,
# --> 404                                            na_value=iNaT)
#     405
#     406         # keep freq in PeriodIndex, reset otherwise
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _assert_take_fillable(self, values, indices, allow_fill, fill_value, na_value)
#    1857                 taken[mask] = na_value
#    1858         else:
# -> 1859             taken = values.take(indices)
#    1860         return taken
#    1861
#
# KeyboardInterrupt:

# %%
print(BO.res['max'])
# Out:
# {'max_val': 2.0538804896742766, 'max_params': {'short_window': 13.0, 'delta_window': 20.0, 'window': 153.0, 'a': 0.1}}

# %%
BO.maximize(init_points=0, n_iter=120, acq="ei", xi=0.0001, **gp_params)
# Out:
# Bayesian Optimization
# ---------------------------------------------------------------------------------------
#  Step |   Time |      Value |         a |   delta_window |   short_window |    window |
# ---------------------------------
# MACD_BOLLStrategy2_12_51_120_0.5207968416993504
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.4417945131
# Sortino Ratio: 5.8964665091
# Max Drawdown: 0.2460769210
# Max Drawdown Duration: 132200
# Total Returns: 1.6798811255
# Annualized Returns: 3.9537234443
# Compound Annual Growth Rate: 9.1765671131
# ---------------------------------
# Trades: 33
# Trade Winning: 54.55%
# Average Trade: 3.63%
# Average Win: 9.62%
# Average Loss: -3.56%
# Best Trade: 26.45%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 10:00:00
# Avg Days in Trade: 1 days 23:43:38
# ---------------------------------
#   151 | 00m27s |    1.67988 | 0.520797 | 39.000000 | 12.000000 | 120.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_12_38_194_0.1700342914822503
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.2109470792
# Sortino Ratio: 6.0170427807
# Max Drawdown: 0.3262853057
# Max Drawdown Duration: 250900
# Total Returns: 1.4690079538
# Annualized Returns: 3.4574179676
# Compound Annual Growth Rate: 7.3913235819
# ---------------------------------
# Trades: 36
# Trade Winning: 44.44%
# Average Trade: 3.10%
# Average Win: 10.47%
# Average Loss: -2.79%
# Best Trade: 30.32%
# Worst Trade: -6.27%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 1 days 15:16:40
# ---------------------------------
#   152 | 00m32s |    1.46901 | 0.170034 | 26.000000 | 12.000000 | 194.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_11_71_104_0.3290337234559117
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.3265957879
# Sortino Ratio: 4.9761591812
# Max Drawdown: 0.2705582865
# Max Drawdown Duration: 124900
# Total Returns: 1.8009963850
# Annualized Returns: 4.2387770909
# Compound Annual Growth Rate: 10.2923125941
# ---------------------------------
# Trades: 26
# Trade Winning: 50.00%
# Average Trade: 4.79%
# Average Win: 12.96%
# Average Loss: -3.38%
# Best Trade: 36.72%
# Worst Trade: -6.90%
# Worst Trade Date: 1 days 01:00:00
# Avg Days in Trade: 2 days 21:11:32
# ---------------------------------
#   153 | 00m32s |    1.80100 | 0.329034 | 60.000000 | 11.000000 | 104.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_41_81_214_0.6437401037008461
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9273733586
# Sortino Ratio: 2.4038799071
# Max Drawdown: 0.3990990595
# Max Drawdown Duration: 273500
# Total Returns: 0.6377970629
# Annualized Returns: 1.5011021684
# Compound Annual Growth Rate: 2.1935728865
# ---------------------------------
# Trades: 14
# Trade Winning: 50.00%
# Average Trade: 4.23%
# Average Win: 12.65%
# Average Loss: -4.18%
# Best Trade: 22.83%
# Worst Trade: -6.70%
# Worst Trade Date: 1 days 19:00:00
# Avg Days in Trade: 4 days 17:21:26
# ---------------------------------
#   154 | 00m46s |    0.63780 | 0.643740 | 40.000000 | 41.000000 | 214.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_12_32_151_1.335538239856611
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.5975946300
# Sortino Ratio: 3.3022142367
# Max Drawdown: 0.2296106113
# Max Drawdown Duration: 250900
# Total Returns: 0.8992772673
# Annualized Returns: 2.1165150084
# Compound Annual Growth Rate: 3.5256208120
# ---------------------------------
# Trades: 28
# Trade Winning: 53.57%
# Average Trade: 2.87%
# Average Win: 8.44%
# Average Loss: -3.56%
# Best Trade: 31.49%
# Worst Trade: -10.35%
# Worst Trade Date: 0 days 13:00:00
# Avg Days in Trade: 1 days 15:02:09
# ---------------------------------
#   155 | 00m35s |    0.89928 | 1.335538 | 20.000000 | 12.000000 | 151.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_30_124_20_2.145328869832084
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0639713720
# Sortino Ratio: 2.9921732180
# Max Drawdown: 0.2892860139
# Max Drawdown Duration: 273500
# Total Returns: 0.6516088184
# Annualized Returns: 1.5336091481
# Compound Annual Growth Rate: 2.2573210194
# ---------------------------------
# Trades: 20
# Trade Winning: 50.00%
# Average Trade: 3.05%
# Average Win: 8.77%
# Average Loss: -2.67%
# Best Trade: 23.61%
# Worst Trade: -9.99%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 2 days 02:36:00
# ---------------------------------
#   156 | 00m22s |    0.65161 | 2.145329 | 94.000000 | 30.000000 | 20.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_97_148_146_1.5333444522576916
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4883901108
# Sortino Ratio: 1.8108232747
# Max Drawdown: 0.5576981008
# Max Drawdown Duration: 250900
# Total Returns: 0.4752101889
# Annualized Returns: 1.1184420352
# Compound Annual Growth Rate: 1.4969511527
# ---------------------------------
# Trades: 8
# Trade Winning: 37.50%
# Average Trade: 10.74%
# Average Win: 45.52%
# Average Loss: -10.12%
# Best Trade: 119.04%
# Worst Trade: -21.47%
# Worst Trade Date: 3 days 00:00:00
# Avg Days in Trade: 9 days 05:15:00
# ---------------------------------
#   157 | 00m31s |    0.47521 | 1.533344 | 51.000000 | 97.000000 | 146.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_63_120_87_0.8578919584411864
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4777484251
# Sortino Ratio: 0.5240699811
# Max Drawdown: 0.5814360123
# Max Drawdown Duration: 273500
# Total Returns: 0.0232330611
# Annualized Returns: 0.0546807133
# Compound Annual Growth Rate: 0.0555428489
# ---------------------------------
# Trades: 21
# Trade Winning: 42.86%
# Average Trade: 0.88%
# Average Win: 10.93%
# Average Loss: -6.66%
# Best Trade: 24.98%
# Worst Trade: -15.67%
# Worst Trade Date: 1 days 14:00:00
# Avg Days in Trade: 3 days 04:02:51
# ---------------------------------
#   158 | 00m24s |    0.02323 | 0.857892 | 57.000000 | 63.000000 | 87.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_67_142_145_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.9475801935
# Sortino Ratio: 3.4663000069
# Max Drawdown: 0.2638492433
# Max Drawdown Duration: 154800
# Total Returns: 1.0071374615
# Annualized Returns: 2.3703718867
# Compound Annual Growth Rate: 4.1539172051
# ---------------------------------
# Trades: 2
# Trade Winning: 100.00%
# Average Trade: 49.86%
# Average Win: 49.86%
# Average Loss: nan%
# Best Trade: 97.90%
# Worst Trade: 1.83%
# Worst Trade Date: 7 days 21:00:00
# Avg Days in Trade: 16 days 10:30:00
# ---------------------------------
#   159 | 00m27s |    1.00714 | 3.000000 | 75.000000 | 67.000000 | 145.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_5_93_113_1.5796412945079858
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1439904632
# Sortino Ratio: 2.2242635944
# Max Drawdown: 0.5219553107
# Max Drawdown Duration: 273500
# Total Returns: 0.8126925774
# Annualized Returns: 1.9127315901
# Compound Annual Growth Rate: 3.0549438949
# ---------------------------------
# Trades: 14
# Trade Winning: 50.00%
# Average Trade: 5.41%
# Average Win: 17.73%
# Average Loss: -6.91%
# Best Trade: 24.98%
# Worst Trade: -13.26%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 4 days 18:25:43
# ---------------------------------
#   160 | 00m22s |    0.81269 | 1.579641 | 88.000000 | 5.000000 | 113.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_49_130_238_1.0341129349108413
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.0169923575
# Sortino Ratio: 4.4411435556
# Max Drawdown: 0.2973260541
# Max Drawdown Duration: 250900
# Total Returns: 1.3194650247
# Annualized Returns: 3.1054577153
# Compound Annual Growth Rate: 6.2438100560
# ---------------------------------
# Trades: 8
# Trade Winning: 75.00%
# Average Trade: 14.67%
# Average Win: 22.30%
# Average Loss: -8.21%
# Best Trade: 95.67%
# Worst Trade: -13.04%
# Worst Trade Date: 2 days 07:00:00
# Avg Days in Trade: 8 days 06:07:30
# ---------------------------------
#   161 | 00m31s |    1.31947 | 1.034113 | 81.000000 | 49.000000 | 238.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_111_207_7_1.054283348477707
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -1.1613672883
# Sortino Ratio: -1.6459789431
# Max Drawdown: 0.5358871759
# Max Drawdown Duration: 273500
# Total Returns: -0.3034949586
# Annualized Returns: -0.7142976456
# Compound Annual Growth Rate: -0.5731151571
# ---------------------------------
# Trades: 104
# Trade Winning: 36.54%
# Average Trade: -0.08%
# Average Win: 3.56%
# Average Loss: -2.18%
# Best Trade: 13.38%
# Worst Trade: -8.32%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 0 days 10:08:05
# ---------------------------------
#   162 | 00m28s |   -0.30349 | 1.054283 | 96.000000 | 111.000000 | 7.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_76_97_105_0.7697683204176138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1499320538
# Sortino Ratio: 0.1798482541
# Max Drawdown: 0.6088124782
# Max Drawdown Duration: 273500
# Total Returns: -0.0994459659
# Annualized Returns: -0.2340533749
# Compound Annual Growth Rate: -0.2184884133
# ---------------------------------
# Trades: 24
# Trade Winning: 41.67%
# Average Trade: 0.25%
# Average Win: 9.62%
# Average Loss: -6.44%
# Best Trade: 20.88%
# Worst Trade: -19.12%
# Worst Trade Date: 1 days 04:00:00
# Avg Days in Trade: 2 days 19:35:00
# ---------------------------------
#   163 | 00m27s |   -0.09945 | 0.769768 | 21.000000 | 76.000000 | 105.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_66_87_39_0.45541672102635317
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.5259995219
# Sortino Ratio: 4.0745635631
# Max Drawdown: 0.2267524957
# Max Drawdown Duration: 167100
# Total Returns: 0.9972765625
# Annualized Returns: 2.3471635378
# Compound Annual Growth Rate: 4.0945209626
# ---------------------------------
# Trades: 41
# Trade Winning: 46.34%
# Average Trade: 2.15%
# Average Win: 7.47%
# Average Loss: -2.45%
# Best Trade: 30.46%
# Worst Trade: -8.39%
# Worst Trade Date: 0 days 15:00:00
# Avg Days in Trade: 1 days 05:08:47
# ---------------------------------
#   164 | 00m27s |    0.99728 | 0.455417 | 21.000000 | 66.000000 | 39.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_104_145_2_2.7021319609278756
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#   165 | 00m24s |    0.00000 | 2.702132 | 41.000000 | 104.000000 | 2.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_79_145_184_1.9286634299016254
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.0931073305
# Sortino Ratio: 4.1834802885
# Max Drawdown: 0.2781478368
# Max Drawdown Duration: 250900
# Total Returns: 1.2435070294
# Annualized Returns: 2.9266850021
# Compound Annual Growth Rate: 5.6978197706
# ---------------------------------
# Trades: 5
# Trade Winning: 60.00%
# Average Trade: 24.72%
# Average Win: 45.35%
# Average Loss: -6.24%
# Best Trade: 118.90%
# Worst Trade: -9.32%
# Worst Trade Date: 4 days 14:00:00
# Avg Days in Trade: 12 days 07:00:00
# ---------------------------------
#   166 | 00m33s |    1.24351 | 1.928663 | 66.000000 | 79.000000 | 184.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_84_132_202_2.6130355296523073
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.2207663080
# Sortino Ratio: 2.8369290887
# Max Drawdown: 0.2889189739
# Max Drawdown Duration: 250900
# Total Returns: 0.6996226327
# Annualized Returns: 1.6466131816
# Compound Annual Growth Rate: 2.4845886511
# ---------------------------------
# Trades: 4
# Trade Winning: 50.00%
# Average Trade: 20.38%
# Average Win: 47.56%
# Average Loss: -6.80%
# Best Trade: 92.22%
# Worst Trade: -11.67%
# Worst Trade Date: 4 days 12:00:00
# Avg Days in Trade: 10 days 23:30:00
# ---------------------------------
#   167 | 00m33s |    0.69962 | 2.613036 | 48.000000 | 84.000000 | 202.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_103_197_207_1.6453291002001154
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0509154278
# Sortino Ratio: 2.5852659799
# Max Drawdown: 0.3926769882
# Max Drawdown Duration: 250900
# Total Returns: 0.7151563485
# Annualized Returns: 1.6831729213
# Compound Annual Growth Rate: 2.5600080439
# ---------------------------------
# Trades: 5
# Trade Winning: 60.00%
# Average Trade: 16.20%
# Average Win: 34.77%
# Average Loss: -11.65%
# Best Trade: 85.43%
# Worst Trade: -13.17%
# Worst Trade Date: 5 days 00:00:00
# Avg Days in Trade: 12 days 20:24:00
# ---------------------------------
#   168 | 00m35s |    0.71516 | 1.645329 | 94.000000 | 103.000000 | 207.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_69_146_179_1.7761893363214112
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.6172011970
# Sortino Ratio: 3.7225069635
# Max Drawdown: 0.3636476061
# Max Drawdown Duration: 250900
# Total Returns: 1.0189578720
# Annualized Returns: 2.3981920899
# Compound Annual Growth Rate: 4.2256387029
# ---------------------------------
# Trades: 7
# Trade Winning: 42.86%
# Average Trade: 16.59%
# Average Win: 47.76%
# Average Loss: -6.78%
# Best Trade: 120.41%
# Worst Trade: -15.48%
# Worst Trade Date: 2 days 09:00:00
# Avg Days in Trade: 9 days 13:34:17
# ---------------------------------
#   169 | 00m32s |    1.01896 | 1.776189 | 77.000000 | 69.000000 | 179.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_40_95_64_2.642189636960302
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0413806571
# Sortino Ratio: 0.0443212380
# Max Drawdown: 0.5953771488
# Max Drawdown Duration: 273500
# Total Returns: -0.0916436144
# Annualized Returns: -0.2156899682
# Compound Annual Growth Rate: -0.2024588907
# ---------------------------------
# Trades: 12
# Trade Winning: 50.00%
# Average Trade: -0.03%
# Average Win: 8.65%
# Average Loss: -8.72%
# Best Trade: 18.79%
# Worst Trade: -17.50%
# Worst Trade Date: 2 days 08:00:00
# Avg Days in Trade: 4 days 09:30:00
# ---------------------------------
#   170 | 00m24s |   -0.09164 | 2.642190 | 55.000000 | 40.000000 | 64.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_12_63_105_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.9298585212
# Sortino Ratio: 5.2915787658
# Max Drawdown: 0.2982556296
# Max Drawdown Duration: 227600
# Total Returns: 1.4739720099
# Annualized Returns: 3.4691012377
# Compound Annual Growth Rate: 7.4310851116
# ---------------------------------
# Trades: 42
# Trade Winning: 38.10%
# Average Trade: 2.82%
# Average Win: 11.57%
# Average Loss: -2.57%
# Best Trade: 41.93%
# Worst Trade: -6.63%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 1 days 18:25:43
# ---------------------------------
#   171 | 00m26s |    1.47397 | 0.100000 | 51.000000 | 12.000000 | 105.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_17_105_189_1.0628328622039742
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8337925762
# Sortino Ratio: 2.6329064790
# Max Drawdown: 0.4166561957
# Max Drawdown Duration: 273500
# Total Returns: 0.6029897177
# Annualized Returns: 1.4191805285
# Compound Annual Growth Rate: 2.0361241045
# ---------------------------------
# Trades: 14
# Trade Winning: 50.00%
# Average Trade: 4.30%
# Average Win: 14.08%
# Average Loss: -5.48%
# Best Trade: 26.75%
# Worst Trade: -13.11%
# Worst Trade Date: 1 days 01:00:00
# Avg Days in Trade: 4 days 17:04:17
# ---------------------------------
#   172 | 00m28s |    0.60299 | 1.062833 | 88.000000 | 17.000000 | 189.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_23_79_166_2.230022255659301
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.4025524078
# Sortino Ratio: 3.3429575598
# Max Drawdown: 0.2586466381
# Max Drawdown Duration: 273500
# Total Returns: 0.7037954874
# Annualized Returns: 1.6564343013
# Compound Annual Growth Rate: 2.5047575069
# ---------------------------------
# Trades: 8
# Trade Winning: 62.50%
# Average Trade: 7.63%
# Average Win: 14.59%
# Average Loss: -3.98%
# Best Trade: 25.83%
# Worst Trade: -7.03%
# Worst Trade Date: 1 days 15:00:00
# Avg Days in Trade: 5 days 01:45:00
# ---------------------------------
#   173 | 00m31s |    0.70380 | 2.230022 | 56.000000 | 23.000000 | 166.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_115_188_10_2.514689355205545
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8110713970
# Sortino Ratio: 1.1198769752
# Max Drawdown: 0.2638492433
# Max Drawdown Duration: 99000
# Total Returns: 0.1477320200
# Annualized Returns: 0.3476981448
# Compound Annual Growth Rate: 0.3830535671
# ---------------------------------
# Trades: 12
# Trade Winning: 41.67%
# Average Trade: 1.64%
# Average Win: 7.97%
# Average Loss: -2.88%
# Best Trade: 25.67%
# Worst Trade: -5.02%
# Worst Trade Date: 3 days 01:00:00
# Avg Days in Trade: 2 days 19:10:00
# ---------------------------------
#   174 | 00m27s |    0.14773 | 2.514689 | 73.000000 | 115.000000 | 10.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_10_69_61_0.8074776136688757
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.7997350207
# Sortino Ratio: 4.9787760152
# Max Drawdown: 0.2710774741
# Max Drawdown Duration: 94000
# Total Returns: 1.4209632125
# Annualized Returns: 3.3443411448
# Compound Annual Growth Rate: 7.0120632718
# ---------------------------------
# Trades: 27
# Trade Winning: 48.15%
# Average Trade: 4.06%
# Average Win: 12.15%
# Average Loss: -3.45%
# Best Trade: 37.27%
# Worst Trade: -8.18%
# Worst Trade Date: 0 days 20:00:00
# Avg Days in Trade: 2 days 22:08:53
# ---------------------------------
#   175 | 00m25s |    1.42096 | 0.807478 | 59.000000 | 10.000000 | 61.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_77_101_161_1.5122674705401775
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.4120487659
# Sortino Ratio: 2.6633752107
# Max Drawdown: 0.3440537073
# Max Drawdown Duration: 250900
# Total Returns: 0.9349573394
# Annualized Returns: 2.2004906752
# Compound Annual Growth Rate: 3.7282687506
# ---------------------------------
# Trades: 12
# Trade Winning: 58.33%
# Average Trade: 7.06%
# Average Win: 16.87%
# Average Loss: -6.67%
# Best Trade: 49.37%
# Worst Trade: -10.52%
# Worst Trade Date: 1 days 18:00:00
# Avg Days in Trade: 5 days 03:25:00
# ---------------------------------
#   176 | 00m28s |    0.93496 | 1.512267 | 24.000000 | 77.000000 | 161.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_104_157_20_2.5412658659259155
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9862025952
# Sortino Ratio: 2.9348614558
# Max Drawdown: 0.3469919168
# Max Drawdown Duration: 273500
# Total Returns: 0.6121247575
# Annualized Returns: 1.4406805147
# Compound Annual Growth Rate: 2.0770030670
# ---------------------------------
# Trades: 11
# Trade Winning: 54.55%
# Average Trade: 6.39%
# Average Win: 16.56%
# Average Loss: -5.82%
# Best Trade: 72.08%
# Worst Trade: -11.07%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 3 days 20:21:49
# ---------------------------------
#   177 | 00m29s |    0.61212 | 2.541266 | 53.000000 | 104.000000 | 20.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_59_77_41_0.16489191472806436
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3875971777
# Sortino Ratio: 3.9905903370
# Max Drawdown: 0.2343439596
# Max Drawdown Duration: 172500
# Total Returns: 0.9158553530
# Annualized Returns: 2.1555327491
# Compound Annual Growth Rate: 3.6191425443
# ---------------------------------
# Trades: 53
# Trade Winning: 32.08%
# Average Trade: 1.64%
# Average Win: 8.91%
# Average Loss: -1.79%
# Best Trade: 30.44%
# Worst Trade: -4.33%
# Worst Trade Date: 0 days 19:00:00
# Avg Days in Trade: 0 days 23:30:34
# ---------------------------------
#   178 | 00m28s |    0.91586 | 0.164892 | 18.000000 | 59.000000 | 41.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_84_186_56_2.36677267204405
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6190048846
# Sortino Ratio: 1.5126704479
# Max Drawdown: 0.3186525192
# Max Drawdown Duration: 178000
# Total Returns: 0.4643266719
# Annualized Returns: 1.0928268797
# Compound Annual Growth Rate: 1.4538110529
# ---------------------------------
# Trades: 8
# Trade Winning: 75.00%
# Average Trade: 5.24%
# Average Win: 7.47%
# Average Loss: -1.44%
# Best Trade: 15.42%
# Worst Trade: -2.18%
# Worst Trade Date: 4 days 09:00:00
# Avg Days in Trade: 5 days 04:22:30
# ---------------------------------
#   179 | 00m32s |    0.46433 | 2.366773 | 102.000000 | 84.000000 | 56.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_93_150_197_2.3047563385794656
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.9569505443
# Sortino Ratio: 4.0388900965
# Max Drawdown: 0.2730722466
# Max Drawdown Duration: 250900
# Total Returns: 1.1368773054
# Annualized Returns: 2.6757241255
# Compound Annual Growth Rate: 4.9725589614
# ---------------------------------
# Trades: 4
# Trade Winning: 75.00%
# Average Trade: 29.01%
# Average Win: 42.67%
# Average Loss: -11.97%
# Best Trade: 114.27%
# Worst Trade: -11.97%
# Worst Trade Date: 4 days 22:00:00
# Avg Days in Trade: 13 days 17:15:00
# ---------------------------------
#   180 | 00m35s |    1.13688 | 2.304756 | 57.000000 | 93.000000 | 197.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_98_132_116_2.271565147560386
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9255921921
# Sortino Ratio: 0.8697052003
# Max Drawdown: 0.5346162108
# Max Drawdown Duration: 250900
# Total Returns: 0.1975367976
# Annualized Returns: 0.4649173420
# Compound Annual Growth Rate: 0.5284758851
# ---------------------------------
# Trades: 7
# Trade Winning: 42.86%
# Average Trade: 8.73%
# Average Win: 39.80%
# Average Loss: -14.57%
# Best Trade: 109.66%
# Worst Trade: -23.88%
# Worst Trade Date: 3 days 08:00:00
# Avg Days in Trade: 7 days 19:00:00
# ---------------------------------
#   181 | 00m38s |    0.19754 | 2.271565 | 34.000000 | 98.000000 | 116.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_15_35_152_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.5765910163
# Sortino Ratio: 6.4952513363
# Max Drawdown: 0.2520595591
# Max Drawdown Duration: 227600
# Total Returns: 1.8296809341
# Annualized Returns: 4.3062882813
# Compound Annual Growth Rate: 10.5663749352
# ---------------------------------
# Trades: 36
# Trade Winning: 52.78%
# Average Trade: 3.45%
# Average Win: 8.87%
# Average Loss: -2.62%
# Best Trade: 30.32%
# Worst Trade: -5.73%
# Worst Trade Date: 1 days 05:00:00
# Avg Days in Trade: 1 days 17:00:00
# ---------------------------------
#   182 | 00m38s |    1.82968 | 0.100000 | 20.000000 | 15.000000 | 152.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_64_160_225_0.2810697104718336
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1050124206
# Sortino Ratio: 2.2431118512
# Max Drawdown: 0.5167223113
# Max Drawdown Duration: 250900
# Total Returns: 0.8765781426
# Annualized Returns: 2.0630909536
# Compound Annual Growth Rate: 3.3993495483
# ---------------------------------
# Trades: 12
# Trade Winning: 25.00%
# Average Trade: 9.84%
# Average Win: 56.77%
# Average Loss: -5.81%
# Best Trade: 130.79%
# Worst Trade: -11.04%
# Worst Trade Date: 5 days 07:00:00
# Avg Days in Trade: 6 days 06:45:00
# ---------------------------------
#   183 | 00m36s |    0.87658 | 0.281070 | 96.000000 | 64.000000 | 225.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_61_138_175_2.335990986706072
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.2162170651
# Sortino Ratio: 4.2747974514
# Max Drawdown: 0.2845500582
# Max Drawdown Duration: 250900
# Total Returns: 1.2621778378
# Annualized Returns: 2.9706281190
# Compound Annual Growth Rate: 5.8297482288
# ---------------------------------
# Trades: 4
# Trade Winning: 75.00%
# Average Trade: 30.72%
# Average Win: 44.01%
# Average Loss: -9.16%
# Best Trade: 116.75%
# Worst Trade: -9.16%
# Worst Trade Date: 4 days 02:00:00
# Avg Days in Trade: 12 days 23:30:00
# ---------------------------------
#   184 | 00m33s |    1.26218 | 2.335991 | 77.000000 | 61.000000 | 175.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_15_34_146_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.4021201808
# Sortino Ratio: 5.8474188188
# Max Drawdown: 0.2794511047
# Max Drawdown Duration: 227600
# Total Returns: 1.7193711559
# Annualized Returns: 4.0466661273
# Compound Annual Growth Rate: 9.5330331436
# ---------------------------------
# Trades: 41
# Trade Winning: 48.78%
# Average Trade: 2.96%
# Average Win: 8.78%
# Average Loss: -2.58%
# Best Trade: 28.08%
# Worst Trade: -6.08%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 12:14:38
# ---------------------------------
#   185 | 00m28s |    1.71937 | 0.100000 | 19.000000 | 15.000000 | 146.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_9_32_197_0.9154031370423451
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.2045668936
# Sortino Ratio: 4.7440368303
# Max Drawdown: 0.2150173236
# Max Drawdown Duration: 203900
# Total Returns: 1.3808013643
# Annualized Returns: 3.2498172894
# Compound Annual Growth Rate: 6.7027463214
# ---------------------------------
# Trades: 33
# Trade Winning: 48.48%
# Average Trade: 3.19%
# Average Win: 9.34%
# Average Loss: -2.60%
# Best Trade: 30.59%
# Worst Trade: -8.17%
# Worst Trade Date: 0 days 14:00:00
# Avg Days in Trade: 1 days 11:23:38
# ---------------------------------
#   186 | 00m33s |    1.38080 | 0.915403 | 23.000000 | 9.000000 | 197.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_10_38_27_1.378730292052831
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.2938230988
# Sortino Ratio: 3.9873825767
# Max Drawdown: 0.3873945218
# Max Drawdown Duration: 227600
# Total Returns: 1.0145670088
# Annualized Returns: 2.3878578713
# Compound Annual Growth Rate: 4.1989301582
# ---------------------------------
# Trades: 40
# Trade Winning: 52.50%
# Average Trade: 2.37%
# Average Win: 8.65%
# Average Loss: -4.56%
# Best Trade: 28.08%
# Worst Trade: -13.33%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 1 days 18:18:00
# ---------------------------------
#   187 | 00m25s |    1.01457 | 1.378730 | 28.000000 | 10.000000 | 27.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_39_60_36_1.597764242556124
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5117685618
# Sortino Ratio: 2.3239916381
# Max Drawdown: 0.3678973382
# Max Drawdown Duration: 273500
# Total Returns: 0.4389092373
# Annualized Returns: 1.0330050829
# Compound Annual Growth Rate: 1.3547412931
# ---------------------------------
# Trades: 24
# Trade Winning: 37.50%
# Average Trade: 2.06%
# Average Win: 10.32%
# Average Loss: -2.90%
# Best Trade: 28.82%
# Worst Trade: -6.54%
# Worst Trade Date: 1 days 05:00:00
# Avg Days in Trade: 2 days 06:25:00
# ---------------------------------
#   188 | 00m21s |    0.43891 | 1.597764 | 21.000000 | 39.000000 | 36.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_38_43_173_2.2062286957491493
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3831417184
# Sortino Ratio: 3.0130372388
# Max Drawdown: 0.2132693414
# Max Drawdown Duration: 273500
# Total Returns: 0.5688364843
# Annualized Returns: 1.3387983886
# Compound Annual Growth Rate: 1.8860670490
# ---------------------------------
# Trades: 9
# Trade Winning: 66.67%
# Average Trade: 5.65%
# Average Win: 9.84%
# Average Loss: -2.71%
# Best Trade: 19.05%
# Worst Trade: -7.61%
# Worst Trade Date: 1 days 13:00:00
# Avg Days in Trade: 3 days 00:53:20
# ---------------------------------
#   189 | 00m26s |    0.56884 | 2.206229 | 5.000000 | 38.000000 | 173.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_79_122_97_0.7480763756826213
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0530483102
# Sortino Ratio: 1.2638486839
# Max Drawdown: 0.5083723416
# Max Drawdown Duration: 250900
# Total Returns: 0.2576521946
# Annualized Returns: 0.6064033381
# Compound Annual Growth Rate: 0.7152327644
# ---------------------------------
# Trades: 19
# Trade Winning: 47.37%
# Average Trade: 1.97%
# Average Win: 10.95%
# Average Loss: -6.10%
# Best Trade: 25.71%
# Worst Trade: -16.14%
# Worst Trade Date: 1 days 15:00:00
# Avg Days in Trade: 3 days 12:37:54
# ---------------------------------
#   190 | 00m26s |    0.25765 | 0.748076 | 43.000000 | 79.000000 | 97.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_10_76_105_2.901968427642844
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7164653249
# Sortino Ratio: 1.3568351166
# Max Drawdown: 0.2324811899
# Max Drawdown Duration: 273500
# Total Returns: 0.3640079554
# Annualized Returns: 0.8567194223
# Compound Annual Growth Rate: 1.0763543422
# ---------------------------------
# Trades: 5
# Trade Winning: 80.00%
# Average Trade: 7.02%
# Average Win: 10.47%
# Average Loss: -6.78%
# Best Trade: 22.29%
# Worst Trade: -6.78%
# Worst Trade Date: 1 days 08:00:00
# Avg Days in Trade: 4 days 03:48:00
# ---------------------------------
#   191 | 00m25s |    0.36401 | 2.901968 | 66.000000 | 10.000000 | 105.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_12_17_225_0.7928808220795363
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.2104645900
# Sortino Ratio: 2.5843911827
# Max Drawdown: 0.2802922480
# Max Drawdown Duration: 143000
# Total Returns: 0.8284467133
# Annualized Returns: 1.9498101045
# Compound Annual Growth Rate: 3.1383758914
# ---------------------------------
# Trades: 47
# Trade Winning: 53.19%
# Average Trade: 1.73%
# Average Win: 6.15%
# Average Loss: -3.29%
# Best Trade: 28.07%
# Worst Trade: -9.85%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 23:16:36
# ---------------------------------
#   192 | 00m28s |    0.82845 | 0.792881 | 5.000000 | 12.000000 | 225.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_9_40_193_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.4405453516
# Sortino Ratio: 1.3755285532
# Max Drawdown: 0.1822214953
# Max Drawdown Duration: 273500
# Total Returns: 0.4732384579
# Annualized Returns: 1.1138014217
# Compound Annual Growth Rate: 1.4891035217
# ---------------------------------
# Trades: 4
# Trade Winning: 100.00%
# Average Trade: 10.52%
# Average Win: 10.52%
# Average Loss: nan%
# Best Trade: 19.77%
# Worst Trade: 6.44%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 3 days 12:45:00
# ---------------------------------
#   193 | 00m31s |    0.47324 | 3.000000 | 31.000000 | 9.000000 | 193.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_40_149_29_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8760502488
# Sortino Ratio: 2.9646540373
# Max Drawdown: 0.3365191076
# Max Drawdown Duration: 250900
# Total Returns: 0.6301529658
# Annualized Returns: 1.4831112253
# Compound Annual Growth Rate: 2.1586027422
# ---------------------------------
# Trades: 81
# Trade Winning: 28.40%
# Average Trade: 0.96%
# Average Win: 7.40%
# Average Loss: -1.59%
# Best Trade: 33.13%
# Worst Trade: -4.42%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 15:35:33
# ---------------------------------
#   194 | 00m28s |    0.63015 | 0.100000 | 109.000000 | 40.000000 | 29.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_8_92_20_2.707081750524659
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1975780031
# Sortino Ratio: 2.7918067983
# Max Drawdown: 0.3689566692
# Max Drawdown Duration: 273500
# Total Returns: 0.7576311728
# Annualized Returns: 1.7831405356
# Compound Annual Growth Rate: 2.7709903082
# ---------------------------------
# Trades: 15
# Trade Winning: 46.67%
# Average Trade: 4.55%
# Average Win: 14.12%
# Average Loss: -3.83%
# Best Trade: 21.35%
# Worst Trade: -11.07%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 3 days 19:04:00
# ---------------------------------
#   195 | 00m26s |    0.75763 | 2.707082 | 84.000000 | 8.000000 | 20.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_16_129_210_0.9778828657606065
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.7898142354
# Sortino Ratio: 4.1479938953
# Max Drawdown: 0.2887956147
# Max Drawdown Duration: 100700
# Total Returns: 1.2243582273
# Annualized Returns: 2.8816168917
# Compound Annual Growth Rate: 5.5640487839
# ---------------------------------
# Trades: 13
# Trade Winning: 61.54%
# Average Trade: 7.22%
# Average Win: 14.61%
# Average Loss: -4.61%
# Best Trade: 32.60%
# Worst Trade: -8.60%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 5 days 07:13:51
# ---------------------------------
#   196 | 00m41s |    1.22436 | 0.977883 | 113.000000 | 16.000000 | 210.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_32_50_1_0.85938120856456
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#   197 | 00m24s |    0.00000 | 0.859381 | 18.000000 | 32.000000 | 1.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_108_120_173_1.6898163204693655
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7251486057
# Sortino Ratio: 2.4584758895
# Max Drawdown: 0.3732482551
# Max Drawdown Duration: 250900
# Total Returns: 0.5035552080
# Annualized Returns: 1.1851541167
# Compound Annual Growth Rate: 1.6113401757
# ---------------------------------
# Trades: 12
# Trade Winning: 58.33%
# Average Trade: 4.62%
# Average Win: 13.80%
# Average Loss: -8.22%
# Best Trade: 33.37%
# Worst Trade: -10.43%
# Worst Trade Date: 4 days 11:00:00
# Avg Days in Trade: 5 days 01:20:00
# ---------------------------------
#   198 | 00m33s |    0.50356 | 1.689816 | 12.000000 | 108.000000 | 173.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_93_145_203_1.9551381411994013
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.7309601535
# Sortino Ratio: 3.6686883066
# Max Drawdown: 0.2891889661
# Max Drawdown Duration: 250900
# Total Returns: 1.0455299212
# Annualized Returns: 2.4607313568
# Compound Annual Growth Rate: 4.3889522227
# ---------------------------------
# Trades: 5
# Trade Winning: 60.00%
# Average Trade: 22.36%
# Average Win: 44.54%
# Average Loss: -10.90%
# Best Trade: 111.90%
# Worst Trade: -11.35%
# Worst Trade Date: 5 days 15:00:00
# Avg Days in Trade: 12 days 08:12:00
# ---------------------------------
#   199 | 00m33s |    1.04553 | 1.955138 | 52.000000 | 93.000000 | 203.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_98_158_71_0.8857598673375852
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0015823128
# Sortino Ratio: 2.7652708934
# Max Drawdown: 0.2753188626
# Max Drawdown Duration: 170500
# Total Returns: 0.6588373365
# Annualized Returns: 1.5506219957
# Compound Annual Growth Rate: 2.2909733809
# ---------------------------------
# Trades: 17
# Trade Winning: 47.06%
# Average Trade: 3.75%
# Average Win: 12.89%
# Average Loss: -4.38%
# Best Trade: 31.21%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 3 days 08:21:11
# ---------------------------------
#   200 | 00m30s |    0.65884 | 0.885760 | 60.000000 | 98.000000 | 71.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_39_50_81_0.9227697852723844
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ...
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0890042758
# Sortino Ratio: 2.2674786621
# Max Drawdown: 0.3147529567
# Max Drawdown Duration: 273500
# Total Returns: 0.6333386720
# Annualized Returns: 1.4906090185
# Compound Annual Growth Rate: 2.1731497696
# ---------------------------------
# Trades: 8
# Trade Winning: 62.50%
# Average Trade: 6.98%
# Average Win: 13.51%
# Average Loss: -3.91%
# Best Trade: 20.37%
# Worst Trade: -7.75%
# Worst Trade Date: 3 days 00:00:00
# Avg Days in Trade: 5 days 21:45:00
# ---------------------------------
#   244 | 00m45s |    0.63334 | 1.935073 | 64.000000 | 26.000000 | 199.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_3_96_43_1.518313610361434
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.2864177956
# Sortino Ratio: 3.5383290619
# Max Drawdown: 0.3954881077
# Max Drawdown Duration: 227600
# Total Returns: 0.9089846062
# Annualized Returns: 2.1393619426
# Compound Annual Growth Rate: 3.5802491895
# ---------------------------------
# Trades: 28
# Trade Winning: 42.86%
# Average Trade: 3.02%
# Average Win: 11.97%
# Average Loss: -3.69%
# Best Trade: 34.70%
# Worst Trade: -7.23%
# Worst Trade Date: 1 days 02:00:00
# Avg Days in Trade: 2 days 11:27:51
# ---------------------------------
#   245 | 00m39s |    0.90898 | 1.518314 | 93.000000 | 3.000000 | 43.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_105_149_151_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.8239721116
# Sortino Ratio: 3.2764331675
# Max Drawdown: 0.2638492433
# Max Drawdown Duration: 155400
# Total Returns: 0.9486832828
# Annualized Returns: 2.2327956898
# Compound Annual Growth Rate: 3.8075887037
# ---------------------------------
# Trades: 2
# Trade Winning: 100.00%
# Average Trade: 46.69%
# Average Win: 46.69%
# Average Loss: nan%
# Best Trade: 90.89%
# Worst Trade: 2.49%
# Worst Trade Date: 8 days 19:00:00
# Avg Days in Trade: 17 days 04:00:00
# ---------------------------------
#   246 | 00m44s |    0.94868 | 3.000000 | 44.000000 | 105.000000 | 151.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_35_96_196_1.9682979793154036
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5046301518
# Sortino Ratio: 1.3138268959
# Max Drawdown: 0.3919225628
# Max Drawdown Duration: 273500
# Total Returns: 0.4136984962
# Annualized Returns: 0.9736697546
# Compound Annual Growth Rate: 1.2587894350
# ---------------------------------
# Trades: 8
# Trade Winning: 62.50%
# Average Trade: 5.31%
# Average Win: 13.58%
# Average Loss: -8.46%
# Best Trade: 20.43%
# Worst Trade: -15.05%
# Worst Trade Date: 3 days 05:00:00
# Avg Days in Trade: 6 days 02:37:30
# ---------------------------------
#   247 | 00m43s |    0.41370 | 1.968298 | 61.000000 | 35.000000 | 196.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_28_92_222_1.5420728853963512
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3415495591
# Sortino Ratio: 2.5133657308
# Max Drawdown: 0.3440427032
# Max Drawdown Duration: 273500
# Total Returns: 0.7604011030
# Annualized Returns: 1.7896597696
# Compound Annual Growth Rate: 2.7849922183
# ---------------------------------
# Trades: 9
# Trade Winning: 66.67%
# Average Trade: 7.07%
# Average Win: 12.36%
# Average Loss: -3.50%
# Best Trade: 18.88%
# Worst Trade: -4.39%
# Worst Trade Date: 3 days 01:00:00
# Avg Days in Trade: 5 days 16:06:40
# ---------------------------------
#   248 | 00m41s |    0.76040 | 1.542073 | 64.000000 | 28.000000 | 222.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_102_106_207_2.206799640149101
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3232081794
# Sortino Ratio: 2.5037679391
# Max Drawdown: 0.3026721560
# Max Drawdown Duration: 264400
# Total Returns: 0.6869326453
# Annualized Returns: 1.6167463655
# Compound Annual Growth Rate: 2.4236644598
# ---------------------------------
# Trades: 8
# Trade Winning: 75.00%
# Average Trade: 8.05%
# Average Win: 14.02%
# Average Loss: -9.86%
# Best Trade: 34.30%
# Worst Trade: -12.94%
# Worst Trade Date: 4 days 04:00:00
# Avg Days in Trade: 4 days 21:45:00
# ---------------------------------
#   249 | 00m42s |    0.68693 | 2.206800 | 4.000000 | 102.000000 | 207.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_14_26_227_0.7921669679030191
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.9419589788
# Sortino Ratio: 7.9212551712
# Max Drawdown: 0.1967131719
# Max Drawdown Duration: 144700
# Total Returns: 1.8411259459
# Annualized Returns: 4.3332249561
# Compound Annual Growth Rate: 10.6767806458
# ---------------------------------
# Trades: 34
# Trade Winning: 52.94%
# Average Trade: 3.61%
# Average Win: 8.75%
# Average Loss: -2.17%
# Best Trade: 31.49%
# Worst Trade: -3.78%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 09:22:56
# ---------------------------------
#   250 | 00m39s |    1.84113 | 0.792167 | 12.000000 | 14.000000 | 227.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_116_175_129_1.3004558047125434
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1322771564
# Sortino Ratio: 2.3841212118
# Max Drawdown: 0.3582552186
# Max Drawdown Duration: 250900
# Total Returns: 0.7934185634
# Annualized Returns: 1.8673687843
# Compound Annual Growth Rate: 2.9541978491
# ---------------------------------
# Trades: 8
# Trade Winning: 50.00%
# Average Trade: 12.33%
# Average Win: 33.32%
# Average Loss: -8.65%
# Best Trade: 109.15%
# Worst Trade: -10.97%
# Worst Trade Date: 2 days 05:00:00
# Avg Days in Trade: 7 days 22:30:00
# ---------------------------------
#   251 | 00m39s |    0.79342 | 1.300456 | 59.000000 | 116.000000 | 129.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_11_32_23_2.1047404909746006
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3302084434
# Sortino Ratio: 4.4614921075
# Max Drawdown: 0.3250297430
# Max Drawdown Duration: 227600
# Total Returns: 0.8368838107
# Annualized Returns: 1.9696674320
# Compound Annual Growth Rate: 3.1834599827
# ---------------------------------
# Trades: 35
# Trade Winning: 48.57%
# Average Trade: 2.26%
# Average Win: 8.15%
# Average Loss: -3.30%
# Best Trade: 34.89%
# Worst Trade: -8.60%
# Worst Trade Date: 0 days 13:00:00
# Avg Days in Trade: 1 days 13:25:43
# ---------------------------------
#   252 | 00m34s |    0.83688 | 2.104740 | 21.000000 | 11.000000 | 23.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_104_156_71_0.673240335023539
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6730161312
# Sortino Ratio: 2.2230616396
# Max Drawdown: 0.2992747339
# Max Drawdown Duration: 273500
# Total Returns: 0.5168811424
# Annualized Returns: 1.2165176807
# Compound Annual Growth Rate: 1.6661387727
# ---------------------------------
# Trades: 20
# Trade Winning: 40.00%
# Average Trade: 2.81%
# Average Win: 13.51%
# Average Loss: -4.33%
# Best Trade: 31.21%
# Worst Trade: -10.41%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 2 days 20:09:00
# ---------------------------------
#   253 | 00m38s |    0.51688 | 0.673240 | 52.000000 | 104.000000 | 71.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_95_164_67_1.6190718142079163
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0366819740
# Sortino Ratio: 2.2920929306
# Max Drawdown: 0.2939222874
# Max Drawdown Duration: 273500
# Total Returns: 0.6594278727
# Annualized Returns: 1.5520118659
# Compound Annual Growth Rate: 2.2937314137
# ---------------------------------
# Trades: 11
# Trade Winning: 72.73%
# Average Trade: 5.27%
# Average Win: 9.23%
# Average Loss: -5.30%
# Best Trade: 20.95%
# Worst Trade: -7.44%
# Worst Trade Date: 1 days 21:00:00
# Avg Days in Trade: 4 days 18:05:27
# ---------------------------------
#   254 | 00m38s |    0.65943 | 1.619072 | 69.000000 | 95.000000 | 67.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_88_171_66_1.7807215111953356
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2715192281
# Sortino Ratio: 1.3516330330
# Max Drawdown: 0.3780094805
# Max Drawdown Duration: 273500
# Total Returns: 0.3232652634
# Annualized Returns: 0.7608285081
# Compound Annual Growth Rate: 0.9333252818
# ---------------------------------
# Trades: 12
# Trade Winning: 58.33%
# Average Trade: 2.94%
# Average Win: 9.00%
# Average Loss: -5.56%
# Best Trade: 19.71%
# Worst Trade: -9.88%
# Worst Trade Date: 0 days 22:00:00
# Avg Days in Trade: 4 days 07:05:00
# ---------------------------------
#   255 | 00m40s |    0.32327 | 1.780722 | 83.000000 | 88.000000 | 66.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_35_124_170_0.42239489445834755
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1625220586
# Sortino Ratio: 2.7453032842
# Max Drawdown: 0.4462869939
# Max Drawdown Duration: 250900
# Total Returns: 0.8224173618
# Annualized Returns: 1.9356195834
# Compound Annual Growth Rate: 3.1063297282
# ---------------------------------
# Trades: 16
# Trade Winning: 50.00%
# Average Trade: 4.90%
# Average Win: 15.26%
# Average Loss: -5.46%
# Best Trade: 41.52%
# Worst Trade: -13.26%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 4 days 16:37:30
# ---------------------------------
#   256 | 00m41s |    0.82242 | 0.422395 | 89.000000 | 35.000000 | 170.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_14_132_207_1.355244161918483
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3743168336
# Sortino Ratio: 3.0122923109
# Max Drawdown: 0.2858235500
# Max Drawdown Duration: 273500
# Total Returns: 0.8710132239
# Annualized Returns: 2.0499935092
# Compound Annual Growth Rate: 3.3687062022
# ---------------------------------
# Trades: 10
# Trade Winning: 60.00%
# Average Trade: 7.42%
# Average Win: 16.02%
# Average Loss: -5.48%
# Best Trade: 26.99%
# Worst Trade: -8.60%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 6 days 00:06:00
# ---------------------------------
#   257 | 00m52s |    0.87101 | 1.355244 | 118.000000 | 14.000000 | 207.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_105_217_124_0.9258952612572717
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.7091593853
# Sortino Ratio: 3.5798096777
# Max Drawdown: 0.2638492433
# Max Drawdown Duration: 147900
# Total Returns: 1.0803975637
# Annualized Returns: 2.5427949107
# Compound Annual Growth Rate: 4.6076479188
# ---------------------------------
# Trades: 8
# Trade Winning: 62.50%
# Average Trade: 11.27%
# Average Win: 20.05%
# Average Loss: -3.35%
# Best Trade: 58.09%
# Worst Trade: -4.64%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 7 days 04:37:30
# ---------------------------------
#   258 | 00m50s |    1.08040 | 0.925895 | 112.000000 | 105.000000 | 124.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_13_34_154_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 3.5866901077
# Sortino Ratio: 6.2478152454
# Max Drawdown: 0.3281119593
# Max Drawdown Duration: 250900
# Total Returns: 1.8985519780
# Annualized Returns: 4.4683813345
# Compound Annual Growth Rate: 11.2398783544
# ---------------------------------
# Trades: 40
# Trade Winning: 47.50%
# Average Trade: 3.23%
# Average Win: 9.54%
# Average Loss: -2.48%
# Best Trade: 32.06%
# Worst Trade: -9.50%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 12:22:30
# ---------------------------------
#   259 | 00m39s |    1.89855 | 0.100000 | 21.000000 | 13.000000 | 154.000000 |
# ---------------------------------
# MACD_BOLLStrategy2_38_120_40_1.2748248897074175
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.5260423515
# Sortino Ratio: 3.6208624466
# Max Drawdown: 0.2566426386
# Max Drawdown Duration: 273500
# Total Returns: 0.9604383092
# Annualized Returns: 2.2604620066
# Compound Annual Growth Rate: 3.8761230187
# ---------------------------------
# Trades: 22
# Trade Winning: 45.45%
# Average Trade: 3.66%
# Average Win: 11.00%
# Average Loss: -2.45%
# Best Trade: 31.73%
# Worst Trade: -5.20%
# Worst Trade Date: 1 days 03:00:00
# Avg Days in Trade: 2 days 13:08:11
# ---------------------------------
#   260 | 00m39s |    0.96044 | 1.274825 | 82.000000 | 38.000000 | 40.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 2.0538804896742766, 'max_params': {'short_window': 13.0, 'delta_window': 20.0, 'window': 153.0, 'a': 0.1}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
# Target.to_csv(config['out_dir'] + "/target_ei.csv")
Target.sort_values(by = "Target")
# Out:
#                                    Parameters    Target
# 16     [51.0, 77.0, 4.0, 0.10832394839036102] -0.580807
# 50                     [1.0, 4.0, 201.0, 0.1] -0.482903
# 161     [111.0, 96.0, 7.0, 1.054283348477707] -0.303495
# 28     [88.0, 112.0, 8.0, 0.5997874742014527] -0.220004
# 38     [8.0, 104.0, 8.0, 0.15765238813540722] -0.211344
# 218    [51.0, 23.0, 83.0, 1.8771996162584086] -0.125757
# 162   [76.0, 21.0, 105.0, 0.7697683204176138] -0.099446
# 169     [40.0, 55.0, 64.0, 2.642189636960302] -0.091644
# 31     [114.0, 8.0, 76.0, 2.1207726683207104] -0.005455
# 138     [33.0, 36.0, 1.0, 1.1115994317643174]  0.000000
# 23       [29.0, 83.0, 3.0, 1.907744335796228]  0.000000
# 65                     [1.0, 120.0, 1.0, 3.0]  0.000000
# 164    [104.0, 41.0, 2.0, 2.7021319609278756]  0.000000
# 196       [32.0, 18.0, 1.0, 0.85938120856456]  0.000000
# 48     [89.0, 35.0, 82.0, 1.7987018872290348]  0.009119
# 19       [19.0, 81.0, 7.0, 1.628468496547067]  0.010876
# 79      [1.0, 9.0, 198.0, 1.2309967584363306]  0.012381
# 33     [97.0, 26.0, 44.0, 2.2908428525471525]  0.018504
# 157    [63.0, 57.0, 87.0, 0.8578919584411864]  0.023233
# 120     [71.0, 16.0, 77.0, 1.606551255944411]  0.029391
# 81   [16.0, 106.0, 225.0, 2.6208054003720562]  0.032181
# 42     [58.0, 38.0, 211.0, 2.594081051180375]  0.059541
# 104    [51.0, 28.0, 59.0, 1.8046535254920912]  0.074640
# 173    [115.0, 73.0, 10.0, 2.514689355205545]  0.147732
# 45     [61.0, 39.0, 11.0, 2.5418895878428565]  0.155494
# 180    [98.0, 34.0, 116.0, 2.271565147560386]  0.197537
# 36    [106.0, 10.0, 37.0, 2.1634218000225682]  0.203653
# 14     [7.0, 114.0, 114.0, 2.719800609630536]  0.207043
# 200    [39.0, 11.0, 81.0, 0.9227697852723844]  0.214587
# 136    [44.0, 58.0, 80.0, 0.2695212235984806]  0.216641
# ..                                        ...       ...
# 58    [15.0, 12.0, 145.0, 0.8958138567037055]  1.296830
# 133                  [13.0, 48.0, 110.0, 0.1]  1.300237
# 223   [22.0, 34.0, 232.0, 1.6460843225138375]  1.303044
# 4     [10.0, 31.0, 200.0, 1.3414644506267552]  1.305347
# 160   [49.0, 81.0, 238.0, 1.0341129349108413]  1.319465
# 103                  [17.0, 44.0, 120.0, 0.1]  1.342351
# 185    [9.0, 23.0, 197.0, 0.9154031370423451]  1.380801
# 143    [48.0, 80.0, 234.0, 1.024677655608165]  1.419652
# 174    [10.0, 59.0, 61.0, 0.8074776136688757]  1.420963
# 151   [12.0, 26.0, 194.0, 0.1700342914822503]  1.469008
# 170                  [12.0, 51.0, 105.0, 0.1]  1.473972
# 142   [13.0, 62.0, 106.0, 0.4801990649633211]  1.523867
# 106                  [10.0, 24.0, 155.0, 0.1]  1.563692
# 135   [42.0, 113.0, 32.0, 0.8572005464921055]  1.620348
# 115  [11.0, 60.0, 107.0, 0.11773276457371275]  1.621551
# 93                   [13.0, 55.0, 108.0, 0.1]  1.636403
# 84                   [11.0, 22.0, 149.0, 0.1]  1.641679
# 150   [12.0, 39.0, 120.0, 0.5207968416993504]  1.679881
# 130                  [13.0, 22.0, 195.0, 0.1]  1.700263
# 184                  [15.0, 19.0, 146.0, 0.1]  1.719371
# 114   [12.0, 65.0, 107.0, 0.4784736002026593]  1.727851
# 152   [11.0, 60.0, 104.0, 0.3290337234559117]  1.800996
# 181                  [15.0, 20.0, 152.0, 0.1]  1.829681
# 249   [14.0, 12.0, 227.0, 0.7921669679030191]  1.841126
# 37   [10.0, 68.0, 104.0, 0.46038578971927757]  1.851741
# 102                  [16.0, 23.0, 152.0, 0.1]  1.853104
# 258                  [13.0, 21.0, 154.0, 0.1]  1.898552
# 112                  [14.0, 19.0, 150.0, 0.1]  1.958322
# 61   [12.0, 61.0, 106.0, 0.37653365428703667]  2.048090
# 77                   [13.0, 20.0, 153.0, 0.1]  2.053880
#
# [260 rows x 2 columns]

# %%
f, ax = plt.subplots(2,2, figsize = (16, 16))
ax[0,0].scatter(BO.X[:,0].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[0,0].set_title('$val$ $vs$ $short\_window$ ', fontsize=18)
ax[0,0].set_xlabel('$short\_window$', fontsize=16)
ax[0,0].set_ylabel('$val$', fontsize=16)
ax[0,0].hlines(0, 0, 120, color='black',linestyle="--")
ax[0,0].hlines(-1, 0, 120, color='black',linestyle="--")
ax[0,0].hlines(1, 0, 120, color='black',linestyle="--")
ax[0,0].vlines(BO.res['max']['max_params']['short_window'], -1.2, 2, color='blue',linestyle="--")

ax[0,1].scatter(BO.X[:,1].flatten() + BO.X[:,0].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[0,1].set_title('$val$ $vs$ $long\_window$ ', fontsize=18)
ax[0,1].set_xlabel('$long\_window$', fontsize=16)
ax[0,1].set_ylabel('$val$', fontsize=16)
ax[0,1].hlines(0, 0, 240,color='black',linestyle="--")
ax[0,1].hlines(-1, 0, 240, color='black',linestyle="--")
ax[0,1].hlines(1, 0, 240,color='black',linestyle="--")
ax[0,1].vlines(BO.res['max']['max_params']['delta_window'] + BO.res['max']['max_params']['short_window'],
               -1.2, 2, color='blue',linestyle="--")

ax[1,0].scatter(BO.X[:,2].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[1,0].set_title('$val$ $vs$ $window$ ', fontsize=18)
ax[1,0].set_xlabel('$window$', fontsize=16)
ax[1,0].set_ylabel('$val$', fontsize=16)
ax[1,0].hlines(0, 0, 240,color='black',linestyle="--")
ax[1,0].hlines(-1, 0, 240, color='black',linestyle="--")
ax[1,0].hlines(1, 0, 240,color='black',linestyle="--")
ax[1,0].vlines(BO.res['max']['max_params']['window'], -1.2, 2, color='blue',linestyle="--")

ax[1,1].scatter(BO.X[:,3].flatten(), BO.Y, c="red", s=10, zorder=10)
ax[1,1].set_title('$val$ $vs$ $a$ ', fontsize=18)
ax[1,1].set_xlabel('$a$', fontsize=16)
ax[1,1].set_ylabel('$val$', fontsize=16)
ax[1,1].hlines(0, 0, 3,color='black',linestyle="--")
ax[1,1].hlines(-1, 0, 3, color='black',linestyle="--")
ax[1,1].hlines(1, 0, 3,color='black',linestyle="--")
ax[1,1].vlines(BO.res['max']['max_params']['a'], -1.2, 2, color='blue',linestyle="--")

# %% [markdown]
# ## Acquisition Function "Probability of Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)
