# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

from BayesianOptimization.bayesian_optimization import BayesianOptimization

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from MACDStrategy import MACDStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
def run_backtest(config, trading_data, ohlc_data, short_window, delta_window):
    short_window = int(short_window)
    long_window = short_window + int(delta_window)
    config['title'] = "MACDStrategy" + "_" + str(short_window) + "_" + str(long_window)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")
    
    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data = trading_data, ohlc_data = ohlc_data
    )
    strategy = MACDStrategy(config, events_queue, data_handler,
                            short_window=short_window, long_window=long_window)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler= data_handler)

    results = backtest.start_trading()
    
    # dict_ans = {
    #     "short_window": [short_window],
    #     "long_window": [long_window],
    #     "Sharpe Ratio": [results['sharpe']],
    #     "Total Returns": [(results['cum_returns'][-1] - 1)],
    #     "Max Drawdown": [(results["max_drawdown"] * 100.0)],
    #     "Max Drawdown Duration": [(results['max_drawdown_duration'])],
    #     "Trades": [results['trade_info']['trading_num']],
    #     "Trade Winning": [results['trade_info']['win_pct']],
    #     "Average Trade": [results['trade_info']['avg_trd_pct']],
    #     "Average Win": [results['trade_info']['avg_win_pct']],
    #     "Average Loss": [results['trade_info']['avg_loss_pct']],
    #     "Best Trade": [results['trade_info']['max_win_pct']],
    #     "Worst Trade": [results['trade_info']['max_loss_pct']],
    #     "Worst Trade Date": [results['trade_info']['max_loss_dt']],
    #     "Avg Days in Trade": [results['trade_info']['avg_dit']]
    # }
    # return pd.DataFrame(dict_ans)
    return (results['cum_returns'][-1] - 1)

# %% [markdown]
# ## Setting

# %%
config = {
    "csv_dir": "C:/backtest/Binance",
    "out_dir": "C:/backtest/results/MACDStrategy",
    "title": "MACDStrategy",
    "is_plot": False,
    "save_plot": False,
    "save_tradelog": False,
    "start_date": pd.Timestamp("2017-07-01T00:0:00", freq = "60" + "T"),    # str(freq) + "T"
    "end_date": pd.Timestamp("2018-09-01T00:00:00", freq = "60" + "T"),
    "equity": 1.0,
    "freq": 60,      # min
    "commission_ratio": 0.001,
    "suggested_quantity": None,     # None or a value
    "max_quantity": None,           # None or a value, Maximum purchase quantity
    "min_quantity": None,           # None or a value, Minimum purchase quantity
    "min_handheld_cash": None,      # None or a value, Minimum handheld funds
    "exchange": "Binance",
    "tickers": ['BTCUSDT']
}

# %%
# trading_data = {}
# for ticker in config['tickers']:
#     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
#     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

ohlc_data = {}
for ticker in config['tickers']:
    # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
    ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker +'_OHLC_60min.h5', key=ticker)

trading_data = None

# %%
gp_params = {"alpha": 1e-5}

# %%
def plot_bo(BO, filename):
    short_window = [x["short_window"] for x in BO.res["all"]["params"]]
    delta_window = [x["delta_window"] for x in BO.res["all"]["params"]]
    long_window = short_window + delta_window
    Target = BO.res["all"]["values"]
    num = np.array([[i,j] for i in range(120) for j in range(240)])
    mean, sigma = BO.gp.predict(num, return_std=True)
    X, Y = np.meshgrid(range(120), range(240))
    Z = mean.shape(240,120)
    
    fig = plt.figure(figsize=(14, 6))
    ax = Axes3D(fig)
    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
    ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=cm.coolwarm)
    plt.scatter(BO.X[:,0], BO.X[:,1], BO.Y, c="red", marker='^')
    ax.view_init(70, 30)
    plt.show()
#     fig.savefig(filename, dpi=150, bbox_inches='tight')

# %% [markdown]
# ## Acquisition Function "Upper Confidence Bound"

# %% [markdown]
# * Prefer exploitation (kappa=1.0)
#
# * Prefer exploration (kappa=10)

# %%
BO = BayesianOptimization(
    run_backtest,
    {'short_window': (1, 120),
    'delta_window': (1, 120)},
    is_int = [1, 1], 
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
BO.explore({
    'short_window': np.arange(1, 120, 20),
    'delta_window': np.arange(1, 120, 20)
    },
    eager=True)
BO.maximize(init_points=0, n_iter=10, acq='ucb', kappa=5, **gp_params)
# Out:
# ---------------------------------
# ADXStrategy_1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -6.9007275153
# Max Drawdown: 98.8338690249
# Max Drawdown Duration: 6661
# Total Returns: -0.9866560406
# ---------------------------------
# Trades: 1231
# Trade Winning: 38%
# Average Trade: -0.13%
# Average Win: 1.35%
# Average Loss: -1.04%
# Best Trade: 11.71%
# Worst Trade: -7.69%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 02:49:49
# ---------------------------------
#     1 | 00m05s |   -0.98666 | 1.000000 |
# ---------------------------------
# ADXStrategy_21
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5715412195
# Max Drawdown: 44.0459039139
# Max Drawdown Duration: 3858
# Total Returns: 0.9908953916
# ---------------------------------
# Trades: 234
# Trade Winning: 42%
# Average Trade: 0.59%
# Average Win: 3.44%
# Average Loss: -1.47%
# Best Trade: 31.17%
# Worst Trade: -9.52%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 0 days 13:16:09
# ---------------------------------
#     2 | 00m05s |    0.99090 | 21.000000 |
# ---------------------------------
# ADXStrategy_41
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5875275955
# Max Drawdown: 59.9307265688
# Max Drawdown Duration: 5371
# Total Returns: 0.1443933318
# ---------------------------------
# Trades: 175
# Trade Winning: 39%
# Average Trade: 0.37%
# Average Win: 3.36%
# Average Loss: -1.54%
# Best Trade: 25.07%
# Worst Trade: -6.98%
# Worst Trade Date: 0 days 18:00:00
# Avg Days in Trade: 0 days 17:49:22
# ---------------------------------
#     3 | 00m04s |    0.14439 | 41.000000 |
# ---------------------------------
# ADXStrategy_61
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8688237540
# Max Drawdown: 52.5145313917
# Max Drawdown Duration: 5830
# Total Returns: 0.3291361075
# ---------------------------------
# Trades: 125
# Trade Winning: 34%
# Average Trade: 0.56%
# Average Win: 5.17%
# Average Loss: -1.86%
# Best Trade: 27.06%
# Worst Trade: -9.55%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 0 days 23:57:36
# ---------------------------------
#     4 | 00m04s |    0.32914 | 61.000000 |
# ---------------------------------
# ADXStrategy_81
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5021898490
# Max Drawdown: 57.3275218982
# Max Drawdown Duration: 5830
# Total Returns: 0.0938114060
# ---------------------------------
# Trades: 119
# Trade Winning: 35%
# Average Trade: 0.42%
# Average Win: 4.82%
# Average Loss: -1.98%
# Best Trade: 30.15%
# Worst Trade: -10.43%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 1 days 00:41:21
# ---------------------------------
#     5 | 00m05s |    0.09381 | 81.000000 |
# ---------------------------------
# ADXStrategy_101
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7445200130
# Max Drawdown: 53.1600102521
# Max Drawdown Duration: 5830
# Total Returns: 0.2389377347
# ---------------------------------
# Trades: 105
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 4.22%
# Average Loss: -2.02%
# Best Trade: 24.74%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 03:27:26
# ---------------------------------
#     6 | 00m05s |    0.23894 | 101.000000 |
# ---------------------------------
# ADXStrategy_121
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5420596438
# Max Drawdown: 56.5896951304
# Max Drawdown Duration: 5830
# Total Returns: 0.1155193189
# ---------------------------------
# Trades: 100
# Trade Winning: 46%
# Average Trade: 0.46%
# Average Win: 3.40%
# Average Loss: -2.05%
# Best Trade: 29.30%
# Worst Trade: -12.39%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 1 days 04:06:00
# ---------------------------------
#     7 | 00m04s |    0.11552 | 121.000000 |
# ---------------------------------
# ADXStrategy_141
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3067396204
# Max Drawdown: 40.3329394527
# Max Drawdown Duration: 5830
# Total Returns: 0.6482326740
# ---------------------------------
# Trades: 86
# Trade Winning: 41%
# Average Trade: 0.95%
# Average Win: 4.82%
# Average Loss: -1.70%
# Best Trade: 27.98%
# Worst Trade: -9.79%
# Worst Trade Date: 0 days 12:00:00
# Avg Days in Trade: 1 days 07:30:42
# ---------------------------------
#     8 | 00m04s |    0.64823 | 141.000000 |
# ---------------------------------
# ADXStrategy_161
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7708650272
# Max Drawdown: 40.7294677642
# Max Drawdown Duration: 5830
# Total Returns: 0.2508738221
# ---------------------------------
# Trades: 83
# Trade Winning: 33%
# Average Trade: 0.64%
# Average Win: 5.60%
# Average Loss: -1.76%
# Best Trade: 29.49%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 08:28:55
# ---------------------------------
#     9 | 00m04s |    0.25087 | 161.000000 |
# ---------------------------------
# ADXStrategy_181
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9320243863
# Max Drawdown: 42.8976564485
# Max Drawdown Duration: 5830
# Total Returns: 0.3231417558
# ---------------------------------
# Trades: 68
# Trade Winning: 38%
# Average Trade: 0.75%
# Average Win: 4.77%
# Average Loss: -1.74%
# Best Trade: 23.84%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 14:57:21
# ---------------------------------
#    10 | 00m04s |    0.32314 | 181.000000 |
# ---------------------------------
# ADXStrategy_201
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6836614752
# Max Drawdown: 51.4784866060
# Max Drawdown Duration: 5830
# Total Returns: 0.2013883465
# ---------------------------------
# Trades: 70
# Trade Winning: 43%
# Average Trade: 0.60%
# Average Win: 4.27%
# Average Loss: -2.14%
# Best Trade: 20.71%
# Worst Trade: -10.11%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 1 days 13:54:00
# ---------------------------------
#    11 | 00m04s |    0.20139 | 201.000000 |
# ---------------------------------
# ADXStrategy_221
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2138615878
# Max Drawdown: 61.4626828553
# Max Drawdown Duration: 5830
# Total Returns: -0.0525022310
# ---------------------------------
# Trades: 68
# Trade Winning: 43%
# Average Trade: 0.35%
# Average Win: 4.51%
# Average Loss: -2.75%
# Best Trade: 39.17%
# Worst Trade: -15.78%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 1 days 14:11:28
# ---------------------------------
#    12 | 00m04s |   -0.05250 | 221.000000 |
# Initialization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# ---------------------------------
# ADXStrategy_23
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7284760920
# Max Drawdown: 28.1398083617
# Max Drawdown Duration: 3858
# Total Returns: 1.1199874275
# ---------------------------------
# Trades: 236
# Trade Winning: 44%
# Average Trade: 0.59%
# Average Win: 3.02%
# Average Loss: -1.29%
# Best Trade: 28.84%
# Worst Trade: -7.35%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 13:16:32
# ---------------------------------
#    13 | 00m06s |    1.11999 | 23.000000 |
# ---------------------------------
# ADXStrategy_13
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -1.0778807157
# Max Drawdown: 74.5365068116
# Max Drawdown Duration: 5604
# Total Returns: -0.5307847903
# ---------------------------------
# Trades: 353
# Trade Winning: 37%
# Average Trade: 0.03%
# Average Win: 2.56%
# Average Loss: -1.47%
# Best Trade: 17.95%
# Worst Trade: -10.77%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 09:06:28
# ---------------------------------
#    14 | 00m06s |   -0.53078 | 13.000000 |
# ---------------------------------
# ADXStrategy_22
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4364670989
# Max Drawdown: 36.0111502612
# Max Drawdown Duration: 3774
# Total Returns: 0.8445350169
# ---------------------------------
# Trades: 233
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 3.34%
# Average Loss: -1.42%
# Best Trade: 29.88%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 13:23:57
# ---------------------------------
#    15 | 00m05s |    0.84454 | 22.000000 |
# ---------------------------------
# ADXStrategy_146
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7094897627
# Max Drawdown: 44.5462599643
# Max Drawdown Duration: 5830
# Total Returns: 0.2218344272
# ---------------------------------
# Trades: 84
# Trade Winning: 37%
# Average Trade: 0.61%
# Average Win: 5.08%
# Average Loss: -2.00%
# Best Trade: 24.11%
# Worst Trade: -10.02%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 1 days 08:22:51
# ---------------------------------
#    16 | 00m06s |    0.22183 | 146.000000 |
# ---------------------------------
# ADXStrategy_107
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8510359885
# Max Drawdown: 49.9953067743
# Max Drawdown Duration: 5830
# Total Returns: 0.2974991015
# ---------------------------------
# Trades: 93
# Trade Winning: 34%
# Average Trade: 0.62%
# Average Win: 5.21%
# Average Loss: -1.78%
# Best Trade: 28.95%
# Worst Trade: -7.51%
# Worst Trade Date: 2 days 21:00:00
# Avg Days in Trade: 1 days 07:00:39
# ---------------------------------
#    17 | 00m06s |    0.29750 | 107.000000 |
# ---------------------------------
# ADXStrategy_27
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0751335575
# Max Drawdown: 59.4010780241
# Max Drawdown Duration: 5830
# Total Returns: -0.1347074726
# ---------------------------------
# Trades: 229
# Trade Winning: 36%
# Average Trade: 0.21%
# Average Win: 3.16%
# Average Loss: -1.44%
# Best Trade: 27.31%
# Worst Trade: -10.23%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 0 days 13:48:28
# ---------------------------------
#    18 | 00m06s |   -0.13471 | 27.000000 |
# ---------------------------------
# ADXStrategy_194
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6014194263
# Max Drawdown: 51.9163819834
# Max Drawdown Duration: 5830
# Total Returns: 0.1511461675
# ---------------------------------
# Trades: 63
# Trade Winning: 30%
# Average Trade: 0.59%
# Average Win: 6.60%
# Average Loss: -2.01%
# Best Trade: 22.11%
# Worst Trade: -10.14%
# Worst Trade Date: 2 days 04:00:00
# Avg Days in Trade: 1 days 17:52:23
# ---------------------------------
#    19 | 00m06s |    0.15115 | 194.000000 |
# ---------------------------------
# ADXStrategy_7
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -2.9345675204
# Max Drawdown: 89.9532365912
# Max Drawdown Duration: 5830
# Total Returns: -0.8326095296
# ---------------------------------
# Trades: 510
# Trade Winning: 37%
# Average Trade: -0.12%
# Average Win: 2.09%
# Average Loss: -1.41%
# Best Trade: 11.05%
# Worst Trade: -9.57%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 06:29:46
# ---------------------------------
#    20 | 00m06s |   -0.83261 | 7.000000 |
# ---------------------------------
# ADXStrategy_136
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9756312419
# Max Drawdown: 54.2216403695
# Max Drawdown Duration: 5830
# Total Returns: 0.4059585955
# ---------------------------------
# Trades: 84
# Trade Winning: 37%
# Average Trade: 0.82%
# Average Win: 5.74%
# Average Loss: -2.06%
# Best Trade: 28.85%
# Worst Trade: -9.74%
# Worst Trade Date: 0 days 19:00:00
# Avg Days in Trade: 1 days 08:33:34
# ---------------------------------
#    21 | 00m06s |    0.40596 | 136.000000 |
# ---------------------------------
# ADXStrategy_130
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9506412493
# Max Drawdown: 54.0941213880
# Max Drawdown Duration: 5830
# Total Returns: 0.3885680771
# ---------------------------------
# Trades: 92
# Trade Winning: 39%
# Average Trade: 0.72%
# Average Win: 4.64%
# Average Loss: -1.80%
# Best Trade: 28.90%
# Worst Trade: -12.17%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 1 days 05:57:23
# ---------------------------------
#    22 | 00m06s |    0.38857 | 130.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 1.1199874275247002, 'max_params': {'window': 23.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
Target.to_csv(config['out_dir'] + "/target_ucb.csv")
Target.sort_values(by = "Target")
# Out:
#    Parameters    Target
# 0       [1.0] -0.986656
# 19      [7.0] -0.832610
# 13     [13.0] -0.530785
# 17     [27.0] -0.134707
# 11    [221.0] -0.052502
# 4      [81.0]  0.093811
# 6     [121.0]  0.115519
# 2      [41.0]  0.144393
# 18    [194.0]  0.151146
# 10    [201.0]  0.201388
# 15    [146.0]  0.221834
# 5     [101.0]  0.238938
# 8     [161.0]  0.250874
# 16    [107.0]  0.297499
# 9     [181.0]  0.323142
# 3      [61.0]  0.329136
# 21    [130.0]  0.388568
# 20    [136.0]  0.405959
# 7     [141.0]  0.648233
# 14     [22.0]  0.844535
# 1      [21.0]  0.990895
# 12     [23.0]  1.119987

# %%
filename = config['out_dir'] + "/target_ucb.png"
plot_bo(BO, filename)

# %% [markdown]
# ## Acquisition Function "Expected Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)

# %%
BO = BayesianOptimization(
    run_backtest,
    {'short_window': (1, 120),
    'delta_window': (1, 120)},
    is_int = [1, 1], 
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
BO.explore({
    'short_window': np.arange(1, 120, 20),
    'delta_window': np.arange(1, 120, 20)
    },
    eager=True)
BO.maximize(init_points=0, n_iter=10, acq="ei", xi=0.01, **gp_params)
# Out:
# ---------------------------------
# MACDStrategy_1_2
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -8.3168538521
# Max Drawdown: 99.5644139122
# Max Drawdown Duration: 6771
# Total Returns: -0.9953158227
# ---------------------------------
# Trades: 1842
# Trade Winning: 33%
# Average Trade: -0.08%
# Average Win: 1.35%
# Average Loss: -0.77%
# Best Trade: 12.60%
# Worst Trade: -10.06%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 01:54:24
# ---------------------------------
#     1 | 00m02s |   -0.99532 | 1.000000 | 1.000000 |
# ---------------------------------
# MACDStrategy_21_42
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4421774148
# Max Drawdown: 47.6935410972
# Max Drawdown Duration: 4035
# Total Returns: 0.8771751288
# ---------------------------------
# Trades: 80
# Trade Winning: 45%
# Average Trade: 1.36%
# Average Win: 7.39%
# Average Loss: -3.58%
# Best Trade: 34.10%
# Worst Trade: -22.53%
# Worst Trade Date: 0 days 17:00:00
# Avg Days in Trade: 1 days 20:08:15
# ---------------------------------
#     2 | 00m04s |    0.87718 | 21.000000 | 21.000000 |
# ---------------------------------
# MACDStrategy_41_82
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4647711965
# Max Drawdown: 43.2254528512
# Max Drawdown Duration: 5830
# Total Returns: 0.8585563259
# ---------------------------------
# Trades: 40
# Trade Winning: 38%
# Average Trade: 2.11%
# Average Win: 11.20%
# Average Loss: -3.35%
# Best Trade: 24.39%
# Worst Trade: -8.70%
# Worst Trade Date: 2 days 12:00:00
# Avg Days in Trade: 3 days 16:58:30
# ---------------------------------
#     3 | 00m07s |    0.85856 | 41.000000 | 41.000000 |
# ---------------------------------
# MACDStrategy_61_122
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9781544348
# Max Drawdown: 60.0023657099
# Max Drawdown Duration: 5604
# Total Returns: 0.4155810854
# ---------------------------------
# Trades: 32
# Trade Winning: 44%
# Average Trade: 2.48%
# Average Win: 13.66%
# Average Loss: -6.22%
# Best Trade: 90.52%
# Worst Trade: -19.60%
# Worst Trade Date: 2 days 13:00:00
# Avg Days in Trade: 4 days 18:07:30
# ---------------------------------
#     4 | 00m10s |    0.41558 | 61.000000 | 61.000000 |
# ---------------------------------
# MACDStrategy_81_162
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4222123200
# Max Drawdown: 54.1415066881
# Max Drawdown Duration: 5604
# Total Returns: 0.8286333831
# ---------------------------------
# Trades: 22
# Trade Winning: 36%
# Average Trade: 5.61%
# Average Win: 27.86%
# Average Loss: -7.10%
# Best Trade: 129.52%
# Worst Trade: -16.21%
# Worst Trade Date: 3 days 00:00:00
# Avg Days in Trade: 6 days 22:24:33
# ---------------------------------
#     5 | 00m12s |    0.82863 | 81.000000 | 81.000000 |
# ---------------------------------
# MACDStrategy_101_202
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7389901868
# Max Drawdown: 43.3702367055
# Max Drawdown Duration: 5604
# Total Returns: 1.1653149647
# ---------------------------------
# Trades: 16
# Trade Winning: 50%
# Average Trade: 7.60%
# Average Win: 22.54%
# Average Loss: -7.34%
# Best Trade: 97.60%
# Worst Trade: -15.20%
# Worst Trade Date: 3 days 01:00:00
# Avg Days in Trade: 9 days 05:30:00
# ---------------------------------
#     6 | 00m15s |    1.16531 | 101.000000 | 101.000000 |
# Initialization
# ---------------------------------------------------------------
#  Step |   Time |      Value |   delta_window |   short_window |
# Bayesian Optimization
# ---------------------------------------------------------------
#  Step |   Time |      Value |   delta_window |   short_window |
# ---------------------------------
# MACDStrategy_113_195
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4531649809
# Max Drawdown: 46.3788425741
# Max Drawdown Duration: 5604
# Total Returns: 0.8692652790
# ---------------------------------
# Trades: 17
# Trade Winning: 47%
# Average Trade: 5.73%
# Average Win: 19.79%
# Average Loss: -6.76%
# Best Trade: 78.94%
# Worst Trade: -14.70%
# Worst Trade Date: 3 days 02:00:00
# Avg Days in Trade: 8 days 19:38:49
# ---------------------------------
#     7 | 00m21s |    0.86927 | 82.000000 | 113.000000 |
# ---------------------------------
# MACDStrategy_48_62
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9451926880
# Max Drawdown: 34.0238819421
# Max Drawdown Duration: 3287
# Total Returns: 1.3982901776
# ---------------------------------
# Trades: 66
# Trade Winning: 53%
# Average Trade: 1.82%
# Average Win: 6.87%
# Average Loss: -3.88%
# Best Trade: 27.80%
# Worst Trade: -14.18%
# Worst Trade Date: 1 days 02:00:00
# Avg Days in Trade: 2 days 05:40:55
# ---------------------------------
#     8 | 00m11s |    1.39829 | 14.000000 | 48.000000 |
# ---------------------------------
# MACDStrategy_75_195
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8974448382
# Max Drawdown: 61.9954413033
# Max Drawdown Duration: 5604
# Total Returns: 0.3570591817
# ---------------------------------
# Trades: 17
# Trade Winning: 35%
# Average Trade: 5.16%
# Average Win: 31.34%
# Average Loss: -9.12%
# Best Trade: 121.76%
# Worst Trade: -21.77%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 8 days 16:52:56
# ---------------------------------
#     9 | 00m20s |    0.35706 | 120.000000 | 75.000000 |
# ---------------------------------
# MACDStrategy_74_79
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6230762650
# Max Drawdown: 61.7935905037
# Max Drawdown Duration: 5830
# Total Returns: 0.1652705242
# ---------------------------------
# Trades: 86
# Trade Winning: 41%
# Average Trade: 0.67%
# Average Win: 6.38%
# Average Loss: -3.25%
# Best Trade: 39.08%
# Worst Trade: -12.47%
# Worst Trade Date: 2 days 07:00:00
# Avg Days in Trade: 1 days 16:49:32
# ---------------------------------
#    10 | 00m11s |    0.16527 | 5.000000 | 74.000000 |
# ---------------------------------
# MACDStrategy_67_125
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5693363804
# Max Drawdown: 70.6885892091
# Max Drawdown Duration: 5604
# Total Returns: 0.1287867754
# ---------------------------------
# Trades: 32
# Trade Winning: 31%
# Average Trade: 1.87%
# Average Win: 19.10%
# Average Loss: -5.96%
# Best Trade: 90.40%
# Worst Trade: -20.42%
# Worst Trade Date: 2 days 15:00:00
# Avg Days in Trade: 4 days 19:20:38
# ---------------------------------
#    11 | 00m14s |    0.12879 | 58.000000 | 67.000000 |
# ---------------------------------
# MACDStrategy_39_56
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3816721870
# Max Drawdown: 44.7057261199
# Max Drawdown Duration: 5830
# Total Returns: 0.7862162876
# ---------------------------------
# Trades: 68
# Trade Winning: 54%
# Average Trade: 1.30%
# Average Win: 5.80%
# Average Loss: -4.07%
# Best Trade: 21.02%
# Worst Trade: -12.81%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 2 days 03:52:04
# ---------------------------------
#    12 | 00m10s |    0.78622 | 17.000000 | 39.000000 |
# ---------------------------------
# MACDStrategy_55_74
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0025859272
# Max Drawdown: 52.7245230861
# Max Drawdown Duration: 5830
# Total Returns: 0.4448224421
# ---------------------------------
# Trades: 52
# Trade Winning: 42%
# Average Trade: 1.36%
# Average Win: 8.74%
# Average Loss: -4.04%
# Best Trade: 25.31%
# Worst Trade: -10.97%
# Worst Trade Date: 2 days 05:00:00
# Avg Days in Trade: 2 days 20:16:09
# ---------------------------------
#    13 | 00m14s |    0.44482 | 19.000000 | 55.000000 |
# ---------------------------------
# MACDStrategy_48_54
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4722565686
# Max Drawdown: 46.8462023902
# Max Drawdown Duration: 5830
# Total Returns: 0.8871453841
# ---------------------------------
# Trades: 102
# Trade Winning: 60%
# Average Trade: 1.01%
# Average Win: 4.01%
# Average Loss: -3.45%
# Best Trade: 24.76%
# Worst Trade: -16.85%
# Worst Trade Date: 1 days 05:00:00
# Avg Days in Trade: 1 days 10:20:00
# ---------------------------------
#    14 | 00m14s |    0.88715 | 6.000000 | 48.000000 |
# ---------------------------------
# MACDStrategy_98_187
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6564682274
# Max Drawdown: 47.3952266241
# Max Drawdown Duration: 5604
# Total Returns: 1.0825297644
# ---------------------------------
# Trades: 18
# Trade Winning: 44%
# Average Trade: 6.44%
# Average Win: 23.36%
# Average Loss: -7.09%
# Best Trade: 88.78%
# Worst Trade: -16.29%
# Worst Trade Date: 3 days 07:00:00
# Avg Days in Trade: 8 days 09:06:40
# ---------------------------------
#    15 | 00m24s |    1.08253 | 89.000000 | 98.000000 |
# ---------------------------------
# MACDStrategy_88_187
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5471579294
# Max Drawdown: 47.2181283150
# Max Drawdown Duration: 5604
# Total Returns: 0.9459833214
# ---------------------------------
# Trades: 18
# Trade Winning: 39%
# Average Trade: 6.86%
# Average Win: 29.58%
# Average Loss: -7.60%
# Best Trade: 118.10%
# Worst Trade: -15.81%
# Worst Trade Date: 3 days 04:00:00
# Avg Days in Trade: 8 days 09:00:00
# ---------------------------------
#    16 | 00m23s |    0.94598 | 99.000000 | 88.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 1.398290177644336, 'max_params': {'short_window': 48.0, 'delta_window': 14.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
# Target.to_csv(config['out_dir'] + "/target_ei.csv")
Target.sort_values(by = "Target")
# Out:
#         Parameters    Target
# 0       [1.0, 1.0] -0.995316
# 10    [67.0, 58.0]  0.128787
# 9      [74.0, 5.0]  0.165271
# 8    [75.0, 120.0]  0.357059
# 3     [61.0, 61.0]  0.415581
# 12    [55.0, 19.0]  0.444822
# 11    [39.0, 17.0]  0.786216
# 4     [81.0, 81.0]  0.828633
# 2     [41.0, 41.0]  0.858556
# 6    [113.0, 82.0]  0.869265
# 1     [21.0, 21.0]  0.877175
# 13     [48.0, 6.0]  0.887145
# 15    [88.0, 99.0]  0.945983
# 14    [98.0, 89.0]  1.082530
# 5   [101.0, 101.0]  1.165315
# 7     [48.0, 14.0]  1.398290

# %%
BO.maximize(init_points=0, n_iter=10, acq="ei", xi=0.0001, **gp_params)
# Out:
# Bayesian Optimization
# ---------------------------------------------------------------
#  Step |   Time |      Value |   delta_window |   short_window |
# ---------------------------------
# MACDStrategy_23_60
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2489834064
# Max Drawdown: 48.3567601222
# Max Drawdown Duration: 5371
# Total Returns: 0.6791356503
# ---------------------------------
# Trades: 61
# Trade Winning: 36%
# Average Trade: 1.38%
# Average Win: 9.33%
# Average Loss: -3.10%
# Best Trade: 37.39%
# Worst Trade: -10.29%
# Worst Trade Date: 0 days 23:00:00
# Avg Days in Trade: 2 days 11:00:59
# ---------------------------------
#    17 | 00m12s |    0.67914 | 37.000000 | 23.000000 |
# ---------------------------------
# MACDStrategy_114_212
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1468236474
# Max Drawdown: 50.0998699723
# Max Drawdown Duration: 5604
# Total Returns: 0.5763591787
# ---------------------------------
# Trades: 15
# Trade Winning: 47%
# Average Trade: 5.11%
# Average Win: 19.78%
# Average Loss: -7.73%
# Best Trade: 70.04%
# Worst Trade: -13.94%
# Worst Trade Date: 2 days 23:00:00
# Avg Days in Trade: 9 days 18:32:00
# ---------------------------------
#    18 | 00m23s |    0.57636 | 98.000000 | 114.000000 |
# ---------------------------------
# MACDStrategy_46_58
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9076364778
# Max Drawdown: 38.0045082954
# Max Drawdown Duration: 4444
# Total Returns: 1.3823472429
# ---------------------------------
# Trades: 72
# Trade Winning: 57%
# Average Trade: 1.66%
# Average Win: 5.66%
# Average Loss: -3.63%
# Best Trade: 23.06%
# Worst Trade: -16.94%
# Worst Trade Date: 1 days 04:00:00
# Avg Days in Trade: 2 days 01:04:10
# ---------------------------------
#    19 | 00m10s |    1.38235 | 12.000000 | 46.000000 |
# ---------------------------------
# MACDStrategy_99_215
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0587365416
# Max Drawdown: 46.7446174893
# Max Drawdown Duration: 5604
# Total Returns: 0.4734487283
# ---------------------------------
# Trades: 14
# Trade Winning: 36%
# Average Trade: 5.25%
# Average Win: 27.31%
# Average Loss: -7.00%
# Best Trade: 87.37%
# Worst Trade: -12.76%
# Worst Trade Date: 5 days 00:00:00
# Avg Days in Trade: 10 days 08:38:34
# ---------------------------------
#    20 | 00m22s |    0.47345 | 116.000000 | 99.000000 |
# ---------------------------------
# MACDStrategy_37_96
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1892138484
# Max Drawdown: 46.0053921391
# Max Drawdown Duration: 5830
# Total Returns: 0.6043200814
# ---------------------------------
# Trades: 40
# Trade Winning: 38%
# Average Trade: 1.73%
# Average Win: 10.07%
# Average Loss: -3.28%
# Best Trade: 24.51%
# Worst Trade: -9.12%
# Worst Trade Date: 2 days 15:00:00
# Avg Days in Trade: 3 days 16:22:30
# ---------------------------------
#    21 | 00m13s |    0.60432 | 59.000000 | 37.000000 |
# ---------------------------------
# MACDStrategy_100_170
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2845860294
# Max Drawdown: 52.6055137600
# Max Drawdown Duration: 5604
# Total Returns: 0.6958287499
# ---------------------------------
# Trades: 20
# Trade Winning: 40%
# Average Trade: 5.16%
# Average Win: 24.02%
# Average Loss: -7.40%
# Best Trade: 106.33%
# Worst Trade: -13.15%
# Worst Trade Date: 3 days 12:00:00
# Avg Days in Trade: 7 days 13:48:00
# ---------------------------------
#    22 | 00m18s |    0.69583 | 70.000000 | 100.000000 |
# ---------------------------------
# MACDStrategy_60_149
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0496439908
# Max Drawdown: 61.4173234511
# Max Drawdown Duration: 5604
# Total Returns: 0.4766692073
# ---------------------------------
# Trades: 24
# Trade Winning: 29%
# Average Trade: 4.42%
# Average Win: 30.32%
# Average Loss: -6.24%
# Best Trade: 136.81%
# Worst Trade: -18.36%
# Worst Trade Date: 3 days 02:00:00
# Avg Days in Trade: 6 days 08:35:00
# ---------------------------------
#    23 | 00m16s |    0.47667 | 89.000000 | 60.000000 |
# ---------------------------------
# MACDStrategy_120_180
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7969040827
# Max Drawdown: 42.9256011621
# Max Drawdown Duration: 5604
# Total Returns: 1.2897513304
# ---------------------------------
# Trades: 19
# Trade Winning: 53%
# Average Trade: 6.51%
# Average Win: 19.20%
# Average Loss: -7.59%
# Best Trade: 81.62%
# Worst Trade: -14.98%
# Worst Trade Date: 3 days 03:00:00
# Avg Days in Trade: 7 days 23:28:25
# ---------------------------------
#    24 | 00m19s |    1.28975 | 60.000000 | 120.000000 |
# ---------------------------------
# MACDStrategy_119_166
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1802090903
# Max Drawdown: 31.9647288099
# Max Drawdown Duration: 2304
# Total Returns: 1.8212484813
# ---------------------------------
# Trades: 21
# Trade Winning: 57%
# Average Trade: 7.20%
# Average Win: 17.96%
# Average Loss: -7.16%
# Best Trade: 95.38%
# Worst Trade: -16.24%
# Worst Trade Date: 2 days 20:00:00
# Avg Days in Trade: 7 days 05:51:26
# ---------------------------------
#    25 | 00m19s |    1.82125 | 47.000000 | 119.000000 |
# ---------------------------------
# MACDStrategy_111_157
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4622138792
# Max Drawdown: 47.3832422685
# Max Drawdown Duration: 5604
# Total Returns: 0.8935242993
# ---------------------------------
# Trades: 23
# Trade Winning: 43%
# Average Trade: 4.68%
# Average Win: 19.44%
# Average Loss: -6.67%
# Best Trade: 87.83%
# Worst Trade: -12.75%
# Worst Trade Date: 3 days 14:00:00
# Avg Days in Trade: 6 days 16:36:31
# ---------------------------------
#    26 | 00m16s |    0.89352 | 46.000000 | 111.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 1.8212484812538583, 'max_params': {'short_window': 119.0, 'delta_window': 47.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
Target.to_csv(config['out_dir'] + "/target_ei.csv")
Target.sort_values(by = "Target")
# Out:
#         Parameters    Target
# 0       [1.0, 1.0] -0.995316
# 10    [67.0, 58.0]  0.128787
# 9      [74.0, 5.0]  0.165271
# 8    [75.0, 120.0]  0.357059
# 3     [61.0, 61.0]  0.415581
# 12    [55.0, 19.0]  0.444822
# 19   [99.0, 116.0]  0.473449
# 22    [60.0, 89.0]  0.476669
# 17   [114.0, 98.0]  0.576359
# 20    [37.0, 59.0]  0.604320
# 16    [23.0, 37.0]  0.679136
# 21   [100.0, 70.0]  0.695829
# 11    [39.0, 17.0]  0.786216
# 4     [81.0, 81.0]  0.828633
# 2     [41.0, 41.0]  0.858556
# 6    [113.0, 82.0]  0.869265
# 1     [21.0, 21.0]  0.877175
# 13     [48.0, 6.0]  0.887145
# 25   [111.0, 46.0]  0.893524
# 15    [88.0, 99.0]  0.945983
# 14    [98.0, 89.0]  1.082530
# 5   [101.0, 101.0]  1.165315
# 23   [120.0, 60.0]  1.289751
# 18    [46.0, 12.0]  1.382347
# 7     [48.0, 14.0]  1.398290
# 24   [119.0, 47.0]  1.821248

# %%
filename = config['out_dir'] + "/target_ei.png"
plot_bo(BO, filename)

# %% [markdown]
# ## Acquisition Function "Probability of Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)

# %%
BO = BayesianOptimization(
    run_backtest,
    {'short_window': (1, 120),
    'delta_window': (1, 120)},
    is_int = [1, 1], 
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
BO.explore({
    'short_window': np.arange(1, 120, 20),
    'delta_window': np.arange(1, 120, 20)
    },
    eager=True)
BO.maximize(init_points=0, n_iter=10, acq="poi", xi=0.01, **gp_params)
# Out:
# ---------------------------------
# ADXStrategy_1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -6.9007275153
# Max Drawdown: 98.8338690249
# Max Drawdown Duration: 6661
# Total Returns: -0.9866560406
# ---------------------------------
# Trades: 1231
# Trade Winning: 38%
# Average Trade: -0.13%
# Average Win: 1.35%
# Average Loss: -1.04%
# Best Trade: 11.71%
# Worst Trade: -7.69%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 02:49:49
# ---------------------------------
#     1 | 00m05s |   -0.98666 | 1.000000 |
# ---------------------------------
# ADXStrategy_21
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5715412195
# Max Drawdown: 44.0459039139
# Max Drawdown Duration: 3858
# Total Returns: 0.9908953916
# ---------------------------------
# Trades: 234
# Trade Winning: 42%
# Average Trade: 0.59%
# Average Win: 3.44%
# Average Loss: -1.47%
# Best Trade: 31.17%
# Worst Trade: -9.52%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 0 days 13:16:09
# ---------------------------------
#     2 | 00m05s |    0.99090 | 21.000000 |
# ---------------------------------
# ADXStrategy_41
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5875275955
# Max Drawdown: 59.9307265688
# Max Drawdown Duration: 5371
# Total Returns: 0.1443933318
# ---------------------------------
# Trades: 175
# Trade Winning: 39%
# Average Trade: 0.37%
# Average Win: 3.36%
# Average Loss: -1.54%
# Best Trade: 25.07%
# Worst Trade: -6.98%
# Worst Trade Date: 0 days 18:00:00
# Avg Days in Trade: 0 days 17:49:22
# ---------------------------------
#     3 | 00m05s |    0.14439 | 41.000000 |
# ---------------------------------
# ADXStrategy_61
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8688237540
# Max Drawdown: 52.5145313917
# Max Drawdown Duration: 5830
# Total Returns: 0.3291361075
# ---------------------------------
# Trades: 125
# Trade Winning: 34%
# Average Trade: 0.56%
# Average Win: 5.17%
# Average Loss: -1.86%
# Best Trade: 27.06%
# Worst Trade: -9.55%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 0 days 23:57:36
# ---------------------------------
#     4 | 00m05s |    0.32914 | 61.000000 |
# ---------------------------------
# ADXStrategy_81
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5021898490
# Max Drawdown: 57.3275218982
# Max Drawdown Duration: 5830
# Total Returns: 0.0938114060
# ---------------------------------
# Trades: 119
# Trade Winning: 35%
# Average Trade: 0.42%
# Average Win: 4.82%
# Average Loss: -1.98%
# Best Trade: 30.15%
# Worst Trade: -10.43%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 1 days 00:41:21
# ---------------------------------
#     5 | 00m05s |    0.09381 | 81.000000 |
# ---------------------------------
# ADXStrategy_101
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7445200130
# Max Drawdown: 53.1600102521
# Max Drawdown Duration: 5830
# Total Returns: 0.2389377347
# ---------------------------------
# Trades: 105
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 4.22%
# Average Loss: -2.02%
# Best Trade: 24.74%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 03:27:26
# ---------------------------------
#     6 | 00m04s |    0.23894 | 101.000000 |
# ---------------------------------
# ADXStrategy_121
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5420596438
# Max Drawdown: 56.5896951304
# Max Drawdown Duration: 5830
# Total Returns: 0.1155193189
# ---------------------------------
# Trades: 100
# Trade Winning: 46%
# Average Trade: 0.46%
# Average Win: 3.40%
# Average Loss: -2.05%
# Best Trade: 29.30%
# Worst Trade: -12.39%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 1 days 04:06:00
# ---------------------------------
#     7 | 00m04s |    0.11552 | 121.000000 |
# ---------------------------------
# ADXStrategy_141
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3067396204
# Max Drawdown: 40.3329394527
# Max Drawdown Duration: 5830
# Total Returns: 0.6482326740
# ---------------------------------
# Trades: 86
# Trade Winning: 41%
# Average Trade: 0.95%
# Average Win: 4.82%
# Average Loss: -1.70%
# Best Trade: 27.98%
# Worst Trade: -9.79%
# Worst Trade Date: 0 days 12:00:00
# Avg Days in Trade: 1 days 07:30:42
# ---------------------------------
#     8 | 00m05s |    0.64823 | 141.000000 |
# ---------------------------------
# ADXStrategy_161
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7708650272
# Max Drawdown: 40.7294677642
# Max Drawdown Duration: 5830
# Total Returns: 0.2508738221
# ---------------------------------
# Trades: 83
# Trade Winning: 33%
# Average Trade: 0.64%
# Average Win: 5.60%
# Average Loss: -1.76%
# Best Trade: 29.49%
# Worst Trade: -9.73%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 08:28:55
# ---------------------------------
#     9 | 00m04s |    0.25087 | 161.000000 |
# ---------------------------------
# ADXStrategy_181
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9320243863
# Max Drawdown: 42.8976564485
# Max Drawdown Duration: 5830
# Total Returns: 0.3231417558
# ---------------------------------
# Trades: 68
# Trade Winning: 38%
# Average Trade: 0.75%
# Average Win: 4.77%
# Average Loss: -1.74%
# Best Trade: 23.84%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 14:57:21
# ---------------------------------
#    10 | 00m04s |    0.32314 | 181.000000 |
# ---------------------------------
# ADXStrategy_201
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6836614752
# Max Drawdown: 51.4784866060
# Max Drawdown Duration: 5830
# Total Returns: 0.2013883465
# ---------------------------------
# Trades: 70
# Trade Winning: 43%
# Average Trade: 0.60%
# Average Win: 4.27%
# Average Loss: -2.14%
# Best Trade: 20.71%
# Worst Trade: -10.11%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 1 days 13:54:00
# ---------------------------------
#    11 | 00m04s |    0.20139 | 201.000000 |
# ---------------------------------
# ADXStrategy_221
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2138615878
# Max Drawdown: 61.4626828553
# Max Drawdown Duration: 5830
# Total Returns: -0.0525022310
# ---------------------------------
# Trades: 68
# Trade Winning: 43%
# Average Trade: 0.35%
# Average Win: 4.51%
# Average Loss: -2.75%
# Best Trade: 39.17%
# Worst Trade: -15.78%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 1 days 14:11:28
# ---------------------------------
#    12 | 00m04s |   -0.05250 | 221.000000 |
# Initialization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# ---------------------------------
# ADXStrategy_22
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4364670989
# Max Drawdown: 36.0111502612
# Max Drawdown Duration: 3774
# Total Returns: 0.8445350169
# ---------------------------------
# Trades: 233
# Trade Winning: 41%
# Average Trade: 0.54%
# Average Win: 3.34%
# Average Loss: -1.42%
# Best Trade: 29.88%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 13:23:57
# ---------------------------------
#    13 | 00m05s |    0.84454 | 22.000000 |
# ---------------------------------
# ADXStrategy_52
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2047532899
# Max Drawdown: 40.0044633116
# Max Drawdown Duration: 4781
# Total Returns: 0.5959807336
# ---------------------------------
# Trades: 152
# Trade Winning: 38%
# Average Trade: 0.62%
# Average Win: 4.18%
# Average Loss: -1.58%
# Best Trade: 25.07%
# Worst Trade: -5.73%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 19:52:30
# ---------------------------------
#    14 | 00m05s |    0.59598 | 52.000000 |
# ---------------------------------
# ADXStrategy_20
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4153726655
# Max Drawdown: 44.2268949807
# Max Drawdown Duration: 3724
# Total Returns: 0.8314923847
# ---------------------------------
# Trades: 241
# Trade Winning: 40%
# Average Trade: 0.53%
# Average Win: 3.43%
# Average Loss: -1.42%
# Best Trade: 31.17%
# Worst Trade: -7.86%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 12:57:31
# ---------------------------------
#    15 | 00m05s |    0.83149 | 20.000000 |
# ---------------------------------
# ADXStrategy_144
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7270559361
# Max Drawdown: 52.5703341320
# Max Drawdown Duration: 5830
# Total Returns: 0.2327131467
# ---------------------------------
# Trades: 86
# Trade Winning: 35%
# Average Trade: 0.61%
# Average Win: 5.06%
# Average Loss: -1.78%
# Best Trade: 25.27%
# Worst Trade: -9.13%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 07:36:59
# ---------------------------------
#    16 | 00m06s |    0.23271 | 144.000000 |
# ---------------------------------
# ADXStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6548398811
# Max Drawdown: 59.6558552739
# Max Drawdown Duration: 5830
# Total Returns: 0.1840274616
# ---------------------------------
# Trades: 81
# Trade Winning: 28%
# Average Trade: 0.63%
# Average Win: 7.48%
# Average Loss: -2.09%
# Best Trade: 28.61%
# Worst Trade: -10.06%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 1 days 09:31:07
# ---------------------------------
#    17 | 00m06s |    0.18403 | 138.000000 |
# ---------------------------------
# ADXStrategy_56
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1103352735
# Max Drawdown: 42.0946006265
# Max Drawdown Duration: 5830
# Total Returns: 0.5069405657
# ---------------------------------
# Trades: 141
# Trade Winning: 35%
# Average Trade: 0.61%
# Average Win: 4.66%
# Average Loss: -1.55%
# Best Trade: 23.29%
# Worst Trade: -8.76%
# Worst Trade Date: 1 days 20:00:00
# Avg Days in Trade: 0 days 21:22:33
# ---------------------------------
#    18 | 00m06s |    0.50694 | 56.000000 |
# ---------------------------------
# ADXStrategy_48
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6922403360
# Max Drawdown: 54.0822412554
# Max Drawdown Duration: 5830
# Total Returns: 0.2100855978
# ---------------------------------
# Trades: 161
# Trade Winning: 37%
# Average Trade: 0.42%
# Average Win: 3.92%
# Average Loss: -1.60%
# Best Trade: 26.55%
# Worst Trade: -9.40%
# Worst Trade Date: 1 days 12:00:00
# Avg Days in Trade: 0 days 19:00:22
# ---------------------------------
#    19 | 00m06s |    0.21009 | 48.000000 |
# ---------------------------------
# ADXStrategy_11
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.6883505718
# Max Drawdown: 71.2006353477
# Max Drawdown Duration: 5604
# Total Returns: -0.4210990306
# ---------------------------------
# Trades: 376
# Trade Winning: 36%
# Average Trade: 0.10%
# Average Win: 2.74%
# Average Loss: -1.37%
# Best Trade: 16.35%
# Worst Trade: -8.72%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 08:35:16
# ---------------------------------
#    20 | 00m05s |   -0.42110 | 11.000000 |
# ---------------------------------
# ADXStrategy_108
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8457720252
# Max Drawdown: 49.2165116646
# Max Drawdown Duration: 5830
# Total Returns: 0.2968767811
# ---------------------------------
# Trades: 101
# Trade Winning: 39%
# Average Trade: 0.60%
# Average Win: 4.33%
# Average Loss: -1.75%
# Best Trade: 29.63%
# Worst Trade: -7.51%
# Worst Trade Date: 2 days 21:00:00
# Avg Days in Trade: 1 days 04:24:21
# ---------------------------------
#    21 | 00m05s |    0.29688 | 108.000000 |
# ---------------------------------
# ADXStrategy_174
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8579634914
# Max Drawdown: 43.9820447360
# Max Drawdown Duration: 5830
# Total Returns: 0.2984961355
# ---------------------------------
# Trades: 81
# Trade Winning: 43%
# Average Trade: 0.65%
# Average Win: 3.90%
# Average Loss: -1.83%
# Best Trade: 25.12%
# Worst Trade: -6.34%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 08:34:49
# ---------------------------------
#    22 | 00m05s |    0.29850 | 174.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 0.9908953915556202, 'max_params': {'window': 21.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
# Target.to_csv(config['out_dir'] + "/target_pi.csv")
Target.sort_values(by = "Target")
# Out:
#    Parameters    Target
# 0       [1.0] -0.986656
# 19     [11.0] -0.421099
# 11    [221.0] -0.052502
# 4      [81.0]  0.093811
# 6     [121.0]  0.115519
# 2      [41.0]  0.144393
# 16    [138.0]  0.184027
# 10    [201.0]  0.201388
# 18     [48.0]  0.210086
# 15    [144.0]  0.232713
# 5     [101.0]  0.238938
# 8     [161.0]  0.250874
# 20    [108.0]  0.296877
# 21    [174.0]  0.298496
# 9     [181.0]  0.323142
# 3      [61.0]  0.329136
# 17     [56.0]  0.506941
# 13     [52.0]  0.595981
# 7     [141.0]  0.648233
# 14     [20.0]  0.831492
# 12     [22.0]  0.844535
# 1      [21.0]  0.990895

# %%
BO.maximize(init_points=0, n_iter=10, acq="poi", xi=0.0001, **gp_params)
# Out:
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |    window |
# ---------------------------------
# ADXStrategy_69
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2325719271
# Max Drawdown: 41.3920074235
# Max Drawdown Duration: 5830
# Total Returns: 0.6258643073
# ---------------------------------
# Trades: 132
# Trade Winning: 33%
# Average Trade: 0.69%
# Average Win: 4.85%
# Average Loss: -1.39%
# Best Trade: 27.78%
# Worst Trade: -10.13%
# Worst Trade Date: 1 days 16:00:00
# Avg Days in Trade: 0 days 22:25:00
# ---------------------------------
#    23 | 00m06s |    0.62586 | 69.000000 |
# ---------------------------------
# ADXStrategy_208
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2793460039
# Max Drawdown: 61.6215017084
# Max Drawdown Duration: 5830
# Total Returns: -0.0173045717
# ---------------------------------
# Trades: 68
# Trade Winning: 40%
# Average Trade: 0.33%
# Average Win: 4.45%
# Average Loss: -2.38%
# Best Trade: 24.35%
# Worst Trade: -11.88%
# Worst Trade Date: 2 days 19:00:00
# Avg Days in Trade: 1 days 14:51:11
# ---------------------------------
#    24 | 00m06s |   -0.01730 | 208.000000 |
# ---------------------------------
# ADXStrategy_38
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2963516724
# Max Drawdown: 60.2835713561
# Max Drawdown Duration: 5604
# Total Returns: -0.0188880136
# ---------------------------------
# Trades: 190
# Trade Winning: 38%
# Average Trade: 0.28%
# Average Win: 3.46%
# Average Loss: -1.70%
# Best Trade: 25.56%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 16:25:54
# ---------------------------------
#    25 | 00m06s |   -0.01889 | 38.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_236
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2293450394
# Max Drawdown: 39.2840697707
# Max Drawdown Duration: 4035
# Total Returns: 0.5468089025
# ---------------------------------
# Trades: 67
# Trade Winning: 43%
# Average Trade: 1.09%
# Average Win: 5.56%
# Average Loss: -2.32%
# Best Trade: 39.78%
# Worst Trade: -12.41%
# Worst Trade Date: 4 days 19:00:00
# Avg Days in Trade: 1 days 15:11:39
# ---------------------------------
#    26 | 00m06s |    0.54681 | 236.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_73
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8653665522
# Max Drawdown: 50.8218232029
# Max Drawdown Duration: 5830
# Total Returns: 0.3170209232
# ---------------------------------
# Trades: 127
# Trade Winning: 40%
# Average Trade: 0.53%
# Average Win: 3.60%
# Average Loss: -1.54%
# Best Trade: 28.07%
# Worst Trade: -16.62%
# Worst Trade Date: 1 days 20:00:00
# Avg Days in Trade: 0 days 23:14:10
# ---------------------------------
#    27 | 00m05s |    0.31702 | 73.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_204
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3546787980
# Max Drawdown: 61.5111994147
# Max Drawdown Duration: 5830
# Total Returns: 0.0263514878
# ---------------------------------
# Trades: 63
# Trade Winning: 38%
# Average Trade: 0.41%
# Average Win: 5.12%
# Average Loss: -2.49%
# Best Trade: 24.35%
# Worst Trade: -12.32%
# Worst Trade Date: 2 days 15:00:00
# Avg Days in Trade: 1 days 18:02:51
# ---------------------------------
#    28 | 00m05s |    0.02635 | 204.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_30
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5687069724
# Max Drawdown: 59.3062769981
# Max Drawdown Duration: 5604
# Total Returns: 0.1343118818
# ---------------------------------
# Trades: 204
# Trade Winning: 35%
# Average Trade: 0.35%
# Average Win: 3.78%
# Average Loss: -1.48%
# Best Trade: 26.63%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 15:26:46
# ---------------------------------
#    29 | 00m05s |    0.13431 | 30.000000 |
# ---------------------------------
# ADXStrategy_191
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3643963576
# Max Drawdown: 55.4176517757
# Max Drawdown Duration: 5830
# Total Returns: 0.0348292399
# ---------------------------------
# Trades: 66
# Trade Winning: 33%
# Average Trade: 0.42%
# Average Win: 5.84%
# Average Loss: -2.29%
# Best Trade: 22.11%
# Worst Trade: -11.48%
# Worst Trade Date: 2 days 03:00:00
# Avg Days in Trade: 1 days 15:40:00
# ---------------------------------
#    30 | 00m05s |    0.03483 | 191.000000 |
# ---------------------------------
# ADXStrategy_134
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0607317746
# Max Drawdown: 58.0646124984
# Max Drawdown Duration: 5830
# Total Returns: 0.4731033513
# ---------------------------------
# Trades: 84
# Trade Winning: 42%
# Average Trade: 0.85%
# Average Win: 4.73%
# Average Loss: -1.92%
# Best Trade: 30.72%
# Worst Trade: -9.74%
# Worst Trade Date: 0 days 19:00:00
# Avg Days in Trade: 1 days 08:27:51
# ---------------------------------
#    31 | 00m05s |    0.47310 | 134.000000 | Warning: Test point chose at random due to repeated sample.
#
# ---------------------------------
# ADXStrategy_80
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-08-07 23:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6597534293
# Max Drawdown: 54.5557019737
# Max Drawdown Duration: 5830
# Total Returns: 0.1880745344
# ---------------------------------
# Trades: 117
# Trade Winning: 38%
# Average Trade: 0.48%
# Average Win: 4.53%
# Average Loss: -1.96%
# Best Trade: 29.79%
# Worst Trade: -9.57%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 1 days 01:13:20
# ---------------------------------
#    32 | 00m05s |    0.18807 | 80.000000 | Warning: Test point chose at random due to repeated sample.

# %%
print(BO.res['max'])
# Out:
# {'max_val': 0.9908953915556202, 'max_params': {'window': 21.0}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
Target.to_csv(config['out_dir'] + "/target_pi.csv")
Target.sort_values(by = "Target")
# Out:
#    Parameters    Target
# 0       [1.0] -0.986656
# 19     [11.0] -0.421099
# 11    [221.0] -0.052502
# 24     [38.0] -0.018888
# 23    [208.0] -0.017305
# 27    [204.0]  0.026351
# 29    [191.0]  0.034829
# 4      [81.0]  0.093811
# 6     [121.0]  0.115519
# 28     [30.0]  0.134312
# 2      [41.0]  0.144393
# 16    [138.0]  0.184027
# 31     [80.0]  0.188075
# 10    [201.0]  0.201388
# 18     [48.0]  0.210086
# 15    [144.0]  0.232713
# 5     [101.0]  0.238938
# 8     [161.0]  0.250874
# 20    [108.0]  0.296877
# 21    [174.0]  0.298496
# 26     [73.0]  0.317021
# 9     [181.0]  0.323142
# 3      [61.0]  0.329136
# 30    [134.0]  0.473103
# 17     [56.0]  0.506941
# 25    [236.0]  0.546809
# 13     [52.0]  0.595981
# 22     [69.0]  0.625864
# 7     [141.0]  0.648233
# 14     [20.0]  0.831492
# 12     [22.0]  0.844535
# 1      [21.0]  0.990895

# %%
filename = config['out_dir'] + "/target_pi.png"
plot_bo(BO, filename)
