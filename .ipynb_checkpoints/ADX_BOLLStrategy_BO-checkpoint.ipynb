# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

from BayesianOptimization.bayesian_optimization import BayesianOptimization

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from ADX_BOLLStrategy import ADX_BOLLStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
def run_backtest(config, trading_data, ohlc_data, window_ADX, window_BOLL, a):
    window_ADX = int(window_ADX)
    window_BOLL = int(window_BOLL)
    config['title'] = "ADX_BOLLStrategy" + "_" + str(window_ADX) + "_" + str(window_BOLL) + "_" + str(a)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")
    
    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data = trading_data, ohlc_data = ohlc_data
    )
    strategy = ADX_BOLLStrategy(config, events_queue, data_handler,
                           window_ADX = window_ADX,
                            window_BOLL = window_BOLL, a = a)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler= data_handler)

    results = backtest.start_trading()
    
    return (results['cum_returns'][-1] - 1)

# %% [markdown]
# ## Setting

# %%
config = {
    "csv_dir": "C:/backtest/Binance",
    "out_dir": "C:/backtest/results/ADX_BOLLStrategy",
    "title": "ADX_BOLLStrategy",
    "is_plot": False,
    "save_plot": False,
    "save_tradelog": False,
    "start_date": pd.Timestamp("2017-07-01T00:0:00", freq = "60" + "T"),    # str(freq) + "T"
    "end_date": pd.Timestamp("2018-04-01T00:00:00", freq = "60" + "T"),
    "equity": 1.0,
    "freq": 60,      # min
    "commission_ratio": 0.001,
    "suggested_quantity": None,     # None or a value
    "max_quantity": None,           # None or a value, Maximum purchase quantity
    "min_quantity": None,           # None or a value, Minimum purchase quantity
    "min_handheld_cash": None,      # None or a value, Minimum handheld funds
    "exchange": "Binance",
    "tickers": ['BTCUSDT']
}

# %%
# trading_data = {}
# for ticker in config['tickers']:
#     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
#     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

ohlc_data = {}
for ticker in config['tickers']:
    # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
    ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker +'_OHLC_60min.h5', key=ticker)

trading_data = None

# %%
gp_params = {"alpha": 1e-5}

# %% [markdown]
# ## Acquisition Function "Upper Confidence Bound"

# %% [markdown]
# * Prefer exploitation (kappa=1.0)
#
# * Prefer exploration (kappa=10)

# %% [markdown]
# ## Acquisition Function "Expected Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)

# %%
BO = BayesianOptimization(
    run_backtest,
    {'window_ADX': (1, 240),
    'window_BOLL': (1, 240),
    'a': (0.1, 3)},
    is_int = [1, 1, 0], 
    invariant = {
        'config': config,
        'trading_data': trading_data,
        'ohlc_data': ohlc_data
    },
    random_state = 1
)
# BO.explore({
#     'short_window': np.arange(1, 120, 20),
#     'delta_window': np.arange(1, 120, 20)
#     },
#     eager=True)
BO.maximize(init_points=40, n_iter=60, acq="ei", xi=0.01, **gp_params)
# Out:
# Initialization
# ------------------------------------------------------------------------
#  Step |   Time |      Value |         a |   window_ADX |   window_BOLL |
# ---------------------------------
# ADX_BOLLStrategy_38_23_0.7441611878525869
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2473373025
# Sortino Ratio: 2.0763982720
# Max Drawdown: 0.3796025386
# Max Drawdown Duration: 250900
# Total Returns: 0.3254574378
# Annualized Returns: 0.7659879515
# Compound Annual Growth Rate: 0.9408718174
# ---------------------------------
# Trades: 71
# Trade Winning: 40.85%
# Average Trade: 0.74%
# Average Win: 4.91%
# Average Loss: -2.14%
# Best Trade: 26.23%
# Worst Trade: -10.16%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 18:40:34
# ---------------------------------
#     1 | 00m03s |    0.32546 | 0.744161 | 38.000000 | 23.000000 |
# ---------------------------------
# ADX_BOLLStrategy_236_58_0.31275609805353877
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0928833763
# Sortino Ratio: 1.7510532492
# Max Drawdown: 0.3260466264
# Max Drawdown Duration: 273500
# Total Returns: 0.2437784782
# Annualized Returns: 0.5737505290
# Compound Annual Growth Rate: 0.6710316989
# ---------------------------------
# Trades: 51
# Trade Winning: 31.37%
# Average Trade: 0.85%
# Average Win: 6.66%
# Average Loss: -1.80%
# Best Trade: 39.78%
# Worst Trade: -5.74%
# Worst Trade Date: 0 days 18:00:00
# Avg Days in Trade: 0 days 20:17:39
# ---------------------------------
#     2 | 00m05s |    0.24378 | 0.312756 | 236.000000 | 58.000000 |
# ---------------------------------
# ADX_BOLLStrategy_141_2_1.4607917266706152
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#     3 | 00m03s |    0.00000 | 1.460792 | 141.000000 | 2.000000 |
# ---------------------------------
# ADX_BOLLStrategy_73_129_0.37889955529183883
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2739124146
# Sortino Ratio: 1.7403142608
# Max Drawdown: 0.4332286813
# Max Drawdown Duration: 273500
# Total Returns: 0.3400718422
# Annualized Returns: 0.8003840242
# Compound Annual Growth Rate: 0.9916144341
# ---------------------------------
# Trades: 61
# Trade Winning: 42.62%
# Average Trade: 0.85%
# Average Win: 4.79%
# Average Loss: -2.08%
# Best Trade: 28.07%
# Worst Trade: -14.48%
# Worst Trade Date: 1 days 15:00:00
# Avg Days in Trade: 1 days 00:22:37
# ---------------------------------
#     4 | 00m08s |    0.34007 | 0.378900 | 73.000000 | 129.000000 |
# ---------------------------------
# ADX_BOLLStrategy_138_61_2.7197734827887152
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4123825713
# Sortino Ratio: 1.8463555640
# Max Drawdown: 0.3677689926
# Max Drawdown Duration: 273500
# Total Returns: 0.3396358708
# Annualized Returns: 0.7993579334
# Compound Annual Growth Rate: 0.9900897941
# ---------------------------------
# Trades: 9
# Trade Winning: 55.56%
# Average Trade: 4.16%
# Average Win: 12.79%
# Average Loss: -6.62%
# Best Trade: 20.74%
# Worst Trade: -9.75%
# Worst Trade Date: 2 days 00:00:00
# Avg Days in Trade: 3 days 15:46:40
# ---------------------------------
#     5 | 00m05s |    0.33964 | 2.719773 | 138.000000 | 61.000000 |
# ---------------------------------
# ADX_BOLLStrategy_204_210_0.44652235714407884
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6451065811
# Sortino Ratio: 0.7969208487
# Max Drawdown: 0.5401283884
# Max Drawdown Duration: 273500
# Total Returns: 0.0955559750
# Annualized Returns: 0.2248979959
# Compound Annual Growth Rate: 0.2396037225
# ---------------------------------
# Trades: 30
# Trade Winning: 33.33%
# Average Trade: 0.74%
# Average Win: 7.61%
# Average Loss: -2.70%
# Best Trade: 24.35%
# Worst Trade: -12.32%
# Worst Trade Date: 2 days 15:00:00
# Avg Days in Trade: 1 days 18:46:00
# ---------------------------------
#     6 | 00m11s |    0.09556 | 0.446522 | 204.000000 | 210.000000 |
# ---------------------------------
# ADX_BOLLStrategy_134_9_1.621918192924292
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4087398368
# Sortino Ratio: 2.3773515625
# Max Drawdown: 0.2573798639
# Max Drawdown Duration: 273500
# Total Returns: 0.3349031387
# Annualized Returns: 0.7882191013
# Compound Annual Growth Rate: 0.9735821020
# ---------------------------------
# Trades: 49
# Trade Winning: 51.02%
# Average Trade: 0.89%
# Average Win: 3.81%
# Average Loss: -2.15%
# Best Trade: 16.61%
# Worst Trade: -4.28%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 17:57:33
# ---------------------------------
#     7 | 00m03s |    0.33490 | 1.621918 | 134.000000 | 9.000000 |
# ---------------------------------
# ADX_BOLLStrategy_80_217_0.342506713186376
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2646986066
# Sortino Ratio: 1.8841286221
# Max Drawdown: 0.5270427415
# Max Drawdown Duration: 273500
# Total Returns: 0.3289227116
# Annualized Returns: 0.7741437275
# Compound Annual Growth Rate: 0.9528354853
# ---------------------------------
# Trades: 46
# Trade Winning: 34.78%
# Average Trade: 1.08%
# Average Win: 7.98%
# Average Loss: -2.59%
# Best Trade: 29.79%
# Worst Trade: -15.54%
# Worst Trade Date: 0 days 22:00:00
# Avg Days in Trade: 1 days 05:16:57
# ---------------------------------
#     8 | 00m11s |    0.32892 | 0.342507 | 80.000000 | 217.000000 |
# ---------------------------------
# ADX_BOLLStrategy_193_142_2.7588978701362126
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0985091064
# Sortino Ratio: 0.6535418166
# Max Drawdown: 0.3031917169
# Max Drawdown Duration: 293900
# Total Returns: 0.1918338908
# Annualized Returns: 0.4514951326
# Compound Annual Growth Rate: 0.5113996338
# ---------------------------------
# Trades: 6
# Trade Winning: 66.67%
# Average Trade: 3.57%
# Average Win: 8.57%
# Average Loss: -6.45%
# Best Trade: 18.84%
# Worst Trade: -10.14%
# Worst Trade Date: 2 days 04:00:00
# Avg Days in Trade: 4 days 11:50:00
# ---------------------------------
#     9 | 00m08s |    0.19183 | 2.758898 | 193.000000 | 142.000000 |
# ---------------------------------
# ADX_BOLLStrategy_145_116_2.7403003071999943
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6530921023
# Sortino Ratio: 1.6104334622
# Max Drawdown: 0.2369021822
# Max Drawdown Duration: 273500
# Total Returns: 0.3445603105
# Annualized Returns: 0.8109479635
# Compound Annual Growth Rate: 1.0073501619
# ---------------------------------
# Trades: 9
# Trade Winning: 55.56%
# Average Trade: 3.82%
# Average Win: 8.68%
# Average Loss: -2.26%
# Best Trade: 18.76%
# Worst Trade: -5.60%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 2 days 13:33:20
# ---------------------------------
#    10 | 00m07s |    0.34456 | 2.740300 | 145.000000 | 116.000000 |
# ---------------------------------
# ADX_BOLLStrategy_130_176_0.9668973254081766
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9916403681
# Sortino Ratio: 2.7338438005
# Max Drawdown: 0.3561694996
# Max Drawdown Duration: 273500
# Total Returns: 0.6873101193
# Annualized Returns: 1.6176347783
# Compound Annual Growth Rate: 2.4254677849
# ---------------------------------
# Trades: 26
# Trade Winning: 50.00%
# Average Trade: 2.50%
# Average Win: 7.29%
# Average Loss: -2.29%
# Best Trade: 21.40%
# Worst Trade: -6.01%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 2 days 06:34:37
# ---------------------------------
#    11 | 00m09s |    0.68731 | 0.966897 | 130.000000 | 176.000000 |
# ---------------------------------
# ADX_BOLLStrategy_205_235_1.7947284501399945
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0739510515
# Sortino Ratio: 0.0639137450
# Max Drawdown: 0.4873893440
# Max Drawdown Duration: 273500
# Total Returns: -0.0671552285
# Annualized Returns: -0.1580547560
# Compound Annual Growth Rate: -0.1509286919
# ---------------------------------
# Trades: 11
# Trade Winning: 45.45%
# Average Trade: 0.08%
# Average Win: 9.06%
# Average Loss: -7.39%
# Best Trade: 21.03%
# Worst Trade: -17.99%
# Worst Trade Date: 2 days 22:00:00
# Avg Days in Trade: 3 days 18:32:44
# ---------------------------------
#    12 | 00m11s |   -0.06716 | 1.794728 | 205.000000 | 235.000000 |
# ---------------------------------
# ADX_BOLLStrategy_72_122_1.7411448796461602
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5122261817
# Sortino Ratio: 1.8402768537
# Max Drawdown: 0.3518691180
# Max Drawdown Duration: 273500
# Total Returns: 0.3734446588
# Annualized Returns: 0.8789293958
# Compound Annual Growth Rate: 1.1103217956
# ---------------------------------
# Trades: 23
# Trade Winning: 47.83%
# Average Trade: 1.88%
# Average Win: 7.75%
# Average Loss: -3.50%
# Best Trade: 24.67%
# Worst Trade: -11.49%
# Worst Trade Date: 1 days 18:00:00
# Avg Days in Trade: 2 days 00:00:00
# ---------------------------------
#    13 | 00m07s |    0.37344 | 1.741145 | 72.000000 | 122.000000 |
# ---------------------------------
# ADX_BOLLStrategy_238_201_1.8804211216085616
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4364203536
# Sortino Ratio: 1.8317110717
# Max Drawdown: 0.3040593273
# Max Drawdown Duration: 273500
# Total Returns: 0.3460810580
# Annualized Returns: 0.8145271541
# Compound Annual Growth Rate: 1.0126977757
# ---------------------------------
# Trades: 10
# Trade Winning: 60.00%
# Average Trade: 4.06%
# Average Win: 12.07%
# Average Loss: -7.95%
# Best Trade: 35.28%
# Worst Trade: -12.47%
# Worst Trade Date: 4 days 14:00:00
# Avg Days in Trade: 3 days 23:06:00
# ---------------------------------
#    14 | 00m10s |    0.34608 | 1.880421 | 238.000000 | 201.000000 |
# ---------------------------------
# ADX_BOLLStrategy_135_31_2.8739534043445145
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0439261027
# Sortino Ratio: 0.9980385205
# Max Drawdown: 0.3645407225
# Max Drawdown Duration: 273500
# Total Returns: 0.2250104966
# Annualized Returns: 0.5295787077
# Compound Annual Growth Rate: 0.6122912894
# ---------------------------------
# Trades: 11
# Trade Winning: 45.45%
# Average Trade: 2.47%
# Average Win: 10.89%
# Average Loss: -4.55%
# Best Trade: 19.91%
# Worst Trade: -7.75%
# Worst Trade Date: 3 days 00:00:00
# Avg Days in Trade: 3 days 07:38:11
# ---------------------------------
#    15 | 00m04s |    0.22501 | 2.873953 | 135.000000 | 31.000000 |
# ---------------------------------
# ADX_BOLLStrategy_26_72_0.8568390408851148
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.4596663494
# Sortino Ratio: 3.4863373079
# Max Drawdown: 0.2613261437
# Max Drawdown Duration: 168600
# Total Returns: 0.9485894752
# Annualized Returns: 2.2325749067
# Compound Annual Growth Rate: 3.8070440283
# ---------------------------------
# Trades: 60
# Trade Winning: 45.00%
# Average Trade: 1.49%
# Average Win: 5.64%
# Average Loss: -1.90%
# Best Trade: 29.51%
# Worst Trade: -6.98%
# Worst Trade Date: 0 days 13:00:00
# Avg Days in Trade: 0 days 22:17:00
# ---------------------------------
#    16 | 00m05s |    0.94859 | 0.856839 | 26.000000 | 72.000000 |
# ---------------------------------
# ADX_BOLLStrategy_179_132_0.769944724416508
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2696785132
# Sortino Ratio: 1.5511058656
# Max Drawdown: 0.3803049305
# Max Drawdown Duration: 273500
# Total Returns: 0.2991861595
# Annualized Returns: 0.7041565710
# Compound Annual Growth Rate: 0.8515435983
# ---------------------------------
# Trades: 33
# Trade Winning: 36.36%
# Average Trade: 1.19%
# Average Win: 7.08%
# Average Loss: -2.18%
# Best Trade: 21.92%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 13:25:27
# ---------------------------------
#    17 | 00m07s |    0.29919 | 0.769945 | 179.000000 | 132.000000 |
# ---------------------------------
# ADX_BOLLStrategy_21_199_1.6470006227550085
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1811439842
# Sortino Ratio: 2.0201149557
# Max Drawdown: 0.2337641722
# Max Drawdown Duration: 172400
# Total Returns: 0.5753482947
# Annualized Returns: 1.3541244120
# Compound Annual Growth Rate: 1.9143403883
# ---------------------------------
# Trades: 31
# Trade Winning: 51.61%
# Average Trade: 1.86%
# Average Win: 5.47%
# Average Loss: -1.99%
# Best Trade: 27.29%
# Worst Trade: -6.58%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 19:46:27
# ---------------------------------
#    18 | 00m10s |    0.57535 | 1.647001 | 21.000000 | 199.000000 |
# ---------------------------------
# ADX_BOLLStrategy_102_150_2.854820601744655
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1082098229
# Sortino Ratio: 1.5485644593
# Max Drawdown: 0.2453619175
# Max Drawdown Duration: 273500
# Total Returns: 0.4621405863
# Annualized Returns: 1.0876817669
# Compound Annual Growth Rate: 1.4451979606
# ---------------------------------
# Trades: 5
# Trade Winning: 80.00%
# Average Trade: 8.49%
# Average Win: 11.40%
# Average Loss: -3.12%
# Best Trade: 20.44%
# Worst Trade: -3.12%
# Worst Trade Date: 2 days 13:00:00
# Avg Days in Trade: 4 days 15:48:00
# ---------------------------------
#    19 | 00m08s |    0.46214 | 2.854821 | 102.000000 | 150.000000 |
# ---------------------------------
# ADX_BOLLStrategy_147_50_1.5298728212797632
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0509244121
# Sortino Ratio: 2.7668066814
# Max Drawdown: 0.2286382145
# Max Drawdown Duration: 177400
# Total Returns: 0.6040628584
# Annualized Returns: 1.4217062439
# Compound Annual Growth Rate: 2.0409100741
# ---------------------------------
# Trades: 20
# Trade Winning: 55.00%
# Average Trade: 2.92%
# Average Win: 7.86%
# Average Loss: -3.11%
# Best Trade: 21.57%
# Worst Trade: -6.16%
# Worst Trade Date: 0 days 10:00:00
# Avg Days in Trade: 2 days 07:51:00
# ---------------------------------
#    20 | 00m05s |    0.60406 | 1.529873 | 147.000000 | 50.000000 |
# ---------------------------------
# ADX_BOLLStrategy_213_58_1.6677414755885676
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9945597598
# Sortino Ratio: 2.2274812658
# Max Drawdown: 0.2845184267
# Max Drawdown Duration: 273500
# Total Returns: 0.5244054267
# Annualized Returns: 1.2342266357
# Compound Annual Growth Rate: 1.6973693859
# ---------------------------------
# Trades: 22
# Trade Winning: 54.55%
# Average Trade: 2.42%
# Average Win: 6.65%
# Average Loss: -2.67%
# Best Trade: 22.50%
# Worst Trade: -6.55%
# Worst Trade Date: 0 days 22:00:00
# Avg Days in Trade: 1 days 20:27:16
# ---------------------------------
#    21 | 00m05s |    0.52441 | 1.667741 | 213.000000 | 58.000000 |
# ---------------------------------
# ADX_BOLLStrategy_140_4_2.319906802878526
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#    22 | 00m03s |    0.00000 | 2.319907 | 140.000000 | 4.000000 |
# ---------------------------------
# ADX_BOLLStrategy_235_197_0.2315026128664944
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1233667798
# Sortino Ratio: 2.8805024111
# Max Drawdown: 0.2478122897
# Max Drawdown Duration: 172400
# Total Returns: 0.6617799123
# Annualized Returns: 1.5575475637
# Compound Annual Growth Rate: 2.3047295387
# ---------------------------------
# Trades: 34
# Trade Winning: 41.18%
# Average Trade: 2.05%
# Average Win: 8.21%
# Average Loss: -2.26%
# Best Trade: 41.17%
# Worst Trade: -9.12%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 12:00:00
# ---------------------------------
#    23 | 00m10s |    0.66178 | 0.231503 | 235.000000 | 197.000000 |
# ---------------------------------
# ADX_BOLLStrategy_157_25_0.5059017456559718
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2102335876
# Sortino Ratio: 1.5514188145
# Max Drawdown: 0.3079789246
# Max Drawdown Duration: 273500
# Total Returns: 0.2873706776
# Annualized Returns: 0.6763479677
# Compound Annual Growth Rate: 0.8121556593
# ---------------------------------
# Trades: 56
# Trade Winning: 42.86%
# Average Trade: 0.77%
# Average Win: 4.66%
# Average Loss: -2.16%
# Best Trade: 20.02%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 16:35:21
# ---------------------------------
#    24 | 00m04s |    0.28737 | 0.505902 | 157.000000 | 25.000000 |
# ---------------------------------
# ADX_BOLLStrategy_158_44_2.3979703988084555
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0224936824
# Sortino Ratio: 0.8742249262
# Max Drawdown: 0.3318795423
# Max Drawdown Duration: 273500
# Total Returns: 0.2030803180
# Annualized Returns: 0.4779644240
# Compound Annual Growth Rate: 0.5451807256
# ---------------------------------
# Trades: 15
# Trade Winning: 53.33%
# Average Trade: 1.63%
# Average Win: 5.58%
# Average Loss: -2.88%
# Best Trade: 17.67%
# Worst Trade: -6.16%
# Worst Trade Date: 0 days 10:00:00
# Avg Days in Trade: 2 days 09:56:00
# ---------------------------------
#    25 | 00m04s |    0.20308 | 2.397970 | 158.000000 | 44.000000 |
# ---------------------------------
# ADX_BOLLStrategy_143_77_0.18642393872894047
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4046590730
# Sortino Ratio: 0.4805663369
# Max Drawdown: 0.4181234648
# Max Drawdown Duration: 273500
# Total Returns: 0.0076218297
# Annualized Returns: 0.0179385353
# Compound Annual Growth Rate: 0.0180311516
# ---------------------------------
# Trades: 56
# Trade Winning: 25.00%
# Average Trade: 0.38%
# Average Win: 7.34%
# Average Loss: -1.94%
# Best Trade: 24.62%
# Worst Trade: -8.54%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 0 days 22:21:26
# ---------------------------------
#    26 | 00m05s |    0.00762 | 0.186424 | 143.000000 | 77.000000 |
# ---------------------------------
# ADX_BOLLStrategy_51_27_2.6610638798763273
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1833172339
# Sortino Ratio: 2.3266078503
# Max Drawdown: 0.2523930841
# Max Drawdown Duration: 273500
# Total Returns: 0.6782682666
# Annualized Returns: 1.5963541148
# Compound Annual Growth Rate: 2.3824217442
# ---------------------------------
# Trades: 17
# Trade Winning: 52.94%
# Average Trade: 3.64%
# Average Win: 9.79%
# Average Loss: -3.28%
# Best Trade: 21.85%
# Worst Trade: -7.52%
# Worst Trade Date: 1 days 11:00:00
# Avg Days in Trade: 2 days 08:10:35
# ---------------------------------
#    27 | 00m04s |    0.67827 | 2.661064 | 51.000000 | 27.000000 |
# ---------------------------------
# ADX_BOLLStrategy_69_53_1.6682857498427974
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0014975447
# Sortino Ratio: 2.5864863912
# Max Drawdown: 0.2695822369
# Max Drawdown Duration: 210400
# Total Returns: 0.6418522832
# Annualized Returns: 1.5106464268
# Compound Annual Growth Rate: 2.2122146201
# ---------------------------------
# Trades: 31
# Trade Winning: 45.16%
# Average Trade: 2.05%
# Average Win: 7.69%
# Average Loss: -2.59%
# Best Trade: 24.37%
# Worst Trade: -8.34%
# Worst Trade Date: 1 days 13:00:00
# Avg Days in Trade: 1 days 17:36:46
# ---------------------------------
#    28 | 00m05s |    0.64185 | 1.668286 | 69.000000 | 53.000000 |
# ---------------------------------
# ADX_BOLLStrategy_216_81_1.3991425261192127
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0469626685
# Sortino Ratio: 2.2789293482
# Max Drawdown: 0.2385396343
# Max Drawdown Duration: 179400
# Total Returns: 0.5890082963
# Annualized Returns: 1.3862742276
# Compound Annual Growth Rate: 1.9741658366
# ---------------------------------
# Trades: 22
# Trade Winning: 54.55%
# Average Trade: 2.76%
# Average Win: 7.58%
# Average Loss: -3.03%
# Best Trade: 39.17%
# Worst Trade: -7.55%
# Worst Trade Date: 1 days 20:00:00
# Avg Days in Trade: 1 days 20:51:49
# ---------------------------------
#    29 | 00m05s |    0.58901 | 1.399143 | 216.000000 | 81.000000 |
# ---------------------------------
# ADX_BOLLStrategy_216_110_2.687194028805455
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6809565945
# Sortino Ratio: 1.5385836757
# Max Drawdown: 0.1824245725
# Max Drawdown Duration: 179400
# Total Returns: 0.3824309638
# Annualized Returns: 0.9000793237
# Compound Annual Growth Rate: 1.1429630440
# ---------------------------------
# Trades: 8
# Trade Winning: 62.50%
# Average Trade: 4.67%
# Average Win: 8.25%
# Average Loss: -1.30%
# Best Trade: 19.54%
# Worst Trade: -2.08%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 3 days 02:45:00
# ---------------------------------
#    30 | 00m07s |    0.38243 | 2.687194 | 216.000000 | 110.000000 |
# ---------------------------------
# ADX_BOLLStrategy_234_116_1.1949945893381744
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3019211076
# Sortino Ratio: 3.2024497419
# Max Drawdown: 0.2097879996
# Max Drawdown Duration: 172500
# Total Returns: 0.6858289858
# Annualized Returns: 1.6141488221
# Compound Annual Growth Rate: 2.4183950262
# ---------------------------------
# Trades: 29
# Trade Winning: 34.48%
# Average Trade: 2.41%
# Average Win: 10.22%
# Average Loss: -1.71%
# Best Trade: 43.91%
# Worst Trade: -5.94%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 1 days 12:24:50
# ---------------------------------
#    31 | 00m08s |    0.68583 | 1.194995 | 234.000000 | 116.000000 |
# ---------------------------------
# ADX_BOLLStrategy_223_42_1.6614316134119567
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3716368738
# Sortino Ratio: 2.8802584136
# Max Drawdown: 0.2121330355
# Max Drawdown Duration: 172700
# Total Returns: 0.6965771950
# Annualized Returns: 1.6394455208
# Compound Annual Growth Rate: 2.4699112356
# ---------------------------------
# Trades: 21
# Trade Winning: 52.38%
# Average Trade: 3.22%
# Average Win: 8.42%
# Average Loss: -2.51%
# Best Trade: 38.71%
# Worst Trade: -9.43%
# Worst Trade Date: 0 days 13:00:00
# Avg Days in Trade: 1 days 22:11:26
# ---------------------------------
#    32 | 00m05s |    0.69658 | 1.661432 | 223.000000 | 42.000000 |
# ---------------------------------
# ADX_BOLLStrategy_97_211_1.9916667579842722
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.6214170060
# Sortino Ratio: 2.5456744184
# Max Drawdown: 0.2431974488
# Max Drawdown Duration: 273500
# Total Returns: 0.7572190941
# Annualized Returns: 1.7821706781
# Compound Annual Growth Rate: 2.7689098132
# ---------------------------------
# Trades: 11
# Trade Winning: 72.73%
# Average Trade: 5.72%
# Average Win: 8.13%
# Average Loss: -0.71%
# Best Trade: 23.03%
# Worst Trade: -1.16%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 3 days 08:16:22
# ---------------------------------
#    33 | 00m11s |    0.75722 | 1.991667 | 97.000000 | 211.000000 |
# ---------------------------------
# ADX_BOLLStrategy_87_16_1.1476569586137009
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7874414613
# Sortino Ratio: 2.6722316324
# Max Drawdown: 0.2858026185
# Max Drawdown Duration: 273500
# Total Returns: 0.5156889224
# Annualized Returns: 1.2137117035
# Compound Annual Growth Rate: 1.6612094837
# ---------------------------------
# Trades: 55
# Trade Winning: 47.27%
# Average Trade: 1.10%
# Average Win: 4.81%
# Average Loss: -2.22%
# Best Trade: 22.50%
# Worst Trade: -6.27%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 18:26:11
# ---------------------------------
#    34 | 00m03s |    0.51569 | 1.147657 | 87.000000 | 16.000000 |
# ---------------------------------
# ADX_BOLLStrategy_142_65_1.7559248274367683
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1418570582
# Sortino Ratio: 1.5729515957
# Max Drawdown: 0.3146971716
# Max Drawdown Duration: 273500
# Total Returns: 0.2517606948
# Annualized Returns: 0.5925372613
# Compound Annual Growth Rate: 0.6963816169
# ---------------------------------
# Trades: 22
# Trade Winning: 54.55%
# Average Trade: 1.50%
# Average Win: 6.30%
# Average Loss: -4.26%
# Best Trade: 18.32%
# Worst Trade: -9.88%
# Worst Trade Date: 0 days 22:00:00
# Avg Days in Trade: 2 days 02:16:22
# ---------------------------------
#    35 | 00m05s |    0.25176 | 1.755925 | 142.000000 | 65.000000 |
# ---------------------------------
# ADX_BOLLStrategy_234_197_1.9497258037730616
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8889920089
# Sortino Ratio: 2.2645804595
# Max Drawdown: 0.2635202910
# Max Drawdown Duration: 172500
# Total Returns: 0.4902427797
# Annualized Returns: 1.1538223401
# Compound Annual Growth Rate: 1.5572496005
# ---------------------------------
# Trades: 12
# Trade Winning: 50.00%
# Average Trade: 4.31%
# Average Win: 12.57%
# Average Loss: -3.96%
# Best Trade: 39.28%
# Worst Trade: -12.47%
# Worst Trade Date: 4 days 14:00:00
# Avg Days in Trade: 3 days 04:10:00
# ---------------------------------
#    36 | 00m12s |    0.49024 | 1.949726 | 234.000000 | 197.000000 |
# ---------------------------------
# ADX_BOLLStrategy_138_26_0.4663131666301761
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7111047788
# Sortino Ratio: 2.4264087024
# Max Drawdown: 0.3279858490
# Max Drawdown Duration: 273500
# Total Returns: 0.5036170229
# Annualized Returns: 1.1852996026
# Compound Annual Growth Rate: 1.6115928594
# ---------------------------------
# Trades: 53
# Trade Winning: 39.62%
# Average Trade: 1.11%
# Average Win: 5.62%
# Average Loss: -1.84%
# Best Trade: 27.31%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 18:56:36
# ---------------------------------
#    37 | 00m04s |    0.50362 | 0.466313 | 138.000000 | 26.000000 |
# ---------------------------------
# ADX_BOLLStrategy_8_112_2.101593304489921
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2334846964
# Sortino Ratio: 1.1735847660
# Max Drawdown: 0.1677093677
# Max Drawdown Duration: 273500
# Total Returns: 0.1465393856
# Annualized Returns: 0.3448911924
# Compound Annual Growth Rate: 0.3796734787
# ---------------------------------
# Trades: 32
# Trade Winning: 50.00%
# Average Trade: 0.67%
# Average Win: 2.89%
# Average Loss: -1.54%
# Best Trade: 8.88%
# Worst Trade: -5.33%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 12:00:00
# ---------------------------------
#    38 | 00m08s |    0.14654 | 2.101593 | 8.000000 | 112.000000 |
# ---------------------------------
# ADX_BOLLStrategy_64_227_1.978473259342708
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8753910034
# Sortino Ratio: 2.1507338114
# Max Drawdown: 0.2253395927
# Max Drawdown Duration: 273500
# Total Returns: 0.4375555646
# Annualized Returns: 1.0298191149
# Compound Annual Growth Rate: 1.3495308503
# ---------------------------------
# Trades: 12
# Trade Winning: 41.67%
# Average Trade: 3.62%
# Average Win: 11.39%
# Average Loss: -1.94%
# Best Trade: 23.92%
# Worst Trade: -4.26%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 2 days 04:45:00
# ---------------------------------
#    39 | 00m12s |    0.43756 | 1.978473 | 64.000000 | 227.000000 |
# ---------------------------------
# ADX_BOLLStrategy_62_216_1.1264233575150757
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7036901752
# Sortino Ratio: 2.2954088888
# Max Drawdown: 0.3344920608
# Max Drawdown Duration: 273500
# Total Returns: 0.4618502625
# Annualized Returns: 1.0869984683
# Compound Annual Growth Rate: 1.4440554058
# ---------------------------------
# Trades: 34
# Trade Winning: 47.06%
# Average Trade: 1.54%
# Average Win: 5.78%
# Average Loss: -2.23%
# Best Trade: 26.51%
# Worst Trade: -9.97%
# Worst Trade Date: 1 days 21:00:00
# Avg Days in Trade: 1 days 08:44:07
# ---------------------------------
#    40 | 00m11s |    0.46185 | 1.126423 | 62.000000 | 216.000000 |
# Bayesian Optimization
# ------------------------------------------------------------------------
#  Step |   Time |      Value |         a |   window_ADX |   window_BOLL |
# ---------------------------------
# ADX_BOLLStrategy_240_170_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6766738635
# Sortino Ratio: 2.5979443727
# Max Drawdown: 0.2768854786
# Max Drawdown Duration: 273500
# Total Returns: 0.4732933333
# Annualized Returns: 1.1139305748
# Compound Annual Growth Rate: 1.4893217372
# ---------------------------------
# Trades: 34
# Trade Winning: 29.41%
# Average Trade: 1.66%
# Average Win: 10.82%
# Average Loss: -2.16%
# Best Trade: 34.70%
# Worst Trade: -6.29%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 10:08:49
# ---------------------------------
#    41 | 00m17s |    0.47329 | 0.100000 | 240.000000 | 170.000000 |
# ---------------------------------
# ADX_BOLLStrategy_64_1_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#    42 | 00m09s |    0.00000 | 0.100000 | 64.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_127_213_2.3377045487651995
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8322374041
# Sortino Ratio: 1.6389710662
# Max Drawdown: 0.2360282559
# Max Drawdown Duration: 273500
# Total Returns: 0.4190300439
# Annualized Returns: 0.9862179432
# Compound Annual Growth Rate: 1.2788899674
# ---------------------------------
# Trades: 6
# Trade Winning: 66.67%
# Average Trade: 6.45%
# Average Win: 10.64%
# Average Loss: -1.94%
# Best Trade: 17.67%
# Worst Trade: -3.25%
# Worst Trade Date: 1 days 10:00:00
# Avg Days in Trade: 4 days 05:50:00
# ---------------------------------
#    43 | 00m19s |    0.41903 | 2.337705 | 127.000000 | 213.000000 |
# ---------------------------------
# ADX_BOLLStrategy_186_88_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9755765444
# Sortino Ratio: 1.0610545887
# Max Drawdown: 0.4689760713
# Max Drawdown Duration: 273500
# Total Returns: 0.2011714716
# Annualized Returns: 0.4734718138
# Compound Annual Growth Rate: 0.5394168198
# ---------------------------------
# Trades: 43
# Trade Winning: 32.56%
# Average Trade: 0.81%
# Average Win: 7.14%
# Average Loss: -2.24%
# Best Trade: 24.62%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 03:11:10
# ---------------------------------
#    44 | 00m14s |    0.20117 | 0.100000 | 186.000000 | 88.000000 |
# ---------------------------------
# ADX_BOLLStrategy_48_172_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0623036236
# Sortino Ratio: 0.9821137731
# Max Drawdown: 0.2073381032
# Max Drawdown Duration: 293900
# Total Returns: 0.3122632458
# Annualized Returns: 0.7349344527
# Compound Annual Growth Rate: 0.8957060585
# ---------------------------------
# Trades: 4
# Trade Winning: 75.00%
# Average Trade: 7.52%
# Average Win: 11.06%
# Average Loss: -3.10%
# Best Trade: 18.36%
# Worst Trade: -3.10%
# Worst Trade Date: 0 days 20:00:00
# Avg Days in Trade: 3 days 11:45:00
# ---------------------------------
#    45 | 00m17s |    0.31226 | 3.000000 | 48.000000 | 172.000000 |
# ---------------------------------
# ADX_BOLLStrategy_231_52_1.0831337440623408
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.4065180401
# Sortino Ratio: 3.8172984693
# Max Drawdown: 0.1956421020
# Max Drawdown Duration: 170600
# Total Returns: 0.7543380344
# Annualized Returns: 1.7753898929
# Compound Annual Growth Rate: 2.7543824184
# ---------------------------------
# Trades: 28
# Trade Winning: 46.43%
# Average Trade: 2.64%
# Average Win: 8.06%
# Average Loss: -2.05%
# Best Trade: 41.72%
# Worst Trade: -5.27%
# Worst Trade Date: 0 days 23:00:00
# Avg Days in Trade: 1 days 12:19:17
# ---------------------------------
#    46 | 00m12s |    0.75434 | 1.083134 | 231.000000 | 52.000000 |
# ---------------------------------
# ADX_BOLLStrategy_1_1_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#    47 | 00m09s |    0.00000 | 3.000000 | 1.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_240_1_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#    48 | 00m09s |    0.00000 | 0.100000 | 240.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_41_58_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0207987387
# Sortino Ratio: 1.2048775835
# Max Drawdown: 0.2094607481
# Max Drawdown Duration: 273500
# Total Returns: 0.5126551988
# Annualized Returns: 1.2065716125
# Compound Annual Growth Rate: 1.6486900648
# ---------------------------------
# Trades: 9
# Trade Winning: 66.67%
# Average Trade: 5.49%
# Average Win: 11.86%
# Average Loss: -7.25%
# Best Trade: 20.15%
# Worst Trade: -12.08%
# Worst Trade Date: 0 days 11:00:00
# Avg Days in Trade: 2 days 10:20:00
# ---------------------------------
#    49 | 00m14s |    0.51266 | 3.000000 | 41.000000 | 58.000000 |
# ---------------------------------
# ADX_BOLLStrategy_167_108_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0826938978
# Sortino Ratio: 0.5750039626
# Max Drawdown: 0.2487590715
# Max Drawdown Duration: 273500
# Total Returns: 0.1934536685
# Annualized Returns: 0.4553073981
# Compound Annual Growth Rate: 0.5162385274
# ---------------------------------
# Trades: 7
# Trade Winning: 42.86%
# Average Trade: 2.98%
# Average Win: 8.68%
# Average Loss: -1.29%
# Best Trade: 17.92%
# Worst Trade: -2.00%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 2 days 06:51:26
# ---------------------------------
#    50 | 00m15s |    0.19345 | 3.000000 | 167.000000 | 108.000000 |
# ---------------------------------
# ADX_BOLLStrategy_2_68_0.13916459812046364
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -1.9259530311
# Sortino Ratio: -3.1769905161
# Max Drawdown: 0.5600910038
# Max Drawdown Duration: 252200
# Total Returns: -0.4790270200
# Annualized Returns: -1.1274252271
# Compound Annual Growth Rate: -0.7844719494
# ---------------------------------
# Trades: 315
# Trade Winning: 43.81%
# Average Trade: 0.02%
# Average Win: 1.80%
# Average Loss: -1.37%
# Best Trade: 11.53%
# Worst Trade: -8.02%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 03:52:34
# ---------------------------------
#    51 | 00m13s |   -0.47903 | 0.139165 | 2.000000 | 68.000000 |
# ---------------------------------
# ADX_BOLLStrategy_240_101_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ...
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#    83 | 00m11s |    0.00000 | 1.640963 | 146.000000 | 3.000000 |
# ---------------------------------
# ADX_BOLLStrategy_12_223_2.8775805047034098
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4946132131
# Sortino Ratio: 0.2843691100
# Max Drawdown: 0.1491366508
# Max Drawdown Duration: 273500
# Total Returns: 0.0409181480
# Annualized Returns: 0.0963038627
# Compound Annual Growth Rate: 0.0989835692
# ---------------------------------
# Trades: 7
# Trade Winning: 57.14%
# Average Trade: 0.85%
# Average Win: 3.83%
# Average Loss: -3.12%
# Best Trade: 7.61%
# Worst Trade: -4.71%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 0 days 13:34:17
# ---------------------------------
#    84 | 00m21s |    0.04092 | 2.877581 | 12.000000 | 223.000000 |
# ---------------------------------
# ADX_BOLLStrategy_42_198_0.20420281473980134
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8725665538
# Sortino Ratio: 1.2288579070
# Max Drawdown: 0.3661191283
# Max Drawdown Duration: 273500
# Total Returns: 0.1728768568
# Annualized Returns: 0.4068783627
# Compound Annual Growth Rate: 0.4554277215
# ---------------------------------
# Trades: 57
# Trade Winning: 40.35%
# Average Trade: 0.65%
# Average Win: 5.02%
# Average Loss: -2.31%
# Best Trade: 25.56%
# Worst Trade: -12.78%
# Worst Trade Date: 1 days 12:00:00
# Avg Days in Trade: 0 days 22:55:47
# ---------------------------------
#    85 | 00m19s |    0.17288 | 0.204203 | 42.000000 | 198.000000 |
# ---------------------------------
# ADX_BOLLStrategy_67_90_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0543168184
# Sortino Ratio: 2.4606853548
# Max Drawdown: 0.2094607481
# Max Drawdown Duration: 273500
# Total Returns: 0.4713277073
# Annualized Returns: 1.1093043300
# Compound Annual Growth Rate: 1.4815121487
# ---------------------------------
# Trades: 5
# Trade Winning: 80.00%
# Average Trade: 8.87%
# Average Win: 13.66%
# Average Loss: -10.29%
# Best Trade: 24.73%
# Worst Trade: -10.29%
# Worst Trade Date: 1 days 19:00:00
# Avg Days in Trade: 4 days 05:48:00
# ---------------------------------
#    86 | 00m15s |    0.47133 | 3.000000 | 67.000000 | 90.000000 |
# ---------------------------------
# ADX_BOLLStrategy_214_175_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1812742294
# Sortino Ratio: 0.1715882013
# Max Drawdown: 0.5862060657
# Max Drawdown Duration: 273500
# Total Returns: -0.0613699705
# Annualized Returns: -0.1444387270
# Compound Annual Growth Rate: -0.1384833851
# ---------------------------------
# Trades: 44
# Trade Winning: 43.18%
# Average Trade: 0.32%
# Average Win: 5.26%
# Average Loss: -3.43%
# Best Trade: 25.56%
# Worst Trade: -15.67%
# Worst Trade Date: 1 days 11:00:00
# Avg Days in Trade: 1 days 03:43:38
# ---------------------------------
#    87 | 00m19s |   -0.06137 | 0.100000 | 214.000000 | 175.000000 |
# ---------------------------------
# ADX_BOLLStrategy_175_208_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2789923272
# Sortino Ratio: 0.9075707927
# Max Drawdown: 0.2360421485
# Max Drawdown Duration: 273500
# Total Returns: 0.2391539389
# Annualized Returns: 0.5628663366
# Compound Annual Growth Rate: 0.6564454335
# ---------------------------------
# Trades: 4
# Trade Winning: 100.00%
# Average Trade: 5.94%
# Average Win: 5.94%
# Average Loss: nan%
# Best Trade: 17.97%
# Worst Trade: 0.72%
# Worst Trade Date: 5 days 19:00:00
# Avg Days in Trade: 5 days 07:15:00
# ---------------------------------
#    88 | 00m19s |    0.23915 | 3.000000 | 175.000000 | 208.000000 |
# ---------------------------------
# ADX_BOLLStrategy_96_48_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7633408705
# Sortino Ratio: 2.3417858694
# Max Drawdown: 0.3543736187
# Max Drawdown Duration: 273500
# Total Returns: 0.5109724067
# Annualized Returns: 1.2026110379
# Compound Annual Growth Rate: 1.6417602387
# ---------------------------------
# Trades: 67
# Trade Winning: 38.81%
# Average Trade: 0.93%
# Average Win: 4.68%
# Average Loss: -1.44%
# Best Trade: 24.08%
# Worst Trade: -7.10%
# Worst Trade Date: 0 days 12:00:00
# Avg Days in Trade: 0 days 18:56:25
# ---------------------------------
#    89 | 00m13s |    0.51097 | 0.100000 | 96.000000 | 48.000000 |
# ---------------------------------
# ADX_BOLLStrategy_204_92_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3473815815
# Sortino Ratio: 1.1475494192
# Max Drawdown: 0.2497446138
# Max Drawdown Duration: 273500
# Total Returns: 0.2510533539
# Annualized Returns: 0.5908724826
# Compound Annual Growth Rate: 0.6941263774
# ---------------------------------
# Trades: 5
# Trade Winning: 60.00%
# Average Trade: 5.11%
# Average Win: 9.77%
# Average Loss: -1.87%
# Best Trade: 21.03%
# Worst Trade: -3.52%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 3 days 15:12:00
# ---------------------------------
#    90 | 00m14s |    0.25105 | 3.000000 | 204.000000 | 92.000000 |
# ---------------------------------
# ADX_BOLLStrategy_225_94_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0791565909
# Sortino Ratio: 2.7958425833
# Max Drawdown: 0.3295115023
# Max Drawdown Duration: 273500
# Total Returns: 0.6332360340
# Annualized Returns: 1.4903674524
# Compound Annual Growth Rate: 2.1726804898
# ---------------------------------
# Trades: 45
# Trade Winning: 31.11%
# Average Trade: 1.57%
# Average Win: 8.47%
# Average Loss: -1.55%
# Best Trade: 38.21%
# Worst Trade: -5.68%
# Worst Trade Date: 0 days 11:00:00
# Avg Days in Trade: 1 days 00:10:40
# ---------------------------------
#    91 | 00m15s |    0.63324 | 0.100000 | 225.000000 | 94.000000 |
# ---------------------------------
# ADX_BOLLStrategy_82_67_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2811427300
# Sortino Ratio: 0.1874890104
# Max Drawdown: 0.3032138917
# Max Drawdown Duration: 273500
# Total Returns: 0.0065981564
# Annualized Returns: 0.0155292450
# Compound Annual Growth Rate: 0.0155986454
# ---------------------------------
# Trades: 7
# Trade Winning: 28.57%
# Average Trade: 0.98%
# Average Win: 17.57%
# Average Loss: -5.65%
# Best Trade: 26.44%
# Worst Trade: -13.99%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 2 days 09:17:09
# ---------------------------------
#    92 | 00m13s |    0.00660 | 3.000000 | 82.000000 | 67.000000 |
# ---------------------------------
# ADX_BOLLStrategy_112_64_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6169473323
# Sortino Ratio: 0.9149028448
# Max Drawdown: 0.4521582041
# Max Drawdown Duration: 273500
# Total Returns: 0.0858882271
# Annualized Returns: 0.2021442421
# Compound Annual Growth Rate: 0.2140118212
# ---------------------------------
# Trades: 67
# Trade Winning: 34.33%
# Average Trade: 0.47%
# Average Win: 5.11%
# Average Loss: -1.95%
# Best Trade: 31.22%
# Worst Trade: -8.79%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 19:44:47
# ---------------------------------
#    93 | 00m14s |    0.08589 | 0.100000 | 112.000000 | 64.000000 |
# ---------------------------------
# ADX_BOLLStrategy_174_166_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3124195613
# Sortino Ratio: 0.7692321959
# Max Drawdown: 0.2526483961
# Max Drawdown Duration: 293900
# Total Returns: 0.2119698183
# Annualized Returns: 0.4988865149
# Compound Annual Growth Rate: 0.5721865854
# ---------------------------------
# Trades: 4
# Trade Winning: 75.00%
# Average Trade: 5.57%
# Average Win: 10.30%
# Average Loss: -8.64%
# Best Trade: 17.97%
# Worst Trade: -8.64%
# Worst Trade Date: 2 days 01:00:00
# Avg Days in Trade: 5 days 11:00:00
# ---------------------------------
#    94 | 00m18s |    0.21197 | 3.000000 | 174.000000 | 166.000000 |
# ---------------------------------
# ADX_BOLLStrategy_8_73_0.8129170829906152
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0873396816
# Sortino Ratio: 0.1385753413
# Max Drawdown: 0.3136550529
# Max Drawdown Duration: 273500
# Total Returns: -0.0487056735
# Annualized Returns: -0.1146323750
# Compound Annual Growth Rate: -0.1108755722
# ---------------------------------
# Trades: 124
# Trade Winning: 45.97%
# Average Trade: 0.21%
# Average Win: 2.70%
# Average Loss: -1.91%
# Best Trade: 10.84%
# Worst Trade: -4.54%
# Worst Trade Date: 0 days 08:00:00
# Avg Days in Trade: 0 days 09:13:04
# ---------------------------------
#    95 | 00m15s |   -0.04871 | 0.812917 | 8.000000 | 73.000000 |
# ---------------------------------
# ADX_BOLLStrategy_123_99_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0662157764
# Sortino Ratio: 1.4223005390
# Max Drawdown: 0.4104140161
# Max Drawdown Duration: 273500
# Total Returns: 0.2556129292
# Annualized Returns: 0.6016037774
# Compound Annual Growth Rate: 0.7086941272
# ---------------------------------
# Trades: 56
# Trade Winning: 32.14%
# Average Trade: 0.80%
# Average Win: 6.90%
# Average Loss: -2.09%
# Best Trade: 25.94%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 01:37:30
# ---------------------------------
#    96 | 00m15s |    0.25561 | 0.100000 | 123.000000 | 99.000000 |
# ---------------------------------
# ADX_BOLLStrategy_54_51_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8777541319
# Sortino Ratio: 1.0014207314
# Max Drawdown: 0.3146011489
# Max Drawdown Duration: 293900
# Total Returns: 0.3292831165
# Annualized Returns: 0.7749919668
# Compound Annual Growth Rate: 0.9540821913
# ---------------------------------
# Trades: 10
# Trade Winning: 70.00%
# Average Trade: 3.46%
# Average Win: 7.69%
# Average Loss: -6.39%
# Best Trade: 19.60%
# Worst Trade: -9.40%
# Worst Trade Date: 1 days 12:00:00
# Avg Days in Trade: 2 days 10:12:00
# ---------------------------------
#    97 | 00m13s |    0.32928 | 3.000000 | 54.000000 | 51.000000 |
# ---------------------------------
# ADX_BOLLStrategy_200_1_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#    98 | 00m09s |    0.00000 | 0.100000 | 200.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_85_107_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6574544693
# Sortino Ratio: 2.1982293305
# Max Drawdown: 0.4596117139
# Max Drawdown Duration: 273500
# Total Returns: 0.5237922636
# Annualized Returns: 1.2327835112
# Compound Annual Growth Rate: 1.6948165349
# ---------------------------------
# Trades: 57
# Trade Winning: 36.84%
# Average Trade: 1.12%
# Average Win: 6.19%
# Average Loss: -1.84%
# Best Trade: 26.50%
# Worst Trade: -7.70%
# Worst Trade Date: 1 days 14:00:00
# Avg Days in Trade: 1 days 02:25:16
# ---------------------------------
#    99 | 00m16s |    0.52379 | 0.100000 | 85.000000 | 107.000000 |
# ---------------------------------
# ADX_BOLLStrategy_193_116_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0647774442
# Sortino Ratio: 1.0732251927
# Max Drawdown: 0.4561441741
# Max Drawdown Duration: 273500
# Total Returns: 0.2321051000
# Annualized Returns: 0.5462763772
# Compound Annual Growth Rate: 0.6343540393
# ---------------------------------
# Trades: 32
# Trade Winning: 31.25%
# Average Trade: 1.13%
# Average Win: 9.77%
# Average Loss: -2.80%
# Best Trade: 23.90%
# Worst Trade: -10.14%
# Worst Trade Date: 2 days 04:00:00
# Avg Days in Trade: 1 days 13:05:38
# ---------------------------------
#   100 | 00m16s |    0.23211 | 0.100000 | 193.000000 | 116.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 0.9485894752027062, 'max_params': {'window_ADX': 26.0, 'window_BOLL': 72.0, 'a': 0.8568390408851148}}

# %%
BO.maximize(init_points=0, n_iter=60, acq="ei", xi=0.0001, **gp_params)
# Out:
# Bayesian Optimization
# ------------------------------------------------------------------------
#  Step |   Time |      Value |         a |   window_ADX |   window_BOLL |
# ---------------------------------
# ADX_BOLLStrategy_215_95_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1305456293
# Sortino Ratio: 1.2329685772
# Max Drawdown: 0.4552628906
# Max Drawdown Duration: 273500
# Total Returns: 0.2641109557
# Annualized Returns: 0.6216045061
# Compound Annual Growth Rate: 0.7360367830
# ---------------------------------
# Trades: 45
# Trade Winning: 31.11%
# Average Trade: 1.07%
# Average Win: 8.28%
# Average Loss: -2.19%
# Best Trade: 46.58%
# Worst Trade: -11.97%
# Worst Trade Date: 1 days 02:00:00
# Avg Days in Trade: 1 days 01:06:40
# ---------------------------------
#   101 | 00m17s |    0.26411 | 0.100000 | 215.000000 | 95.000000 |
# ---------------------------------
# ADX_BOLLStrategy_62_72_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2934618381
# Sortino Ratio: 1.7308754189
# Max Drawdown: 0.4682829317
# Max Drawdown Duration: 273500
# Total Returns: 0.3605911872
# Annualized Returns: 0.8486778077
# Compound Annual Growth Rate: 1.0641337811
# ---------------------------------
# Trades: 63
# Trade Winning: 36.51%
# Average Trade: 0.87%
# Average Win: 5.92%
# Average Loss: -2.03%
# Best Trade: 26.51%
# Worst Trade: -11.07%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 1 days 00:14:17
# ---------------------------------
#   102 | 00m15s |    0.36059 | 0.100000 | 62.000000 | 72.000000 |
# ---------------------------------
# ADX_BOLLStrategy_1_240_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -3.7849982167
# Sortino Ratio: -4.6742963136
# Max Drawdown: 0.7204874366
# Max Drawdown Duration: 252200
# Total Returns: -0.6711602693
# Annualized Returns: -1.5796249219
# Compound Annual Growth Rate: -0.9270228189
# ---------------------------------
# Trades: 354
# Trade Winning: 40.11%
# Average Trade: -0.09%
# Average Win: 1.61%
# Average Loss: -1.23%
# Best Trade: 9.15%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 03:05:25
# ---------------------------------
#   103 | 00m21s |   -0.67116 | 0.100000 | 1.000000 | 240.000000 |
# ---------------------------------
# ADX_BOLLStrategy_84_1_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#   104 | 00m10s |    0.00000 | 3.000000 | 84.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_109_218_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8575980847
# Sortino Ratio: 1.0599777490
# Max Drawdown: 0.4937165115
# Max Drawdown Duration: 273500
# Total Returns: 0.1707407798
# Annualized Returns: 0.4018509488
# Compound Annual Growth Rate: 0.4491968707
# ---------------------------------
# Trades: 50
# Trade Winning: 38.00%
# Average Trade: 0.72%
# Average Win: 6.17%
# Average Loss: -2.61%
# Best Trade: 25.90%
# Worst Trade: -9.57%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 1 days 04:58:48
# ---------------------------------
#   105 | 00m21s |    0.17074 | 0.100000 | 109.000000 | 218.000000 |
# ---------------------------------
# ADX_BOLLStrategy_81_64_2.7535145584960072
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.0759194613
# Sortino Ratio: 0.0615247499
# Max Drawdown: 0.4657208313
# Max Drawdown Duration: 273500
# Total Returns: -0.0562740592
# Annualized Returns: -0.1324451259
# Compound Annual Growth Rate: -0.1274346477
# ---------------------------------
# Trades: 12
# Trade Winning: 25.00%
# Average Trade: 0.43%
# Average Win: 19.59%
# Average Loss: -5.96%
# Best Trade: 26.68%
# Worst Trade: -16.62%
# Worst Trade Date: 1 days 20:00:00
# Avg Days in Trade: 2 days 01:30:00
# ---------------------------------
#   106 | 00m15s |   -0.05627 | 2.753515 | 81.000000 | 64.000000 |
# ---------------------------------
# ADX_BOLLStrategy_186_188_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7628072200
# Sortino Ratio: 0.8864833816
# Max Drawdown: 0.4685605036
# Max Drawdown Duration: 273500
# Total Returns: 0.1322423759
# Annualized Returns: 0.3112421314
# Compound Annual Growth Rate: 0.3395235275
# ---------------------------------
# Trades: 39
# Trade Winning: 30.77%
# Average Trade: 0.73%
# Average Win: 7.83%
# Average Loss: -2.43%
# Best Trade: 22.11%
# Worst Trade: -9.22%
# Worst Trade Date: 2 days 23:00:00
# Avg Days in Trade: 1 days 09:04:37
# ---------------------------------
#   107 | 00m19s |    0.13224 | 0.100000 | 186.000000 | 188.000000 |
# ---------------------------------
# ADX_BOLLStrategy_240_186_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6924571958
# Sortino Ratio: 2.5557787932
# Max Drawdown: 0.2768854786
# Max Drawdown Duration: 273500
# Total Returns: 0.4848999676
# Annualized Returns: 1.1412476400
# Compound Annual Growth Rate: 1.5357238096
# ---------------------------------
# Trades: 34
# Trade Winning: 29.41%
# Average Trade: 1.67%
# Average Win: 10.65%
# Average Loss: -2.07%
# Best Trade: 34.70%
# Worst Trade: -6.29%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 1 days 11:14:07
# ---------------------------------
#   108 | 00m19s |    0.48490 | 0.100000 | 240.000000 | 186.000000 |
# ---------------------------------
# ADX_BOLLStrategy_220_20_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2963891765
# Sortino Ratio: -0.4061682577
# Max Drawdown: 0.4784685018
# Max Drawdown Duration: 273500
# Total Returns: -0.1566806910
# Annualized Returns: -0.3687594985
# Compound Annual Growth Rate: -0.3303978372
# ---------------------------------
# Trades: 88
# Trade Winning: 27.27%
# Average Trade: 0.10%
# Average Win: 4.52%
# Average Loss: -1.55%
# Best Trade: 34.21%
# Worst Trade: -7.19%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 09:51:49
# ---------------------------------
#   109 | 00m14s |   -0.15668 | 0.100000 | 220.000000 | 20.000000 |
# ---------------------------------
# ADX_BOLLStrategy_176_1_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#   110 | 00m11s |    0.00000 | 0.100000 | 176.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_222_134_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7187049872
# Sortino Ratio: 1.1548762699
# Max Drawdown: 0.1768833023
# Max Drawdown Duration: 273500
# Total Returns: 0.3315821436
# Annualized Returns: 0.7804028958
# Compound Annual Growth Rate: 0.9620457158
# ---------------------------------
# Trades: 6
# Trade Winning: 83.33%
# Average Trade: 5.34%
# Average Win: 6.59%
# Average Loss: -0.91%
# Best Trade: 19.84%
# Worst Trade: -0.91%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 2 days 15:40:00
# ---------------------------------
#   111 | 00m18s |    0.33158 | 3.000000 | 222.000000 | 134.000000 |
# ---------------------------------
# ADX_BOLLStrategy_86_58_1.339346095776921
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6339590303
# Sortino Ratio: 1.9609527870
# Max Drawdown: 0.4313512077
# Max Drawdown Duration: 273500
# Total Returns: 0.4872047913
# Annualized Returns: 1.1466722116
# Compound Annual Growth Rate: 1.5449969378
# ---------------------------------
# Trades: 32
# Trade Winning: 43.75%
# Average Trade: 1.75%
# Average Win: 7.85%
# Average Loss: -2.99%
# Best Trade: 25.05%
# Worst Trade: -9.86%
# Worst Trade Date: 1 days 08:00:00
# Avg Days in Trade: 1 days 17:43:08
# ---------------------------------
#   112 | 00m15s |    0.48720 | 1.339346 | 86.000000 | 58.000000 |
# ---------------------------------
# ADX_BOLLStrategy_27_180_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.4649466193
# Sortino Ratio: -0.1279322019
# Max Drawdown: 0.2114067171
# Max Drawdown Duration: 299200
# Total Returns: -0.0952232468
# Annualized Returns: -0.2241148957
# Compound Annual Growth Rate: -0.2098362965
# ---------------------------------
# Trades: 5
# Trade Winning: 60.00%
# Average Trade: -1.38%
# Average Win: 4.32%
# Average Loss: -9.93%
# Best Trade: 8.10%
# Worst Trade: -17.28%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 1 days 01:00:00
# ---------------------------------
#   113 | 00m19s |   -0.09522 | 3.000000 | 27.000000 | 180.000000 |
# ---------------------------------
# ADX_BOLLStrategy_17_131_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5149222172
# Sortino Ratio: 0.9832098968
# Max Drawdown: 0.1270873579
# Max Drawdown Duration: 273500
# Total Returns: 0.2443045802
# Annualized Returns: 0.5749887487
# Compound Annual Growth Rate: 0.6726957385
# ---------------------------------
# Trades: 4
# Trade Winning: 100.00%
# Average Trade: 5.95%
# Average Win: 5.95%
# Average Loss: nan%
# Best Trade: 12.58%
# Worst Trade: 0.01%
# Worst Trade Date: 0 days 20:00:00
# Avg Days in Trade: 1 days 06:30:00
# ---------------------------------
#   114 | 00m18s |    0.24430 | 3.000000 | 17.000000 | 131.000000 |
# ---------------------------------
# ADX_BOLLStrategy_156_133_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.9512599824
# Sortino Ratio: 2.7164409247
# Max Drawdown: 0.2981720317
# Max Drawdown Duration: 250900
# Total Returns: 0.6057677885
# Annualized Returns: 1.4257189220
# Compound Annual Growth Rate: 2.0485226011
# ---------------------------------
# Trades: 40
# Trade Winning: 37.50%
# Average Trade: 1.57%
# Average Win: 7.44%
# Average Loss: -1.95%
# Best Trade: 22.40%
# Worst Trade: -7.08%
# Worst Trade Date: 1 days 22:00:00
# Avg Days in Trade: 1 days 08:52:30
# ---------------------------------
#   115 | 00m18s |    0.60577 | 0.100000 | 156.000000 | 133.000000 |
# ---------------------------------
# ADX_BOLLStrategy_200_5_0.8523102770647875
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.9078667293
# Sortino Ratio: -1.0837581468
# Max Drawdown: 0.4431374550
# Max Drawdown Duration: 273500
# Total Returns: -0.2090538992
# Annualized Returns: -0.4920236855
# Compound Annual Growth Rate: -0.4241873078
# ---------------------------------
# Trades: 130
# Trade Winning: 38.46%
# Average Trade: 0.05%
# Average Win: 2.17%
# Average Loss: -1.28%
# Best Trade: 10.61%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 06:05:05
# ---------------------------------
#   116 | 00m14s |   -0.20905 | 0.852310 | 200.000000 | 5.000000 |
# ---------------------------------
# ADX_BOLLStrategy_85_193_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8984819163
# Sortino Ratio: 1.1116257745
# Max Drawdown: 0.2022443322
# Max Drawdown Duration: 273500
# Total Returns: 0.3676845115
# Annualized Returns: 0.8653724666
# Compound Annual Growth Rate: 1.0895504324
# ---------------------------------
# Trades: 4
# Trade Winning: 100.00%
# Average Trade: 8.69%
# Average Win: 8.69%
# Average Loss: nan%
# Best Trade: 23.12%
# Worst Trade: 0.12%
# Worst Trade Date: 2 days 15:00:00
# Avg Days in Trade: 4 days 09:00:00
# ---------------------------------
#   117 | 00m19s |    0.36768 | 3.000000 | 85.000000 | 193.000000 |
# ---------------------------------
# ADX_BOLLStrategy_226_122_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4112963278
# Sortino Ratio: 1.8054494052
# Max Drawdown: 0.4173363206
# Max Drawdown Duration: 273500
# Total Returns: 0.3776239184
# Annualized Returns: 0.8887655897
# Compound Annual Growth Rate: 1.1254664158
# ---------------------------------
# Trades: 47
# Trade Winning: 42.55%
# Average Trade: 1.10%
# Average Win: 5.25%
# Average Loss: -1.97%
# Best Trade: 31.63%
# Worst Trade: -9.13%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 00:01:17
# ---------------------------------
#   118 | 00m18s |    0.37762 | 0.100000 | 226.000000 | 122.000000 |
# ---------------------------------
# ADX_BOLLStrategy_135_132_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9701062097
# Sortino Ratio: 0.5294213593
# Max Drawdown: 0.2812395145
# Max Drawdown Duration: 273500
# Total Returns: 0.1633185407
# Annualized Returns: 0.3843821646
# Compound Annual Growth Rate: 0.4276659157
# ---------------------------------
# Trades: 4
# Trade Winning: 50.00%
# Average Trade: 4.47%
# Average Win: 12.73%
# Average Loss: -3.79%
# Best Trade: 18.71%
# Worst Trade: -5.60%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 3 days 22:30:00
# ---------------------------------
#   119 | 00m18s |    0.16332 | 3.000000 | 135.000000 | 132.000000 |
# ---------------------------------
# ADX_BOLLStrategy_220_18_0.5023246155019785
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6157238293
# Sortino Ratio: 0.8990629741
# Max Drawdown: 0.3823532726
# Max Drawdown Duration: 273500
# Total Returns: 0.0882639992
# Annualized Returns: 0.2077357960
# Compound Annual Growth Rate: 0.2202723795
# ---------------------------------
# Trades: 60
# Trade Winning: 35.00%
# Average Trade: 0.48%
# Average Win: 5.16%
# Average Loss: -2.04%
# Best Trade: 34.21%
# Worst Trade: -4.15%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 0 days 13:51:00
# ---------------------------------
#   120 | 00m15s |    0.08826 | 0.502325 | 220.000000 | 18.000000 |
# ---------------------------------
# ADX_BOLLStrategy_166_145_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7475362329
# Sortino Ratio: 1.2056594227
# Max Drawdown: 0.1932566438
# Max Drawdown Duration: 273500
# Total Returns: 0.3678167970
# Annualized Returns: 0.8656838101
# Compound Annual Growth Rate: 1.0900261346
# ---------------------------------
# Trades: 6
# Trade Winning: 83.33%
# Average Trade: 5.76%
# Average Win: 7.03%
# Average Loss: -0.54%
# Best Trade: 17.92%
# Worst Trade: -0.54%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 3 days 17:10:00
# ---------------------------------
#   121 | 00m20s |    0.36782 | 3.000000 | 166.000000 | 145.000000 |
# ---------------------------------
# ADX_BOLLStrategy_146_218_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.5177094542
# Sortino Ratio: 0.9809284927
# Max Drawdown: 0.1822214953
# Max Drawdown Duration: 273500
# Total Returns: 0.2458033403
# Annualized Returns: 0.5785161905
# Compound Annual Growth Rate: 0.6774414798
# ---------------------------------
# Trades: 5
# Trade Winning: 80.00%
# Average Trade: 4.93%
# Average Win: 6.32%
# Average Loss: -0.65%
# Best Trade: 18.76%
# Worst Trade: -0.65%
# Worst Trade Date: 0 days 04:00:00
# Avg Days in Trade: 2 days 21:48:00
# ---------------------------------
#   122 | 00m24s |    0.24580 | 3.000000 | 146.000000 | 218.000000 |
# ---------------------------------
# ADX_BOLLStrategy_16_84_2.767879974699874
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4732920865
# Sortino Ratio: 0.2226088575
# Max Drawdown: 0.2120239790
# Max Drawdown Duration: 273500
# Total Returns: 0.0505946556
# Annualized Returns: 0.1190782329
# Compound Annual Growth Rate: 0.1231798027
# ---------------------------------
# Trades: 8
# Trade Winning: 50.00%
# Average Trade: 1.41%
# Average Win: 9.26%
# Average Loss: -6.44%
# Best Trade: 23.29%
# Worst Trade: -17.28%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 0 days 23:52:30
# ---------------------------------
#   123 | 00m17s |    0.05059 | 2.767880 | 16.000000 | 84.000000 |
# ---------------------------------
# ADX_BOLLStrategy_41_39_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.0970074262
# Sortino Ratio: -0.0632011607
# Max Drawdown: 0.3215925153
# Max Drawdown Duration: 293900
# Total Returns: -0.0541325153
# Annualized Returns: -0.1274048453
# Compound Annual Growth Rate: -0.1227672648
# ---------------------------------
# Trades: 13
# Trade Winning: 38.46%
# Average Trade: 0.10%
# Average Win: 8.68%
# Average Loss: -5.27%
# Best Trade: 20.15%
# Worst Trade: -10.54%
# Worst Trade Date: 0 days 15:00:00
# Avg Days in Trade: 1 days 21:36:55
# ---------------------------------
#   124 | 00m15s |   -0.05413 | 3.000000 | 41.000000 | 39.000000 |
# ---------------------------------
# ADX_BOLLStrategy_181_229_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3036637508
# Sortino Ratio: 0.6404500037
# Max Drawdown: 0.2075371968
# Max Drawdown Duration: 293900
# Total Returns: 0.1969335138
# Annualized Returns: 0.4634974693
# Compound Annual Growth Rate: 0.5266642487
# ---------------------------------
# Trades: 4
# Trade Winning: 50.00%
# Average Trade: 5.12%
# Average Win: 11.49%
# Average Loss: -1.26%
# Best Trade: 18.84%
# Worst Trade: -1.97%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 4 days 01:30:00
# ---------------------------------
#   125 | 00m22s |    0.19693 | 3.000000 | 181.000000 | 229.000000 |
# ---------------------------------
# ADX_BOLLStrategy_164_220_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3643155191
# Sortino Ratio: 0.7633043085
# Max Drawdown: 0.1907415074
# Max Drawdown Duration: 273500
# Total Returns: 0.2322872971
# Annualized Returns: 0.5467051914
# Compound Annual Growth Rate: 0.6349229066
# ---------------------------------
# Trades: 3
# Trade Winning: 100.00%
# Average Trade: 7.67%
# Average Win: 7.67%
# Average Loss: nan%
# Best Trade: 17.92%
# Worst Trade: 0.95%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 5 days 01:00:00
# ---------------------------------
#   126 | 00m22s |    0.23229 | 3.000000 | 164.000000 | 220.000000 |
# ---------------------------------
# ADX_BOLLStrategy_228_222_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8710879745
# Sortino Ratio: 0.7898511472
# Max Drawdown: 0.4790074917
# Max Drawdown Duration: 273500
# Total Returns: 0.1735628513
# Annualized Returns: 0.4084929010
# Compound Annual Growth Rate: 0.4574320018
# ---------------------------------
# Trades: 38
# Trade Winning: 39.47%
# Average Trade: 0.90%
# Average Win: 6.71%
# Average Loss: -2.90%
# Best Trade: 31.63%
# Worst Trade: -10.28%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 08:47:22
# ---------------------------------
#   127 | 00m21s |    0.17356 | 0.100000 | 228.000000 | 222.000000 |
# ---------------------------------
# ADX_BOLLStrategy_35_240_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2189530535
# Sortino Ratio: 1.7521769539
# Max Drawdown: 0.3445243390
# Max Drawdown Duration: 273500
# Total Returns: 0.2972319665
# Annualized Returns: 0.6995572344
# Compound Annual Growth Rate: 0.8449954954
# ---------------------------------
# Trades: 66
# Trade Winning: 33.33%
# Average Trade: 0.74%
# Average Win: 5.81%
# Average Loss: -1.79%
# Best Trade: 29.36%
# Worst Trade: -6.97%
# Worst Trade Date: 0 days 10:00:00
# Avg Days in Trade: 0 days 18:00:00
# ---------------------------------
#   128 | 00m24s |    0.29723 | 0.100000 | 35.000000 | 240.000000 |
# ---------------------------------
# ADX_BOLLStrategy_97_63_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5085533435
# Sortino Ratio: 0.3939412729
# Max Drawdown: 0.3675559949
# Max Drawdown Duration: 273500
# Total Returns: 0.0583740141
# Annualized Returns: 0.1373875239
# Compound Annual Growth Rate: 0.1428522553
# ---------------------------------
# Trades: 9
# Trade Winning: 44.44%
# Average Trade: 1.47%
# Average Win: 11.91%
# Average Loss: -6.89%
# Best Trade: 23.03%
# Worst Trade: -13.99%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 2 days 14:06:40
# ---------------------------------
#   129 | 00m17s |    0.05837 | 3.000000 | 97.000000 | 63.000000 |
# ---------------------------------
# ADX_BOLLStrategy_221_1_2.454165609901493
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#   130 | 00m12s |    0.00000 | 2.454166 | 221.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_110_117_0.29702133561548905
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7829977279
# Sortino Ratio: 0.9892944822
# Max Drawdown: 0.5253125047
# Max Drawdown Duration: 273500
# Total Returns: 0.1430302695
# Annualized Returns: 0.3366322302
# Compound Annual Growth Rate: 0.3697557410
# ---------------------------------
# Trades: 50
# Trade Winning: 36.00%
# Average Trade: 0.69%
# Average Win: 6.71%
# Average Loss: -2.69%
# Best Trade: 25.90%
# Worst Trade: -9.55%
# Worst Trade Date: 0 days 09:00:00
# Avg Days in Trade: 1 days 05:55:12
# ---------------------------------
#   131 | 00m18s |    0.14303 | 0.297021 | 110.000000 | 117.000000 |
# ---------------------------------
# ADX_BOLLStrategy_82_45_0.16666915645142422
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.1231935518
# Sortino Ratio: 3.4957518371
# Max Drawdown: 0.3491015952
# Max Drawdown Duration: 273500
# Total Returns: 0.7353181444
# Annualized Returns: 1.7306251867
# Compound Annual Growth Rate: 2.6592854432
# ---------------------------------
# Trades: 64
# Trade Winning: 37.50%
# Average Trade: 1.22%
# Average Win: 5.91%
# Average Loss: -1.59%
# Best Trade: 29.12%
# Worst Trade: -6.38%
# Worst Trade Date: 1 days 00:00:00
# Avg Days in Trade: 0 days 19:58:08
# ---------------------------------
#   132 | 00m15s |    0.73532 | 0.166669 | 82.000000 | 45.000000 |
# ---------------------------------
# ADX_BOLLStrategy_50_62_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6419949794
# Sortino Ratio: 0.9375592652
# Max Drawdown: 0.4830058835
# Max Drawdown Duration: 273500
# Total Returns: 0.0892397208
# Annualized Returns: 0.2100322285
# Compound Annual Growth Rate: 0.2228489360
# ---------------------------------
# Trades: 78
# Trade Winning: 33.33%
# Average Trade: 0.45%
# Average Win: 5.35%
# Average Loss: -2.00%
# Best Trade: 26.79%
# Worst Trade: -7.97%
# Worst Trade Date: 0 days 08:00:00
# Avg Days in Trade: 0 days 19:33:51
# ---------------------------------
#   133 | 00m16s |    0.08924 | 0.100000 | 50.000000 | 62.000000 |
# ---------------------------------
# ADX_BOLLStrategy_82_150_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.2561866811
# Sortino Ratio: 1.2861515385
# Max Drawdown: 0.2182973575
# Max Drawdown Duration: 293900
# Total Returns: 0.4187249710
# Annualized Returns: 0.9854999316
# Compound Annual Growth Rate: 1.2777370452
# ---------------------------------
# Trades: 4
# Trade Winning: 75.00%
# Average Trade: 9.88%
# Average Win: 14.52%
# Average Loss: -4.03%
# Best Trade: 26.44%
# Worst Trade: -4.03%
# Worst Trade Date: 2 days 08:00:00
# Avg Days in Trade: 4 days 09:00:00
# ---------------------------------
#   134 | 00m20s |    0.41872 | 3.000000 | 82.000000 | 150.000000 |
# ---------------------------------
# ADX_BOLLStrategy_149_139_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.4931987244
# Sortino Ratio: 1.1015631923
# Max Drawdown: 0.2484412923
# Max Drawdown Duration: 273500
# Total Returns: 0.2837601452
# Annualized Returns: 0.6678503149
# Compound Annual Growth Rate: 0.8002167124
# ---------------------------------
# Trades: 8
# Trade Winning: 75.00%
# Average Trade: 3.59%
# Average Win: 5.74%
# Average Loss: -2.86%
# Best Trade: 17.92%
# Worst Trade: -5.60%
# Worst Trade Date: 1 days 06:00:00
# Avg Days in Trade: 2 days 21:37:30
# ---------------------------------
#   135 | 00m18s |    0.28376 | 3.000000 | 149.000000 | 139.000000 |
# ---------------------------------
# ADX_BOLLStrategy_138_26_1.3843488578437746
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8906631753
# Sortino Ratio: 2.6053096622
# Max Drawdown: 0.2572510329
# Max Drawdown Duration: 273500
# Total Returns: 0.5645373766
# Annualized Returns: 1.3286801233
# Compound Annual Growth Rate: 1.8674877697
# ---------------------------------
# Trades: 30
# Trade Winning: 50.00%
# Average Trade: 1.93%
# Average Win: 6.30%
# Average Loss: -2.44%
# Best Trade: 21.68%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 09:58:00
# ---------------------------------
#   136 | 00m15s |    0.56454 | 1.384349 | 138.000000 | 26.000000 |
# ---------------------------------
# ADX_BOLLStrategy_58_152_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3651732552
# Sortino Ratio: 1.4930175626
# Max Drawdown: 0.2182973575
# Max Drawdown Duration: 192900
# Total Returns: 0.4186640500
# Annualized Returns: 0.9853565498
# Compound Annual Growth Rate: 1.2775068549
# ---------------------------------
# Trades: 4
# Trade Winning: 100.00%
# Average Trade: 9.52%
# Average Win: 9.52%
# Average Loss: nan%
# Best Trade: 19.60%
# Worst Trade: 3.25%
# Worst Trade Date: 2 days 00:00:00
# Avg Days in Trade: 3 days 20:15:00
# ---------------------------------
#   137 | 00m23s |    0.41866 | 3.000000 | 58.000000 | 152.000000 |
# ---------------------------------
# ADX_BOLLStrategy_240_17_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.3004208282
# Sortino Ratio: 2.0882566189
# Max Drawdown: 0.2507649327
# Max Drawdown Duration: 273500
# Total Returns: 0.5786887000
# Annualized Returns: 1.3619863009
# Compound Annual Growth Rate: 1.9289054908
# ---------------------------------
# Trades: 4
# Trade Winning: 75.00%
# Average Trade: 13.50%
# Average Win: 21.33%
# Average Loss: -9.99%
# Best Trade: 34.70%
# Worst Trade: -9.99%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 5 days 12:15:00
# ---------------------------------
#   138 | 00m14s |    0.57869 | 3.000000 | 240.000000 | 17.000000 |
# ---------------------------------
# ADX_BOLLStrategy_194_162_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.4637895529
# Sortino Ratio: 0.2293844904
# Max Drawdown: 0.3366167350
# Max Drawdown Duration: 293900
# Total Returns: 0.0453862599
# Annualized Returns: 0.1068198917
# Compound Annual Growth Rate: 0.1101184831
# ---------------------------------
# Trades: 5
# Trade Winning: 60.00%
# Average Trade: 1.68%
# Average Win: 9.34%
# Average Loss: -9.80%
# Best Trade: 18.84%
# Worst Trade: -12.99%
# Worst Trade Date: 2 days 02:00:00
# Avg Days in Trade: 4 days 16:48:00
# ---------------------------------
#   139 | 00m21s |    0.04539 | 3.000000 | 194.000000 | 162.000000 |
# ---------------------------------
# ADX_BOLLStrategy_1_94_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -4.2716418150
# Sortino Ratio: -6.0898511092
# Max Drawdown: 0.7645663265
# Max Drawdown Duration: 356600
# Total Returns: -0.7311213830
# Annualized Returns: -1.7207478009
# Compound Annual Growth Rate: -0.9545620394
# ---------------------------------
# Trades: 387
# Trade Winning: 39.53%
# Average Trade: -0.12%
# Average Win: 1.59%
# Average Loss: -1.24%
# Best Trade: 10.19%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 03:08:32
# ---------------------------------
#   140 | 00m18s |   -0.73112 | 0.100000 | 1.000000 | 94.000000 |
# ---------------------------------
# ADX_BOLLStrategy_58_38_0.12344401630206449
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8157731435
# Sortino Ratio: 2.5779591564
# Max Drawdown: 0.2913855462
# Max Drawdown Duration: 273500
# Total Returns: 0.5800525669
# Annualized Returns: 1.3651962618
# Compound Annual Growth Rate: 1.9348643412
# ---------------------------------
# Trades: 80
# Trade Winning: 36.25%
# Average Trade: 0.88%
# Average Win: 5.20%
# Average Loss: -1.57%
# Best Trade: 19.54%
# Worst Trade: -6.42%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 0 days 16:40:30
# ---------------------------------
#   141 | 00m16s |    0.58005 | 0.123444 | 58.000000 | 38.000000 |
# ---------------------------------
# ADX_BOLLStrategy_219_196_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.1322342390
# Sortino Ratio: -0.1329287044
# Max Drawdown: 0.6043924222
# Max Drawdown Duration: 273500
# Total Returns: -0.1517598409
# Annualized Returns: -0.3571779168
# Compound Annual Growth Rate: -0.3211656298
# ---------------------------------
# Trades: 45
# Trade Winning: 28.89%
# Average Trade: 0.11%
# Average Win: 7.55%
# Average Loss: -2.91%
# Best Trade: 39.17%
# Worst Trade: -11.43%
# Worst Trade Date: 1 days 07:00:00
# Avg Days in Trade: 1 days 03:22:40
# ---------------------------------
#   142 | 00m22s |   -0.15176 | 0.100000 | 219.000000 | 196.000000 |
# ---------------------------------
# ADX_BOLLStrategy_92_226_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6286305982
# Sortino Ratio: 0.8319841297
# Max Drawdown: 0.1907415074
# Max Drawdown Duration: 273500
# Total Returns: 0.2866186843
# Annualized Returns: 0.6745780963
# Compound Annual Growth Rate: 0.8096653008
# ---------------------------------
# Trades: 3
# Trade Winning: 100.00%
# Average Trade: 9.40%
# Average Win: 9.40%
# Average Loss: nan%
# Best Trade: 23.12%
# Worst Trade: 0.95%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 4 days 11:40:00
# ---------------------------------
#   143 | 00m22s |    0.28662 | 3.000000 | 92.000000 | 226.000000 |
# ---------------------------------
# ADX_BOLLStrategy_28_107_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 2.0987387715
# Sortino Ratio: 3.4164246741
# Max Drawdown: 0.2686727915
# Max Drawdown Duration: 227600
# Total Returns: 0.8024796621
# Annualized Returns: 1.8886947447
# Compound Annual Growth Rate: 3.0013790198
# ---------------------------------
# Trades: 78
# Trade Winning: 35.90%
# Average Trade: 1.11%
# Average Win: 6.12%
# Average Loss: -1.70%
# Best Trade: 32.29%
# Worst Trade: -6.01%
# Worst Trade Date: 0 days 01:00:00
# Avg Days in Trade: 0 days 18:06:09
# ---------------------------------
#   144 | 00m18s |    0.80248 | 0.100000 | 28.000000 | 107.000000 |
# ---------------------------------
# ADX_BOLLStrategy_138_77_2.413707349920391
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8049616108
# Sortino Ratio: 2.1968588054
# Max Drawdown: 0.3141670040
# Max Drawdown Duration: 273500
# Total Returns: 0.4588357542
# Annualized Returns: 1.0799036021
# Compound Annual Growth Rate: 1.4322101080
# ---------------------------------
# Trades: 11
# Trade Winning: 54.55%
# Average Trade: 4.23%
# Average Win: 11.86%
# Average Loss: -4.93%
# Best Trade: 20.74%
# Worst Trade: -9.75%
# Worst Trade Date: 2 days 00:00:00
# Avg Days in Trade: 3 days 09:00:00
# ---------------------------------
#   145 | 00m17s |    0.45884 | 2.413707 | 138.000000 | 77.000000 |
# ---------------------------------
# ADX_BOLLStrategy_201_73_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.3826845756
# Sortino Ratio: -0.1974077518
# Max Drawdown: 0.3418648477
# Max Drawdown Duration: 273500
# Total Returns: -0.1503634444
# Annualized Returns: -0.3538913952
# Compound Annual Growth Rate: -0.3185325429
# ---------------------------------
# Trades: 6
# Trade Winning: 33.33%
# Average Trade: -1.88%
# Average Win: 10.50%
# Average Loss: -8.07%
# Best Trade: 17.48%
# Worst Trade: -17.28%
# Worst Trade Date: 0 days 06:00:00
# Avg Days in Trade: 2 days 18:50:00
# ---------------------------------
#   146 | 00m17s |   -0.15036 | 3.000000 | 201.000000 | 73.000000 |
# ---------------------------------
# ADX_BOLLStrategy_35_1_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
#   147 | 00m14s |    0.00000 | 0.100000 | 35.000000 | 1.000000 |
# ---------------------------------
# ADX_BOLLStrategy_131_226_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0979495015
# Sortino Ratio: 1.3956874321
# Max Drawdown: 0.4580677816
# Max Drawdown Duration: 273500
# Total Returns: 0.2702723683
# Annualized Returns: 0.6361058426
# Compound Annual Growth Rate: 0.7560175814
# ---------------------------------
# Trades: 38
# Trade Winning: 31.58%
# Average Trade: 1.11%
# Average Win: 9.04%
# Average Loss: -2.55%
# Best Trade: 28.75%
# Worst Trade: -10.41%
# Worst Trade Date: 0 days 03:00:00
# Avg Days in Trade: 1 days 13:55:16
# ---------------------------------
#   148 | 00m25s |    0.27027 | 0.100000 | 131.000000 | 226.000000 |
# ---------------------------------
# ADX_BOLLStrategy_188_215_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0860519871
# Sortino Ratio: 1.2957499100
# Max Drawdown: 0.4513995754
# Max Drawdown Duration: 273500
# Total Returns: 0.2467590757
# Annualized Returns: 0.5807655839
# Compound Annual Growth Rate: 0.6804718016
# ---------------------------------
# Trades: 34
# Trade Winning: 38.24%
# Average Trade: 1.04%
# Average Win: 6.64%
# Average Loss: -2.42%
# Best Trade: 22.11%
# Worst Trade: -7.54%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 1 days 14:30:00
# ---------------------------------
#   149 | 00m25s |    0.24676 | 0.100000 | 188.000000 | 215.000000 |
# ---------------------------------
# ADX_BOLLStrategy_13_218_2.9192147457614697
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.5338451096
# Sortino Ratio: -0.1652403563
# Max Drawdown: 0.1758640694
# Max Drawdown Duration: 299200
# Total Returns: -0.0651037029
# Annualized Returns: -0.1532263399
# Compound Annual Growth Rate: -0.1465273454
# ---------------------------------
# Trades: 6
# Trade Winning: 50.00%
# Average Trade: -0.79%
# Average Win: 2.88%
# Average Loss: -4.46%
# Best Trade: 4.02%
# Worst Trade: -10.54%
# Worst Trade Date: 0 days 05:00:00
# Avg Days in Trade: 0 days 13:50:00
# ---------------------------------
#   150 | 00m24s |   -0.06510 | 2.919215 | 13.000000 | 218.000000 |
# ---------------------------------
# ADX_BOLLStrategy_168_143_2.603387210812651
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0741150720
# Sortino Ratio: 0.7413444716
# Max Drawdown: 0.3306575233
# Max Drawdown Duration: 273500
# Total Returns: 0.2150577486
# Annualized Returns: 0.5061541853
# Compound Annual Growth Rate: 0.5816305850
# ---------------------------------
# Trades: 6
# Trade Winning: 50.00%
# Average Trade: 3.99%
# Average Win: 12.84%
# Average Loss: -4.87%
# Best Trade: 17.33%
# Worst Trade: -12.01%
# Worst Trade Date: 2 days 16:00:00
# Avg Days in Trade: 4 days 15:40:00
# ---------------------------------
#   151 | 00m23s |    0.21506 | 2.603387 | 168.000000 | 143.000000 |
# ---------------------------------
# ADX_BOLLStrategy_184_103_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.6957691045
# Sortino Ratio: 0.8392949945
# Max Drawdown: 0.2094607481
# Max Drawdown Duration: 273500
# Total Returns: 0.2736832820
# Annualized Returns: 0.6441336782
# Compound Annual Growth Rate: 0.7671353917
# ---------------------------------
# Trades: 6
# Trade Winning: 66.67%
# Average Trade: 4.57%
# Average Win: 7.87%
# Average Loss: -2.02%
# Best Trade: 18.84%
# Worst Trade: -4.03%
# Worst Trade Date: 2 days 08:00:00
# Avg Days in Trade: 2 days 20:40:00
# ---------------------------------
#   152 | 00m19s |    0.27368 | 3.000000 | 184.000000 | 103.000000 |
# ---------------------------------
# ADX_BOLLStrategy_101_25_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9027123433
# Sortino Ratio: 0.7438744689
# Max Drawdown: 0.2659450519
# Max Drawdown Duration: 273500
# Total Returns: 0.1572962189
# Annualized Returns: 0.3702081884
# Compound Annual Growth Rate: 0.4103320153
# ---------------------------------
# Trades: 10
# Trade Winning: 40.00%
# Average Trade: 2.01%
# Average Win: 9.52%
# Average Loss: -3.00%
# Best Trade: 20.44%
# Worst Trade: -9.20%
# Worst Trade Date: 0 days 16:00:00
# Avg Days in Trade: 2 days 04:12:00
# ---------------------------------
#   153 | 00m16s |    0.15730 | 3.000000 | 101.000000 | 25.000000 |
# ---------------------------------
# ADX_BOLLStrategy_224_50_2.9824501822051754
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9143720890
# Sortino Ratio: 0.5144073954
# Max Drawdown: 0.1784219487
# Max Drawdown Duration: 192900
# Total Returns: 0.1188482091
# Annualized Returns: 0.2797179774
# Compound Annual Growth Rate: 0.3025263816
# ---------------------------------
# Trades: 7
# Trade Winning: 71.43%
# Average Trade: 2.12%
# Average Win: 5.45%
# Average Loss: -6.21%
# Best Trade: 17.67%
# Worst Trade: -10.54%
# Worst Trade Date: 0 days 15:00:00
# Avg Days in Trade: 2 days 17:00:00
# ---------------------------------
#   154 | 00m16s |    0.11885 | 2.982450 | 224.000000 | 50.000000 |
# ---------------------------------
# ADX_BOLLStrategy_197_222_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.0906437008
# Sortino Ratio: 0.4900544230
# Max Drawdown: 0.2253388824
# Max Drawdown Duration: 273500
# Total Returns: 0.1829048286
# Annualized Returns: 0.4304799297
# Compound Annual Growth Rate: 0.4848846432
# ---------------------------------
# Trades: 3
# Trade Winning: 66.67%
# Average Trade: 6.38%
# Average Win: 11.49%
# Average Loss: -3.85%
# Best Trade: 18.84%
# Worst Trade: -3.85%
# Worst Trade Date: 2 days 17:00:00
# Avg Days in Trade: 5 days 11:00:00
# ---------------------------------
#   155 | 00m24s |    0.18290 | 3.000000 | 197.000000 | 222.000000 |
# ---------------------------------
# ADX_BOLLStrategy_142_240_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.7399433910
# Sortino Ratio: 1.1618167204
# Max Drawdown: 0.1822214953
# Max Drawdown Duration: 273500
# Total Returns: 0.2953888404
# Annualized Returns: 0.6952193021
# Compound Annual Growth Rate: 0.8388317782
# ---------------------------------
# Trades: 4
# Trade Winning: 75.00%
# Average Trade: 7.18%
# Average Win: 9.86%
# Average Loss: -0.87%
# Best Trade: 20.36%
# Worst Trade: -0.87%
# Worst Trade Date: 0 days 07:00:00
# Avg Days in Trade: 3 days 17:00:00
# ---------------------------------
#   156 | 00m24s |    0.29539 | 3.000000 | 142.000000 | 240.000000 |
# ---------------------------------
# ADX_BOLLStrategy_122_16_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7693460158
# Sortino Ratio: 0.6202715185
# Max Drawdown: 0.2925533840
# Max Drawdown Duration: 273500
# Total Returns: 0.1266635036
# Annualized Returns: 0.2981118461
# Compound Annual Growth Rate: 0.3240412346
# ---------------------------------
# Trades: 10
# Trade Winning: 50.00%
# Average Trade: 1.63%
# Average Win: 6.95%
# Average Loss: -3.69%
# Best Trade: 17.67%
# Worst Trade: -6.16%
# Worst Trade Date: 0 days 10:00:00
# Avg Days in Trade: 2 days 13:48:00
# ---------------------------------
#   157 | 00m18s |    0.12666 | 3.000000 | 122.000000 | 16.000000 |
# ---------------------------------
# ADX_BOLLStrategy_233_44_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2341048643
# Sortino Ratio: 1.5828392815
# Max Drawdown: 0.2472538551
# Max Drawdown Duration: 273500
# Total Returns: 0.2955562051
# Annualized Returns: 0.6956132071
# Compound Annual Growth Rate: 0.8393909837
# ---------------------------------
# Trades: 66
# Trade Winning: 31.82%
# Average Trade: 0.74%
# Average Win: 5.34%
# Average Loss: -1.41%
# Best Trade: 30.44%
# Worst Trade: -7.24%
# Worst Trade Date: 0 days 02:00:00
# Avg Days in Trade: 0 days 14:35:27
# ---------------------------------
#   158 | 00m18s |    0.29556 | 0.100000 | 233.000000 | 44.000000 |
# ---------------------------------
# ADX_BOLLStrategy_234_152_3.0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.8551181695
# Sortino Ratio: 1.6630053765
# Max Drawdown: 0.2182973575
# Max Drawdown Duration: 191400
# Total Returns: 0.3302194541
# Annualized Returns: 0.7771957061
# Compound Annual Growth Rate: 0.9573232922
# ---------------------------------
# Trades: 7
# Trade Winning: 71.43%
# Average Trade: 4.59%
# Average Win: 7.07%
# Average Loss: -1.61%
# Best Trade: 20.17%
# Worst Trade: -2.04%
# Worst Trade Date: 2 days 19:00:00
# Avg Days in Trade: 3 days 14:00:00
# ---------------------------------
#   159 | 00m21s |    0.33022 | 3.000000 | 234.000000 | 152.000000 |
# ---------------------------------
# ADX_BOLLStrategy_158_204_0.1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2017-10-27 22:00:00
# 	End Date	: 2018-04-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.6367091754
# Sortino Ratio: 0.6998738742
# Max Drawdown: 0.4669966854
# Max Drawdown Duration: 273500
# Total Returns: 0.0891755739
# Annualized Returns: 0.2098812539
# Compound Annual Growth Rate: 0.2226794492
# ---------------------------------
# Trades: 43
# Trade Winning: 34.88%
# Average Trade: 0.56%
# Average Win: 6.46%
# Average Loss: -2.60%
# Best Trade: 21.16%
# Worst Trade: -9.22%
# Worst Trade Date: 2 days 23:00:00
# Avg Days in Trade: 1 days 07:53:01
# ---------------------------------
#   160 | 00m24s |    0.08918 | 0.100000 | 158.000000 | 204.000000 |

# %%
print(BO.res['max'])
# Out:
# {'max_val': 0.9485894752027062, 'max_params': {'window_ADX': 26.0, 'window_BOLL': 72.0, 'a': 0.8568390408851148}}

# %%
Target = pd.DataFrame({'Parameters': BO.X.tolist(), 'Target': BO.Y})
# Target.to_csv(config['out_dir'] + "/target_ei.csv")
Target.sort_values(by = "Target")
# Out:
#                              Parameters    Target
# 139                    [1.0, 94.0, 0.1] -0.731121
# 102                   [1.0, 240.0, 0.1] -0.671160
# 58                    [1.0, 169.0, 0.1] -0.628136
# 50     [2.0, 68.0, 0.13916459812046364] -0.479027
# 70     [4.0, 156.0, 0.7836778791234862] -0.433329
# 115    [200.0, 5.0, 0.8523102770647875] -0.209054
# 73                   [167.0, 74.0, 3.0] -0.190399
# 108                  [220.0, 20.0, 0.1] -0.156681
# 141                 [219.0, 196.0, 0.1] -0.151760
# 145                  [201.0, 73.0, 3.0] -0.150363
# 112                  [27.0, 180.0, 3.0] -0.095223
# 11   [205.0, 235.0, 1.7947284501399945] -0.067155
# 149   [13.0, 218.0, 2.9192147457614697] -0.065104
# 55                  [159.0, 240.0, 0.1] -0.062882
# 86                  [214.0, 175.0, 0.1] -0.061370
# 105    [81.0, 64.0, 2.7535145584960072] -0.056274
# 123                   [41.0, 39.0, 3.0] -0.054133
# 94      [8.0, 73.0, 0.8129170829906152] -0.048706
# 47                    [240.0, 1.0, 0.1]  0.000000
# 62                    [106.0, 1.0, 0.1]  0.000000
# 129     [221.0, 1.0, 2.454165609901493]  0.000000
# 46                      [1.0, 1.0, 3.0]  0.000000
# 21      [140.0, 4.0, 2.319906802878526]  0.000000
# 41                     [64.0, 1.0, 0.1]  0.000000
# 146                    [35.0, 1.0, 0.1]  0.000000
# 103                    [84.0, 1.0, 3.0]  0.000000
# 2      [141.0, 2.0, 1.4607917266706152]  0.000000
# 97                    [200.0, 1.0, 0.1]  0.000000
# 82     [146.0, 3.0, 1.6409627303367202]  0.000000
# 109                   [176.0, 1.0, 0.1]  0.000000
# ..                                  ...       ...
# 36    [138.0, 26.0, 0.4663131666301761]  0.503617
# 88                    [96.0, 48.0, 0.1]  0.510972
# 56                   [240.0, 35.0, 3.0]  0.512065
# 48                    [41.0, 58.0, 3.0]  0.512655
# 33     [87.0, 16.0, 1.1476569586137009]  0.515689
# 98                   [85.0, 107.0, 0.1]  0.523792
# 20    [213.0, 58.0, 1.6677414755885676]  0.524405
# 135   [138.0, 26.0, 1.3843488578437746]  0.564537
# 81    [80.0, 168.0, 2.8562143900078505]  0.564907
# 17    [21.0, 199.0, 1.6470006227550085]  0.575348
# 137                  [240.0, 17.0, 3.0]  0.578689
# 140   [58.0, 38.0, 0.12344401630206449]  0.580053
# 28    [216.0, 81.0, 1.3991425261192127]  0.589008
# 19    [147.0, 50.0, 1.5298728212797632]  0.604063
# 114                 [156.0, 133.0, 0.1]  0.605768
# 78                  [240.0, 137.0, 0.1]  0.622113
# 66    [69.0, 226.0, 1.8940577816927975]  0.622470
# 90                   [225.0, 94.0, 0.1]  0.633236
# 27     [69.0, 53.0, 1.6682857498427974]  0.641852
# 22   [235.0, 197.0, 0.2315026128664944]  0.661780
# 26     [51.0, 27.0, 2.6610638798763273]  0.678268
# 30   [234.0, 116.0, 1.1949945893381744]  0.685829
# 10   [130.0, 176.0, 0.9668973254081766]  0.687310
# 31    [223.0, 42.0, 1.6614316134119567]  0.696577
# 131   [82.0, 45.0, 0.16666915645142422]  0.735318
# 45    [231.0, 52.0, 1.0831337440623408]  0.754338
# 32    [97.0, 211.0, 1.9916667579842722]  0.757219
# 143                  [28.0, 107.0, 0.1]  0.802480
# 65                    [51.0, 41.0, 0.1]  0.807736
# 15     [26.0, 72.0, 0.8568390408851148]  0.948589
#
# [160 rows x 2 columns]

# %% [markdown]
# ## Acquisition Function "Probability of Improvement"

# %% [markdown]
# * Prefer exploitation (xi=1e-4)
# * Prefer exploration (xi=0.1)
