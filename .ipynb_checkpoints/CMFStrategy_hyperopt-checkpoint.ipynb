# %%
import numpy as np
import pandas as pd
import queue
import matplotlib.pyplot as plt

from Backtest.backtest import Backtest
from Backtest.data import OHLCDataHandler
from CCIStrategy import CCIStrategy
from Backtest.open_json_gz_files import open_json_gz_files
from Backtest.generate_bars import generate_bars

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import hyperopt.pyll.stochastic

# %%
def run_backtest(config, trading_data, ohlc_data, window):
    window = int(window)
    config['title'] = "CCIStrategy" + "_" + str(window)
    print("---------------------------------")
    print(config['title'])
    print("---------------------------------")
    
    events_queue = queue.Queue()

    data_handler = OHLCDataHandler(
        config, events_queue,
        trading_data = trading_data, ohlc_data = ohlc_data
    )
    strategy = CCIStrategy(config, events_queue, data_handler,window = window)

    backtest = Backtest(config, events_queue, strategy,
                        data_handler= data_handler)

    results = backtest.start_trading()
    
    # dict_ans = {
    #     "short_window": [short_window],
    #     "long_window": [long_window],
    #     "Sharpe Ratio": [results['sharpe']],
    #     "Total Returns": [(results['cum_returns'][-1] - 1)],
    #     "Max Drawdown": [(results["max_drawdown"] * 100.0)],
    #     "Max Drawdown Duration": [(results['max_drawdown_duration'])],
    #     "Trades": [results['trade_info']['trading_num']],
    #     "Trade Winning": [results['trade_info']['win_pct']],
    #     "Average Trade": [results['trade_info']['avg_trd_pct']],
    #     "Average Win": [results['trade_info']['avg_win_pct']],
    #     "Average Loss": [results['trade_info']['avg_loss_pct']],
    #     "Best Trade": [results['trade_info']['max_win_pct']],
    #     "Worst Trade": [results['trade_info']['max_loss_pct']],
    #     "Worst Trade Date": [results['trade_info']['max_loss_dt']],
    #     "Avg Days in Trade": [results['trade_info']['avg_dit']]
    # }
    # return pd.DataFrame(dict_ans)
    return -1 * (results['cum_returns'][-1] - 1)

# %%
def f(params):
    config = {
        "csv_dir": "./Binance",
        "out_dir": "./results/CMFStrategy",
        "title": "CMFStrategy",
        "is_plot": False,
        "save_plot": False,
        "save_tradelog": False,
        "start_date": pd.Timestamp("2018-02-01T00:0:00", freq = "60" + "T"),    # str(freq) + "T"
        "end_date": pd.Timestamp("2018-06-01T00:00:00", freq = "60" + "T"),
        "equity": 1.0,
        "freq": 30,      # min
        "commission_ratio": 0.001,
        "suggested_quantity": None,     # None or a value
        "max_quantity": None,           # None or a value, Maximum purchase quantity
        "min_quantity": None,           # None or a value, Minimum purchase quantity
        "min_handheld_cash": None,      # None or a value, Minimum handheld funds
        "exchange": "Binance",
        "tickers": ['BTCUSDT']
    }
    # trading_data = {}
    # for ticker in config['tickers']:
    #     # trading_data[ticker] = open_gz_files(config['csv_dir'], ticker)
    #     trading_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '.h5', key=ticker)

    ohlc_data = {}
    for ticker in config['tickers']:
        # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
        ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker + '_OHLC_30min.h5', key=ticker)

    trading_data = None
    
    window = params['window']
    val = run_backtest(config, trading_data, ohlc_data, window)
    return {'loss': val, 'status': STATUS_OK}

# %%
space = {
    'window': hp.randint('window', 240),
}

# %%
# print(hyperopt.pyll.stochastic.sample(space))

# %%
trials = Trials()

# %%
best = fmin(fn=f, space=space, algo=tpe.suggest, max_evals=50, trials=trials)
# Out:
# ---------------------------------
# CCIStrategy_10
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# D:\Dev\test\backtest\CCIStrategy.py:56: RuntimeWarning: invalid value encountered in double_scalars
#   cci = (tp_current - tp_ma) / (0.015 * md)
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -5.3434181140
# Sortino Ratio: -9.3346616739
# Information Ratio: -5.1798017477
# Max Drawdown: 0.6877190733
# Max Drawdown Duration: 430800
# Total Returns: -0.6801766000
# Annualized Returns: -2.0688704917
# Compound Annual Growth Rate: -0.9688037805
# ---------------------------------
# Trades: 214
# Trade Winning: 34.11%
# Average Trade: -0.31%
# Average Win: 1.99%
# Average Loss: -1.49%
# Best Trade: 9.65%
# Worst Trade: -5.32%
# Worst Trade Date: 10.0
# Avg Days in Trade: 13.915555555555555
# ---------------------------------
# ---------------------------------
# CCIStrategy_184
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.1172121705
# Sortino Ratio: -0.1541492678
# Information Ratio: 0.1693543758
# Max Drawdown: 0.2986779841
# Max Drawdown Duration: 418500
# Total Returns: -0.1003461793
# Annualized Returns: -0.3052196287
# Compound Annual Growth Rate: -0.2750421410
# ---------------------------------
# Trades: 16
# Trade Winning: 25.00%
# Average Trade: -0.23%
# Average Win: 9.63%
# Average Loss: -3.52%
# Best Trade: 19.75%
# Worst Trade: -9.30%
# Worst Trade Date: 24.0
# Avg Days in Trade: 6.125
# ---------------------------------
# ---------------------------------
# CCIStrategy_109
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7816281399
# Sortino Ratio: 1.2360181213
# Information Ratio: 1.0536721353
# Max Drawdown: 0.2521696498
# Max Drawdown Duration: 239500
# Total Returns: 0.0685036952
# Annualized Returns: 0.2083654062
# Compound Annual Growth Rate: 0.2232834114
# ---------------------------------
# Trades: 21
# Trade Winning: 38.10%
# Average Trade: 0.69%
# Average Win: 7.24%
# Average Loss: -3.34%
# Best Trade: 22.62%
# Worst Trade: -9.82%
# Worst Trade Date: 43.0
# Avg Days in Trade: 34.19
# ---------------------------------
# ---------------------------------
# CCIStrategy_132
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8402488715
# Sortino Ratio: 1.1434323367
# Information Ratio: 1.1389999313
# Max Drawdown: 0.2287888069
# Max Drawdown Duration: 236100
# Total Returns: 0.0825748976
# Annualized Returns: 0.2511653135
# Compound Annual Growth Rate: 0.2729449010
# ---------------------------------
# Trades: 19
# Trade Winning: 26.32%
# Average Trade: 0.79%
# Average Win: 11.14%
# Average Loss: -2.90%
# Best Trade: 20.72%
# Worst Trade: -9.84%
# Worst Trade Date: 12.0
# Avg Days in Trade: 40.78944444444444
# ---------------------------------
# ---------------------------------
# CCIStrategy_87
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2083064704
# Sortino Ratio: -0.3568158219
# Information Ratio: 0.0903242418
# Max Drawdown: 0.3605323556
# Max Drawdown Duration: 494000
# Total Returns: -0.1263748955
# Annualized Returns: -0.3843903073
# Compound Annual Growth Rate: -0.3369740462
# ---------------------------------
# Trades: 29
# Trade Winning: 31.03%
# Average Trade: -0.11%
# Average Win: 7.31%
# Average Loss: -3.45%
# Best Trade: 22.50%
# Worst Trade: -9.37%
# Worst Trade Date: 19.0
# Avg Days in Trade: 1.7238888888888888
# ---------------------------------
# ---------------------------------
# CCIStrategy_44
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2756038393
# Sortino Ratio: 2.7896969647
# Information Ratio: 1.4456027500
# Max Drawdown: 0.2218609357
# Max Drawdown Duration: 177100
# Total Returns: 0.1946767099
# Annualized Returns: 0.5921416593
# Compound Annual Growth Rate: 0.7177895574
# ---------------------------------
# Trades: 48
# Trade Winning: 43.75%
# Average Trade: 0.66%
# Average Win: 4.15%
# Average Loss: -2.05%
# Best Trade: 13.38%
# Worst Trade: -4.15%
# Worst Trade Date: 17.0
# Avg Days in Trade: 11.270555555555555
# ---------------------------------
# ---------------------------------
# CCIStrategy_146
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1856939421
# Sortino Ratio: 1.6081354984
# Information Ratio: 1.3409904570
# Max Drawdown: 0.2224666554
# Max Drawdown Duration: 223000
# Total Returns: 0.1631979143
# Annualized Returns: 0.4963936560
# Compound Annual Growth Rate: 0.5837856790
# ---------------------------------
# Trades: 16
# Trade Winning: 31.25%
# Average Trade: 1.36%
# Average Win: 10.54%
# Average Loss: -2.81%
# Best Trade: 20.72%
# Worst Trade: -7.68%
# Worst Trade Date: 32.0
# Avg Days in Trade: 15.25
# ---------------------------------
# ---------------------------------
# CCIStrategy_134
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7700518568
# Sortino Ratio: 1.0341895296
# Information Ratio: 1.0668201321
# Max Drawdown: 0.2287888069
# Max Drawdown Duration: 236100
# Total Returns: 0.0661746207
# Annualized Returns: 0.2012811378
# Compound Annual Growth Rate: 0.2151909741
# ---------------------------------
# Trades: 19
# Trade Winning: 26.32%
# Average Trade: 0.72%
# Average Win: 11.14%
# Average Loss: -3.01%
# Best Trade: 20.72%
# Worst Trade: -9.84%
# Worst Trade Date: 12.0
# Avg Days in Trade: 40.68388888888889
# ---------------------------------
# ---------------------------------
# CCIStrategy_143
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3198728808
# Sortino Ratio: 1.7829082831
# Information Ratio: 1.4776878053
# Max Drawdown: 0.2201159537
# Max Drawdown Duration: 223000
# Total Returns: 0.1968805684
# Annualized Returns: 0.5988450621
# Compound Annual Growth Rate: 0.7274463406
# ---------------------------------
# Trades: 16
# Trade Winning: 31.25%
# Average Trade: 1.51%
# Average Win: 11.07%
# Average Loss: -2.84%
# Best Trade: 20.72%
# Worst Trade: -7.68%
# Worst Trade Date: 32.0
# Avg Days in Trade: 16.0
# ---------------------------------
# ---------------------------------
# CCIStrategy_132
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8402488715
# Sortino Ratio: 1.1434323367
# Information Ratio: 1.1389999313
# Max Drawdown: 0.2287888069
# Max Drawdown Duration: 236100
# Total Returns: 0.0825748976
# Annualized Returns: 0.2511653135
# Compound Annual Growth Rate: 0.2729449010
# ---------------------------------
# Trades: 19
# Trade Winning: 26.32%
# Average Trade: 0.79%
# Average Win: 11.14%
# Average Loss: -2.90%
# Best Trade: 20.72%
# Worst Trade: -9.84%
# Worst Trade Date: 12.0
# Avg Days in Trade: 40.78944444444444
# ---------------------------------
# ---------------------------------
# CCIStrategy_134
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7700518568
# Sortino Ratio: 1.0341895296
# Information Ratio: 1.0668201321
# Max Drawdown: 0.2287888069
# Max Drawdown Duration: 236100
# Total Returns: 0.0661746207
# Annualized Returns: 0.2012811378
# Compound Annual Growth Rate: 0.2151909741
# ---------------------------------
# Trades: 19
# Trade Winning: 26.32%
# Average Trade: 0.72%
# Average Win: 11.14%
# Average Loss: -3.01%
# Best Trade: 20.72%
# Worst Trade: -9.84%
# Worst Trade Date: 12.0
# Avg Days in Trade: 40.68388888888889
# ---------------------------------
# ---------------------------------
# CCIStrategy_106
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.7187848167
# Sortino Ratio: 1.1406996833
# Information Ratio: 0.9846718251
# Max Drawdown: 0.2424104588
# Max Drawdown Duration: 237100
# Total Returns: 0.0538696442
# Annualized Returns: 0.1638535011
# Compound Annual Growth Rate: 0.1730327560
# ---------------------------------
# Trades: 22
# Trade Winning: 36.36%
# Average Trade: 0.58%
# Average Win: 7.22%
# Average Loss: -3.21%
# Best Trade: 19.58%
# Worst Trade: -9.79%
# Worst Trade Date: 44.0
# Avg Days in Trade: 28.454444444444444
# ---------------------------------
# ---------------------------------
# CCIStrategy_201
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.3468473617
# Sortino Ratio: -0.4330874367
# Information Ratio: -0.0134047645
# Max Drawdown: 0.3188109688
# Max Drawdown Duration: 418500
# Total Returns: -0.1409481782
# Annualized Returns: -0.4287173754
# Compound Annual Growth Rate: -0.3700459153
# ---------------------------------
# Trades: 16
# Trade Winning: 25.00%
# Average Trade: -0.51%
# Average Win: 9.33%
# Average Loss: -3.79%
# Best Trade: 19.75%
# Worst Trade: -10.58%
# Worst Trade Date: 1.0
# Avg Days in Trade: 1.8122222222222222
# ---------------------------------
# ---------------------------------
# CCIStrategy_207
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1623024819
# Sortino Ratio: 0.2227859539
# Information Ratio: 0.4046944826
# Max Drawdown: 0.2835163744
# Max Drawdown Duration: 418500
# Total Returns: -0.0593697079
# Annualized Returns: -0.1805828615
# Compound Annual Growth Rate: -0.1698638266
# ---------------------------------
# Trades: 15
# Trade Winning: 26.67%
# Average Trade: 0.07%
# Average Win: 10.88%
# Average Loss: -3.86%
# Best Trade: 19.75%
# Worst Trade: -10.58%
# Worst Trade Date: 1.0
# Avg Days in Trade: 20.2
# ---------------------------------
# ---------------------------------
# CCIStrategy_3
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -10.6596251114
# Sortino Ratio: -14.1018621942
# Information Ratio: -10.7018888874
# Max Drawdown: 0.9151335398
# Max Drawdown Duration: 575200
# Total Returns: -0.9141967047
# Annualized Returns: -2.7806816435
# Compound Annual Growth Rate: -0.9994297378
# ---------------------------------
# Trades: 627
# Trade Winning: 33.65%
# Average Trade: -0.18%
# Average Win: 1.17%
# Average Loss: -0.86%
# Best Trade: 11.71%
# Worst Trade: -7.00%
# Worst Trade Date: 4.0
# Avg Days in Trade: 4.773333333333333
# ---------------------------------
# ---------------------------------
# CCIStrategy_239
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8273682774
# Sortino Ratio: 1.1018640579
# Information Ratio: 0.9468220290
# Max Drawdown: 0.2250842072
# Max Drawdown Duration: 480400
# Total Returns: 0.0735837602
# Annualized Returns: 0.2238172705
# Compound Annual Growth Rate: 0.2410595785
# ---------------------------------
# Trades: 13
# Trade Winning: 30.77%
# Average Trade: 1.03%
# Average Win: 9.92%
# Average Loss: -2.92%
# Best Trade: 22.90%
# Worst Trade: -6.83%
# Worst Trade Date: 28.0
# Avg Days in Trade: 42.38444444444445
# ---------------------------------
# ---------------------------------
# CCIStrategy_90
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.6756515464
# Sortino Ratio: -1.1101894236
# Information Ratio: -0.3305815834
# Max Drawdown: 0.3584315877
# Max Drawdown Duration: 494000
# Total Returns: -0.2070721655
# Annualized Returns: -0.6298445034
# Compound Annual Growth Rate: -0.5062553615
# ---------------------------------
# Trades: 29
# Trade Winning: 27.59%
# Average Trade: -0.47%
# Average Win: 7.28%
# Average Loss: -3.42%
# Best Trade: 18.79%
# Worst Trade: -9.37%
# Worst Trade Date: 19.0
# Avg Days in Trade: 2.8961111111111113
# ---------------------------------
# ---------------------------------
# CCIStrategy_95
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1089392534
# Sortino Ratio: 0.1781518529
# Information Ratio: 0.3921280747
# Max Drawdown: 0.3103205603
# Max Drawdown Duration: 494000
# Total Returns: -0.0778877065
# Annualized Returns: -0.2369084405
# Compound Annual Growth Rate: -0.2185807693
# ---------------------------------
# Trades: 26
# Trade Winning: 30.77%
# Average Trade: 0.05%
# Average Win: 8.13%
# Average Loss: -3.54%
# Best Trade: 18.82%
# Worst Trade: -9.46%
# Worst Trade Date: 18.0
# Avg Days in Trade: 11.846111111111112
# ---------------------------------
# ---------------------------------
# CCIStrategy_1
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Information Ratio: 0.2019076551
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
# ---------------------------------
# CCIStrategy_104
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9111216875
# Sortino Ratio: 1.4413474034
# Information Ratio: 1.1670929809
# Max Drawdown: 0.2257542942
# Max Drawdown Duration: 236100
# Total Returns: 0.0970093440
# Annualized Returns: 0.2950700881
# Compound Annual Growth Rate: 0.3252762364
# ---------------------------------
# Trades: 22
# Trade Winning: 36.36%
# Average Trade: 0.76%
# Average Win: 7.36%
# Average Loss: -3.01%
# Best Trade: 19.58%
# Worst Trade: -9.79%
# Worst Trade Date: 44.0
# Avg Days in Trade: 28.18166666666667
# ---------------------------------
# ---------------------------------
# CCIStrategy_44
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2756038393
# Sortino Ratio: 2.7896969647
# Information Ratio: 1.4456027500
# Max Drawdown: 0.2218609357
# Max Drawdown Duration: 177100
# Total Returns: 0.1946767099
# Annualized Returns: 0.5921416593
# Compound Annual Growth Rate: 0.7177895574
# ---------------------------------
# Trades: 48
# Trade Winning: 43.75%
# Average Trade: 0.66%
# Average Win: 4.15%
# Average Loss: -2.05%
# Best Trade: 13.38%
# Worst Trade: -4.15%
# Worst Trade Date: 17.0
# Avg Days in Trade: 11.270555555555555
# ---------------------------------
# ---------------------------------
# CCIStrategy_103
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9445308720
# Sortino Ratio: 1.5031989796
# Information Ratio: 1.2033744085
# Max Drawdown: 0.2291429571
# Max Drawdown Duration: 223000
# Total Returns: 0.1047560986
# Annualized Returns: 0.3186331333
# Compound Annual Growth Rate: 0.3539480155
# ---------------------------------
# Trades: 22
# Trade Winning: 36.36%
# Average Trade: 0.80%
# Average Win: 7.47%
# Average Loss: -3.01%
# Best Trade: 19.58%
# Worst Trade: -9.79%
# Worst Trade Date: 44.0
# Avg Days in Trade: 29.227222222222224
# ---------------------------------
# ---------------------------------
# CCIStrategy_186
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.0563748069
# Sortino Ratio: -0.0747145407
# Information Ratio: 0.2160562896
# Max Drawdown: 0.2912648743
# Max Drawdown Duration: 418500
# Total Returns: -0.0908366639
# Annualized Returns: -0.2762948526
# Compound Annual Growth Rate: -0.2514815887
# ---------------------------------
# Trades: 16
# Trade Winning: 25.00%
# Average Trade: -0.17%
# Average Win: 9.63%
# Average Loss: -3.44%
# Best Trade: 19.75%
# Worst Trade: -9.30%
# Worst Trade Date: 24.0
# Avg Days in Trade: 5.75
# ---------------------------------
# ---------------------------------
# CCIStrategy_76
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2076670958
# Sortino Ratio: -0.2984025039
# Information Ratio: 0.0914311977
# Max Drawdown: 0.3214532515
# Max Drawdown Duration: 494000
# Total Returns: -0.1248644637
# Annualized Returns: -0.3797960770
# Compound Annual Growth Rate: -0.3334811598
# ---------------------------------
# Trades: 33
# Trade Winning: 39.39%
# Average Trade: -0.05%
# Average Win: 4.60%
# Average Loss: -3.08%
# Best Trade: 14.59%
# Worst Trade: -7.36%
# Worst Trade Date: 1.0
# Avg Days in Trade: 38.696666666666665
# ---------------------------------
# ---------------------------------
# CCIStrategy_49
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1748394054
# Sortino Ratio: 2.5381096428
# Information Ratio: 1.3727952919
# Max Drawdown: 0.2167010778
# Max Drawdown Duration: 312400
# Total Returns: 0.1506844691
# Annualized Returns: 0.4583319268
# Compound Annual Growth Rate: 0.5325286353
# ---------------------------------
# Trades: 46
# Trade Winning: 36.96%
# Average Trade: 0.62%
# Average Win: 4.91%
# Average Loss: -1.89%
# Best Trade: 13.38%
# Worst Trade: -4.37%
# Worst Trade Date: 37.0
# Avg Days in Trade: 13.803888888888888
# ---------------------------------
# ---------------------------------
# CCIStrategy_203
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2943377594
# Sortino Ratio: 0.3942411960
# Information Ratio: 0.5189016343
# Max Drawdown: 0.2749162915
# Max Drawdown Duration: 240600
# Total Returns: -0.0336865764
# Annualized Returns: -0.1024633367
# Compound Annual Growth Rate: -0.0989809879
# ---------------------------------
# Trades: 15
# Trade Winning: 26.67%
# Average Trade: 0.26%
# Average Win: 11.21%
# Average Loss: -3.73%
# Best Trade: 19.75%
# Worst Trade: -10.58%
# Worst Trade Date: 1.0
# Avg Days in Trade: 19.266666666666666
# ---------------------------------
# ---------------------------------
# CCIStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3257907672
# Sortino Ratio: 1.9177515274
# Information Ratio: 1.4710947280
# Max Drawdown: 0.2069742779
# Max Drawdown Duration: 221500
# Total Returns: 0.1970040127
# Annualized Returns: 0.5992205386
# Compound Annual Growth Rate: 0.7279883194
# ---------------------------------
# Trades: 17
# Trade Winning: 29.41%
# Average Trade: 1.43%
# Average Win: 11.16%
# Average Loss: -2.62%
# Best Trade: 20.72%
# Worst Trade: -7.68%
# Worst Trade Date: 32.0
# Avg Days in Trade: 7.293888888888889
# ---------------------------------
# ---------------------------------
# CCIStrategy_69
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.3400387409
# Sortino Ratio: -0.5207589104
# Information Ratio: -0.0135952837
# Max Drawdown: 0.3065743226
# Max Drawdown Duration: 428500
# Total Returns: -0.1426933697
# Annualized Returns: -0.4340256662
# Compound Annual Growth Rate: -0.3739304882
# ---------------------------------
# Trades: 36
# Trade Winning: 33.33%
# Average Trade: -0.09%
# Average Win: 5.22%
# Average Loss: -2.74%
# Best Trade: 16.83%
# Worst Trade: -7.30%
# Worst Trade Date: 3.0
# Avg Days in Trade: 29.52777777777778
# ---------------------------------
# ---------------------------------
# CCIStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3257907672
# Sortino Ratio: 1.9177515274
# Information Ratio: 1.4710947280
# Max Drawdown: 0.2069742779
# Max Drawdown Duration: 221500
# Total Returns: 0.1970040127
# Annualized Returns: 0.5992205386
# Compound Annual Growth Rate: 0.7279883194
# ---------------------------------
# Trades: 17
# Trade Winning: 29.41%
# Average Trade: 1.43%
# Average Win: 11.16%
# Average Loss: -2.62%
# Best Trade: 20.72%
# Worst Trade: -7.68%
# Worst Trade Date: 32.0
# Avg Days in Trade: 7.293888888888889
# ---------------------------------
# ---------------------------------
# CCIStrategy_86
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2207456832
# Sortino Ratio: -0.3707472752
# Information Ratio: 0.0792529594
# Max Drawdown: 0.3642720030
# Max Drawdown Duration: 494000
# Total Returns: -0.1283874003
# Annualized Returns: -0.3905116759
# Compound Annual Growth Rate: -0.3416088599
# ---------------------------------
# Trades: 29
# Trade Winning: 31.03%
# Average Trade: -0.12%
# Average Win: 7.35%
# Average Loss: -3.48%
# Best Trade: 21.66%
# Worst Trade: -9.37%
# Worst Trade Date: 19.0
# Avg Days in Trade: 1.7583333333333333
# ---------------------------------
# ---------------------------------
# CCIStrategy_89
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.2603015774
# Sortino Ratio: -0.4217622656
# Information Ratio: 0.0406152653
# Max Drawdown: 0.3499448177
# Max Drawdown Duration: 494000
# Total Returns: -0.1378208377
# Annualized Returns: -0.4192050480
# Compound Annual Growth Rate: -0.3630444436
# ---------------------------------
# Trades: 28
# Trade Winning: 35.71%
# Average Trade: -0.17%
# Average Win: 6.22%
# Average Loss: -3.72%
# Best Trade: 22.50%
# Worst Trade: -9.37%
# Worst Trade Date: 19.0
# Avg Days in Trade: 5.142777777777778
# ---------------------------------
# ---------------------------------
# CCIStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3257907672
# Sortino Ratio: 1.9177515274
# Information Ratio: 1.4710947280
# Max Drawdown: 0.2069742779
# Max Drawdown Duration: 221500
# Total Returns: 0.1970040127
# Annualized Returns: 0.5992205386
# Compound Annual Growth Rate: 0.7279883194
# ---------------------------------
# Trades: 17
# Trade Winning: 29.41%
# Average Trade: 1.43%
# Average Win: 11.16%
# Average Loss: -2.62%
# Best Trade: 20.72%
# Worst Trade: -7.68%
# Worst Trade Date: 32.0
# Avg Days in Trade: 7.293888888888889
# ---------------------------------
# ---------------------------------
# CCIStrategy_39
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.5419378638
# Sortino Ratio: 1.1575167938
# Information Ratio: 0.7755191329
# Max Drawdown: 0.2186210983
# Max Drawdown Duration: 386500
# Total Returns: 0.0357609342
# Annualized Returns: 0.1087728416
# Compound Annual Growth Rate: 0.1127930222
# ---------------------------------
# Trades: 54
# Trade Winning: 46.30%
# Average Trade: 0.36%
# Average Win: 3.71%
# Average Loss: -2.54%
# Best Trade: 16.97%
# Worst Trade: -8.50%
# Worst Trade Date: 21.0
# Avg Days in Trade: 5.833333333333333
# ---------------------------------
# ---------------------------------
# CCIStrategy_33
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.5224099275
# Sortino Ratio: -0.8964108036
# Information Ratio: -0.2311320127
# Max Drawdown: 0.3283126561
# Max Drawdown Duration: 494000
# Total Returns: -0.1779548864
# Annualized Returns: -0.5412794462
# Compound Annual Growth Rate: -0.4490135206
# ---------------------------------
# Trades: 65
# Trade Winning: 36.92%
# Average Trade: -0.03%
# Average Win: 4.06%
# Average Loss: -2.42%
# Best Trade: 13.00%
# Worst Trade: -7.39%
# Worst Trade Date: 23.0
# Avg Days in Trade: 46.06111111111111
# ---------------------------------
# ---------------------------------
# CCIStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3257907672
# Sortino Ratio: 1.9177515274
# Information Ratio: 1.4710947280
# Max Drawdown: 0.2069742779
# Max Drawdown Duration: 221500
# Total Returns: 0.1970040127
# Annualized Returns: 0.5992205386
# Compound Annual Growth Rate: 0.7279883194
# ---------------------------------
# Trades: 17
# Trade Winning: 29.41%
# Average Trade: 1.43%
# Average Win: 11.16%
# Average Loss: -2.62%
# Best Trade: 20.72%
# Worst Trade: -7.68%
# Worst Trade Date: 32.0
# Avg Days in Trade: 7.293888888888889
# ---------------------------------
# ---------------------------------
# CCIStrategy_177
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.1791137306
# Sortino Ratio: 0.2338747562
# Information Ratio: 0.3983572357
# Max Drawdown: 0.2599983105
# Max Drawdown Duration: 418500
# Total Returns: -0.0507280077
# Annualized Returns: -0.1542976900
# Compound Annual Growth Rate: -0.1464480734
# ---------------------------------
# Trades: 16
# Trade Winning: 31.25%
# Average Trade: 0.11%
# Average Win: 8.05%
# Average Loss: -3.51%
# Best Trade: 19.75%
# Worst Trade: -8.75%
# Worst Trade Date: 32.0
# Avg Days in Trade: 4.687222222222222
# ---------------------------------
# ---------------------------------
# CCIStrategy_117
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8696126387
# Sortino Ratio: 1.3348848161
# Information Ratio: 1.2014094559
# Max Drawdown: 0.2463791348
# Max Drawdown Duration: 238400
# Total Returns: 0.0899927597
# Annualized Returns: 0.2737279775
# Compound Annual Growth Rate: 0.2996612088
# ---------------------------------
# Trades: 20
# Trade Winning: 30.00%
# Average Trade: 0.83%
# Average Win: 10.20%
# Average Loss: -3.19%
# Best Trade: 22.62%
# Worst Trade: -9.83%
# Worst Trade Date: 34.0
# Avg Days in Trade: 41.7
# ---------------------------------
# ---------------------------------
# CCIStrategy_92
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.3662495367
# Sortino Ratio: -0.5666946425
# Information Ratio: -0.0546808469
# Max Drawdown: 0.3183621218
# Max Drawdown Duration: 494000
# Total Returns: -0.1563982091
# Annualized Returns: -0.4757112195
# Compound Annual Growth Rate: -0.4038783778
# ---------------------------------
# Trades: 27
# Trade Winning: 29.63%
# Average Trade: -0.30%
# Average Win: 7.11%
# Average Loss: -3.42%
# Best Trade: 18.79%
# Worst Trade: -9.37%
# Worst Trade Date: 19.0
# Avg Days in Trade: 7.629444444444444
# ---------------------------------
# ---------------------------------
# CCIStrategy_222
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3608089886
# Sortino Ratio: 0.5013410719
# Information Ratio: 0.5719972433
# Max Drawdown: 0.3028583889
# Max Drawdown Duration: 418500
# Total Returns: -0.0200361533
# Annualized Returns: -0.0609432997
# Compound Annual Growth Rate: -0.0597054616
# ---------------------------------
# Trades: 14
# Trade Winning: 28.57%
# Average Trade: 0.37%
# Average Win: 10.53%
# Average Loss: -3.69%
# Best Trade: 25.11%
# Worst Trade: -10.58%
# Worst Trade Date: 1.0
# Avg Days in Trade: 30.5
# ---------------------------------
# ---------------------------------
# CCIStrategy_160
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.3197910441
# Sortino Ratio: 0.4149427757
# Information Ratio: 0.5042832593
# Max Drawdown: 0.2297937695
# Max Drawdown Duration: 418500
# Total Returns: -0.0253508040
# Annualized Returns: -0.0771086956
# Compound Annual Growth Rate: -0.0751307642
# ---------------------------------
# Trades: 16
# Trade Winning: 31.25%
# Average Trade: 0.26%
# Average Win: 8.16%
# Average Loss: -3.33%
# Best Trade: 19.48%
# Worst Trade: -9.06%
# Worst Trade Date: 33.0
# Avg Days in Trade: 7.937222222222222
# ---------------------------------
# ---------------------------------
# CCIStrategy_0
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# D:\Dev\test\backtest\CCIStrategy.py:55: RuntimeWarning: divide by zero encountered in double_scalars
#   md = np.sum(np.abs(tp - tp_ma))/t
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: nan
# Sortino Ratio: nan
# Information Ratio: 0.2019076551
# Max Drawdown: 0.0000000000
# Max Drawdown Duration: 0
# Total Returns: 0.0000000000
# Annualized Returns: 0.0000000000
# Compound Annual Growth Rate: 0.0000000000
# ---------------------------------
# Trades: 0
# Trade Winning: nan%
# Average Trade: nan%
# Average Win: nan%
# Average Loss: nan%
# Best Trade: nan%
# Worst Trade: nan%
# Worst Trade Date: 0
# Avg Days in Trade: 0
# ---------------------------------
# ---------------------------------
# CCIStrategy_16
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -3.9332189572
# Sortino Ratio: -6.8765325250
# Information Ratio: -3.4829728498
# Max Drawdown: 0.6477260468
# Max Drawdown Duration: 494000
# Total Returns: -0.6066092327
# Annualized Returns: -1.8451030827
# Compound Annual Growth Rate: -0.9414414705
# ---------------------------------
# Trades: 145
# Trade Winning: 33.10%
# Average Trade: -0.41%
# Average Win: 2.58%
# Average Loss: -1.88%
# Best Trade: 9.65%
# Worst Trade: -6.72%
# Worst Trade Date: 5.0
# Avg Days in Trade: 20.213333333333335
# ---------------------------------
# ---------------------------------
# CCIStrategy_113
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9892562565
# Sortino Ratio: 1.5736227193
# Information Ratio: 1.3255408129
# Max Drawdown: 0.2436446137
# Max Drawdown Duration: 237900
# Total Returns: 0.1183597996
# Annualized Returns: 0.3600110572
# Compound Annual Growth Rate: 0.4052994425
# ---------------------------------
# Trades: 20
# Trade Winning: 35.00%
# Average Trade: 0.96%
# Average Win: 8.87%
# Average Loss: -3.31%
# Best Trade: 22.62%
# Worst Trade: -10.31%
# Worst Trade Date: 35.0
# Avg Days in Trade: 42.5
# ---------------------------------
# ---------------------------------
# CCIStrategy_133
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.8402488715
# Sortino Ratio: 1.1434323367
# Information Ratio: 1.1389999313
# Max Drawdown: 0.2287888069
# Max Drawdown Duration: 236100
# Total Returns: 0.0825748976
# Annualized Returns: 0.2511653135
# Compound Annual Growth Rate: 0.2729449010
# ---------------------------------
# Trades: 19
# Trade Winning: 26.32%
# Average Trade: 0.79%
# Average Win: 11.14%
# Average Loss: -2.90%
# Best Trade: 20.72%
# Worst Trade: -9.84%
# Worst Trade Date: 12.0
# Avg Days in Trade: 40.78944444444444
# ---------------------------------
# ---------------------------------
# CCIStrategy_82
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: -0.4288683244
# Sortino Ratio: -0.6404405668
# Information Ratio: -0.1004043284
# Max Drawdown: 0.3570185336
# Max Drawdown Duration: 494000
# Total Returns: -0.1634405690
# Annualized Returns: -0.4971317308
# Compound Annual Growth Rate: -0.4188863206
# ---------------------------------
# Trades: 31
# Trade Winning: 29.03%
# Average Trade: -0.28%
# Average Win: 6.41%
# Average Loss: -3.02%
# Best Trade: 14.59%
# Worst Trade: -9.62%
# Worst Trade Date: 20.0
# Avg Days in Trade: 42.70944444444444
# ---------------------------------
# ---------------------------------
# CCIStrategy_57
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.1201822722
# Sortino Ratio: 2.0314107321
# Information Ratio: 1.2150543838
# Max Drawdown: 0.2046017399
# Max Drawdown Duration: 428500
# Total Returns: 0.1282576539
# Annualized Returns: 0.3901170306
# Compound Annual Growth Rate: 0.4434725977
# ---------------------------------
# Trades: 41
# Trade Winning: 29.27%
# Average Trade: 0.63%
# Average Win: 6.90%
# Average Loss: -1.96%
# Best Trade: 17.17%
# Worst Trade: -4.91%
# Worst Trade Date: 43.0
# Avg Days in Trade: 20.95111111111111
# ---------------------------------
# ---------------------------------
# CCIStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3257907672
# Sortino Ratio: 1.9177515274
# Information Ratio: 1.4710947280
# Max Drawdown: 0.2069742779
# Max Drawdown Duration: 221500
# Total Returns: 0.1970040127
# Annualized Returns: 0.5992205386
# Compound Annual Growth Rate: 0.7279883194
# ---------------------------------
# Trades: 17
# Trade Winning: 29.41%
# Average Trade: 1.43%
# Average Win: 11.16%
# Average Loss: -2.62%
# Best Trade: 20.72%
# Worst Trade: -7.68%
# Worst Trade Date: 32.0
# Avg Days in Trade: 7.293888888888889
# ---------------------------------
# ---------------------------------
# CCIStrategy_165
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.2806167692
# Sortino Ratio: 0.3682586580
# Information Ratio: 0.4747892214
# Max Drawdown: 0.2399656679
# Max Drawdown Duration: 418500
# Total Returns: -0.0322662620
# Annualized Returns: -0.0981432135
# Compound Annual Growth Rate: -0.0949467310
# ---------------------------------
# Trades: 16
# Trade Winning: 31.25%
# Average Trade: 0.21%
# Average Win: 8.07%
# Average Loss: -3.36%
# Best Trade: 19.48%
# Worst Trade: -8.75%
# Worst Trade Date: 32.0
# Avg Days in Trade: 9.125
# ---------------------------------
# ---------------------------------
# CCIStrategy_43
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.2711859570
# Sortino Ratio: 2.7764173230
# Information Ratio: 1.4323856018
# Max Drawdown: 0.2000074313
# Max Drawdown Duration: 177100
# Total Returns: 0.1931525428
# Annualized Returns: 0.5875056510
# Compound Annual Growth Rate: 0.7111322589
# ---------------------------------
# Trades: 48
# Trade Winning: 43.75%
# Average Trade: 0.66%
# Average Win: 4.16%
# Average Loss: -2.07%
# Best Trade: 13.38%
# Worst Trade: -4.15%
# Worst Trade Date: 17.0
# Avg Days in Trade: 11.333333333333334
# ---------------------------------
# ---------------------------------
# CCIStrategy_98
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-02-01 00:00:00
# 	End Date	: 2018-06-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 0.9103204967
# Sortino Ratio: 1.4304102985
# Information Ratio: 1.1865811331
# Max Drawdown: 0.2407825593
# Max Drawdown Duration: 311600
# Total Returns: 0.0971755173
# Annualized Returns: 0.2955755317
# Compound Annual Growth Rate: 0.3258869476
# ---------------------------------
# Trades: 23
# Trade Winning: 34.78%
# Average Trade: 0.76%
# Average Win: 7.96%
# Average Loss: -3.08%
# Best Trade: 19.21%
# Worst Trade: -8.96%
# Worst Trade Date: 45.0
# Avg Days in Trade: 23.17388888888889
# ---------------------------------

# %%
best
# Out:
# {'window': 138}

# %%
for trial in trials.trials:
    print(trial['misc']['vals'], "\t",trial)
# Out:
# {'window': [10]} 	 {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 0.6801766000241355, 'status': 'ok'}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [0]}, 'vals': {'window': [10]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 52, 45, 427000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 52, 51, 246000)}
# {'window': [184]} 	 {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 0.10034617931297574, 'status': 'ok'}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [1]}, 'vals': {'window': [184]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 52, 51, 247000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 53, 45, 372000)}
# {'window': [109]} 	 {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': -0.06850369519265631, 'status': 'ok'}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [2]}, 'vals': {'window': [109]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 53, 45, 373000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 54, 19, 338000)}
# {'window': [132]} 	 {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': -0.08257489757416936, 'status': 'ok'}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [3]}, 'vals': {'window': [132]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 54, 19, 339000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 55, 8, 459000)}
# {'window': [87]} 	 {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 0.12637489553632164, 'status': 'ok'}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [4]}, 'vals': {'window': [87]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 55, 8, 460000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 55, 37, 903000)}
# {'window': [44]} 	 {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': -0.19467670989477814, 'status': 'ok'}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [5]}, 'vals': {'window': [44]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 55, 37, 905000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 55, 53, 966000)}
# {'window': [146]} 	 {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': -0.16319791428563657, 'status': 'ok'}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [6]}, 'vals': {'window': [146]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 55, 53, 968000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 56, 40, 161000)}
# {'window': [134]} 	 {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': -0.06617462065118618, 'status': 'ok'}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [7]}, 'vals': {'window': [134]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 56, 40, 163000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 57, 20, 516000)}
# {'window': [143]} 	 {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': -0.19688056836787182, 'status': 'ok'}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [8]}, 'vals': {'window': [143]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 57, 20, 517000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 58, 4, 451000)}
# {'window': [132]} 	 {'state': 2, 'tid': 9, 'spec': None, 'result': {'loss': -0.08257489757416936, 'status': 'ok'}, 'misc': {'tid': 9, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [9]}, 'vals': {'window': [132]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 58, 4, 452000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 58, 45, 138000)}
# {'window': [134]} 	 {'state': 2, 'tid': 10, 'spec': None, 'result': {'loss': -0.06617462065118618, 'status': 'ok'}, 'misc': {'tid': 10, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [10]}, 'vals': {'window': [134]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 58, 45, 139000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 59, 25, 963000)}
# {'window': [106]} 	 {'state': 2, 'tid': 11, 'spec': None, 'result': {'loss': -0.0538696441852442, 'status': 'ok'}, 'misc': {'tid': 11, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [11]}, 'vals': {'window': [106]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 59, 25, 964000), 'refresh_time': datetime.datetime(2018, 9, 4, 9, 59, 58, 935000)}
# {'window': [201]} 	 {'state': 2, 'tid': 12, 'spec': None, 'result': {'loss': 0.1409481782258405, 'status': 'ok'}, 'misc': {'tid': 12, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [12]}, 'vals': {'window': [201]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 9, 59, 58, 936000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 0, 58, 213000)}
# {'window': [207]} 	 {'state': 2, 'tid': 13, 'spec': None, 'result': {'loss': 0.05936970787616991, 'status': 'ok'}, 'misc': {'tid': 13, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [13]}, 'vals': {'window': [207]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 0, 58, 215000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 1, 58, 873000)}
# {'window': [3]} 	 {'state': 2, 'tid': 14, 'spec': None, 'result': {'loss': 0.9141967046989097, 'status': 'ok'}, 'misc': {'tid': 14, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [14]}, 'vals': {'window': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 1, 58, 875000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 2, 2, 679000)}
# {'window': [239]} 	 {'state': 2, 'tid': 15, 'spec': None, 'result': {'loss': -0.07358376017514634, 'status': 'ok'}, 'misc': {'tid': 15, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [15]}, 'vals': {'window': [239]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 2, 2, 681000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 3, 12, 178000)}
# {'window': [90]} 	 {'state': 2, 'tid': 16, 'spec': None, 'result': {'loss': 0.20707216548805296, 'status': 'ok'}, 'misc': {'tid': 16, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [16]}, 'vals': {'window': [90]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 3, 12, 179000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 3, 40, 12000)}
# {'window': [95]} 	 {'state': 2, 'tid': 17, 'spec': None, 'result': {'loss': 0.0778877064568071, 'status': 'ok'}, 'misc': {'tid': 17, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [17]}, 'vals': {'window': [95]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 3, 40, 13000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 4, 10, 431000)}
# {'window': [1]} 	 {'state': 2, 'tid': 18, 'spec': None, 'result': {'loss': -0.0, 'status': 'ok'}, 'misc': {'tid': 18, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [18]}, 'vals': {'window': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 4, 10, 432000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 4, 12, 757000)}
# {'window': [104]} 	 {'state': 2, 'tid': 19, 'spec': None, 'result': {'loss': -0.09700934403717887, 'status': 'ok'}, 'misc': {'tid': 19, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [19]}, 'vals': {'window': [104]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 4, 12, 759000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 4, 44, 35000)}
# {'window': [44]} 	 {'state': 2, 'tid': 20, 'spec': None, 'result': {'loss': -0.19467670989477814, 'status': 'ok'}, 'misc': {'tid': 20, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [20]}, 'vals': {'window': [44]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 4, 44, 38000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 4, 58, 956000)}
# {'window': [103]} 	 {'state': 2, 'tid': 21, 'spec': None, 'result': {'loss': -0.10475609861469515, 'status': 'ok'}, 'misc': {'tid': 21, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [21]}, 'vals': {'window': [103]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 4, 58, 959000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 5, 30, 822000)}
# {'window': [186]} 	 {'state': 2, 'tid': 22, 'spec': None, 'result': {'loss': 0.09083666387831435, 'status': 'ok'}, 'misc': {'tid': 22, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [22]}, 'vals': {'window': [186]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 5, 30, 827000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 6, 24, 388000)}
# {'window': [76]} 	 {'state': 2, 'tid': 23, 'spec': None, 'result': {'loss': 0.12486446368159321, 'status': 'ok'}, 'misc': {'tid': 23, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [23]}, 'vals': {'window': [76]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 6, 24, 390000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 6, 47, 958000)}
# {'window': [49]} 	 {'state': 2, 'tid': 24, 'spec': None, 'result': {'loss': -0.15068446908391442, 'status': 'ok'}, 'misc': {'tid': 24, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [24]}, 'vals': {'window': [49]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 6, 47, 960000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 7, 4, 494000)}
# {'window': [203]} 	 {'state': 2, 'tid': 25, 'spec': None, 'result': {'loss': 0.0336865764329336, 'status': 'ok'}, 'misc': {'tid': 25, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [25]}, 'vals': {'window': [203]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 7, 4, 499000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 8, 2, 499000)}
# {'window': [138]} 	 {'state': 2, 'tid': 26, 'spec': None, 'result': {'loss': -0.1970040127033359, 'status': 'ok'}, 'misc': {'tid': 26, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [26]}, 'vals': {'window': [138]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 8, 2, 501000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 8, 43, 679000)}
# {'window': [69]} 	 {'state': 2, 'tid': 27, 'spec': None, 'result': {'loss': 0.14269336971070856, 'status': 'ok'}, 'misc': {'tid': 27, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [27]}, 'vals': {'window': [69]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 8, 43, 682000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 9, 5, 165000)}
# {'window': [138]} 	 {'state': 2, 'tid': 28, 'spec': None, 'result': {'loss': -0.1970040127033359, 'status': 'ok'}, 'misc': {'tid': 28, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [28]}, 'vals': {'window': [138]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 9, 5, 168000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 9, 45, 796000)}
# {'window': [86]} 	 {'state': 2, 'tid': 29, 'spec': None, 'result': {'loss': 0.12838740030703766, 'status': 'ok'}, 'misc': {'tid': 29, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [29]}, 'vals': {'window': [86]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 9, 45, 801000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 10, 12, 3000)}
# {'window': [89]} 	 {'state': 2, 'tid': 30, 'spec': None, 'result': {'loss': 0.1378208376970449, 'status': 'ok'}, 'misc': {'tid': 30, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [30]}, 'vals': {'window': [89]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 10, 12, 5000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 10, 39, 957000)}
# {'window': [138]} 	 {'state': 2, 'tid': 31, 'spec': None, 'result': {'loss': -0.1970040127033359, 'status': 'ok'}, 'misc': {'tid': 31, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [31]}, 'vals': {'window': [138]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 10, 39, 959000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 11, 20, 92000)}
# {'window': [39]} 	 {'state': 2, 'tid': 32, 'spec': None, 'result': {'loss': -0.035760934219832174, 'status': 'ok'}, 'misc': {'tid': 32, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [32]}, 'vals': {'window': [39]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 11, 20, 95000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 11, 33, 223000)}
# {'window': [33]} 	 {'state': 2, 'tid': 33, 'spec': None, 'result': {'loss': 0.17795488643399926, 'status': 'ok'}, 'misc': {'tid': 33, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [33]}, 'vals': {'window': [33]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 11, 33, 226000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 11, 45, 457000)}
# {'window': [138]} 	 {'state': 2, 'tid': 34, 'spec': None, 'result': {'loss': -0.1970040127033359, 'status': 'ok'}, 'misc': {'tid': 34, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [34]}, 'vals': {'window': [138]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 11, 45, 461000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 12, 25, 782000)}
# {'window': [177]} 	 {'state': 2, 'tid': 35, 'spec': None, 'result': {'loss': 0.05072800766105978, 'status': 'ok'}, 'misc': {'tid': 35, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [35]}, 'vals': {'window': [177]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 12, 25, 787000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 13, 15, 872000)}
# {'window': [117]} 	 {'state': 2, 'tid': 36, 'spec': None, 'result': {'loss': -0.08999275972565202, 'status': 'ok'}, 'misc': {'tid': 36, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [36]}, 'vals': {'window': [117]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 13, 15, 874000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 13, 51, 132000)}
# {'window': [92]} 	 {'state': 2, 'tid': 37, 'spec': None, 'result': {'loss': 0.15639820914638003, 'status': 'ok'}, 'misc': {'tid': 37, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [37]}, 'vals': {'window': [92]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 13, 51, 134000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 14, 18, 240000)}
# {'window': [222]} 	 {'state': 2, 'tid': 38, 'spec': None, 'result': {'loss': 0.020036153327430473, 'status': 'ok'}, 'misc': {'tid': 38, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [38]}, 'vals': {'window': [222]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 14, 18, 243000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 15, 13, 391000)}
# {'window': [160]} 	 {'state': 2, 'tid': 39, 'spec': None, 'result': {'loss': 0.025350804040564556, 'status': 'ok'}, 'misc': {'tid': 39, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [39]}, 'vals': {'window': [160]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 15, 13, 394000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 15, 52, 102000)}
# {'window': [0]} 	 {'state': 2, 'tid': 40, 'spec': None, 'result': {'loss': -0.0, 'status': 'ok'}, 'misc': {'tid': 40, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [40]}, 'vals': {'window': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 15, 52, 104000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 25, 34, 942000)}
# {'window': [16]} 	 {'state': 2, 'tid': 41, 'spec': None, 'result': {'loss': 0.6066092326777177, 'status': 'ok'}, 'misc': {'tid': 41, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [41]}, 'vals': {'window': [16]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 25, 34, 945000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 25, 39, 941000)}
# {'window': [113]} 	 {'state': 2, 'tid': 42, 'spec': None, 'result': {'loss': -0.11835979962366672, 'status': 'ok'}, 'misc': {'tid': 42, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [42]}, 'vals': {'window': [113]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 25, 39, 944000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 26, 4, 451000)}
# {'window': [133]} 	 {'state': 2, 'tid': 43, 'spec': None, 'result': {'loss': -0.08257489757416936, 'status': 'ok'}, 'misc': {'tid': 43, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [43]}, 'vals': {'window': [133]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 26, 4, 455000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 26, 32, 229000)}
# {'window': [82]} 	 {'state': 2, 'tid': 44, 'spec': None, 'result': {'loss': 0.1634405690195675, 'status': 'ok'}, 'misc': {'tid': 44, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [44]}, 'vals': {'window': [82]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 26, 32, 232000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 26, 49, 970000)}
# {'window': [57]} 	 {'state': 2, 'tid': 45, 'spec': None, 'result': {'loss': -0.1282576538950082, 'status': 'ok'}, 'misc': {'tid': 45, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [45]}, 'vals': {'window': [57]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 26, 49, 972000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 27, 2, 937000)}
# {'window': [138]} 	 {'state': 2, 'tid': 46, 'spec': None, 'result': {'loss': -0.1970040127033359, 'status': 'ok'}, 'misc': {'tid': 46, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [46]}, 'vals': {'window': [138]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 27, 2, 939000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 27, 32, 413000)}
# {'window': [165]} 	 {'state': 2, 'tid': 47, 'spec': None, 'result': {'loss': 0.03226626198456961, 'status': 'ok'}, 'misc': {'tid': 47, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [47]}, 'vals': {'window': [165]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 27, 32, 416000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 28, 6, 482000)}
# {'window': [43]} 	 {'state': 2, 'tid': 48, 'spec': None, 'result': {'loss': -0.19315254278834182, 'status': 'ok'}, 'misc': {'tid': 48, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [48]}, 'vals': {'window': [43]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 28, 6, 484000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 28, 17, 521000)}
# {'window': [98]} 	 {'state': 2, 'tid': 49, 'spec': None, 'result': {'loss': -0.09717551725511164, 'status': 'ok'}, 'misc': {'tid': 49, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'window': [49]}, 'vals': {'window': [98]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2018, 9, 4, 10, 28, 17, 523000), 'refresh_time': datetime.datetime(2018, 9, 4, 10, 28, 38, 425000)}

# %%
config = {
    "csv_dir": "./Binance",
    "out_dir": "./results/AOStrategy",
    "title": "AOStrategy",
    "is_plot": False,
    "save_plot": False,
    "save_tradelog": False,
    "start_date": pd.Timestamp("2018-04-01T00:0:00", freq = "60" + "T"),    # str(freq) + "T"
    "end_date": pd.Timestamp("2018-08-01T00:00:00", freq = "60" + "T"),
    "equity": 1.0,
    "freq": 60,      # min
    "commission_ratio": 0.001,
    "suggested_quantity": None,     # None or a value
    "max_quantity": None,           # None or a value, Maximum purchase quantity
    "min_quantity": None,           # None or a value, Minimum purchase quantity
    "min_handheld_cash": None,      # None or a value, Minimum handheld funds
    "exchange": "Binance",
    "tickers": ['BTCUSDT']
}
ohlc_data = {}
for ticker in config['tickers']:
    # ohlc_data[ticker] = generate_bars(trading_data, ticker, config['freq'])
    ohlc_data[ticker] = pd.read_hdf(config['csv_dir'] + '\\' + ticker +'_OHLC_60min.h5', key=ticker)

trading_data = None
run_backtest(config,ohlc_data,ohlc_data,best['window'])
# Out:
# ---------------------------------
# CCIStrategy_138
# ---------------------------------
# Data Time Interval for BTCUSDT:
# 	Start Date	: 2018-04-01 00:00:00
# 	End Date	: 2018-08-01 00:00:00
# ---------------------------------
# Running Backtest...
# ---------------------------------
# ---------------------------------
# Backtest complete.
# ---------------------------------
# Sharpe Ratio: 1.3732848080
# Sortino Ratio: 1.8615318696
# Information Ratio: 0.1690999848
# Max Drawdown: 0.2477290145
# Max Drawdown Duration: 216800
# Total Returns: 0.1858657488
# Annualized Returns: 0.5560737566
# Compound Annual Growth Rate: 0.6653277852
# ---------------------------------
# Trades: 10
# Trade Winning: 30.00%
# Average Trade: 2.34%
# Average Win: 14.81%
# Average Loss: -3.01%
# Best Trade: 24.14%
# Worst Trade: -5.92%
# Worst Trade Date: 0.0
# Avg Days in Trade: 11.9
# ---------------------------------
# -0.18586574876606332

# %%
f, ax = plt.subplots(1,2, figsize = (16, 8))
xs = [t['misc']['vals']['window'] for t in trials.trials]
ys = [-1 * t['result']['loss'] for t in trials.trials]
ax[0].scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax[0].set_title('$val$ $vs$ $window$ ', fontsize=18)
ax[0].set_xlabel('$window$', fontsize=16)
ax[0].set_ylabel('$val$', fontsize=16)
ax[0].hlines(0, 0, 120, color='black',linestyle="--")
ax[0].hlines(-1, 0, 120, color='black',linestyle="--")
ax[0].hlines(1, 0, 120, color='black',linestyle="--")
ax[0].vlines(best['window'], -1.2, 2, color='blue',linestyle="--")
